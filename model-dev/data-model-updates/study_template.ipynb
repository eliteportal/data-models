# %%
# create template for study folders
import synapseclient as sc
import pandas as pd
import numpy as np

syn = sc.login()
# Out:
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (4.2.0) is available. Your version (3.2.0) can be upgraded by typing:
#     pip install --upgrade synapseclient
#
# Python Synapse Client version 4.2.0 release notes
#
# https://python-docs.synapse.org/news/
# Welcome, Nicholas Lee!

# %%
import os
from pathlib import Path
import re

# %%
cwd = Path(os.getcwd())

ROOT_DIR_NAME = "ELITE-data-models"

for p in cwd.parents:
    if bool(re.search(ROOT_DIR_NAME + "$", str(p))):
        print(p)
        ROOT_DIR = p
# Out:
# /Users/nlee/Documents/Projects/ELITE/ELITE-data-models

# %%
dm = pd.read_csv(Path(ROOT_DIR, 'EL.data.model.csv'))
dm_cols = list(dm.columns)
dm_cols
# Out:
# ['Attribute',
#  'Description',
#  'Valid Values',
#  'DependsOn',
#  'DependsOn Component',
#  'Required',
#  'Parent',
#  'Validation Rules',
#  'Properties',
#  'Source',
#  'Module',
#  'multivalue',
#  'columnType',
#  'Ontology',
#  'Notes',
#  'UsedIn']

# %%
cols = syn.getColumns("syn57394664")
cols = [c for c in cols]
study_temp = pd.DataFrame(cols)
# study_temp = study_temp.set_index("name")
study_temp = study_temp[['name', 'columnType']]
study_temp = study_temp[~study_temp['name'].isin(['id'])]
study_temp = study_temp.rename(columns={'name': 'Attribute'})
study_temp
# Out:
#            Attribute   columnType
# 1           studyKey       STRING
# 2          studyName       STRING
# 3   projectShortName       STRING
# 4    projectFullName       STRING
# 5        dataTypeAll  STRING_LIST
# 6            Species  STRING_LIST
# 7       specimenType  STRING_LIST
# 8      studyAbstract       STRING
# 9   studyDescription       STRING
# 10        studyFocus       STRING
# 11           program       STRING
# 12       grantNumber  STRING_LIST
# 13         studyWiki       STRING
# 14    acknowledgment       STRING
# 15           methods       STRING
# 16    relatedStudies  STRING_LIST
# 17         studyType       STRING
# 18     isModelSystem      BOOLEAN
# 19        isFeatured      BOOLEAN
# 20        ackContext       STRING
# 21     studyMetadata       STRING
# 22        accessReqs       STRING
# 23        isReleased      BOOLEAN
# 24       newsRelease       STRING
# 25      metadataType       STRING

# %%
for c in list(set(dm_cols) - set(study_temp.columns)): 
    study_temp[c] = None

study_temp = study_temp.assign(
    Required=True,
    Module="ManifestColumn",
    Properties="ManifestColumn",
    Source="Sage Bionetworks",
    Parent="ManifestColumn",
    UsedIn="study_folder_template",
    Ontology="Sage Bionetworks",
)

study_temp
# Out:
#            Attribute   columnType                 UsedIn DependsOn Component  \
# 1           studyKey       STRING  study_folder_template                None
# 2          studyName       STRING  study_folder_template                None
# 3   projectShortName       STRING  study_folder_template                None
# 4    projectFullName       STRING  study_folder_template                None
# 5        dataTypeAll  STRING_LIST  study_folder_template                None
# 6            Species  STRING_LIST  study_folder_template                None
# 7       specimenType  STRING_LIST  study_folder_template                None
# 8      studyAbstract       STRING  study_folder_template                None
# 9   studyDescription       STRING  study_folder_template                None
# 10        studyFocus       STRING  study_folder_template                None
# 11           program       STRING  study_folder_template                None
# 12       grantNumber  STRING_LIST  study_folder_template                None
# 13         studyWiki       STRING  study_folder_template                None
# 14    acknowledgment       STRING  study_folder_template                None
# 15           methods       STRING  study_folder_template                None
# 16    relatedStudies  STRING_LIST  study_folder_template                None
# 17         studyType       STRING  study_folder_template                None
# 18     isModelSystem      BOOLEAN  study_folder_template                None
# 19        isFeatured      BOOLEAN  study_folder_template                None
# 20        ackContext       STRING  study_folder_template                None
# 21     studyMetadata       STRING  study_folder_template                None
# 22        accessReqs       STRING  study_folder_template                None
# 23        isReleased      BOOLEAN  study_folder_template                None
# 24       newsRelease       STRING  study_folder_template                None
# 25      metadataType       STRING  study_folder_template                None
#
#    DependsOn Validation Rules          Ontology            Source Notes  \
# 1       None             None  Sage Bionetworks  Sage Bionetworks  None
# 2       None             None  Sage Bionetworks  Sage Bionetworks  None
# 3       None             None  Sage Bionetworks  Sage Bionetworks  None
# 4       None             None  Sage Bionetworks  Sage Bionetworks  None
# 5       None             None  Sage Bionetworks  Sage Bionetworks  None
# 6       None             None  Sage Bionetworks  Sage Bionetworks  None
# 7       None             None  Sage Bionetworks  Sage Bionetworks  None
# 8       None             None  Sage Bionetworks  Sage Bionetworks  None
# 9       None             None  Sage Bionetworks  Sage Bionetworks  None
# 10      None             None  Sage Bionetworks  Sage Bionetworks  None
# 11      None             None  Sage Bionetworks  Sage Bionetworks  None
# 12      None             None  Sage Bionetworks  Sage Bionetworks  None
# 13      None             None  Sage Bionetworks  Sage Bionetworks  None
# 14      None             None  Sage Bionetworks  Sage Bionetworks  None
# 15      None             None  Sage Bionetworks  Sage Bionetworks  None
# 16      None             None  Sage Bionetworks  Sage Bionetworks  None
# 17      None             None  Sage Bionetworks  Sage Bionetworks  None
# 18      None             None  Sage Bionetworks  Sage Bionetworks  None
# 19      None             None  Sage Bionetworks  Sage Bionetworks  None
# 20      None             None  Sage Bionetworks  Sage Bionetworks  None
# 21      None             None  Sage Bionetworks  Sage Bionetworks  None
# 22      None             None  Sage Bionetworks  Sage Bionetworks  None
# 23      None             None  Sage Bionetworks  Sage Bionetworks  None
# 24      None             None  Sage Bionetworks  Sage Bionetworks  None
# 25      None             None  Sage Bionetworks  Sage Bionetworks  None
#
#     Required          Module Valid Values      Properties Description  \
# 1       True  ManifestColumn         None  ManifestColumn        None
# 2       True  ManifestColumn         None  ManifestColumn        None
# 3       True  ManifestColumn         None  ManifestColumn        None
# 4       True  ManifestColumn         None  ManifestColumn        None
# 5       True  ManifestColumn         None  ManifestColumn        None
# 6       True  ManifestColumn         None  ManifestColumn        None
# 7       True  ManifestColumn         None  ManifestColumn        None
# 8       True  ManifestColumn         None  ManifestColumn        None
# 9       True  ManifestColumn         None  ManifestColumn        None
# 10      True  ManifestColumn         None  ManifestColumn        None
# 11      True  ManifestColumn         None  ManifestColumn        None
# 12      True  ManifestColumn         None  ManifestColumn        None
# 13      True  ManifestColumn         None  ManifestColumn        None
# 14      True  ManifestColumn         None  ManifestColumn        None
# 15      True  ManifestColumn         None  ManifestColumn        None
# 16      True  ManifestColumn         None  ManifestColumn        None
# 17      True  ManifestColumn         None  ManifestColumn        None
# 18      True  ManifestColumn         None  ManifestColumn        None
# 19      True  ManifestColumn         None  ManifestColumn        None
# 20      True  ManifestColumn         None  ManifestColumn        None
# 21      True  ManifestColumn         None  ManifestColumn        None
# 22      True  ManifestColumn         None  ManifestColumn        None
# 23      True  ManifestColumn         None  ManifestColumn        None
# 24      True  ManifestColumn         None  ManifestColumn        None
# 25      True  ManifestColumn         None  ManifestColumn        None
#
#    multivalue          Parent
# 1        None  ManifestColumn
# 2        None  ManifestColumn
# 3        None  ManifestColumn
# 4        None  ManifestColumn
# 5        None  ManifestColumn
# 6        None  ManifestColumn
# 7        None  ManifestColumn
# 8        None  ManifestColumn
# 9        None  ManifestColumn
# 10       None  ManifestColumn
# 11       None  ManifestColumn
# 12       None  ManifestColumn
# 13       None  ManifestColumn
# 14       None  ManifestColumn
# 15       None  ManifestColumn
# 16       None  ManifestColumn
# 17       None  ManifestColumn
# 18       None  ManifestColumn
# 19       None  ManifestColumn
# 20       None  ManifestColumn
# 21       None  ManifestColumn
# 22       None  ManifestColumn
# 23       None  ManifestColumn
# 24       None  ManifestColumn
# 25       None  ManifestColumn

# %%
study_temp['multivalue'] = np.select(
    [
        study_temp['columnType'] == 'STRING_LIST'
    ],
    [
        True
    ],
    default = False
)

# %%
# add manifest attribute
new_manifest = [
    {
        "Attribute": "study_folder_template",
        "columnType": "NA",
        "Parent": "Component",
        "Module": "Template",
        "multivalue": "NA",
        "Description": "Annotations for study folders",
        "Properties": "Template",
        "DependsOn": ",".join(study_temp["Attribute"].tolist() + ["Component"]),
        "Source": "Sage Bionetworks",
        "Ontology": "Sage Bionetworks",
    }
]

new_manifest

# study_temp.loc[-1, "Attribute"] : "study_folder_annotations"
# study_temp.loc[-1,]
# Out:
# [{'Attribute': 'study_folder_template',
#   'columnType': 'NA',
#   'Parent': 'Component',
#   'Module': 'Template',
#   'multivalue': 'NA',
#   'Description': 'Annotations for study folders',
#   'Properties': 'Template',
#   'DependsOn': 'studyKey,studyName,projectShortName,projectFullName,dataTypeAll,Species,specimenType,studyAbstract,studyDescription,studyFocus,program,grantNumber,studyWiki,acknowledgment,methods,relatedStudies,studyType,isModelSystem,isFeatured,ackContext,studyMetadata,accessReqs,isReleased,newsRelease,metadataType,Component',
#   'Source': 'Sage Bionetworks',
#   'Ontology': 'Sage Bionetworks'}]

# %%
study_temp = pd.concat([study_temp, pd.DataFrame(new_manifest)], axis = 0).reset_index(drop = True)

# %%
study_temp.loc[study_temp["Attribute"] == "metadataType", 'Valid Values'] = 'study'

# %%
study_temp.loc[study_temp["Attribute"] == "Species", 'Attribute'] = 'species'

# %%
study_temp["Valid Values"] = np.select(
    [
        study_temp["Attribute"] == "program",
        study_temp["Attribute"] == "projectShortName",
        study_temp["Attribute"] == "isFeatured",
        study_temp["Attribute"] == "isReleased",
        study_temp["Attribute"] == "Species",
        study_temp["Attribute"] == "isModelSystem",
    ],
    ["ELITE,AD", "LC,ILO,LLFS,LG", "TRUE,FALSE", "TRUE,FALSE", "Human,Mouse", 'TRUE,FALSE'],
    default=None,
)
# study_temp["Valid Values"]
# Out:
# 0               None
# 1               None
# 2     LC,ILO,LLFS,LG
# 3               None
# 4               None
# 5        Human,Mouse
# 6               None
# 7               None
# 8               None
# 9               None
# 10          ELITE,AD
# 11              None
# 12              None
# 13              None
# 14              None
# 15              None
# 16              None
# 17        TRUE,FALSE
# 18        TRUE,FALSE
# 19              None
# 20              None
# 21              None
# 22        TRUE,FALSE
# 23              None
# 24              None
# 25              None
# Name: Valid Values, dtype: object

# %%
study_temp = study_temp[dm_cols]

# %%
study_temp.to_csv(Path(ROOT_DIR, "data/rfc_tables_cleaned/study_RFC.csv"), index=False)

# %%
dm
# Out:
#                     Attribute  \
# 0          acquisitionBatchID
# 1        acquisitionBatchSize
# 2    acquisitionBatchSizeUnit
# 3             acquisitionMode
# 4         acquisitionSoftware
# ..                        ...
# 190                 visitCode
# 191   Whole_Genome_Sequencing
# 192              rnaBatchSize
# 193          rnaBatchSizeUnit
# 194                  scRNAseq
#
#                                            Description  \
# 0    Acquisition batch identifier, provided by the ...
# 1                                The number of samples
# 2    The unit of measurement for number of samples ...
# 3    The specific aspect of a mass spectrometer met...
# 4    The name of the acquisition software used. Pro...
# ..                                                 ...
# 190  Indicate which longitudinal visit for the indi...
# 191               Template for Whole_Genome_Sequencing
# 192                              The number of samples
# 193  The unit of measurement for number of samples ...
# 194                              Template for scRNAseq
#
#                                           Valid Values  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193  AFU,AI,AU/ml,bp g/dl,DK units/ml,g/l,gm,HAU,IU...
# 194                                                NaN
#
#                                              DependsOn  DependsOn Component  \
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 190                                                NaN                  NaN
# 191  Filename,specimenID,sampleType,measurementTech...                  NaN
# 192                                                NaN                  NaN
# 193                                                NaN                  NaN
# 194  Filename,specimenID,sampleType,measurementTech...                  NaN
#
#      Required          Parent  Validation Rules      Properties  Source  \
# 0       False  ManifestColumn               NaN  ManifestColumn     NaN
# 1       False  ManifestColumn               NaN  ManifestColumn     NaN
# 2       False  ManifestColumn               NaN  ManifestColumn     NaN
# 3        True  ManifestColumn               NaN  ManifestColumn     NaN
# 4        True  ManifestColumn               NaN  ManifestColumn     NaN
# ..        ...             ...               ...             ...     ...
# 190      True  ManifestColumn               NaN  ManifestColumn     NaN
# 191     False       Component               NaN        Template     NaN
# 192     False  ManifestColumn               NaN  ManifestColumn     NaN
# 193      True  ManifestColumn               NaN  ManifestColumn     NaN
# 194     False       Component               NaN        Template     NaN
#
#              Module multivalue columnType  \
# 0    ManifestColumn      False     STRING
# 1    ManifestColumn      False     STRING
# 2    ManifestColumn      False     STRING
# 3    ManifestColumn      False     STRING
# 4    ManifestColumn      False     STRING
# ..              ...        ...        ...
# 190  ManifestColumn      False     NUMBER
# 191        Template        NaN        NaN
# 192  ManifestColumn      False     NUMBER
# 193  ManifestColumn      False     STRING
# 194        Template        NaN        NaN
#
#                                               Ontology  \
# 0                                     Sage Bionetworks
# 1                                     Sage Bionetworks
# 2                                     Sage Bionetworks
# 3    https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 4            http://purl.obolibrary.org/obo/MS_1001455
# ..                                                 ...
# 190                                   Sage Bionetworks
# 191                                   Sage Bionetworks
# 192                                   Sage Bionetworks
# 193                                   Sage Bionetworks
# 194                                   Sage Bionetworks
#
#                                                  Notes            UsedIn
# 0                                                           Metabolomics
# 1                                                           Metabolomics
# 2                                                           Metabolomics
# 3    A data contributor should be able to write in ...      Metabolomics
# 4    A data contributor should be able to write in ...      Metabolomics
# ..                                                 ...               ...
# 190                                                     Individual_Human
# 191                                                                  NaN
# 192                                                             scRNAseq
# 193                                                             scRNAseq
# 194                                                                  NaN
#
# [195 rows x 16 columns]

# %%
additions = study_temp.loc[study_temp['Attribute'].isin(list(set(study_temp['Attribute']) - set(dm['Attribute'])))]

# %%
dm_new = pd.concat([dm, additions]).reset_index(drop = True)

# %%
dm_new
# Out:
#                     Attribute  \
# 0          acquisitionBatchID
# 1        acquisitionBatchSize
# 2    acquisitionBatchSizeUnit
# 3             acquisitionMode
# 4         acquisitionSoftware
# ..                        ...
# 215                accessReqs
# 216                isReleased
# 217               newsRelease
# 218              metadataType
# 219     study_folder_template
#
#                                            Description Valid Values  \
# 0    Acquisition batch identifier, provided by the ...          NaN
# 1                                The number of samples          NaN
# 2    The unit of measurement for number of samples ...          NaN
# 3    The specific aspect of a mass spectrometer met...          NaN
# 4    The name of the acquisition software used. Pro...          NaN
# ..                                                 ...          ...
# 215                                               None         None
# 216                                               None   TRUE,FALSE
# 217                                               None         None
# 218                                               None         None
# 219                      Annotations for study folders         None
#
#                                              DependsOn DependsOn Component  \
# 0                                                  NaN                 NaN
# 1                                                  NaN                 NaN
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# ..                                                 ...                 ...
# 215                                               None                None
# 216                                               None                None
# 217                                               None                None
# 218                                               None                None
# 219  studyKey,studyName,projectShortName,projectFul...                None
#
#     Required          Parent Validation Rules      Properties  \
# 0      False  ManifestColumn              NaN  ManifestColumn
# 1      False  ManifestColumn              NaN  ManifestColumn
# 2      False  ManifestColumn              NaN  ManifestColumn
# 3       True  ManifestColumn              NaN  ManifestColumn
# 4       True  ManifestColumn              NaN  ManifestColumn
# ..       ...             ...              ...             ...
# 215     True  ManifestColumn             None  ManifestColumn
# 216     True  ManifestColumn             None  ManifestColumn
# 217     True  ManifestColumn             None  ManifestColumn
# 218     True  ManifestColumn             None  ManifestColumn
# 219      NaN       Component             None        Template
#
#                Source          Module multivalue columnType  \
# 0                 NaN  ManifestColumn      False     STRING
# 1                 NaN  ManifestColumn      False     STRING
# 2                 NaN  ManifestColumn      False     STRING
# 3                 NaN  ManifestColumn      False     STRING
# 4                 NaN  ManifestColumn      False     STRING
# ..                ...             ...        ...        ...
# 215  Sage Bionetworks  ManifestColumn      False     STRING
# 216  Sage Bionetworks  ManifestColumn      False    BOOLEAN
# 217  Sage Bionetworks  ManifestColumn      False     STRING
# 218  Sage Bionetworks  ManifestColumn      False     STRING
# 219  Sage Bionetworks        Template         NA         NA
#
#                                               Ontology  \
# 0                                     Sage Bionetworks
# 1                                     Sage Bionetworks
# 2                                     Sage Bionetworks
# 3    https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 4            http://purl.obolibrary.org/obo/MS_1001455
# ..                                                 ...
# 215                                   Sage Bionetworks
# 216                                   Sage Bionetworks
# 217                                   Sage Bionetworks
# 218                                   Sage Bionetworks
# 219                                   Sage Bionetworks
#
#                                                  Notes                 UsedIn
# 0                                                                Metabolomics
# 1                                                                Metabolomics
# 2                                                                Metabolomics
# 3    A data contributor should be able to write in ...           Metabolomics
# 4    A data contributor should be able to write in ...           Metabolomics
# ..                                                 ...                    ...
# 215                                               None  study_folder_template
# 216                                               None  study_folder_template
# 217                                               None  study_folder_template
# 218                                               None  study_folder_template
# 219                                                NaN                    NaN
#
# [220 rows x 16 columns]

# %%
dm_new.to_csv(Path(ROOT_DIR, "EL.data.model.csv"))

# %%
syn.get("syn58352475", downloadFile = False)
# Out:
# File(species=['Mus musculus (mouse)'], DOI=['10.1038/S42003-023-05128-Y'], downloadLink=['ftp://ftp.pride.ebi.ac.uk/pride/data/archive/2023/07/PXD035255/031519-MouseLiver-26-GC2191-01.raw'], createdBy='3466893', dataRepository=['PRIDE'], _file_handle={'id': '139500629', 'etag': 'b711bde1-51b9-4fc2-b8c5-f01666c4a2ff', 'createdBy': '3466893', 'createdOn': '2024-04-22T20:20:43.000Z', 'modifiedOn': '2024-04-22T20:20:43.000Z', 'concreteType': 'org.sagebionetworks.repo.model.file.ExternalFileHandle', 'contentType': 'NOT_SET', 'fileName': '031519-MouseLiver-26-GC2191-01.raw', 'status': 'AVAILABLE', 'externalURL': 'ftp://ftp.pride.ebi.ac.uk/pride/data/archive/2023/07/PXD035255/031519-MouseLiver-26-GC2191-01.raw', 'contentSize': None, 'contentMd5': None, 'storageLocationId': None}, id='syn58352475', dataCoordinationCenter=['ELITE'], parentId='syn58351053', name='031519-MouseLiver-26-GC2191-01.raw', cacheDir=None, fileName=['031519-MouseLiver-26-GC2191-01.raw'], forceVersion=[False], versionNumber=1, createdOn='2024-04-22T20:20:43.568Z', fileType=['raw'], dataRepositoryLink=['https://www.ebi.ac.uk/pride/'], synapseStore=False, etag='a9f4a344-78b2-4f43-b8d9-dd34d71d8e5c', modifiedBy='3466893', versionLabel='1', isLatestVersion=True, modifiedOn='2024-05-20T20:08:43.174Z', project=['LC'], projectAccessions=['PXD035255'], files=[], path=None, dataFileHandleId='139500629', studyKey=['PXD035255'], concreteType='org.sagebionetworks.repo.model.FileEntity', metadataLink=['https://www.ebi.ac.uk/pride/ws/archive/v2/files/cab1e68c34be069270d162a52c949bf43519ac406acafd8bc79db7e8dcd1b3b2'])

# %%
query = syn.tableQuery(
    """ SELECT "dataFileKey" FROM syn52234677 WHERE study = 'PXD035255'"""
)
query = query.asDataFrame()

query["dataFileKey"].to_csv("ftp-test.csv", index=False)

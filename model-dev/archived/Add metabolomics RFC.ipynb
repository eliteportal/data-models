# %%
import pandas as pd
import numpy as np
import re

RFC = "Metabolomics"

# %%
dm = pd.read_csv('../EL.data.model.csv').drop(columns = ['Unnamed: 0'], errors = 'ignore')

# %%
dm['Parent'].unique()
# Out:
# array(['ValidValue', 'ManifestColumn', 'MeasurementUnit', 'Demographics',
#        'BaseAnnotation', 'AnalysisType', 'Component', 'Ontology',
#        'Template', nan, 'labelQuantiation', 'Repository',
#        'cleavageAgents', 'databaseName', 'databaseSource', 'dataFile',
#        'digestionMethod', 'labelFreeQuantitation', 'measurementTechnique',
#        'modificationParameters', 'msAnalyteType', 'msAnalyzerTypeMS1',
#        'msAnalyzerTypeMS2', 'msAssayTechnique', 'msInstrumentModel',
#        'platformLocation', 'proteomics digestionReagent',
#        'proteomicsAssayType', 'sampleType', 'technologyPlatformVersion'],
#       dtype=object)

# %%
other_values = ["Other","Unknown","Not collected","Not applicable","Not specified"]

# %%
p_df = pd.read_excel("../_data/RFC Tables/EL RFC Metabolomics Human Data Model.xlsx")

p_df = p_df.rename(
    columns={
        "key": "Attribute",
        "description": "Description",
        "required": "Required",
        "requires": "Module",
        "concept source ontology": "Ontology",
        "valid values": "Valid Values",
        "type": "columnType",
        "note": "Notes",
    }
)
p_df = p_df.fillna("")

p_df
# Out:
#                          Attribute  \
# 0                       specimenID
# 1                       sampleType
# 2                specifySampleType
# 3             measurementTechnique
# 4      specifyMeasurementTechnique
# ..                             ...
# 64               processingBatchID
# 65             processingBatchSize
# 66         processingBatchSizeUnit
# 67  specifyProcessingBatchSizeUnit
# 68            specifyOtherDataFile
#
#                                           Description  \
# 0   Identifying string linked to a particular samp...
# 1   The type of sample collected or the term used ...
# 2      If "other" is selected list the type of sample
# 3   The name of the measurement technique describi...
# 4   If "other" is selected list the name of the me...
# ..                                                ...
# 64  Processing batch identifier, provided by the d...
# 65                              The number of samples
# 66  The unit of measurement for number of samples ...
# 67                   If "other" list units of measure
# 68  If "other" is selected, list the name of the d...
#
#                                          Valid Values  Required  \
# 0                                                          True
# 1                                                          True
# 2                                                         False
# 3                                                          True
# 4                                                         False
# ..                                                ...       ...
# 64                                                 \n     False
# 65                                                        False
# 66  AFU,\nAI,\nAU/ml,\nDK units/ml,\nbp\ng/dl,\ng/...     False
# 67                                                        False
# 68                                                        False
#
#                                             Module multivalue columnType  \
# 0                       Biospecimen,\nmetabolomics        0.0     string
# 1                                     metabolomics        0.0     string
# 2                metabolomics,\nsampleType = other        0.0     string
# 3                                     metabolomics        1.0     string
# 4       metabolomics\nmeasurementTechnique = other        0.0     string
# ..                                             ...        ...        ...
# 64                                    metabolomics        0.0     string
# 65                                    metabolomics        0.0     string
# 66              metabolomics,\nprocessingBatchSize        0.0     string
# 67  metabolomics,\nProcessingBatchSizeUnit = other        0.0     string
# 68                  metabolomics, dataFile = other        0.0     string
#
#                Ontology                                              Notes
# 0      Sage Bionetworks            values unique to each data contributor)
# 1   Sage Bionetworks,\n  A data contributor should be able to write in ...
# 2      Sage Bionetworks
# 3      Sage Bionetworks  A data contributor should be able to write in ...
# 4      Sage Bionetworks  A data contributor should be able to write in ...
# ..                  ...                                                ...
# 64     Sage Bionetworks
# 65     Sage Bionetworks
# 66     Sage Bionetworks
# 67     Sage Bionetworks
# 68     Sage Bionetworks
#
# [69 rows x 9 columns]

# %%
# string clean up
# Do not need to explicitly add "other" type values. Will add back later for list type attributes
p_df["Valid Values"] = (
    p_df["Valid Values"]
    .replace("n/a (unique to each data contributor)", "", regex=False)
    .str.replace(
        "Other|Unknown|Not collected|Not applicable|Not specified", "", regex=True
    )
    .str.strip(",")
)

# replace note type values
p_df["Valid Values"] = p_df["Valid Values"].apply(
    lambda x: ",".join(
        [y.strip() for y in x.split(",") if not bool(re.search("Possible values", y))]
    ).strip(",")
)

p_df = p_df.replace(r"\n", ",", regex=True).replace(r",,", ",", regex=True)

p_df
# Out:
#                          Attribute  \
# 0                       specimenID
# 1                       sampleType
# 2                specifySampleType
# 3             measurementTechnique
# 4      specifyMeasurementTechnique
# ..                             ...
# 64               processingBatchID
# 65             processingBatchSize
# 66         processingBatchSizeUnit
# 67  specifyProcessingBatchSizeUnit
# 68            specifyOtherDataFile
#
#                                           Description  \
# 0   Identifying string linked to a particular samp...
# 1   The type of sample collected or the term used ...
# 2      If "other" is selected list the type of sample
# 3   The name of the measurement technique describi...
# 4   If "other" is selected list the name of the me...
# ..                                                ...
# 64  Processing batch identifier, provided by the d...
# 65                              The number of samples
# 66  The unit of measurement for number of samples ...
# 67                   If "other" list units of measure
# 68  If "other" is selected, list the name of the d...
#
#                                          Valid Values  Required  \
# 0                                                          True
# 1                                                          True
# 2                                                         False
# 3                                                          True
# 4                                                         False
# ..                                                ...       ...
# 64                                                        False
# 65                                                        False
# 66  AFU,AI,AU/ml,DK units/ml,bp,g/dl,g/l,gm,HAU,IU...     False
# 67                                                        False
# 68                                                        False
#
#                                           Module multivalue columnType  \
# 0                       Biospecimen,metabolomics        0.0     string
# 1                                   metabolomics        0.0     string
# 2                metabolomics,sampleType = other        0.0     string
# 3                                   metabolomics        1.0     string
# 4      metabolomics,measurementTechnique = other        0.0     string
# ..                                           ...        ...        ...
# 64                                  metabolomics        0.0     string
# 65                                  metabolomics        0.0     string
# 66              metabolomics,processingBatchSize        0.0     string
# 67  metabolomics,ProcessingBatchSizeUnit = other        0.0     string
# 68                metabolomics, dataFile = other        0.0     string
#
#              Ontology                                              Notes
# 0    Sage Bionetworks            values unique to each data contributor)
# 1   Sage Bionetworks,  A data contributor should be able to write in ...
# 2    Sage Bionetworks
# 3    Sage Bionetworks  A data contributor should be able to write in ...
# 4    Sage Bionetworks  A data contributor should be able to write in ...
# ..                ...                                                ...
# 64   Sage Bionetworks
# 65   Sage Bionetworks
# 66   Sage Bionetworks
# 67   Sage Bionetworks
# 68   Sage Bionetworks
#
# [69 rows x 9 columns]

# %%
p_df["Required"] = (
    p_df["Required"].astype(str)
    .apply(lambda x: False if bool(re.search("f", x)) else True)
    .astype(bool)
)

p_df = p_df.drop(columns=["multivalue"])

p_df
# Out:
#                          Attribute  \
# 0                       specimenID
# 1                       sampleType
# 2                specifySampleType
# 3             measurementTechnique
# 4      specifyMeasurementTechnique
# ..                             ...
# 64               processingBatchID
# 65             processingBatchSize
# 66         processingBatchSizeUnit
# 67  specifyProcessingBatchSizeUnit
# 68            specifyOtherDataFile
#
#                                           Description  \
# 0   Identifying string linked to a particular samp...
# 1   The type of sample collected or the term used ...
# 2      If "other" is selected list the type of sample
# 3   The name of the measurement technique describi...
# 4   If "other" is selected list the name of the me...
# ..                                                ...
# 64  Processing batch identifier, provided by the d...
# 65                              The number of samples
# 66  The unit of measurement for number of samples ...
# 67                   If "other" list units of measure
# 68  If "other" is selected, list the name of the d...
#
#                                          Valid Values  Required  \
# 0                                                          True
# 1                                                          True
# 2                                                          True
# 3                                                          True
# 4                                                          True
# ..                                                ...       ...
# 64                                                         True
# 65                                                         True
# 66  AFU,AI,AU/ml,DK units/ml,bp,g/dl,g/l,gm,HAU,IU...      True
# 67                                                         True
# 68                                                         True
#
#                                           Module columnType  \
# 0                       Biospecimen,metabolomics     string
# 1                                   metabolomics     string
# 2                metabolomics,sampleType = other     string
# 3                                   metabolomics     string
# 4      metabolomics,measurementTechnique = other     string
# ..                                           ...        ...
# 64                                  metabolomics     string
# 65                                  metabolomics     string
# 66              metabolomics,processingBatchSize     string
# 67  metabolomics,ProcessingBatchSizeUnit = other     string
# 68                metabolomics, dataFile = other     string
#
#              Ontology                                              Notes
# 0    Sage Bionetworks            values unique to each data contributor)
# 1   Sage Bionetworks,  A data contributor should be able to write in ...
# 2    Sage Bionetworks
# 3    Sage Bionetworks  A data contributor should be able to write in ...
# 4    Sage Bionetworks  A data contributor should be able to write in ...
# ..                ...                                                ...
# 64   Sage Bionetworks
# 65   Sage Bionetworks
# 66   Sage Bionetworks
# 67   Sage Bionetworks
# 68   Sage Bionetworks
#
# [69 rows x 8 columns]

# %%
# split the values out and create new attributes to add to the model.
# These will be the intermediate attributes that will allow the original column i.e. SampleType to then have the user fill in specifySampleType
p_df_others = p_df.loc[p_df["Module"].str.contains("=", na=False)].copy(deep=True)
p_df_others["others"] = (
    p_df_others["Module"]
    .str.split(",")
    .apply(lambda x: "".join([y.strip() for y in x if bool(re.search("=", y))]))
)

# in case there are multiple equals signs
p_df_others = p_df_others.explode("others")

p_df_others["Parent"] = (
    p_df_others["others"].str.split("=").apply(lambda x: x[0].strip())
)
p_df_others["OtherValue"] = (
    p_df_others["others"].str.split("=").apply(lambda x: x[1].strip())
)

p_df_others["others"] = (
    p_df_others["others"]
    .str.split("=")
    .apply(lambda x: x[1].strip().capitalize() + x[0][0].upper() + x[0][1:])
)
# Swap others -> Attribute and Attribute -> DependsOn
p_df_others = p_df_others.rename(
    columns={"Attribute": "DependsOn", "others": "Attribute"}
)
p_df_others["Required"] = False
p_df_others["Module"] = "Other"
p_df_others["Valid Values"] = ""
p_df_others
# Out:
#                             DependsOn  \
# 2                   specifySampleType
# 4         specifyMeasurementTechnique
# 6              specifyPlatformVersion
# 9             specifyPlatformLocation
# 17           specifyMSAnalyzerTypeMS1
# 19           specifyMSAnalyzerTypeMS2
# 21            specifyMSAssayTechnique
# 22                      msAnalyteType
# 23               specifyMSAnalyteType
# 24           specifyMSInstrumentModel
# 26          specifySampleIntroduction
# 36                        ionProperty
# 37                     vacuumPressure
# 38                 vacuumPressureUnit
# 39          specifyVacuumPressueUnits
# 40                      lensVoltages
# 41                  lensVoltagesUnit
# 42            specifyLensVoltageUnits
# 43                 gasFlowTemperature
# 44             gasFlowTemperatureUnit
# 46                        controlType
# 47                 specifyControlType
# 50  specifyExperimentalBatchSizeUnits
# 53              specifyBatchSizeUnits
# 59        specifySampleBatchSizeUnits
# 63   specifyAcquisitionBatchSizeUnits
# 67     specifyProcessingBatchSizeUnit
# 68               specifyOtherDataFile
#
#                                           Description Valid Values  Required  \
# 2      If "other" is selected list the type of sample                  False
# 4   If "other" is selected list the name of the me...                  False
# 6    If "other" list the name of the platform version                  False
# 9   If "other" list the name of the platform location                  False
# 17  If "other" is selected list the name of the ma...                  False
# 19  If "other" is selected list the name of the ma...                  False
# 21  If "other" is selected list the name of the ma...                  False
# 22  The type of biospecimen subjected to analysis ...                  False
# 23               If "other" list the type of analyte                   False
# 24  If "other" is selected list the name of the in...                  False
# 26  If "other" list the name of the sample introdu...                  False
# 36  Ion charge state (positive or negative-ion ana...                  False
# 37                 The recorded vacuum pressure value                  False
# 38                      Unit of vacuum pressure value                  False
# 39             If "other" provide the unit of measure                  False
# 40  The skimmer/focusing lens voltages e.g., capil...                  False
# 41                              Unit of lens voltages                  False
# 42             If "other" provide the unit of measure                  False
# 43  e.g., nebulization gas, cone gas, etc.,Unit of...                  False
# 44                       Unit of gas flow temperature                  False
# 46  Control samples suitable for normalization and...                  False
# 47                If "other" specify the control type                  False
# 50                   If "other" list units of measure                  False
# 53                If "other" list the unit of measure                  False
# 59                If "other" list the unit of measure                  False
# 63                   If "other" list units of measure                  False
# 67                   If "other" list units of measure                  False
# 68  If "other" is selected, list the name of the d...                  False
#
#    Module columnType                                           Ontology  \
# 2   Other     string                                   Sage Bionetworks
# 4   Other     string                                   Sage Bionetworks
# 6   Other     string                                   Sage Bionetworks
# 9   Other     string                                   Sage Bionetworks
# 17  Other     string                                   Sage Bionetworks
# 19  Other     string                                   Sage Bionetworks
# 21  Other     string                                   Sage Bionetworks
# 22  Other     string        http://purl.obolibrary.org/obo/NCIT_C156434
# 23  Other     string                                   Sage Bionetworks
# 24  Other     string                                   Sage Bionetworks
# 26  Other     string                                   Sage Bionetworks
# 36  Other     string  Sage Bionetworks,Proposed minimum metadata rel...
# 37  Other     number  Sage Bionetworks,Proposed minimum metadata rel...
# 38  Other     string  Sage Bionetworks,Proposed minimum metadata rel...
# 39  Other     string                                   Sage Bionetworks
# 40  Other     number  Sage Bionetworks,Proposed minimum metadata rel...
# 41  Other     string  Sage Bionetworks,Proposed minimum metadata rel...
# 42  Other     string                                   Sage Bionetworks
# 43  Other     number  Sage Bionetworks,Proposed minimum metadata rel...
# 44  Other     string  Sage Bionetworks,Proposed minimum metadata rel...
# 46  Other     string  https://doi.org/10.1101/2020.05.19.105197,http...
# 47  Other     string                                   Sage Bionetworks
# 50  Other
# 53  Other     string                                   Sage Bionetworks
# 59  Other     string                                   Sage Bionetworks
# 63  Other
# 67  Other     string                                   Sage Bionetworks
# 68  Other     string                                   Sage Bionetworks
#
#                                                 Notes  \
# 2
# 4   A data contributor should be able to write in ...
# 6   A data contributor should be able to write in ...
# 9
# 17
# 19
# 21  A data contributor should be able to write in ...
# 22  A data contributor should be able to write in ...
# 23
# 24
# 26  A data contributor should be able to write in ...
# 36
# 37
# 38
# 39
# 40
# 41
# 42
# 43
# 44
# 46  A data contributor should be able to write in ...
# 47
# 50
# 53
# 59
# 63
# 67
# 68
#
#                           Attribute                     Parent OtherValue
# 2                  OtherSampleType                  sampleType      other
# 4        OtherMeasurementTechnique        measurementTechnique      other
# 6   OtherTechnologyPlatformVersion   technologyPlatformVersion      other
# 9            OtherPlatformLocation            platformLocation      other
# 17          OtherMsAnalyzerTypeMS1           msAnalyzerTypeMS1      other
# 19          OtherMsAnalyzerTypeMS2           msAnalyzerTypeMS2      other
# 21           OtherMsAssayTechnique            msAssayTechnique      other
# 22                TargetedMsTarget                    msTarget   Targeted
# 23              OtherMsAnalyteType               msAnalyteType      other
# 24          OtherMsInstrumentModel           msInstrumentModel      other
# 26          OtherSampleIntdocution           sampleIntdocution      other
# 36         YesHasIonizationSource?        hasIonizationSource?        Yes
# 37         YesHasIonizationSource?        hasIonizationSource?        Yes
# 38         YesHasIonizationSource?        hasIonizationSource?        Yes
# 39        OtherVaccumPressureUnits         vaccumPressureUnits      other
# 40         YesHasIonizationSource?        hasIonizationSource?        Yes
# 41         YesHasIonizationSource?        hasIonizationSource?        Yes
# 42           OtherLensVoltageUnits            lensVoltageUnits      other
# 43         YesHasIonizationSource?        hasIonizationSource?        Yes
# 44         YesHasIonizationSource?        hasIonizationSource?        Yes
# 46              YesHasAssayControl             hasAssayControl        Yes
# 47                OtherControlType                 controlType      other
# 50  OtherExperimentalBatchSizeUnit   experimentalBatchSizeUnit      other
# 53              OtherBatchSizeUnit               batchSizeUnit      other
# 59        OtherSampleBatchSizeUnit         sampleBatchSizeUnit      other
# 63   OtherAcquisitionBatchSizeUnit    acquisitionBatchSizeUnit      other
# 67    OtherProcessingBatchSizeUnit     ProcessingBatchSizeUnit      other
# 68                   OtherDataFile                    dataFile      other

# %%
# Assign data modeling variables
p_df_others = p_df_others.assign(
    Description=p_df_others["DependsOn"].apply(
        lambda x: f"When {re.sub('specify|other', '',x, flags=re.IGNORECASE)} = `other`, add your custom value to the cell"
    ),
    columnType="string",
    Ontology="Sage Bionetworks",
    Required=False,
    Properties="ValidValue",
)

# %%
p_df_others
# Out:
#                             DependsOn  \
# 2                   specifySampleType
# 4         specifyMeasurementTechnique
# 6              specifyPlatformVersion
# 9             specifyPlatformLocation
# 17           specifyMSAnalyzerTypeMS1
# 19           specifyMSAnalyzerTypeMS2
# 21            specifyMSAssayTechnique
# 22                      msAnalyteType
# 23               specifyMSAnalyteType
# 24           specifyMSInstrumentModel
# 26          specifySampleIntroduction
# 36                        ionProperty
# 37                     vacuumPressure
# 38                 vacuumPressureUnit
# 39          specifyVacuumPressueUnits
# 40                      lensVoltages
# 41                  lensVoltagesUnit
# 42            specifyLensVoltageUnits
# 43                 gasFlowTemperature
# 44             gasFlowTemperatureUnit
# 46                        controlType
# 47                 specifyControlType
# 50  specifyExperimentalBatchSizeUnits
# 53              specifyBatchSizeUnits
# 59        specifySampleBatchSizeUnits
# 63   specifyAcquisitionBatchSizeUnits
# 67     specifyProcessingBatchSizeUnit
# 68               specifyOtherDataFile
#
#                                           Description Valid Values  Required  \
# 2   When SampleType = `other`, add your custom val...                  False
# 4   When MeasurementTechnique = `other`, add your ...                  False
# 6   When PlatformVersion = `other`, add your custo...                  False
# 9   When PlatformLocation = `other`, add your cust...                  False
# 17  When MSAnalyzerTypeMS1 = `other`, add your cus...                  False
# 19  When MSAnalyzerTypeMS2 = `other`, add your cus...                  False
# 21  When MSAssayTechnique = `other`, add your cust...                  False
# 22  When msAnalyteType = `other`, add your custom ...                  False
# 23  When MSAnalyteType = `other`, add your custom ...                  False
# 24  When MSInstrumentModel = `other`, add your cus...                  False
# 26  When SampleIntroduction = `other`, add your cu...                  False
# 36  When ionProperty = `other`, add your custom va...                  False
# 37  When vacuumPressure = `other`, add your custom...                  False
# 38  When vacuumPressureUnit = `other`, add your cu...                  False
# 39  When VacuumPressueUnits = `other`, add your cu...                  False
# 40  When lensVoltages  = `other`, add your custom ...                  False
# 41  When lensVoltagesUnit  = `other`, add your cus...                  False
# 42  When LensVoltageUnits = `other`, add your cust...                  False
# 43  When gasFlowTemperature = `other`, add your cu...                  False
# 44  When gasFlowTemperatureUnit = `other`, add you...                  False
# 46  When controlType = `other`, add your custom va...                  False
# 47  When ControlType = `other`, add your custom va...                  False
# 50  When ExperimentalBatchSizeUnits = `other`, add...                  False
# 53  When BatchSizeUnits = `other`, add your custom...                  False
# 59  When SampleBatchSizeUnits = `other`, add your ...                  False
# 63  When AcquisitionBatchSizeUnits = `other`, add ...                  False
# 67  When ProcessingBatchSizeUnit = `other`, add yo...                  False
# 68  When DataFile = `other`, add your custom value...                  False
#
#    Module columnType          Ontology  \
# 2   Other     string  Sage Bionetworks
# 4   Other     string  Sage Bionetworks
# 6   Other     string  Sage Bionetworks
# 9   Other     string  Sage Bionetworks
# 17  Other     string  Sage Bionetworks
# 19  Other     string  Sage Bionetworks
# 21  Other     string  Sage Bionetworks
# 22  Other     string  Sage Bionetworks
# 23  Other     string  Sage Bionetworks
# 24  Other     string  Sage Bionetworks
# 26  Other     string  Sage Bionetworks
# 36  Other     string  Sage Bionetworks
# 37  Other     string  Sage Bionetworks
# 38  Other     string  Sage Bionetworks
# 39  Other     string  Sage Bionetworks
# 40  Other     string  Sage Bionetworks
# 41  Other     string  Sage Bionetworks
# 42  Other     string  Sage Bionetworks
# 43  Other     string  Sage Bionetworks
# 44  Other     string  Sage Bionetworks
# 46  Other     string  Sage Bionetworks
# 47  Other     string  Sage Bionetworks
# 50  Other     string  Sage Bionetworks
# 53  Other     string  Sage Bionetworks
# 59  Other     string  Sage Bionetworks
# 63  Other     string  Sage Bionetworks
# 67  Other     string  Sage Bionetworks
# 68  Other     string  Sage Bionetworks
#
#                                                 Notes  \
# 2
# 4   A data contributor should be able to write in ...
# 6   A data contributor should be able to write in ...
# 9
# 17
# 19
# 21  A data contributor should be able to write in ...
# 22  A data contributor should be able to write in ...
# 23
# 24
# 26  A data contributor should be able to write in ...
# 36
# 37
# 38
# 39
# 40
# 41
# 42
# 43
# 44
# 46  A data contributor should be able to write in ...
# 47
# 50
# 53
# 59
# 63
# 67
# 68
#
#                           Attribute                     Parent OtherValue  \
# 2                  OtherSampleType                  sampleType      other
# 4        OtherMeasurementTechnique        measurementTechnique      other
# 6   OtherTechnologyPlatformVersion   technologyPlatformVersion      other
# 9            OtherPlatformLocation            platformLocation      other
# 17          OtherMsAnalyzerTypeMS1           msAnalyzerTypeMS1      other
# 19          OtherMsAnalyzerTypeMS2           msAnalyzerTypeMS2      other
# 21           OtherMsAssayTechnique            msAssayTechnique      other
# 22                TargetedMsTarget                    msTarget   Targeted
# 23              OtherMsAnalyteType               msAnalyteType      other
# 24          OtherMsInstrumentModel           msInstrumentModel      other
# 26          OtherSampleIntdocution           sampleIntdocution      other
# 36         YesHasIonizationSource?        hasIonizationSource?        Yes
# 37         YesHasIonizationSource?        hasIonizationSource?        Yes
# 38         YesHasIonizationSource?        hasIonizationSource?        Yes
# 39        OtherVaccumPressureUnits         vaccumPressureUnits      other
# 40         YesHasIonizationSource?        hasIonizationSource?        Yes
# 41         YesHasIonizationSource?        hasIonizationSource?        Yes
# 42           OtherLensVoltageUnits            lensVoltageUnits      other
# 43         YesHasIonizationSource?        hasIonizationSource?        Yes
# 44         YesHasIonizationSource?        hasIonizationSource?        Yes
# 46              YesHasAssayControl             hasAssayControl        Yes
# 47                OtherControlType                 controlType      other
# 50  OtherExperimentalBatchSizeUnit   experimentalBatchSizeUnit      other
# 53              OtherBatchSizeUnit               batchSizeUnit      other
# 59        OtherSampleBatchSizeUnit         sampleBatchSizeUnit      other
# 63   OtherAcquisitionBatchSizeUnit    acquisitionBatchSizeUnit      other
# 67    OtherProcessingBatchSizeUnit     ProcessingBatchSizeUnit      other
# 68                   OtherDataFile                    dataFile      other
#
#     Properties
# 2   ValidValue
# 4   ValidValue
# 6   ValidValue
# 9   ValidValue
# 17  ValidValue
# 19  ValidValue
# 21  ValidValue
# 22  ValidValue
# 23  ValidValue
# 24  ValidValue
# 26  ValidValue
# 36  ValidValue
# 37  ValidValue
# 38  ValidValue
# 39  ValidValue
# 40  ValidValue
# 41  ValidValue
# 42  ValidValue
# 43  ValidValue
# 44  ValidValue
# 46  ValidValue
# 47  ValidValue
# 50  ValidValue
# 53  ValidValue
# 59  ValidValue
# 63  ValidValue
# 67  ValidValue
# 68  ValidValue

# %%
# Add other attributes to the list of valid values
p_df.loc[~p_df.replace("", np.nan)["Valid Values"].isna(), 'Valid Values'] = p_df.loc[~p_df.replace("", np.nan)["Valid Values"].isna()].apply(lambda x: re.sub(',+', ',', ','.join(x['Valid Values'] + ',' + p_df_others.loc[p_df_others['Parent'] == x['Attribute'], 'Attribute'].values)), axis = 1)

# %%
# Last bit of cleanup
p_df["Properties"] = "ManifestColumn"
p_df["Module"] = p_df["Attribute"].apply(
    lambda x: "Other" if bool(re.search("specify", x)) else "Metadata"
)

# %%
print("Shape of original data frame:", p_df.shape)
print("Shape of others data frame:", p_df_others.shape)

p_df_final = pd.concat([p_df, p_df_others]).reset_index(drop=True).replace("", np.nan)
p_df_final = p_df_final.set_index("Attribute")

print("Shape of final data frame:", p_df_final.shape)

p_df_final.info()
# Out:
# Shape of original data frame: (69, 9)
# Shape of others data frame: (28, 12)
# Shape of final data frame: (97, 11)
# <class 'pandas.core.frame.DataFrame'>
# Index: 97 entries, specimenID to OtherDataFile
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Description   97 non-null     object
#  1   Valid Values  8 non-null      object
#  2   Required      97 non-null     bool
#  3   Module        97 non-null     object
#  4   columnType    95 non-null     object
#  5   Ontology      95 non-null     object
#  6   Notes         32 non-null     object
#  7   Properties    97 non-null     object
#  8   DependsOn     28 non-null     object
#  9   Parent        28 non-null     object
#  10  OtherValue    28 non-null     object
# dtypes: bool(1), object(10)
# memory usage: 8.4+ KB

# %%
p_df_final["UsedIn"] = RFC

# %%
# Add proteomics template to the data model updated with the attributes in DependsOn
dm.loc[dm["Attribute"] == RFC, "DependsOn"] = (
    "Component," + "Filename," + ",".join(p_df["Attribute"])
)

dm.loc[dm["Attribute"] == "proteomics"]
# Out:
#       Attribute                                        Description  \
# 515  proteomics  Template used for contributing metadata to the...
#
#     Valid Values                                          DependsOn  \
# 515          NaN  Component,Filename,specimenID,sampleType,speci...
#
#     Properties Required     Parent  DependsOn Component Source  \
# 515        NaN     True  Component                  NaN    NaN
#
#     Validation Rules    Module Ontology UsedIn columnType Notes multivalue
# 515              NaN  Template      NaN    NaN        NaN   NaN        NaN

# %%
dm['Module'].unique()
# Out:
# array(['ValidValues', 'Instrument', 'Assay', 'Unspecified', 'Metadata',
#        'SampleType', 'BaseAnnotation', 'Analysis', 'Template',
#        'Model Organism', 'Ontology', 'Tool', 'Unit', 'Consortium',
#        'Other', 'Repository'], dtype=object)

# %%
dm = dm.set_index('Attribute')

# %%
dm.shape
# Out:
# (755, 15)

# %%
# combine duplicated rows
p_df_final = p_df_final.fillna("").astype(str).groupby(level=0).apply(
    lambda x: x.apply(lambda y: ",".join(y))
)

# %%
p_df_final.index.is_unique
# Out:
# True

# %%
# Update empty values with the new dataframe
dm.update(p_df_final, overwrite=False, errors = 'ignore')

# %%
dm['Description'].update(p_df_final['Description'])

# %%
dm.loc[dm['UsedIn'].str.contains(RFC, na = False)].shape
# Out:
# (65, 15)

# %%
# join in the new template
dm_final = pd.concat([dm, p_df_final])
dm_final.shape
# Out:
# (832, 16)

# %%
# Replace any other values to leave open for contributors to add
dm_final.loc["platformLocation", "Valid Values"] = np.nan
dm_final.loc["dataFile", "Valid Values"] = np.nan
dm_final.loc["acquisitionMode", "Valid Values"] = np.nan
dm_final.loc["acquisitionSoftware", "Valid Values"] = np.nan

# %%
# qa check
with pd.option_context('display.max_rows', None):
    display(dm_final[dm_final.index.duplicated(keep=False)].sort_index())
# Out:
#                                                                          Description  \
# Attribute
# OtherDataFile                      When DataFile = `other`, add your custom value...
# OtherDataFile                      When DataFile = `other`, add your custom value...
# OtherMeasurementTechnique          When MeasurementTechnique = `other`, add your ...
# OtherMeasurementTechnique          When MeasurementTechnique = `other`, add your ...
# OtherMsAnalyteType                 When MSAnalyteType = `other`, add your custom ...
# OtherMsAnalyteType                 When MSAnalyteType = `other`, add your custom ...
# OtherMsAnalyzerTypeMS1             When MSAnalyzerTypeMS1 = `other`, add your cus...
# OtherMsAnalyzerTypeMS1             When MSAnalyzerTypeMS1 = `other`, add your cus...
# OtherMsAnalyzerTypeMS2             When MSAnalyzerTypeMS2 = `other`, add your cus...
# OtherMsAnalyzerTypeMS2             When MSAnalyzerTypeMS2 = `other`, add your cus...
# OtherMsAssayTechnique              When MSAssayTechnique = `other`, add your cust...
# OtherMsAssayTechnique              When MSAssayTechnique = `other`, add your cust...
# OtherMsInstrumentModel             When MSInstrumentModel = `other`, add your cus...
# OtherMsInstrumentModel             When MSInstrumentModel = `other`, add your cus...
# OtherPlatformLocation              When PlatformLocation = `other`, add your cust...
# OtherPlatformLocation              When PlatformLocation = `other`, add your cust...
# OtherSampleType                    When SampleType = `other`, add your custom val...
# OtherSampleType                    When SampleType = `other`, add your custom val...
# OtherTechnologyPlatformVersion     When PlatformVersion = `other`, add your custo...
# OtherTechnologyPlatformVersion     When PlatformVersion = `other`, add your custo...
# acquisitionBatchID                 Acquisition batch identifier, provided by the ...
# acquisitionBatchID                 Acquisition batch identifier, provided by the ...
# acquisitionBatchSize                                           The number of samples
# acquisitionBatchSize                                           The number of samples
# acquisitionBatchSizeUnit           The unit of measurement for number of samples ...
# acquisitionBatchSizeUnit           The unit of measurement for number of samples ...
# acquisitionMode                    The specific aspect of a mass spectrometer met...
# acquisitionMode                    The specific aspect of a mass spectrometer met...
# acquisitionSoftware                The name of the acquisition software used.,Pro...
# acquisitionSoftware                The name of the acquisition software used.,Pro...
# acquistionSoftwareVersion          The version number of software used.,Provide a...
# acquistionSoftwareVersion          The version number of software used.,Provide a...
# batchID                            ID used to identify a batch, provided by the d...
# batchID                            ID used to identify a batch, provided by the d...
# batchLabel                         Used to supply batch label information with an...
# batchLabel                         Used to supply batch label information with an...
# batchSize                                                      The number of samples
# batchSize                                                      The number of samples
# batchSizeUnit                      The unit of measurement for number of samples ...
# batchSizeUnit                      The unit of measurement for number of samples ...
# controlType                        Control samples suitable for normalization and...
# controlType                        Control samples suitable for normalization and...
# dataFile                           Name of additional file(s) accompanying the da...
# dataFile                           Name of additional file(s) accompanying the da...
# databaseName                       The name of the search database (nr, SwissProt...
# databaseName                       The name of the search database (nr, SwissProt...
# databaseSource                     The name of the organization, project, or labo...
# databaseSource                     The name of the organization, project, or labo...
# databaseWeblink                    An internet address that may provide details o...
# databaseWeblink                    An internet address that may provide details o...
# experiementalBatchSize                                        The number of samples
# experiementalBatchSize                                        The number of samples
# experiementalBatchSizeUnit         The unit of measurement for number of samples ...
# experiementalBatchSizeUnit         The unit of measurement for number of samples ...
# extractionMethod                   The name of the process used to separate a des...
# extractionMethod                   The name of the process used to separate a des...
# gasFlowTemperature                 e.g., nebulization gas, cone gas, etc.,Unit of...
# gasFlowTemperature                 e.g., nebulization gas, cone gas, etc.,Unit of...
# gasFlowTemperatureUnit                                  Unit of gas flow temperature
# gasFlowTemperatureUnit                                  Unit of gas flow temperature
# hasAssayControl                    Boolean flag indicating whether or not a speci...
# hasAssayControl                    Boolean flag indicating whether or not a speci...
# instrumentModel                    The model of the instrument used.,Provide a va...
# instrumentModel                    The model of the instrument used.,Provide a va...
# ionProperty                        Ion charge state (positive or negative-ion ana...
# ionProperty                        Ion charge state (positive or negative-ion ana...
# lensVoltages                       The skimmer/focusing lens voltages e.g., capil...
# lensVoltages                       The skimmer/focusing lens voltages e.g., capil...
# lensVoltagesUnit                                               Unit of lens voltages
# lensVoltagesUnit                                               Unit of lens voltages
# measurementTechnique               The name of the measurement technique describi...
# measurementTechnique               The name of the measurement technique describi...
# msAnalyteType                      The type of biospecimen subjected to analysis ...
# msAnalyteType                      The type of biospecimen subjected to analysis ...
# msAnalyzerTypeMS1                  Describes the mass spectrometer analyzer used ...
# msAnalyzerTypeMS1                  Describes the mass spectrometer analyzer used ...
# msAnalyzerTypeMS2                  Describes the mass spectrometer analyzer used ...
# msAnalyzerTypeMS2                  Describes the mass spectrometer analyzer used ...
# msAssayTechnique                   Specified the mass spectrometer technique used...
# msAssayTechnique                   Specified the mass spectrometer technique used...
# msTarget                           Specifies whether or not a specific molecule(s...
# msTarget                           Specifies whether or not a specific molecule(s...
# platformLocation                   The name of the laboratory, facility, vendor, ...
# platformLocation                   The name of the laboratory, facility, vendor, ...
# processingBatchID                  Processing batch identifier, provided by the d...
# processingBatchID                  Processing batch identifier, provided by the d...
# processingBatchSize                                            The number of samples
# processingBatchSize                                            The number of samples
# processingBatchSizeUnit            The unit of measurement for number of samples ...
# processingBatchSizeUnit            The unit of measurement for number of samples ...
# sampleBatchID                      Sample batch lot identifier, provided by the d...
# sampleBatchID                      Sample batch lot identifier, provided by the d...
# sampleBatchSize                                                The number of samples
# sampleBatchSize                                                The number of samples
# sampleBatchSizeUnit                The unit of measurement for number of samples ...
# sampleBatchSizeUnit                The unit of measurement for number of samples ...
# sampleIntroduction                 The sample introduction and delivery. From GC,...
# sampleIntroduction                 The sample introduction and delivery. From GC,...
# samplePrepProtocol                 An internet address that may provide more deta...
# samplePrepProtocol                 An internet address that may provide more deta...
# sampleType                         The type of sample collected or the term used ...
# sampleType                         The type of sample collected or the term used ...
# specifyAcquisitionBatchSizeUnits                    If "other" list units of measure
# specifyAcquisitionBatchSizeUnits                    If "other" list units of measure
# specifyBatchSizeUnits                            If "other" list the unit of measure
# specifyBatchSizeUnits                            If "other" list the unit of measure
# specifyControlType                               If "other" specify the control type
# specifyControlType                               If "other" specify the control type
# specifyDatabaseName                  If "other" list the name of the search database
# specifyDatabaseName                  If "other" list the name of the search database
# specifyDatabaseSource                If "other" list the name of the database source
# specifyDatabaseSource                If "other" list the name of the database source
# specifyExperimentalBatchSizeUnits                   If "other" list units of measure
# specifyExperimentalBatchSizeUnits                   If "other" list units of measure
# specifyLensVoltageUnits                       If "other" provide the unit of measure
# specifyLensVoltageUnits                       If "other" provide the unit of measure
# specifyMSAnalyteType                            If "other" list the type of analyte
# specifyMSAnalyteType                            If "other" list the type of analyte
# specifyMSAnalyzerTypeMS1           If "other" is selected list the name of the ma...
# specifyMSAnalyzerTypeMS1           If "other" is selected list the name of the ma...
# specifyMSAnalyzerTypeMS2           If "other" is selected list the name of the ma...
# specifyMSAnalyzerTypeMS2           If "other" is selected list the name of the ma...
# specifyMSAssayTechnique            If "other" is selected list the name of the ma...
# specifyMSAssayTechnique            If "other" is selected list the name of the ma...
# specifyMSInstrumentModel           If "other" is selected list the name of the in...
# specifyMSInstrumentModel           If "other" is selected list the name of the in...
# specifyMeasurementTechnique        If "other" is selected list the name of the me...
# specifyMeasurementTechnique        If "other" is selected list the name of the me...
# specifyOtherDataFile               If "other" is selected, list the name of the d...
# specifyOtherDataFile               If "other" is selected, list the name of the d...
# specifyPlatformLocation            If "other" list the name of the platform location
# specifyPlatformLocation            If "other" list the name of the platform location
# specifyPlatformVersion              If "other" list the name of the platform version
# specifyPlatformVersion              If "other" list the name of the platform version
# specifyProcessingBatchSizeUnit                      If "other" list units of measure
# specifyProcessingBatchSizeUnit                      If "other" list units of measure
# specifySampleBatchSizeUnits                      If "other" list the unit of measure
# specifySampleBatchSizeUnits                      If "other" list the unit of measure
# specifySampleIntroduction          If "other" list the name of the sample introdu...
# specifySampleIntroduction          If "other" list the name of the sample introdu...
# specifySampleType                     If "other" is selected list the type of sample
# specifySampleType                     If "other" is selected list the type of sample
# specifyVacuumPressueUnits                     If "other" provide the unit of measure
# specifyVacuumPressueUnits                     If "other" provide the unit of measure
# specimenID                         Identifying string linked to a particular samp...
# specimenID                         Identifying string linked to a particular samp...
# spectrometerFrequency              The frequency at which a spectrometer causes h...
# spectrometerFrequency              The frequency at which a spectrometer causes h...
# technologyPlatformVersion          The specific version (application, manufacture...
# technologyPlatformVersion          The specific version (application, manufacture...
# vacuumPressure                                    The recorded vacuum pressure value
# vacuumPressure                                    The recorded vacuum pressure value
# vacuumPressureUnit                                     Unit of vacuum pressure value
# vacuumPressureUnit                                     Unit of vacuum pressure value
#
#                                                                         Valid Values  \
# Attribute
# OtherDataFile
# OtherDataFile
# OtherMeasurementTechnique
# OtherMeasurementTechnique
# OtherMsAnalyteType
# OtherMsAnalyteType
# OtherMsAnalyzerTypeMS1
# OtherMsAnalyzerTypeMS1
# OtherMsAnalyzerTypeMS2
# OtherMsAnalyzerTypeMS2
# OtherMsAssayTechnique
# OtherMsAssayTechnique
# OtherMsInstrumentModel
# OtherMsInstrumentModel
# OtherPlatformLocation
# OtherPlatformLocation
# OtherSampleType
# OtherSampleType
# OtherTechnologyPlatformVersion
# OtherTechnologyPlatformVersion
# acquisitionBatchID
# acquisitionBatchID
# acquisitionBatchSize
# acquisitionBatchSize
# acquisitionBatchSizeUnit           AFU,AI,AU/ml,DK units/ml,bp,g/dl,g/l,gm,HAU,IU...
# acquisitionBatchSizeUnit           AFU, AI, AU/ml, DK units/ml, bpg/dl, g/l, gm, ...
# acquisitionMode                                                                  NaN
# acquisitionMode                                                                  NaN
# acquisitionSoftware                                                              NaN
# acquisitionSoftware                                                              NaN
# acquistionSoftwareVersion
# acquistionSoftwareVersion
# batchID
# batchID
# batchLabel
# batchLabel
# batchSize
# batchSize
# batchSizeUnit                      AFU,AI,AU/ml,DK units/ml,bp,g/dl,g/l,gm,HAU,IU...
# batchSizeUnit                      AFU, AI, AU/ml, DK units/ml, bpg/dl, g/l, gm, ...
# controlType                        GIS, GoldenWest, NIST SRM 1950, AIBL pool, Bak...
# controlType
# dataFile                                                                         NaN
# dataFile                                                                         NaN
# databaseName
# databaseName                       MassBank of North America (MoNA), NIST17, Metl...
# databaseSource                     OtherDatabaseSource, Unknown, Not collected, N...
# databaseSource
# databaseWeblink
# databaseWeblink
# experiementalBatchSize
# experiementalBatchSize
# experiementalBatchSizeUnit
# experiementalBatchSizeUnit         AFU, AI, AU/ml, DK units/ml, bpg/dl, g/l, gm, ...
# extractionMethod
# extractionMethod                   Unknown, Not collected, Not applicable, Not Sp...
# gasFlowTemperature
# gasFlowTemperature
# gasFlowTemperatureUnit
# gasFlowTemperatureUnit                                        C, F, K, Not Specified
# hasAssayControl                                           Yes,No,YesHasAssayControl
# hasAssayControl                                               YesHasAssayControl, No
# instrumentModel
# instrumentModel
# ionProperty
# ionProperty                                                       Positive, Negative
# lensVoltages
# lensVoltages
# lensVoltagesUnit
# lensVoltagesUnit                   AFU, AI, AU/ml, DK units/ml, bpg/dl, g/l, gm, ...
# measurementTechnique
# measurementTechnique
# msAnalyteType
# msAnalyteType                      Protein, metabolite, Lipid, Other, Unknown, No...
# msAnalyzerTypeMS1                  LTQ Orbitrap XL, Orbitrap Fusion, Orbitrap Fus...
# msAnalyzerTypeMS1                  LTQ Orbitrap XL,Orbitrap Fusion,Orbitrap Fusio...
# msAnalyzerTypeMS2                  LTQ Orbitrap XL,Orbitrap Fusion,Orbitrap Fusio...
# msAnalyzerTypeMS2                  LTQ Orbitrap XL, Orbitrap Fusion, Orbitrap Fus...
# msAssayTechnique                   DDA-MS, DIA-MS, FIA-MSMS, HPLC-MSMS, LC-MS, LC...
# msAssayTechnique
# msTarget                                       Targeted,Untargeted,TargetedMsTarget
# msTarget                           TargetedMsTarget, UnTargetedMsTarget, Unknown,...
# platformLocation                                                                 NaN
# platformLocation                                                                 NaN
# processingBatchID
# processingBatchID
# processingBatchSize
# processingBatchSize
# processingBatchSizeUnit
# processingBatchSizeUnit            AFU, AI, AU/ml, DK units/ml, bpg/dl, g/l, gm, ...
# sampleBatchID
# sampleBatchID
# sampleBatchSize
# sampleBatchSize
# sampleBatchSizeUnit                AFU, AI, AU/ml, DK units/ml, bpg/dl, g/l, gm, ...
# sampleBatchSizeUnit                AFU,AI,AU/ml,DK units/ml,bp,g/dl,g/l,gm,HAU,IU...
# sampleIntroduction                 Other, Unknown, Not collected, Not applicable,...
# sampleIntroduction
# samplePrepProtocol
# samplePrepProtocol
# sampleType                         Amniotic Fluid, Appendix, B cell, Basophils, B...
# sampleType
# specifyAcquisitionBatchSizeUnits
# specifyAcquisitionBatchSizeUnits
# specifyBatchSizeUnits
# specifyBatchSizeUnits
# specifyControlType
# specifyControlType
# specifyDatabaseName
# specifyDatabaseName
# specifyDatabaseSource
# specifyDatabaseSource
# specifyExperimentalBatchSizeUnits
# specifyExperimentalBatchSizeUnits
# specifyLensVoltageUnits
# specifyLensVoltageUnits
# specifyMSAnalyteType
# specifyMSAnalyteType
# specifyMSAnalyzerTypeMS1
# specifyMSAnalyzerTypeMS1
# specifyMSAnalyzerTypeMS2
# specifyMSAnalyzerTypeMS2
# specifyMSAssayTechnique
# specifyMSAssayTechnique
# specifyMSInstrumentModel
# specifyMSInstrumentModel
# specifyMeasurementTechnique
# specifyMeasurementTechnique
# specifyOtherDataFile
# specifyOtherDataFile
# specifyPlatformLocation
# specifyPlatformLocation
# specifyPlatformVersion
# specifyPlatformVersion
# specifyProcessingBatchSizeUnit
# specifyProcessingBatchSizeUnit
# specifySampleBatchSizeUnits
# specifySampleBatchSizeUnits
# specifySampleIntroduction
# specifySampleIntroduction
# specifySampleType
# specifySampleType
# specifyVacuumPressueUnits
# specifyVacuumPressueUnits
# specimenID
# specimenID
# spectrometerFrequency
# spectrometerFrequency
# technologyPlatformVersion
# technologyPlatformVersion          10x Visium Spatial Gene Expression, Affymetrix...
# vacuumPressure
# vacuumPressure
# vacuumPressureUnit                 AFU, AI, AU/ml, DK units/ml, bpg/dl, g/l, gm, ...
# vacuumPressureUnit
#
#                                                      DependsOn  \
# Attribute
# OtherDataFile                             specifyOtherDataFile
# OtherDataFile                             specifyOtherDataFile
# OtherMeasurementTechnique          specifyMeasurementTechnique
# OtherMeasurementTechnique          specifyMeasurementTechnique
# OtherMsAnalyteType                        specifyMSAnalyteType
# OtherMsAnalyteType                        specifyMSAnalyteType
# OtherMsAnalyzerTypeMS1                specifyMSAnalyzerTypeMS1
# OtherMsAnalyzerTypeMS1                specifyMSAnalyzerTypeMS1
# OtherMsAnalyzerTypeMS2                specifyMSAnalyzerTypeMS2
# OtherMsAnalyzerTypeMS2                specifyMSAnalyzerTypeMS2
# OtherMsAssayTechnique                  specifyMSAssayTechnique
# OtherMsAssayTechnique                  specifyMSAssayTechnique
# OtherMsInstrumentModel                specifyMSInstrumentModel
# OtherMsInstrumentModel                specifyMSInstrumentModel
# OtherPlatformLocation                  specifyPlatformLocation
# OtherPlatformLocation                  specifyPlatformLocation
# OtherSampleType                              specifySampleType
# OtherSampleType                              specifySampleType
# OtherTechnologyPlatformVersion          specifyPlatformVersion
# OtherTechnologyPlatformVersion          specifyPlatformVersion
# acquisitionBatchID
# acquisitionBatchID
# acquisitionBatchSize
# acquisitionBatchSize
# acquisitionBatchSizeUnit
# acquisitionBatchSizeUnit
# acquisitionMode
# acquisitionMode
# acquisitionSoftware
# acquisitionSoftware
# acquistionSoftwareVersion
# acquistionSoftwareVersion
# batchID
# batchID
# batchLabel
# batchLabel
# batchSize
# batchSize
# batchSizeUnit
# batchSizeUnit
# controlType
# controlType
# dataFile                                                     ,
# dataFile                                                     ,
# databaseName
# databaseName                                                 ,
# databaseSource                                               ,
# databaseSource
# databaseWeblink
# databaseWeblink
# experiementalBatchSize
# experiementalBatchSize
# experiementalBatchSizeUnit
# experiementalBatchSizeUnit
# extractionMethod
# extractionMethod
# gasFlowTemperature
# gasFlowTemperature
# gasFlowTemperatureUnit
# gasFlowTemperatureUnit
# hasAssayControl
# hasAssayControl
# instrumentModel
# instrumentModel
# ionProperty
# ionProperty
# lensVoltages
# lensVoltages
# lensVoltagesUnit
# lensVoltagesUnit
# measurementTechnique
# measurementTechnique
# msAnalyteType
# msAnalyteType
# msAnalyzerTypeMS1
# msAnalyzerTypeMS1
# msAnalyzerTypeMS2
# msAnalyzerTypeMS2
# msAssayTechnique
# msAssayTechnique
# msTarget
# msTarget
# platformLocation
# platformLocation
# processingBatchID
# processingBatchID
# processingBatchSize
# processingBatchSize
# processingBatchSizeUnit
# processingBatchSizeUnit
# sampleBatchID
# sampleBatchID
# sampleBatchSize
# sampleBatchSize
# sampleBatchSizeUnit
# sampleBatchSizeUnit
# sampleIntroduction
# sampleIntroduction
# samplePrepProtocol
# samplePrepProtocol
# sampleType
# sampleType
# specifyAcquisitionBatchSizeUnits
# specifyAcquisitionBatchSizeUnits
# specifyBatchSizeUnits
# specifyBatchSizeUnits
# specifyControlType
# specifyControlType
# specifyDatabaseName
# specifyDatabaseName
# specifyDatabaseSource
# specifyDatabaseSource
# specifyExperimentalBatchSizeUnits
# specifyExperimentalBatchSizeUnits
# specifyLensVoltageUnits
# specifyLensVoltageUnits
# specifyMSAnalyteType
# specifyMSAnalyteType
# specifyMSAnalyzerTypeMS1
# specifyMSAnalyzerTypeMS1
# specifyMSAnalyzerTypeMS2
# specifyMSAnalyzerTypeMS2
# specifyMSAssayTechnique
# specifyMSAssayTechnique
# specifyMSInstrumentModel
# specifyMSInstrumentModel
# specifyMeasurementTechnique
# specifyMeasurementTechnique
# specifyOtherDataFile
# specifyOtherDataFile
# specifyPlatformLocation
# specifyPlatformLocation
# specifyPlatformVersion
# specifyPlatformVersion
# specifyProcessingBatchSizeUnit
# specifyProcessingBatchSizeUnit
# specifySampleBatchSizeUnits
# specifySampleBatchSizeUnits
# specifySampleIntroduction
# specifySampleIntroduction
# specifySampleType
# specifySampleType
# specifyVacuumPressueUnits
# specifyVacuumPressueUnits
# specimenID
# specimenID
# spectrometerFrequency
# spectrometerFrequency
# technologyPlatformVersion
# technologyPlatformVersion
# vacuumPressure
# vacuumPressure
# vacuumPressureUnit
# vacuumPressureUnit
#
#                                                       Properties   Required  \
# Attribute
# OtherDataFile                                         ValidValue      False
# OtherDataFile                                         ValidValue      False
# OtherMeasurementTechnique                             ValidValue      False
# OtherMeasurementTechnique                             ValidValue      False
# OtherMsAnalyteType                                    ValidValue      False
# OtherMsAnalyteType                                    ValidValue      False
# OtherMsAnalyzerTypeMS1                                ValidValue      False
# OtherMsAnalyzerTypeMS1                                ValidValue      False
# OtherMsAnalyzerTypeMS2                                ValidValue      False
# OtherMsAnalyzerTypeMS2                                ValidValue      False
# OtherMsAssayTechnique                                 ValidValue      False
# OtherMsAssayTechnique                                 ValidValue      False
# OtherMsInstrumentModel                                ValidValue      False
# OtherMsInstrumentModel                                ValidValue      False
# OtherPlatformLocation                                 ValidValue      False
# OtherPlatformLocation                                 ValidValue      False
# OtherSampleType                                       ValidValue      False
# OtherSampleType                                       ValidValue      False
# OtherTechnologyPlatformVersion                        ValidValue      False
# OtherTechnologyPlatformVersion                        ValidValue      False
# acquisitionBatchID                                ManifestColumn      False
# acquisitionBatchID                                ManifestColumn       True
# acquisitionBatchSize                              ManifestColumn       True
# acquisitionBatchSize                              ManifestColumn      False
# acquisitionBatchSizeUnit                          ManifestColumn       True
# acquisitionBatchSizeUnit                          ManifestColumn      False
# acquisitionMode                                   ManifestColumn       True
# acquisitionMode                                   ManifestColumn       True
# acquisitionSoftware                               ManifestColumn       True
# acquisitionSoftware                               ManifestColumn       True
# acquistionSoftwareVersion                         ManifestColumn       True
# acquistionSoftwareVersion                         ManifestColumn       True
# batchID                                           ManifestColumn       True
# batchID                                           ManifestColumn      False
# batchLabel                                        ManifestColumn       True
# batchLabel                                        ManifestColumn      False
# batchSize                                         ManifestColumn      False
# batchSize                                         ManifestColumn       True
# batchSizeUnit                                     ManifestColumn       True
# batchSizeUnit                                     ManifestColumn      False
# controlType                                       ManifestColumn      False
# controlType                                       ManifestColumn       True
# dataFile                           ManifestColumn,ManifestColumn  True,True
# dataFile                                          ManifestColumn       True
# databaseName                                      ManifestColumn       True
# databaseName                       ManifestColumn,ManifestColumn       True
# databaseSource                     ManifestColumn,ManifestColumn      False
# databaseSource                                    ManifestColumn       True
# databaseWeblink                                   ManifestColumn      False
# databaseWeblink                                   ManifestColumn       True
# experiementalBatchSize                            ManifestColumn       True
# experiementalBatchSize                            ManifestColumn      False
# experiementalBatchSizeUnit                        ManifestColumn       True
# experiementalBatchSizeUnit                        ManifestColumn      False
# extractionMethod                                  ManifestColumn       True
# extractionMethod                                  ManifestColumn       True
# gasFlowTemperature                                ManifestColumn      False
# gasFlowTemperature                                ManifestColumn       True
# gasFlowTemperatureUnit                            ManifestColumn       True
# gasFlowTemperatureUnit                            ManifestColumn      False
# hasAssayControl                                   ManifestColumn       True
# hasAssayControl                                   ManifestColumn       True
# instrumentModel                                   ManifestColumn       True
# instrumentModel                                   ManifestColumn       True
# ionProperty                                       ManifestColumn       True
# ionProperty                                       ManifestColumn      False
# lensVoltages                                      ManifestColumn      False
# lensVoltages                                      ManifestColumn       True
# lensVoltagesUnit                                  ManifestColumn       True
# lensVoltagesUnit                                  ManifestColumn      False
# measurementTechnique                              ManifestColumn       True
# measurementTechnique                              ManifestColumn       True
# msAnalyteType                                     ManifestColumn       True
# msAnalyteType                                     ManifestColumn      False
# msAnalyzerTypeMS1                                 ManifestColumn       True
# msAnalyzerTypeMS1                                 ManifestColumn       True
# msAnalyzerTypeMS2                                 ManifestColumn       True
# msAnalyzerTypeMS2                                 ManifestColumn       True
# msAssayTechnique                                  ManifestColumn       True
# msAssayTechnique                                  ManifestColumn       True
# msTarget                                          ManifestColumn       True
# msTarget                                          ManifestColumn       True
# platformLocation                                  ManifestColumn       True
# platformLocation                                  ManifestColumn       True
# processingBatchID                                 ManifestColumn       True
# processingBatchID                                 ManifestColumn      False
# processingBatchSize                               ManifestColumn       True
# processingBatchSize                               ManifestColumn      False
# processingBatchSizeUnit                           ManifestColumn       True
# processingBatchSizeUnit                           ManifestColumn      False
# sampleBatchID                                     ManifestColumn       True
# sampleBatchID                                     ManifestColumn      False
# sampleBatchSize                                   ManifestColumn       True
# sampleBatchSize                                   ManifestColumn      False
# sampleBatchSizeUnit                               ManifestColumn      False
# sampleBatchSizeUnit                               ManifestColumn       True
# sampleIntroduction                                ManifestColumn       True
# sampleIntroduction                                ManifestColumn       True
# samplePrepProtocol                                ManifestColumn      False
# samplePrepProtocol                                ManifestColumn       True
# sampleType                                        ManifestColumn       True
# sampleType                                        ManifestColumn       True
# specifyAcquisitionBatchSizeUnits                  ManifestColumn       True
# specifyAcquisitionBatchSizeUnits                  ManifestColumn      False
# specifyBatchSizeUnits                             ManifestColumn       True
# specifyBatchSizeUnits                             ManifestColumn      False
# specifyControlType                                ManifestColumn      False
# specifyControlType                                ManifestColumn       True
# specifyDatabaseName                               ManifestColumn       True
# specifyDatabaseName                               ManifestColumn      False
# specifyDatabaseSource                             ManifestColumn       True
# specifyDatabaseSource                             ManifestColumn      False
# specifyExperimentalBatchSizeUnits                 ManifestColumn       True
# specifyExperimentalBatchSizeUnits                 ManifestColumn      False
# specifyLensVoltageUnits                           ManifestColumn       True
# specifyLensVoltageUnits                           ManifestColumn      False
# specifyMSAnalyteType                              ManifestColumn      False
# specifyMSAnalyteType                              ManifestColumn       True
# specifyMSAnalyzerTypeMS1                          ManifestColumn      False
# specifyMSAnalyzerTypeMS1                          ManifestColumn       True
# specifyMSAnalyzerTypeMS2                          ManifestColumn       True
# specifyMSAnalyzerTypeMS2                          ManifestColumn      False
# specifyMSAssayTechnique                           ManifestColumn      False
# specifyMSAssayTechnique                           ManifestColumn       True
# specifyMSInstrumentModel                          ManifestColumn       True
# specifyMSInstrumentModel                          ManifestColumn      False
# specifyMeasurementTechnique                       ManifestColumn      False
# ...
# msAnalyzerTypeMS1
# msAnalyzerTypeMS2
# msAnalyzerTypeMS2
# msAssayTechnique                   A data contributor should be able to write in ...
# msAssayTechnique                   A data contributor should be able to write in ...
# msTarget
# msTarget
# platformLocation                   A data contributor should be able to write in ...
# platformLocation                   A data contributor should be able to write in ...
# processingBatchID
# processingBatchID
# processingBatchSize
# processingBatchSize
# processingBatchSizeUnit
# processingBatchSizeUnit
# sampleBatchID
# sampleBatchID
# sampleBatchSize
# sampleBatchSize
# sampleBatchSizeUnit
# sampleBatchSizeUnit
# sampleIntroduction                 A data contributor should be able to write in ...
# sampleIntroduction                 A data contributor should be able to write in ...
# samplePrepProtocol                 A data contributor should be able to write in ...
# samplePrepProtocol                 A data contributor should be able to write in ...
# sampleType                         A data contributor should be able to write in ...
# sampleType                         A data contributor should be able to write in ...
# specifyAcquisitionBatchSizeUnits
# specifyAcquisitionBatchSizeUnits
# specifyBatchSizeUnits
# specifyBatchSizeUnits
# specifyControlType
# specifyControlType
# specifyDatabaseName                A data contributor should be able to write in ...
# specifyDatabaseName                A data contributor should be able to write in ...
# specifyDatabaseSource              A data contributor should be able to write in ...
# specifyDatabaseSource              A data contributor should be able to write in ...
# specifyExperimentalBatchSizeUnits
# specifyExperimentalBatchSizeUnits
# specifyLensVoltageUnits
# specifyLensVoltageUnits
# specifyMSAnalyteType
# specifyMSAnalyteType
# specifyMSAnalyzerTypeMS1
# specifyMSAnalyzerTypeMS1
# specifyMSAnalyzerTypeMS2
# specifyMSAnalyzerTypeMS2
# specifyMSAssayTechnique            A data contributor should be able to write in ...
# specifyMSAssayTechnique            A data contributor should be able to write in ...
# specifyMSInstrumentModel
# specifyMSInstrumentModel
# specifyMeasurementTechnique        A data contributor should be able to write in ...
# specifyMeasurementTechnique        A data contributor should be able to write in ...
# specifyOtherDataFile
# specifyOtherDataFile
# specifyPlatformLocation
# specifyPlatformLocation
# specifyPlatformVersion             A data contributor should be able to write in ...
# specifyPlatformVersion             A data contributor should be able to write in ...
# specifyProcessingBatchSizeUnit
# specifyProcessingBatchSizeUnit
# specifySampleBatchSizeUnits
# specifySampleBatchSizeUnits
# specifySampleIntroduction          A data contributor should be able to write in ...
# specifySampleIntroduction          A data contributor should be able to write in ...
# specifySampleType
# specifySampleType
# specifyVacuumPressueUnits
# specifyVacuumPressueUnits
# specimenID                                   values unique to each data contributor)
# specimenID                                   values unique to each data contributor)
# spectrometerFrequency
# spectrometerFrequency
# technologyPlatformVersion          A data contributor should be able to write in ...
# technologyPlatformVersion          A data contributor should be able to write in ...
# vacuumPressure
# vacuumPressure
# vacuumPressureUnit
# vacuumPressureUnit
#
#                                   multivalue OtherValue
# Attribute
# OtherDataFile                            NaN        NaN
# OtherDataFile                            NaN      other
# OtherMeasurementTechnique                NaN      other
# OtherMeasurementTechnique                NaN        NaN
# OtherMsAnalyteType                       NaN        NaN
# OtherMsAnalyteType                       NaN      other
# OtherMsAnalyzerTypeMS1                   NaN        NaN
# OtherMsAnalyzerTypeMS1                   NaN      other
# OtherMsAnalyzerTypeMS2                   NaN      other
# OtherMsAnalyzerTypeMS2                   NaN        NaN
# OtherMsAssayTechnique                    NaN      other
# OtherMsAssayTechnique                    NaN        NaN
# OtherMsInstrumentModel                   NaN      other
# OtherMsInstrumentModel                   NaN        NaN
# OtherPlatformLocation                    NaN      other
# OtherPlatformLocation                    NaN        NaN
# OtherSampleType                          NaN      other
# OtherSampleType                          NaN        NaN
# OtherTechnologyPlatformVersion           NaN      other
# OtherTechnologyPlatformVersion           NaN        NaN
# acquisitionBatchID                       NaN        NaN
# acquisitionBatchID                       NaN
# acquisitionBatchSize                     NaN
# acquisitionBatchSize                     NaN        NaN
# acquisitionBatchSizeUnit                 NaN
# acquisitionBatchSizeUnit                 NaN        NaN
# acquisitionMode                          NaN        NaN
# acquisitionMode                          NaN
# acquisitionSoftware                      NaN
# acquisitionSoftware                      NaN        NaN
# acquistionSoftwareVersion                NaN        NaN
# acquistionSoftwareVersion                NaN
# batchID                                  NaN
# batchID                                  NaN        NaN
# batchLabel                               NaN
# batchLabel                               NaN        NaN
# batchSize                                NaN        NaN
# batchSize                                NaN
# batchSizeUnit                            NaN
# batchSizeUnit                            NaN        NaN
# controlType                              NaN        NaN
# controlType                              NaN
# dataFile                                 NaN          ,
# dataFile                                 NaN        NaN
# databaseName                             NaN
# databaseName                             NaN        NaN
# databaseSource                           NaN        NaN
# databaseSource                           NaN
# databaseWeblink                          NaN        NaN
# databaseWeblink                          NaN
# experiementalBatchSize                   NaN
# experiementalBatchSize                   NaN        NaN
# experiementalBatchSizeUnit               NaN
# experiementalBatchSizeUnit               NaN        NaN
# extractionMethod                         NaN
# extractionMethod                         NaN        NaN
# gasFlowTemperature                       NaN        NaN
# gasFlowTemperature                       NaN
# gasFlowTemperatureUnit                   NaN
# gasFlowTemperatureUnit                   NaN        NaN
# hasAssayControl                          NaN
# hasAssayControl                          NaN        NaN
# instrumentModel                          NaN
# instrumentModel                          NaN        NaN
# ionProperty                              NaN
# ionProperty                              NaN        NaN
# lensVoltages                             NaN        NaN
# lensVoltages                             NaN
# lensVoltagesUnit                         NaN
# lensVoltagesUnit                         NaN        NaN
# measurementTechnique                     NaN
# measurementTechnique                     NaN        NaN
# msAnalyteType                            NaN
# msAnalyteType                            NaN        NaN
# msAnalyzerTypeMS1                        NaN        NaN
# msAnalyzerTypeMS1                        NaN
# msAnalyzerTypeMS2                        NaN
# msAnalyzerTypeMS2                        NaN        NaN
# msAssayTechnique                         NaN        NaN
# msAssayTechnique                         NaN
# msTarget                                 NaN
# msTarget                                 NaN        NaN
# platformLocation                         NaN
# platformLocation                         NaN        NaN
# processingBatchID                        NaN
# processingBatchID                        NaN        NaN
# processingBatchSize                      NaN
# processingBatchSize                      NaN        NaN
# processingBatchSizeUnit                  NaN
# processingBatchSizeUnit                  NaN        NaN
# sampleBatchID                            NaN
# sampleBatchID                            NaN        NaN
# sampleBatchSize                          NaN
# sampleBatchSize                          NaN        NaN
# sampleBatchSizeUnit                      NaN        NaN
# sampleBatchSizeUnit                      NaN
# sampleIntroduction                       NaN        NaN
# sampleIntroduction                       NaN
# samplePrepProtocol                       NaN        NaN
# samplePrepProtocol                       NaN
# sampleType                               NaN        NaN
# sampleType                               NaN
# specifyAcquisitionBatchSizeUnits         NaN
# specifyAcquisitionBatchSizeUnits         NaN        NaN
# specifyBatchSizeUnits                    NaN
# specifyBatchSizeUnits                    NaN        NaN
# specifyControlType                       NaN        NaN
# specifyControlType                       NaN
# specifyDatabaseName                      NaN
# specifyDatabaseName                      NaN        NaN
# specifyDatabaseSource                    NaN
# specifyDatabaseSource                    NaN        NaN
# specifyExperimentalBatchSizeUnits        NaN
# specifyExperimentalBatchSizeUnits        NaN        NaN
# specifyLensVoltageUnits                  NaN
# specifyLensVoltageUnits                  NaN        NaN
# specifyMSAnalyteType                     NaN        NaN
# specifyMSAnalyteType                     NaN
# specifyMSAnalyzerTypeMS1                 NaN        NaN
# specifyMSAnalyzerTypeMS1                 NaN
# specifyMSAnalyzerTypeMS2                 NaN
# specifyMSAnalyzerTypeMS2                 NaN        NaN
# specifyMSAssayTechnique                  NaN        NaN
# specifyMSAssayTechnique                  NaN
# specifyMSInstrumentModel                 NaN
# specifyMSInstrumentModel                 NaN        NaN
# specifyMeasurementTechnique              NaN        NaN
# specifyMeasurementTechnique              NaN
# specifyOtherDataFile                     NaN
# specifyOtherDataFile                     NaN        NaN
# specifyPlatformLocation                  NaN
# specifyPlatformLocation                  NaN        NaN
# specifyPlatformVersion                   NaN
# specifyPlatformVersion                   NaN        NaN
# specifyProcessingBatchSizeUnit           NaN
# specifyProcessingBatchSizeUnit           NaN        NaN
# specifySampleBatchSizeUnits              NaN
# specifySampleBatchSizeUnits              NaN        NaN
# specifySampleIntroduction                NaN
# specifySampleIntroduction                NaN        NaN
# specifySampleType                        NaN
# specifySampleType                        NaN        NaN
# specifyVacuumPressueUnits                NaN        NaN
# specifyVacuumPressueUnits                NaN
# specimenID                               NaN
# specimenID                               NaN        NaN
# spectrometerFrequency                    NaN
# spectrometerFrequency                    NaN        NaN
# technologyPlatformVersion                NaN
# technologyPlatformVersion                NaN        NaN
# vacuumPressure                           NaN
# vacuumPressure                           NaN        NaN
# vacuumPressureUnit                       NaN        NaN
# vacuumPressureUnit                       NaN

# %%
apply_cols = [x for x in dm_final.columns if x not in ['Description']]

# %%
# join duplicate values and then get unique list. Then join for single string. Could break if there are commas in teh description or something
dm_final[apply_cols] = (
    dm_final[apply_cols]
    .fillna("")
    .astype(str)
    .groupby(level=0)
    .apply(
        lambda x: x.apply(
            lambda y: ",".join(np.unique(",".join(y).split(",")))
        ).str.strip(",| ")
    )
)

dm_final[["Module", "UsedIn"]] = (
    dm_final[["Module", "UsedIn"]]
    .fillna("")
    .apply(
        lambda c: c.str.split(",").apply(
            lambda x: ",".join(
                [y for y in x if y not in ["Unspecified", "Metabolomics Human"]]
            )
        )
    )
)

# %%
dm_final.loc["msTarget"]
# Out:
#                                                  Description  \
# Attribute
# msTarget   Specifies whether or not a specific molecule(s...
# msTarget   Specifies whether or not a specific molecule(s...
#
#                                                 Valid Values DependsOn  \
# Attribute
# msTarget   Not Specified, Not applicable, Not collected, ...
# msTarget   Not Specified, Not applicable, Not collected, ...
#
#                Properties Required          Parent DependsOn Component  \
# Attribute
# msTarget   ManifestColumn     True  ManifestColumn
# msTarget   ManifestColumn     True  ManifestColumn
#
#                      Source Validation Rules    Module  \
# Attribute
# msTarget   Sage Bionetworks                   Metadata
# msTarget   Sage Bionetworks                   Metadata
#
#                          Ontology                   UsedIn columnType Notes  \
# Attribute
# msTarget   DSLWG,Sage Bionetworks  Metabolomics,proteomics     string
# msTarget   DSLWG,Sage Bionetworks  Metabolomics,proteomics     string
#
#           multivalue OtherValue
# Attribute
# msTarget
# msTarget

# %%
dm_final.shape
# Out:
# (832, 16)

# %%
# Check there are unique attributes
dm_final.index.is_unique
# Out:
# True

# %%
# remove duplicate rows
dm_final = dm_final[~dm_final.index.duplicated(keep="first")]

# %%
dm_final = dm_final.loc[~dm_final.duplicated(subset="Attribute", keep="first")]
dm_final = dm_final.set_index('Attribute')

# %%
dm_final.shape
# Out:
# (730, 15)

# %%
dm_final = dm_final.sort_index(key=lambda x: x.str.lower())

# %%
# no longer need column
dm_final = dm_final.drop(columns=["OtherValue"], errors='ignore')

# %%
# Write out data model
dm_final.to_csv('../EL.data.model.csv')

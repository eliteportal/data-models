# %%
import pandas as pd
import numpy as np
import os

import urllib
from glob import glob
import yaml
import re
import copy
import json
import requests
from tqdm import tqdm
from requests.exceptions import HTTPError

from utils import utils

# %% [markdown]
# - OWL ontologies
# - Websites:
#   - OLS
#   - Ontobee

# %% [markdown]
# # Functions

# %%
# Clean list columns into single string
def join_strings(string):
    try:
        return ",".join(string)
    except:
        return ""


def sort_lists(l):
    try:
        return ",".join(sorted(np.unique(l)))
    except:
        return l


validation_coder = {
    "number": "regex search ([0-9]+\.[0-9]*.?)|([0-9]+)",
    "integer": "regex search ([0-9]+)",
    "string": "",
}

# %%
# parse url into api call
def url_to_api_call(url):
    url = url.replace("ols4", "ols4/api")

    test = urllib.parse.urlparse(url)

    url_parts = list(urllib.parse.urlparse(url))

    iri = urllib.parse.parse_qs(test.query)["iri"][0]

    new_iri = urllib.parse.quote_plus(urllib.parse.quote_plus(iri))

    url_parts[2] = url_parts[2].replace("classes", "terms")

    url_parts[2] = "/".join([url_parts[2], new_iri])

    url_parts[4] = ""

    new_url = urllib.parse.urlunparse(url_parts)

    return new_url

# %%
def get_response(u, params=None):
    """_summary_

    Args:
        u (_type_): _description_
        params (_type_, optional): _description_. Defaults to None.

    Returns:
        _type_: _description_
    """
    try:
        response = requests.get(u, params=params)

        # If the response was successful, no Exception will be raised
        response.raise_for_status()

    except HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")  # Python 3.6
    except Exception as err:
        print(f"Other error occurred: {err}")  # Python 3.6
    else:
        print(response)
        return response

# %% [markdown]
# # Pull in current data model

# %%
dm = utils.load_and_backup_dm("../EL.data.model.csv", output_dir="../backups")

# these ontologies are too large
indexes = dm[
    dm["Source"].str.contains(
        "https://www.ebi.ac.uk/ols4/ontologies/mondo|https://www.ebi.ac.uk/ols4/ontologies/maxo|https://www.ebi.ac.uk/ols4/ontologies/hp",
        regex=True,
        na=False,
    )
].index.tolist()

dm.loc[indexes, "Valid Values"] = np.nan
dm.loc[indexes, "Description"] = (
    dm.loc[indexes, "Description"] + " Please see the source ontology."
)
dm.loc[indexes, "Validation Rules"] = "str"

dm.loc[dm["Properties"] == "Valid Value", "Validation Rules"] = np.nan

dm["Required"] = dm["Required"].replace("False,True", "True")

dm["Source"] = dm["Source"].replace(
    "https://ontobee.org/ontology/NCITiri=http://purl.obolibrary.org/obo/NCIT_C62690https://www.ebi.ac.uk/ols4/ontologies/edam/terms?iri=http%3A%2F%2Fedamontology.org%2Fdata_1045",
    "https://ontobee.org/ontology/NCITiri=http://purl.obolibrary.org/obo/NCIT_C62690, https://www.ebi.ac.uk/ols4/ontologies/edam/terms?iri=http%3A%2F%2Fedamontology.org%2Fdata_1045",
)

dm = dm.replace("-The%20life%20stage", "", regex=True)

# %%
# Attributes with ontologies
dm_test = dm[
    (
        dm["Source"]
        .fillna("")
        .str.contains("http", regex=True, flags=re.IGNORECASE, na=False)
    )
    & (dm["Source"].str.contains("purl|ebi", regex=True, na=False))
    & (
        dm["Valid Values"].str.contains(
            "not", flags=re.IGNORECASE, regex=True, na=False
        )
    )
].reset_index(drop=True)

dm_test["Source"] = dm_test["Source"].str.replace("ols", "ols4", regex=True)
dm_test["Source"] = dm_test["Source"].str.replace(
    "terms", "terms?", regex=True)

dm_test["Valid Values"] = dm_test["Valid Values"].str.split(",")

with pd.option_context("display.max_colwidth", None):
    display(dm_test)
# Out:
#                     Attribute  \
# 0             acquisitionMode
# 1         acquisitionSoftware
# 2                    cellType
# 3                  commonName
# 4                databaseName
# 5              databaseSource
# 6                   diagnosis
# 7            extractionMethod
# 8                   lifeStage
# 9      modificationParameters
# 10              msAnalyteType
# 11                      organ
# 12        protoemicsAssayType
# 13                        sex
# 14               speciesGroup
# 15                speciesName
# 16             specimenSource
# 17               specimenType
# 18                      taxon
# 19  technologyPlatformVersion
# 20                     tissue
#
#                                                                                                                                                               Description  \
# 0                          The specific aspect of a mass spectrometer method by which mass ranges are selected and possibly dissociated (full scan, MSn, SIM, MRM, etc.).
# 1                                                                                                                               The name of the acquisition software used
# 2                                                                                                                                                Indicate the cell type.
# 3    The biological species common name the individual belongs to (ex. "Horned Lark").note: As a default, the valid scientific name for the species should be indicated.
# 4                                                                             The name of the search database (nr, SwissProt or est_human, and/or mass spectral library).
# 5                                                   The name of the organization, project, or laboratory from where the database is obtained (UniProt, NCBI, EBI, other).
# 6                                                                                                                                      Indicate the disease or condition.
# 7                                                                    The name of the process used to separate a desired component of an input material from the remainder
# 8   The life stage of the individual. note: Other values are possible depending on life stage terminology for individual species. Please let the data curation team know.
# 9                                                                      Modification parameters for the search engine run. [ PSI: PI http://www.w3.org/2002/07/owl#Axiom ]
# 10                                                                                                                          the type of biospecimen subjected to analysis
# 11                                                                                                                                Indicate the organ the specimen is from
# 12                                                                                                                   Type of peptide quantification used (ex. Label Free)
# 13                                                                                                                                   The biological sex of the individual
# 14                                                                                 The taxonomic ranking including both species and subspecies the individual belongs to.
# 15                                                The scientific name of the species (typically a taxonomic group, ex. "Eremophila alpestris") the individual belongs to.
# 16                                                                                                                           Indicate the biological area of the specimen
# 17                                                                                                                    Type of biological material comprising the Specimen
# 18                                                        Taxonomic identifier. The National Center for Biotechnology Information taxon ID (formatted as, ex. "txid9989")
# 19                 The specific version (application, manufacturer, model, lab, etc.) of a technology that is used to carry out a laboratory or computational experiment.
# 20                                                                           Type of biological material comprising the Specimen,Indicate the tissue the specimen is from
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Valid Values  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [Not Specified, Not applicable, Not collected, Unknown]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [Not Specified, Not applicable, Not collected, Unknown]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [Not applicable, Not collected, OtherCellType, Unknown]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [Not applicable, Not collected, Unknown]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [HMDB, MassBank of North America (MoNA), Metlin, NIST17, Not Specified, Not applicable, Not collected, OtherDatabaseNameDatabaseName, Unknown]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [Not Specified, Not applicable, Not collected, OtherDatabaseSourceDatabaseSource, Unknown]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [Not applicable, Not collected, OtherDiagnosis, Unknown]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [Not Specified, Not applicable, Not collected, OtherExtractionMethodExtractionMethod, Unknown]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [Adult, Juvenile, Not applicable, Not collected, OtherLifeStage, Post-Juvenile, Unknown]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [Not Specified, Not applicable, Not collected, OtherModificationParametersModificationParameters, Unknown]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [Lipid, Not Specified, Not applicable, Not collected, OtherMsAnalyteType, Protein, Unknown, metabolite]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [Not applicable, Not collected, OtherOrgan, Unknown]
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [ITRAQ, Label Free, Not applicable, Not collected, OtherProtoemicsAssayType, SILAC, TMT, Targeted Absolute Quantitation, Unknown]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [Female, Male, Not applicable, Not collected, OtherSex, Unknown]
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [Bird, Human, Mammal, Not applicable, Not collected, OtherSpeciesGroup, Primate, Rodent, Unknown]
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [Not applicable, Not collected, Unknown]
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [Not applicable, Not collected, OtherSpecimenSource, Unknown]
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [Cerebrospinal Fluid (CSF), Not applicable, Not collected, OtherSpecimenType, Plasma, Saliva, Serum, Sputum, Unknown, Urine, blood, organoid, stool, swabs, tissue]
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [Not applicable, Not collected, Unknown]
# 19  [10x Visium Spatial Gene Expression, Affymetrix Genome-Wide Human SNP 5.0 Array, Affymetrix Genome-Wide Human SNP 6.0 Array, Affymetrix Human Gene 1.0 ST Array, Affymetrix Human Genome U133 Plus 2.0 Array, Affymetrix U133AB, Agilent 44Karray, BGISEQ-500, Bionano Irys, Cherry Imaging FACE Platform, Cherry Imaging TRACE Platform, Chromium X, EnVision 2103 Multiplate Reader, Illumina 1M, Illumina Genome Analyzer IIx, Illumina HiSeq 2000, Illumina HiSeq 2500, Illumina HiSeq 3000, Illumina HiSeq 4000, Illumina HiSeq X, Illumina Human660W-Quad v1.0 BeadChip, Illumina HumanHap300, Illumina HumanMethylation450, Illumina HumanOmni1-Quadv1.0, Illumina HumanOmniExpress-24 v1.0 BeadChip, Illumina HumanOmniExpress-24 v1.2 BeadChip, Illumina Infinium MethylationEPIC BeadChip v1.0 (850k), Illumina Infinium MethylationEPIC BeadChip v2.0 (935k)Illumina MiSeq, Illumina MouseWG-6 v2.0 expression BeadChip, Illumina NextSeq 1000, Illumina NextSeq 2000, Illumina NextSeq 500, Illumina NextSeq 550, Illumina NovaSeq 6000, Illumina Omni2pt5M, Illumina Omni5M, Illumina WholeGenome DASL, Illumina h650, Infinium HumanOmniExpressExome, LI-COR Odyssey CLx, LTQ Orbitrap XL, LifeViz Infinity System, LifeViz Micro System, Nanostring Counter, Nanostring GeoMx, Not Specified, Not applicable, Not collected, Olympus DP80, Orbitrap Fusion Lumos Tribrid, OtherTechnologyPlatformVersionTechnologyPlatformVersion, PacBio RS II, PacBio Sequel II System, PacBio Sequel IIe System, Perlegen 300Karray, Promega GloMax Discover, Q Exative HF, Spectramax M Series, Unknown, Vectra H1 3D Imaging System, Vevo 3100 Imaging System, Zeiss LSM 980, scale]
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [Not applicable, Not collected, OtherTissue, Unknown]
#
#    Required DependsOn  DependsOn Component    Properties Validation Rules  \
# 0      True       NaN                  NaN   unspecified              NaN
# 1      True       NaN                  NaN   unspecified              NaN
# 2      True       NaN                  NaN   unspecified              NaN
# 3      True       NaN                  NaN   unspecified              NaN
# 4      True       NaN                  NaN   unspecified              NaN
# 5      True       NaN                  NaN   unspecified              NaN
# 6     False       NaN                  NaN  DataProperty              NaN
# 7      True       NaN                  NaN   unspecified              NaN
# 8      True       NaN                  NaN   unspecified              NaN
# 9      True       NaN                  NaN   unspecified              NaN
# 10    False       NaN                  NaN  DataProperty              NaN
# 11     True       NaN                  NaN   unspecified              NaN
# 12     True       NaN                  NaN   unspecified              NaN
# 13     True       NaN                  NaN   unspecified              NaN
# 14     True       NaN                  NaN   unspecified              NaN
# 15     True       NaN                  NaN   unspecified              NaN
# 16     True       NaN                  NaN   unspecified              NaN
# 17     True       NaN                  NaN   unspecified              NaN
# 18     True       NaN                  NaN   unspecified              NaN
# 19     True       NaN                  NaN   unspecified              NaN
# 20     True       NaN                  NaN    ValidValue              NaN
#
#                                                                                   Template  \
# 0                                                            Metabolomics Human,Proteomics
# 1                                                            Metabolomics Human,Proteomics
# 2                                                   Biospecimen human,Biospecimen nonHuman
# 3                                                                      Individual nonHuman
# 4                                                            Metabolomics Human,Proteomics
# 5                                                            Metabolomics Human,Proteomics
# 6                                                                         Individual Human
# 7                                                            Metabolomics Human,Microbiome
# 8                                                                      Individual nonHuman
# 9                                                                               Proteomics
# 10                                                           Metabolomics Human,Proteomics
# 11                                                  Biospecimen human,Biospecimen nonHuman
# 12                                                                              Proteomics
# 13                                                    Individual Human,Individual nonHuman
# 14                                                    Individual Human,Individual nonHuman
# 15                                                                     Individual nonHuman
# 16                                                  Biospecimen human,Biospecimen nonHuman
# 17                                                  Biospecimen human,Biospecimen nonHuman
# 18                                                                     Individual nonHuman
# 19  Metabolomics Human,Microbiome,Proteomics,RNAseq,Whole Genome Sequencing,bsSeq,scRNAseq
# 20                                                  Biospecimen human,Biospecimen nonHuman
#
#          Parent  \
# 0   unspecified
# 1   unspecified
# 2   unspecified
# 3   unspecified
# 4   unspecified
# 5   unspecified
# 6   unspecified
# 7   unspecified
# 8   unspecified
# 9   unspecified
# 10  unspecified
# 11  unspecified
# 12  unspecified
# 13  unspecified
# 14  unspecified
# 15  unspecified
# 16  unspecified
# 17  unspecified
# 18  unspecified
# 19  unspecified
# 20  unspecified
#
#                                                                                                                                                                                                          Source  \
# 0                                                                                                        https://www.ebi.ac.uk/ols4/ontologies/ms/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMS_1003213
# 1                                                                                                                                                                     http://purl.obolibrary.org/obo/MS_1001455
# 2      https://bioportal.bioontology.org/ontologies/CCF/p=classes&conceptid=http%3A%2F%2Fpurl.org%2Fccf%2Fcell_type,https://www.ebi.ac.uk/ols4/ontologies/ccf/terms?iri=http%3A%2F%2Fpurl.org%2Fccf%2Fcell_type
# 3                                                                                                                https://www.ebi.ac.uk/ols4/ontologies/edam/terms?iri=http%3A%2F%2Fedamontology.org%2Fdata_1874
# 4                                                                                                                                                                     http://purl.obolibrary.org/obo/MS_1001013
# 5                                                                                                                                                                     http://purl.obolibrary.org/obo/MS_1001012
# 6                                                                               https://www.ebi.ac.uk/ols4/ontologies/hp,https://www.ebi.ac.uk/ols4/ontologies/maxo,https://www.ebi.ac.uk/ols4/ontologies/mondo
# 7                                                                                                                                                                    http://purl.obolibrary.org/obo/OBI_0302884
# 8   -The%20life%20stage,Biological Collections Ontology,https://www.animalaudiograms.org/audiogram_metadata_scheme#:~:text=range%3A%20female%3B%20male-,https://www.ebi.ac.uk/ols4/ontologies/pato,life%20stage
# 9                                                                                                        https://www.ebi.ac.uk/ols4/ontologies/ms/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMS_1001055
# 10                                                                                                                                                                  http://purl.obolibrary.org/obo/NCIT_C156434
# 11                                                                                                                                                                   http://purl.obolibrary.org/obo/NCIT_C13018
# 12                                              DSLWG,Sage Bionetworks,https://www.ebi.ac.uk/ols4/ontologies/pride/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPRIDE_0000514&viewMode=All&siblings=false
# 13                                                                                                    Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C28421,https://www.synapse.org/#!Synapse:syn25878249
# 14                                https://ontobee.org/ontology/NCITiri=http://purl.obolibrary.org/obo/NCIT_C62690https://www.ebi.ac.uk/ols4/ontologies/edam/terms?iri=http%3A%2F%2Fedamontology.org%2Fdata_1045
# 15                                                                                                               https://www.ebi.ac.uk/ols4/ontologies/edam/terms?iri=http%3A%2F%2Fedamontology.org%2Fdata_1045
# 16                                                   https://www.ebi.ac.uk/ols4/ontologies/ccf/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FUBERON_0004537&lang=en&viewMode=PreferredRoots&siblings=false
# 17                                                                                                                                                  Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C70713
# 18                                                                                       http://edamontology.org/data_1179,http://purl.obolibrary.org/obo/TAXRANK_0000010,https://www.ncbi.nlm.nih.gov/taxonomy
# 19                                                                                                                                                  Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C45378
# 20                                                                                                       Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C12801,http://purl.obolibrary.org/obo/NCIT_C70713
#
#              Type  \
# 0          STRING
# 1          STRING
# 2          STRING
# 3          STRING
# 4          STRING
# 5          STRING
# 6          STRING
# 7          STRING
# 8          STRING
# 9          STRING
# 10         STRING
# 11         STRING
# 12         STRING
# 13         STRING
# 14         STRING
# 15         STRING
# 16         STRING
# 17         STRING
# 18         STRING
# 19         STRING
# 20  STRING,STRING
#
#                                                                                                                                                                                                       Ontology  \
# 0                                                                                                         https://www.ebi.ac.uk/ols/ontologies/ms/termsiri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMS_1003213
# 1                                                                                                                                                                    http://purl.obolibrary.org/obo/MS_1001455
# 2       https://bioportal.bioontology.org/ontologies/CCF/p=classes&conceptid=http%3A%2F%2Fpurl.org%2Fccf%2Fcell_type,https://www.ebi.ac.uk/ols/ontologies/ccf/termsiri=http%3A%2F%2Fpurl.org%2Fccf%2Fcell_type
# 3                                                                                                                 https://www.ebi.ac.uk/ols/ontologies/edam/termsiri=http%3A%2F%2Fedamontology.org%2Fdata_1874
# 4                                                                                                                                                                    http://purl.obolibrary.org/obo/MS_1001013
# 5                                                                                                                                                                    http://purl.obolibrary.org/obo/MS_1001012
# 6                                                                                 https://www.ebi.ac.uk/ols/ontologies/hp,https://www.ebi.ac.uk/ols/ontologies/maxo,https://www.ebi.ac.uk/ols/ontologies/mondo
# 7                                                                                                                                                                   http://purl.obolibrary.org/obo/OBI_0302884
# 8   -The%20life%20stage,Biological Collections Ontology,https://www.animalaudiograms.org/audiogram_metadata_scheme#:~:text=range%3A%20female%3B%20male-,https://www.ebi.ac.uk/ols/ontologies/pato,life%20stage
# 9                                                                                                         https://www.ebi.ac.uk/ols/ontologies/ms/termsiri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMS_1001055
# 10                                                                                                                                                                 http://purl.obolibrary.org/obo/NCIT_C156434
# 11                                                                                                                                                                  http://purl.obolibrary.org/obo/NCIT_C13018
# 12                                               DSLWG,Sage Bionetworks,https://www.ebi.ac.uk/ols/ontologies/pride/termsiri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPRIDE_0000514&viewMode=All&siblings=false
# 13                                                                                                   Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C28421,https://www.synapse.org/#!Synapse:syn25878249
# 14                                 https://ontobee.org/ontology/NCITiri=http://purl.obolibrary.org/obo/NCIT_C62690https://www.ebi.ac.uk/ols/ontologies/edam/termsiri=http%3A%2F%2Fedamontology.org%2Fdata_1045
# 15                                                                                                                https://www.ebi.ac.uk/ols/ontologies/edam/termsiri=http%3A%2F%2Fedamontology.org%2Fdata_1045
# 16                                                    https://www.ebi.ac.uk/ols/ontologies/ccf/termsiri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FUBERON_0004537&lang=en&viewMode=PreferredRoots&siblings=false
# 17                                                                                                                                                 Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C70713
# 18                                                                                      http://edamontology.org/data_1179,http://purl.obolibrary.org/obo/TAXRANK_0000010,https://www.ncbi.nlm.nih.gov/taxonomy
# 19                                                                                                                                                 Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C45378
# 20                                                                                                      Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C12801,http://purl.obolibrary.org/obo/NCIT_C70713
#
#     multivalue        UsedIn module
# 0        False           NaN    NaN
# 1        False           NaN    NaN
# 2        False           NaN    NaN
# 3        False           NaN    NaN
# 4        False           NaN    NaN
# 5        False           NaN    NaN
# 6         True           NaN    NaN
# 7        False           NaN    NaN
# 8        False           NaN    NaN
# 9        False           NaN    NaN
# 10       False           NaN    NaN
# 11       False           NaN    NaN
# 12       False           NaN    NaN
# 13       False           NaN    NaN
# 14       False           NaN    NaN
# 15       False           NaN    NaN
# 16       False           NaN    NaN
# 17        True           NaN    NaN
# 18       False           NaN    NaN
# 19  False,True           NaN    NaN
# 20       False  specimenType    NaN

# %% [markdown]
# # OLS
#
# https://www.ebi.ac.uk/ols4/help
# replace ols with ols4

# %%
# to use for searching ols4 for terms
base_url = "http://www.ebi.ac.uk/ols4/api/terms"

# %% [markdown]
# ## Functions

# %% [markdown]
# purl case

# %%
def simplify_response(response):
    """Get the terms from the response. Helps to simplify parsing the json"""

    j = response.json()["_embedded"]["terms"]

    if len(j) == 1:
        return j[0]
    else:
        print(f"Response has {len(j)} terms")
        return j


def iri_request(iri):
    """Get call to iri site"""
    response = get_response(base_url, params={"iri": iri})

    return response


def get_iri(url):
    """Extract iri from url"""
    test = urllib.parse.urlparse(url)

    params = urllib.parse.parse_qs(test.query)

    iri = params["iri"][0]

    return iri


def find_defining_ontology(terms):
    """look for defining ontology"""
    if len(terms) > 1:
        for t in terms:
            if t["is_defining_ontology"] == True:
                return t
            else:
                pass
    elif len(terms) == 1:
        return terms[0]
    else:
        return None


# term = find_defining_ontology(terms)
# term.


def get_all_terms(url, json_response):
    """get all terms from pages"""
    pages = json_response["page"]["totalPages"]
    size = json_response["page"]["size"]

    # get the original link
    # url = json_response['_links']['self']['href']

    terms_list = []

    for i in tqdm(range(pages)):
        response = requests.get(url, params={"page": i, "size": size})

        temp_d = response.json()

        for term in temp_d["_embedded"]["terms"]:
            terms_list.append(term)

    print("Length of terms: ", len(terms_list), sep="\t")

    return terms_list


# terms_list = get_all_terms(url, json_response)
def get_labels_from_terms_list(terms_list):
    vv = []

    for t in terms_list:
        # if t['has_children'] == False:
        vv.append(t)

    labels = []

    for i in vv:
        labels.append(i["label"])

    labels = sorted(np.unique(labels))

    return labels


def purl_main(iri):
    response = iri_request(iri)
    json_response = response.json()
    terms = json_response["_embedded"]["terms"]
    term = find_defining_ontology(terms)

    # get descendants
    url = term["_links"]["hierarchicalDescendants"]["href"]
    d = get_response(url)
    json_response = d.json()

    terms_list = get_all_terms(url, json_response)

    valid_values = get_labels_from_terms_list(terms_list)

    return valid_values

# %% [markdown]
# # Start extraction

# %%
with pd.option_context("display.max_colwidth", 0):
    display(dm_test.iloc[4, :])
# Out:
# Attribute              databaseName
# Description            The name of the search database (nr, SwissProt or est_human, and/or mass spectral library).
# Valid Values           [HMDB, MassBank of North America (MoNA), Metlin, NIST17, Not Specified, Not applicable, Not collected, OtherDatabaseNameDatabaseName, Unknown]
# Required               True
# DependsOn              NaN
# DependsOn Component    NaN
# Properties             unspecified
# Validation Rules       NaN
# Template               Metabolomics Human,Proteomics
# Parent                 unspecified
# Source                 http://purl.obolibrary.org/obo/MS_1001013
# Type                   STRING
# Ontology               http://purl.obolibrary.org/obo/MS_1001013
# multivalue             False
# UsedIn                 NaN
# module                 NaN
# Name: 4, dtype: object

# %%
# {
#     # could replace with this link to get higher level terms
#     "https://www.ebi.ac.uk/ols4/ontologies/maxo": "http://purl.obolibrary.org/obo/MONDO_0700096"
# }

# dm_test["Source"] = dm_test["Source"].str.replace(
#     "https://www.ebi.ac.uk/ols4/ontologies/mondo|https://www.ebi.ac.uk/ols4/ontologies/maxo|https://www.ebi.ac.uk/ols4/ontologies/hp",
#     "LLFS data dictionary",
#     regex=True,
# )

# %%
dm_test["purl"] = (
    dm_test["Source"]
    .str.split(",")
    .apply(
        lambda x: sorted(
            np.unique([y for y in x if bool(re.search("ebi|purl", y))]))
    )
)

# %%
other_vvs = ["Other", "Unknown", "Not Available", "Not Given"]

# %%
dm.query('Attribute.str.contains("diagnosis")', engine="python")
# Out:
#            Attribute                                        Description  \
# 395        diagnosis                 Indicate the disease or condition.
# 396  diagnosisStatus  Whether the individual has been diagnosed with...
#
#                                           Valid Values Required DependsOn  \
# 395  Not applicable,Not collected,OtherDiagnosis,Un...    False       NaN
# 396  False,Not applicable,Not collected,TrueDiagnos...     True       NaN
#
#      DependsOn Component    Properties Validation Rules          Template  \
# 395                  NaN  DataProperty              NaN  Individual Human
# 396                  NaN   unspecified              NaN  Individual Human
#
#           Parent                                             Source    Type  \
# 395  unspecified  https://www.ebi.ac.uk/ols/ontologies/hp,https:...  STRING
# 396  unspecified                                   Sage Bionetworks  STRING
#
#                                               Ontology multivalue UsedIn  \
# 395  https://www.ebi.ac.uk/ols/ontologies/hp,https:...       True    NaN
# 396                                   Sage Bionetworks       True    NaN
#
#     module
# 395    NaN
# 396    NaN

# %% [markdown]
# ## Main extraction

# %%
dm_test["extraction_status"] = ""

errors = []

for i, v in dm_test.iterrows():
    storage = dm_test.loc[i, "Valid Values"]
    for url in v["purl"]:
        print(url)
        # for world countries
        if dm_test.at[i, "extraction_status"] == "done":
            next
        else:
            if (
                url
                == "https://wits.worldbank.org/countryprofile/metadata/en/country/all"
            ):
                x = pd.read_excel(
                    io="http://wits.worldbank.org/data/public/WITSCountryProfile-Country_Indicator_ProductMetada-en.xlsx",
                    sheet_name="Country-Metadata",
                )

                dm_test.at[i, "Valid Values"] = sorted(
                    storage + x["Country Code"].tolist()
                )

                dm_test.at[i, "extraction_status"] = "done"

            elif "terms" in url and "ebi.ac.uk" in url:
                url = url_to_api_call(url)

                result = get_response(url)

                try:
                    json_result = result.json()

                    url_descendents = json_result["_links"]["hierarchicalDescendants"][
                        "href"
                    ]

                    json_result = get_response(url_descendents).json()

                    terms_list = get_all_terms(url_descendents, json_result)

                    result = get_labels_from_terms_list(terms_list)

                    dm_test.at[i, "Valid Values"] = sorted(storage + result)

                    dm_test.at[i, "extraction_status"] = "done"

                except Exception as e:
                    dm_test.at[i, "extraction_status"] = "error"
                    print(e)
                    next

            elif "http://purl" in url:
                try:
                    result = purl_main(url)

                    dm_test.at[i, "Valid Values"] = sorted(storage + result)

                    dm_test.at[i, "extraction_status"] = "done"
                except Exception as e:
                    print(e)

            else:
                dm_test.at[i, "extraction_status"] = "error"
                print("Error")
                errors.append(url)

        print("-" * 20)

dm_test["Valid Values"] = (
    dm_test["Valid Values"].apply(lambda x: ",".join(x)).apply(utils.clean_list)
)

errors
# Out:
# https://www.ebi.ac.uk/ols4/ontologies/ms/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMS_1003213
# <Response [200]>
# <Response [200]>
# 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# Length of terms: 	8
# --------------------
# http://purl.obolibrary.org/obo/MS_1001455
# <Response [200]>
# <Response [200]>
# 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# Length of terms: 	25
# --------------------
# https://bioportal.bioontology.org/ontologies/CCF/p=classes&conceptid=http%3A%2F%2Fpurl.org%2Fccf%2Fcell_type
# Error
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/ccf/terms?iri=http%3A%2F%2Fpurl.org%2Fccf%2Fcell_type
# <Response [200]>
# <Response [200]>
# 100%|██████████| 67/67 [01:28<00:00,  1.32s/it]
# Length of terms: 	1321
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/edam/terms?iri=http%3A%2F%2Fedamontology.org%2Fdata_1874
# <Response [200]>
# 'hierarchicalDescendants'
# --------------------
# http://purl.obolibrary.org/obo/MS_1001013
# <Response [200]>
# <Response [200]>
# 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# Length of terms: 	11
# --------------------
# http://purl.obolibrary.org/obo/MS_1001012
# <Response [200]>
# <Response [200]>
# 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# Length of terms: 	3
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/hp
# Error
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/maxo
# Error
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/mondo
# Error
# --------------------
# http://purl.obolibrary.org/obo/OBI_0302884
# <Response [200]>
# <Response [200]>
# 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# Length of terms: 	10
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/pato
# Error
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/ms/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMS_1001055
# <Response [200]>
# <Response [200]>
# 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Length of terms: 	21
# --------------------
# http://purl.obolibrary.org/obo/NCIT_C156434
# <Response [200]>
# <Response [200]>
# 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
# Length of terms: 	1
# --------------------
# http://purl.obolibrary.org/obo/NCIT_C13018
# <Response [200]>
# <Response [200]>
# 100%|██████████| 18/18 [00:21<00:00,  1.20s/it]
# Length of terms: 	359
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/pride/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPRIDE_0000514&viewMode=All&siblings=false
# HTTP error occurred: 404 Client Error:  for url: https://www.ebi.ac.uk/ols4/api/ontologies/pride/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FPRIDE_0000514
# 'NoneType' object has no attribute 'json'
# --------------------
# http://purl.obolibrary.org/obo/NCIT_C28421
# <Response [200]>
# <Response [200]>
# 100%|██████████| 1/1 [00:00<00:00,  1.46it/s]
# Length of terms: 	2
# --------------------
# https://ontobee.org/ontology/NCITiri=http://purl.obolibrary.org/obo/NCIT_C62690https://www.ebi.ac.uk/ols4/ontologies/edam/terms?iri=http%3A%2F%2Fedamontology.org%2Fdata_1045
# HTTP error occurred: 500 Server Error: Internal Server Error for url: https://ontobee.org/ontology/NCITiri=http://purl.obolibrary.org/obo/NCIT_C62690https://www.ebi.ac.uk/ols4/api/ontologies/edam/terms/http%253A%252F%252Fedamontology.org%252Fdata_1045
# 'NoneType' object has no attribute 'json'
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/edam/terms?iri=http%3A%2F%2Fedamontology.org%2Fdata_1045
# <Response [200]>
# 'hierarchicalDescendants'
# --------------------
# https://www.ebi.ac.uk/ols4/ontologies/ccf/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FUBERON_0004537&lang=en&viewMode=PreferredRoots&siblings=false
# <Response [200]>
# <Response [200]>
# 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# Length of terms: 	22
# --------------------
# http://purl.obolibrary.org/obo/NCIT_C70713
# <Response [200]>
# <Response [200]>
# 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Length of terms: 	17
# --------------------
# http://purl.obolibrary.org/obo/TAXRANK_0000010
# <Response [200]>
# 'hierarchicalDescendants'
# --------------------
# http://purl.obolibrary.org/obo/NCIT_C45378
# <Response [200]>
# 'hierarchicalDescendants'
# --------------------
# http://purl.obolibrary.org/obo/NCIT_C12801
# <Response [200]>
# <Response [200]>
# 100%|██████████| 26/26 [00:31<00:00,  1.20s/it]
# Length of terms: 	507
# --------------------
# http://purl.obolibrary.org/obo/NCIT_C70713
# --------------------
# ['https://bioportal.bioontology.org/ontologies/CCF/p=classes&conceptid=http%3A%2F%2Fpurl.org%2Fccf%2Fcell_type',
#  'https://www.ebi.ac.uk/ols4/ontologies/hp',
#  'https://www.ebi.ac.uk/ols4/ontologies/maxo',
#  'https://www.ebi.ac.uk/ols4/ontologies/mondo',
#  'https://www.ebi.ac.uk/ols4/ontologies/pato']

# %%
no_vvs = ["diagnosis", "extractionMethod", "taxon", "commonName"]
dm_test.loc[dm_test["Attribute"].isin(no_vvs), "Valid Values"] = np.nan

# %%
# dm_test['Required'] = dm_test['Required'].replace('False,True', 'True')

# %%
# drop extra columns
dm_test = dm_test.drop(columns=["purl", "extraction_status"])

# %%
# join new valid values df with current dm
dm_test
# Out:
#                     Attribute  \
# 0             acquisitionMode
# 1         acquisitionSoftware
# 2                    cellType
# 3                  commonName
# 4                databaseName
# 5              databaseSource
# 6                   diagnosis
# 7            extractionMethod
# 8                   lifeStage
# 9      modificationParameters
# 10              msAnalyteType
# 11                      organ
# 12        protoemicsAssayType
# 13                        sex
# 14               speciesGroup
# 15                speciesName
# 16             specimenSource
# 17               specimenType
# 18                      taxon
# 19  technologyPlatformVersion
# 20                     tissue
#
#                                           Description  \
# 0   The specific aspect of a mass spectrometer met...
# 1           The name of the acquisition software used
# 2                            Indicate the cell type.
# 3   The biological species common name the individ...
# 4   The name of the search database (nr, SwissProt...
# 5   The name of the organization, project, or labo...
# 6                  Indicate the disease or condition.
# 7   The name of the process used to separate a des...
# 8   The life stage of the individual. note: Other ...
# 9   Modification parameters for the search engine ...
# 10      the type of biospecimen subjected to analysis
# 11            Indicate the organ the specimen is from
# 12  Type of peptide quantification used (ex. Label...
# 13               The biological sex of the individual
# 14  The taxonomic ranking including both species a...
# 15  The scientific name of the species (typically ...
# 16       Indicate the biological area of the specimen
# 17  Type of biological material comprising the Spe...
# 18  Taxonomic identifier. The National Center for ...
# 19  The specific version (application, manufacture...
# 20  Type of biological material comprising the Spe...
#
#                                          Valid Values Required DependsOn  \
# 0   Not Specified,Not applicable,Not collected,Unk...     True       NaN
# 1   4000 Series Explorer Software,4700 Explorer,63...     True       NaN
# 2   A2 amacrine cell,Acinar cell,Adipocyte,Afferen...     True       NaN
# 3                                                 NaN     True       NaN
# 4   HMDB,MassBank of North America (MoNA),Metlin,N...     True       NaN
# 5   DB source EBI,DB source NCBI,DB source UniProt...     True       NaN
# 6                                                 NaN    False       NaN
# 7                                                 NaN     True       NaN
# 8   Adult,Juvenile,Not applicable,Not collected,Ot...     True       NaN
# 9   Fixed modification,H2O neutral loss,H3PO4 neut...     True       NaN
# 10  Lipid,Molecular Test Analyte Type,Not Specifie...    False       NaN
# 11  Abdominal Skin,Accessory Lacrimal Gland,Adrena...     True       NaN
# 12  ITRAQ,Label Free,Not applicable,Not collected,...     True       NaN
# 13  Female,Male,Not applicable,Not collected,Other...     True       NaN
# 14  Bird,Human,Mammal,Not applicable,Not collected...     True       NaN
# 15               Not applicable,Not collected,Unknown     True       NaN
# 16  Afferent Arteriole Endothelial Cell,Ascending ...     True       NaN
# 17  Analyte Type,Cerebrospinal Fluid (CSF),Cytolog...     True       NaN
# 18                                                NaN     True       NaN
# 19  10x Visium Spatial Gene Expression,Affymetrix ...     True       NaN
# 20  Abdominal Peritoneum,Accessory Tissue,Acinar S...     True       NaN
#
#     DependsOn Component    Properties Validation Rules  \
# 0                   NaN   unspecified              NaN
# 1                   NaN   unspecified              NaN
# 2                   NaN   unspecified              NaN
# 3                   NaN   unspecified              NaN
# 4                   NaN   unspecified              NaN
# 5                   NaN   unspecified              NaN
# 6                   NaN  DataProperty              NaN
# 7                   NaN   unspecified              NaN
# 8                   NaN   unspecified              NaN
# 9                   NaN   unspecified              NaN
# 10                  NaN  DataProperty              NaN
# 11                  NaN   unspecified              NaN
# 12                  NaN   unspecified              NaN
# 13                  NaN   unspecified              NaN
# 14                  NaN   unspecified              NaN
# 15                  NaN   unspecified              NaN
# 16                  NaN   unspecified              NaN
# 17                  NaN   unspecified              NaN
# 18                  NaN   unspecified              NaN
# 19                  NaN   unspecified              NaN
# 20                  NaN    ValidValue              NaN
#
#                                              Template       Parent  \
# 0                       Metabolomics Human,Proteomics  unspecified
# 1                       Metabolomics Human,Proteomics  unspecified
# 2              Biospecimen human,Biospecimen nonHuman  unspecified
# 3                                 Individual nonHuman  unspecified
# 4                       Metabolomics Human,Proteomics  unspecified
# 5                       Metabolomics Human,Proteomics  unspecified
# 6                                    Individual Human  unspecified
# 7                       Metabolomics Human,Microbiome  unspecified
# 8                                 Individual nonHuman  unspecified
# 9                                          Proteomics  unspecified
# 10                      Metabolomics Human,Proteomics  unspecified
# 11             Biospecimen human,Biospecimen nonHuman  unspecified
# 12                                         Proteomics  unspecified
# 13               Individual Human,Individual nonHuman  unspecified
# 14               Individual Human,Individual nonHuman  unspecified
# 15                                Individual nonHuman  unspecified
# 16             Biospecimen human,Biospecimen nonHuman  unspecified
# 17             Biospecimen human,Biospecimen nonHuman  unspecified
# 18                                Individual nonHuman  unspecified
# 19  Metabolomics Human,Microbiome,Proteomics,RNAse...  unspecified
# 20             Biospecimen human,Biospecimen nonHuman  unspecified
#
#                                                Source           Type  \
# 0   https://www.ebi.ac.uk/ols4/ontologies/ms/terms...         STRING
# 1           http://purl.obolibrary.org/obo/MS_1001455         STRING
# 2   https://bioportal.bioontology.org/ontologies/C...         STRING
# 3   https://www.ebi.ac.uk/ols4/ontologies/edam/ter...         STRING
# 4           http://purl.obolibrary.org/obo/MS_1001013         STRING
# 5           http://purl.obolibrary.org/obo/MS_1001012         STRING
# 6   https://www.ebi.ac.uk/ols4/ontologies/hp,https...         STRING
# 7          http://purl.obolibrary.org/obo/OBI_0302884         STRING
# 8   -The%20life%20stage,Biological Collections Ont...         STRING
# 9   https://www.ebi.ac.uk/ols4/ontologies/ms/terms...         STRING
# 10        http://purl.obolibrary.org/obo/NCIT_C156434         STRING
# 11         http://purl.obolibrary.org/obo/NCIT_C13018         STRING
# 12  DSLWG,Sage Bionetworks,https://www.ebi.ac.uk/o...         STRING
# 13  Sage Bionetworks,http://purl.obolibrary.org/ob...         STRING
# 14  https://ontobee.org/ontology/NCITiri=http://pu...         STRING
# 15  https://www.ebi.ac.uk/ols4/ontologies/edam/ter...         STRING
# 16  https://www.ebi.ac.uk/ols4/ontologies/ccf/term...         STRING
# 17  Sage Bionetworks,http://purl.obolibrary.org/ob...         STRING
# 18  http://edamontology.org/data_1179,http://purl....         STRING
# 19  Sage Bionetworks,http://purl.obolibrary.org/ob...         STRING
# 20  Sage Bionetworks,http://purl.obolibrary.org/ob...  STRING,STRING
#
#                                              Ontology  multivalue  \
# 0   https://www.ebi.ac.uk/ols/ontologies/ms/termsi...       False
# 1           http://purl.obolibrary.org/obo/MS_1001455       False
# 2   https://bioportal.bioontology.org/ontologies/C...       False
# 3   https://www.ebi.ac.uk/ols/ontologies/edam/term...       False
# 4           http://purl.obolibrary.org/obo/MS_1001013       False
# 5           http://purl.obolibrary.org/obo/MS_1001012       False
# 6   https://www.ebi.ac.uk/ols/ontologies/hp,https:...        True
# 7          http://purl.obolibrary.org/obo/OBI_0302884       False
# 8   -The%20life%20stage,Biological Collections Ont...       False
# 9   https://www.ebi.ac.uk/ols/ontologies/ms/termsi...       False
# 10        http://purl.obolibrary.org/obo/NCIT_C156434       False
# 11         http://purl.obolibrary.org/obo/NCIT_C13018       False
# 12  DSLWG,Sage Bionetworks,https://www.ebi.ac.uk/o...       False
# 13  Sage Bionetworks,http://purl.obolibrary.org/ob...       False
# 14  https://ontobee.org/ontology/NCITiri=http://pu...       False
# 15  https://www.ebi.ac.uk/ols/ontologies/edam/term...       False
# 16  https://www.ebi.ac.uk/ols/ontologies/ccf/terms...       False
# 17  Sage Bionetworks,http://purl.obolibrary.org/ob...        True
# 18  http://edamontology.org/data_1179,http://purl....       False
# 19  Sage Bionetworks,http://purl.obolibrary.org/ob...  False,True
# 20  Sage Bionetworks,http://purl.obolibrary.org/ob...       False
#
#           UsedIn module
# 0            NaN    NaN
# 1            NaN    NaN
# 2            NaN    NaN
# 3            NaN    NaN
# 4            NaN    NaN
# 5            NaN    NaN
# 6            NaN    NaN
# 7            NaN    NaN
# 8            NaN    NaN
# 9            NaN    NaN
# 10           NaN    NaN
# 11           NaN    NaN
# 12           NaN    NaN
# 13           NaN    NaN
# 14           NaN    NaN
# 15           NaN    NaN
# 16           NaN    NaN
# 17           NaN    NaN
# 18           NaN    NaN
# 19           NaN    NaN
# 20  specimenType    NaN

# %%
# dm.loc[dm["Attribute"] == dm_test.loc[0, "Attribute"],] =
replacements = dm_test.set_index("Attribute").to_dict()

# %%
for k, v in replacements.items():
    for a, av in v.items():
        dm.loc[dm["Attribute"] == a, k] = av

# %%
dm.loc[dm["Attribute"].isin(dm_test["Attribute"])]
# Out:
#                      Attribute  \
# 359            acquisitionMode
# 360        acquisitionSoftware
# 379                   cellType
# 382                 commonName
# 391               databaseName
# 392             databaseSource
# 395                  diagnosis
# 407           extractionMethod
# 439                  lifeStage
# 455     modificationParameters
# 456              msAnalyteType
# 472                      organ
# 523        protoemicsAssayType
# 557                        sex
# 565               speciesGroup
# 566                speciesName
# 606             specimenSource
# 607               specimenType
# 613                      taxon
# 614  technologyPlatformVersion
# 616                     tissue
#
#                                            Description  \
# 359  The specific aspect of a mass spectrometer met...
# 360          The name of the acquisition software used
# 379                           Indicate the cell type.
# 382  The biological species common name the individ...
# 391  The name of the search database (nr, SwissProt...
# 392  The name of the organization, project, or labo...
# 395                 Indicate the disease or condition.
# 407  The name of the process used to separate a des...
# 439  The life stage of the individual. note: Other ...
# 455  Modification parameters for the search engine ...
# 456      the type of biospecimen subjected to analysis
# 472            Indicate the organ the specimen is from
# 523  Type of peptide quantification used (ex. Label...
# 557               The biological sex of the individual
# 565  The taxonomic ranking including both species a...
# 566  The scientific name of the species (typically ...
# 606       Indicate the biological area of the specimen
# 607  Type of biological material comprising the Spe...
# 613  Taxonomic identifier. The National Center for ...
# 614  The specific version (application, manufacture...
# 616  Type of biological material comprising the Spe...
#
#                                           Valid Values Required DependsOn  \
# 359  Not Specified,Not applicable,Not collected,Unk...     True       NaN
# 360  4000 Series Explorer Software,4700 Explorer,63...     True       NaN
# 379  A2 amacrine cell,Acinar cell,Adipocyte,Afferen...     True       NaN
# 382                                                NaN     True       NaN
# 391  HMDB,MassBank of North America (MoNA),Metlin,N...     True       NaN
# 392  DB source EBI,DB source NCBI,DB source UniProt...     True       NaN
# 395                                                NaN    False       NaN
# 407                                                NaN     True       NaN
# 439  Adult,Juvenile,Not applicable,Not collected,Ot...     True       NaN
# 455  Fixed modification,H2O neutral loss,H3PO4 neut...     True       NaN
# 456  Lipid,Molecular Test Analyte Type,Not Specifie...    False       NaN
# 472  Abdominal Skin,Accessory Lacrimal Gland,Adrena...     True       NaN
# 523  ITRAQ,Label Free,Not applicable,Not collected,...     True       NaN
# 557  Female,Male,Not applicable,Not collected,Other...     True       NaN
# 565  Bird,Human,Mammal,Not applicable,Not collected...     True       NaN
# 566               Not applicable,Not collected,Unknown     True       NaN
# 606  Afferent Arteriole Endothelial Cell,Ascending ...     True       NaN
# 607  Analyte Type,Cerebrospinal Fluid (CSF),Cytolog...     True       NaN
# 613                                                NaN     True       NaN
# 614  10x Visium Spatial Gene Expression,Affymetrix ...     True       NaN
# 616  Abdominal Peritoneum,Accessory Tissue,Acinar S...     True       NaN
#
#      DependsOn Component    Properties Validation Rules  \
# 359                  NaN   unspecified              NaN
# 360                  NaN   unspecified              NaN
# 379                  NaN   unspecified              NaN
# 382                  NaN   unspecified              NaN
# 391                  NaN   unspecified              NaN
# 392                  NaN   unspecified              NaN
# 395                  NaN  DataProperty              NaN
# 407                  NaN   unspecified              NaN
# 439                  NaN   unspecified              NaN
# 455                  NaN   unspecified              NaN
# 456                  NaN  DataProperty              NaN
# 472                  NaN   unspecified              NaN
# 523                  NaN   unspecified              NaN
# 557                  NaN   unspecified              NaN
# 565                  NaN   unspecified              NaN
# 566                  NaN   unspecified              NaN
# 606                  NaN   unspecified              NaN
# 607                  NaN   unspecified              NaN
# 613                  NaN   unspecified              NaN
# 614                  NaN   unspecified              NaN
# 616                  NaN    ValidValue              NaN
#
#                                               Template       Parent  \
# 359                      Metabolomics Human,Proteomics  unspecified
# 360                      Metabolomics Human,Proteomics  unspecified
# 379             Biospecimen human,Biospecimen nonHuman  unspecified
# 382                                Individual nonHuman  unspecified
# 391                      Metabolomics Human,Proteomics  unspecified
# 392                      Metabolomics Human,Proteomics  unspecified
# 395                                   Individual Human  unspecified
# 407                      Metabolomics Human,Microbiome  unspecified
# 439                                Individual nonHuman  unspecified
# 455                                         Proteomics  unspecified
# 456                      Metabolomics Human,Proteomics  unspecified
# 472             Biospecimen human,Biospecimen nonHuman  unspecified
# 523                                         Proteomics  unspecified
# 557               Individual Human,Individual nonHuman  unspecified
# 565               Individual Human,Individual nonHuman  unspecified
# 566                                Individual nonHuman  unspecified
# 606             Biospecimen human,Biospecimen nonHuman  unspecified
# 607             Biospecimen human,Biospecimen nonHuman  unspecified
# 613                                Individual nonHuman  unspecified
# 614  Metabolomics Human,Microbiome,Proteomics,RNAse...  unspecified
# 616             Biospecimen human,Biospecimen nonHuman  unspecified
#
#                                                 Source           Type  \
# 359  https://www.ebi.ac.uk/ols4/ontologies/ms/terms...         STRING
# 360          http://purl.obolibrary.org/obo/MS_1001455         STRING
# 379  https://bioportal.bioontology.org/ontologies/C...         STRING
# 382  https://www.ebi.ac.uk/ols4/ontologies/edam/ter...         STRING
# 391          http://purl.obolibrary.org/obo/MS_1001013         STRING
# 392          http://purl.obolibrary.org/obo/MS_1001012         STRING
# 395  https://www.ebi.ac.uk/ols4/ontologies/hp,https...         STRING
# 407         http://purl.obolibrary.org/obo/OBI_0302884         STRING
# 439  -The%20life%20stage,Biological Collections Ont...         STRING
# 455  https://www.ebi.ac.uk/ols4/ontologies/ms/terms...         STRING
# 456        http://purl.obolibrary.org/obo/NCIT_C156434         STRING
# 472         http://purl.obolibrary.org/obo/NCIT_C13018         STRING
# 523  DSLWG,Sage Bionetworks,https://www.ebi.ac.uk/o...         STRING
# 557  Sage Bionetworks,http://purl.obolibrary.org/ob...         STRING
# 565  https://ontobee.org/ontology/NCITiri=http://pu...         STRING
# 566  https://www.ebi.ac.uk/ols4/ontologies/edam/ter...         STRING
# 606  https://www.ebi.ac.uk/ols4/ontologies/ccf/term...         STRING
# 607  Sage Bionetworks,http://purl.obolibrary.org/ob...         STRING
# 613  http://edamontology.org/data_1179,http://purl....         STRING
# 614  Sage Bionetworks,http://purl.obolibrary.org/ob...         STRING
# 616  Sage Bionetworks,http://purl.obolibrary.org/ob...  STRING,STRING
#
#                                               Ontology  multivalue  \
# 359  https://www.ebi.ac.uk/ols/ontologies/ms/termsi...       False
# 360          http://purl.obolibrary.org/obo/MS_1001455       False
# 379  https://bioportal.bioontology.org/ontologies/C...       False
# 382  https://www.ebi.ac.uk/ols/ontologies/edam/term...       False
# 391          http://purl.obolibrary.org/obo/MS_1001013       False
# 392          http://purl.obolibrary.org/obo/MS_1001012       False
# 395  https://www.ebi.ac.uk/ols/ontologies/hp,https:...        True
# 407         http://purl.obolibrary.org/obo/OBI_0302884       False
# 439  -The%20life%20stage,Biological Collections Ont...       False
# 455  https://www.ebi.ac.uk/ols/ontologies/ms/termsi...       False
# 456        http://purl.obolibrary.org/obo/NCIT_C156434       False
# 472         http://purl.obolibrary.org/obo/NCIT_C13018       False
# 523  DSLWG,Sage Bionetworks,https://www.ebi.ac.uk/o...       False
# 557  Sage Bionetworks,http://purl.obolibrary.org/ob...       False
# 565  https://ontobee.org/ontology/NCITiri=http://pu...       False
# 566  https://www.ebi.ac.uk/ols/ontologies/edam/term...       False
# 606  https://www.ebi.ac.uk/ols/ontologies/ccf/terms...       False
# 607  Sage Bionetworks,http://purl.obolibrary.org/ob...        True
# 613  http://edamontology.org/data_1179,http://purl....       False
# 614  Sage Bionetworks,http://purl.obolibrary.org/ob...  False,True
# 616  Sage Bionetworks,http://purl.obolibrary.org/ob...       False
#
#            UsedIn module
# 359           NaN    NaN
# 360           NaN    NaN
# 379           NaN    NaN
# 382           NaN    NaN
# 391           NaN    NaN
# 392           NaN    NaN
# 395           NaN    NaN
# 407           NaN    NaN
# 439           NaN    NaN
# 455           NaN    NaN
# 456           NaN    NaN
# 472           NaN    NaN
# 523           NaN    NaN
# 557           NaN    NaN
# 565           NaN    NaN
# 566           NaN    NaN
# 606           NaN    NaN
# 607           NaN    NaN
# 613           NaN    NaN
# 614           NaN    NaN
# 616  specimenType    NaN

# %%
dm = dm.replace("-The%20life%20stage", "", regex=True)

dm[["Source", "Ontology"]] = (
    dm[["Source", "Ontology"]].fillna("").applymap(utils.clean_list).replace("", np.nan)
)

# %% [markdown]
# # Update data model

# %%
sum(dm.duplicated(subset="Attribute"))
# Out:
# 0

# %%
dm.reset_index(drop=True, inplace=True)

# %%
# write out new data model
dm.to_csv("../EL.data.model.csv")

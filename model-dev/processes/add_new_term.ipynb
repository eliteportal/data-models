# %% [markdown]
# # MERGE NEW TERM WITH DM
# rules to merge?
# - if exisiting value exists, and no new value keep
# - if exisiting value exists and new value adds information, combine
# - if no exisiting value preseent, update with new value
#
# process:
# - describe na before changes
# - make changes
# - commit changes?

# %%
import pandas as pd

# %% [markdown]
# ## check what attributes are already in the data model

# %%
import os

# %%
cwd = Path(os.getcwd())

ROOT_DIR_NAME = "ELITE-data-models"

for p in cwd.parents:
    if bool(re.search(ROOT_DIR_NAME + "$", str(p))):
        print(p)
        ROOT_DIR = p
# Out:
# /Users/nlee/Documents/Projects/ELITE/ELITE-data-models

# %%
new_term_path = "../../data/rfc_tables_cleaned/genotyping_assay_cleaned_rfc.csv"
new_term_df = pd.read_csv(new_term_path)

print('--- New Term ---')
display(new_term_df.head())

dm = pd.read_csv('../../EL.data.model.csv')

dm['columnType'] = dm['columnType'].str.upper()

print('--- Exisiting Data Model ---')
display(dm.head())
# Out:
# --- New Term ---
#                     Attribute  \
# 0            genotyping_assay
# 1        measurementTechnique
# 2  OtherMeasurementTechnique
# 3            OtherSampleType
# 4        reagentCatalogNumber
#
#                                          Description  \
# 0                      Template for genotyping_assay
# 1  The measurement technique describing the assay...
# 2  When column = `other`, add your custom value t...
# 3  When column = `other`, add your custom value t...
# 4  If the assay reagent is a commercial product, ...
#
#                                         Valid Values  Required    Module  \
# 0                                                NaN     False  Template
# 1  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     False  Metadata
# 2                                                NaN     False     Other
# 3                                                NaN     False     Other
# 4                                                NaN     False  Metadata
#
#   columnType                  Ontology Notes      Properties  \
# 0        NaN          Sage Bionetworks   NaN             NaN
# 1     STRING  Sage Bionetworks,ImmPort   NaN  ManifestColumn
# 2     STRING          Sage Bionetworks   NaN      ValidValue
# 3     STRING          Sage Bionetworks   NaN      ValidValue
# 4     STRING  Sage Bionetworks,ImmPort   NaN  ManifestColumn
#
#                                            DependsOn                Parent  \
# 0  Component,Filename,OtherMeasurementTechnique ,...             Component
# 1                                                NaN                   NaN
# 2                        specifyMeasurementTechnique  measurementTechnique
# 3                                  specifySampleType            sampleType
# 4                                                NaN                   NaN
#
#              UsedIn
# 0               NaN
# 1  genotyping_assay
# 2  genotyping_assay
# 3  genotyping_assay
# 4  genotyping_assay
# --- Exisiting Data Model ---
#                             Attribute  \
# 0                                 10x
# 1  10x Visium Spatial Gene Expression
# 2                   Accel-NGS 2S Plus
# 3                Accel-NGS Methyl-Seq
# 4                  acquisitionBatchID
#
#                                          Description Valid Values DependsOn  \
# 0                                                NaN          NaN       NaN
# 1                              Instrument Model Name          NaN       NaN
# 2                                                NaN          NaN       NaN
# 3                                                NaN          NaN       NaN
# 4  Acquisition batch identifier, provided by the ...          NaN       NaN
#
#        Properties Required          Parent  DependsOn Component  \
# 0             NaN    False      ValidValue                  NaN
# 1             NaN    False      ValidValue                  NaN
# 2             NaN    False      ValidValue                  NaN
# 3             NaN    False      ValidValue                  NaN
# 4  ManifestColumn    False  ManifestColumn                  NaN
#
#              Source Validation Rules          Module          Ontology  \
# 0               NaN              NaN     ValidValues               NaN
# 1               NaN              NaN      Instrument               NaN
# 2               NaN              NaN     ValidValues               NaN
# 3               NaN              NaN     ValidValues               NaN
# 4  Sage Bionetworks              NaN  Assay,Metadata  Sage Bionetworks
#
#          UsedIn columnType Notes multivalue
# 0           NaN        NaN   NaN        NaN
# 1           NaN        NaN   NaN        NaN
# 2           NaN        NaN   NaN        NaN
# 3           NaN        NaN   NaN        NaN
# 4  Metabolomics     STRING   NaN        NaN

# %%
new_term_df['exists'] = new_term_df['Attribute'].isin(dm['Attribute'])

new_terms_to_add = new_term_df[~new_term_df["exists"]]

new_terms_to_add
# Out:
#                      Attribute  \
# 0             genotyping_assay
# 2   OtherMeasurementTechnique
# 3             OtherSampleType
# 6                   reagentIDs
# 19                treatmentIDs
# 25              YesUseReagent
# 26            YesUseTreatment
#
#                                           Description Valid Values  Required  \
# 0                       Template for genotyping_assay          NaN     False
# 2   When column = `other`, add your custom value t...          NaN     False
# 3   When column = `other`, add your custom value t...          NaN     False
# 6   One or more identifiers, separated by a semico...          NaN     False
# 19  One or more identifiers, separated by a semico...          NaN     False
# 25  When column = `Yes`, add your custom value to ...          NaN     False
# 26  When column = `Yes`, add your custom value to ...          NaN     False
#
#       Module columnType                  Ontology Notes      Properties  \
# 0   Template        NaN          Sage Bionetworks   NaN             NaN
# 2      Other     STRING          Sage Bionetworks   NaN      ValidValue
# 3      Other     STRING          Sage Bionetworks   NaN      ValidValue
# 6   Metadata     STRING  Sage Bionetworks,ImmPort   NaN  ManifestColumn
# 19  Metadata     STRING  Sage Bionetworks,ImmPort   NaN  ManifestColumn
# 25     Other     STRING          Sage Bionetworks   NaN      ValidValue
# 26     Other     STRING          Sage Bionetworks   NaN      ValidValue
#
#                                             DependsOn                Parent  \
# 0   Component,Filename,OtherMeasurementTechnique ,...             Component
# 2                         specifyMeasurementTechnique  measurementTechnique
# 3                                   specifySampleType            sampleType
# 6                                                 NaN                   NaN
# 19                                                NaN                   NaN
# 25  reagentCatalogNumber,reagentContact,reagentIDs...            useReagent
# 26  treatmentAmountUnit,treatmentAmountValue,treat...          useTreatment
#
#               UsedIn  exists
# 0                NaN   False
# 2   genotyping_assay   False
# 3   genotyping_assay   False
# 6   genotyping_assay   False
# 19  genotyping_assay   False
# 25  genotyping_assay   False
# 26  genotyping_assay   False

# %%
import numpy as np

# %%
# cleanup 
dm['columnType'] = dm['columnType'].fillna('').str.split(',').apply(lambda x: ','.join(np.unique(x))).replace('', np.nan)

# %%
dm['UsedIn'] = dm['UsedIn'].str.replace('genotyping', 'genotyping_assay')

# %%
index_keys = ['Attribute']
keys = ['dm', 'new_term']

df1 = dm[dm["Attribute"].isin(new_term_df["Attribute"])].set_index(index_keys).sort_index()
df2 = (
    new_term_df[new_term_df["Attribute"].isin(dm["Attribute"])]
    .set_index(index_keys)
    .sort_index()
)


df = pd.concat(
    [df1, df2],
    keys=keys,
    axis=1,
).sort_index(level=1, axis=1)

# easier to process
df = df.stack(future_stack=True).dropna(how = 'all', axis = 0)

# if new term does not have value then also drop since it provides no info
df = df[~df['new_term'].isna()]

# if dm is empty, then fill with new term
df['dm'] = df['dm'].fillna(df['new_term'])

# remove duplicates
df = df[df['dm'] != df['new_term']]

df.index = df.index.set_names(["Attribute", "column"])

df
# Out:
#                                                                                          dm  \
# Attribute                   column
# measurementTechnique        Description   The name of the measurement technique describi...
#                             Ontology                                       Sage Bionetworks
#                             Required                                                   True
#                             UsedIn                                  Metabolomics,proteomics
# reagentCatalogNumber        Module                                                    Assay
# reagentContact              Module                                                    Assay
# reagentLotNumber            Module                                                    Assay
# reagentManufacturer         Module                                                    Assay
# reagentName                 Module                                                    Assay
# reagentWeblink              Module                                                    Assay
# sampleType                  Description   The type of sample collected or the term used ...
#                             Notes         Cell and ChEBI ontologies.,A data contributor ...
#                             Ontology                                       Sage Bionetworks
#                             UsedIn        Metabolomics,Microbiome,RNAseq,Whole Genome Se...
#                             Valid Values  Appendix, B cell, Basophils, Bone, Bone Marrow...
# specifyMeasurementTechnique UsedIn        Metabolomics,Microbiome,RNAseq,Whole Genome Se...
# specifySampleType           UsedIn        Metabolomics,Microbiome,RNAseq,Whole Genome Se...
# specimenID                  Description   Identifying string linked to a particular samp...
#                             UsedIn        Biospecimen human,Biospecimen nonHuman,Metabol...
# useReagent                  Description                 Was a reagent applied to the sample
#                             Valid Values                                   No,YesUseReagent
# useTreatment                Description               Was a treatment applied to the sample
#                             Valid Values                                 No,YesUseTreatment
#
#                                                                                    new_term
# Attribute                   column
# measurementTechnique        Description   The measurement technique describing the assay...
#                             Ontology                               Sage Bionetworks,ImmPort
#                             Required                                                  False
#                             UsedIn                                         genotyping_assay
# reagentCatalogNumber        Module                                                 Metadata
# reagentContact              Module                                                 Metadata
# reagentLotNumber            Module                                                 Metadata
# reagentManufacturer         Module                                                 Metadata
# reagentName                 Module                                                 Metadata
# reagentWeblink              Module                                                 Metadata
# sampleType                  Description                        The type of sample collected
#                             Notes         The sample types are adopted from Uberon, Cell...
#                             Ontology                               Sage Bionetworks,ImmPort
#                             UsedIn                                         genotyping_assay
#                             Valid Values  Amniotic Fluid,Appendix,B cell,Basophils,Bone,...
# specifyMeasurementTechnique UsedIn                                         genotyping_assay
# specifySampleType           UsedIn                                         genotyping_assay
# specimenID                  Description   Identifying string linked to a particular samp...
#                             UsedIn                                         genotyping_assay
# useReagent                  Description                Was a reagent applied to the sample?
#                             Valid Values                                  No,YesUseReagent
# useTreatment                Description              Was a treatment applied to the sample?
#                             Valid Values                                No,YesUseTreatment

# %%
def combine_str_cols(df, combo_col): 
    # Expand list cols
    df.loc[df.index.get_level_values("column") == combo_col, "dm"] = df.loc[
        df.index.get_level_values("column") == combo_col, :
    ].agg(",".join, axis=1)

    df.loc[df.index.get_level_values("column") == combo_col, "dm"] = df.loc[
        df.index.get_level_values("column") == combo_col, "dm"
    ].apply(lambda x: ",".join(list(np.unique([s.strip() for s in x.split(",")]))))

    # df = df.drop(combo_col, level=1, axis=0)

    return df

# %%
df = combine_str_cols(df, 'Valid Values')
df = combine_str_cols(df, "Ontology")
df = combine_str_cols(df, "UsedIn")

# %%
df
# Out:
#                                                                                          dm  \
# Attribute                   column
# measurementTechnique        Description   The name of the measurement technique describi...
#                             Ontology                               ImmPort,Sage Bionetworks
#                             Required                                                   True
#                             UsedIn                 Metabolomics,genotyping_assay,proteomics
# reagentCatalogNumber        Module                                                    Assay
# reagentContact              Module                                                    Assay
# reagentLotNumber            Module                                                    Assay
# reagentManufacturer         Module                                                    Assay
# reagentName                 Module                                                    Assay
# reagentWeblink              Module                                                    Assay
# sampleType                  Description   The type of sample collected or the term used ...
#                             Notes         Cell and ChEBI ontologies.,A data contributor ...
#                             Ontology                               ImmPort,Sage Bionetworks
#                             UsedIn        Metabolomics,Microbiome,RNAseq,Whole Genome Se...
#                             Valid Values  Amniotic Fluid,Appendix,B cell,Basophils,Bone,...
# specifyMeasurementTechnique UsedIn        Metabolomics,Microbiome,RNAseq,Whole Genome Se...
# specifySampleType           UsedIn        Metabolomics,Microbiome,RNAseq,Whole Genome Se...
# specimenID                  Description   Identifying string linked to a particular samp...
#                             UsedIn        Biospecimen human,Biospecimen nonHuman,Metabol...
# useReagent                  Description                 Was a reagent applied to the sample
#                             Valid Values                                   No,YesUseReagent
# useTreatment                Description               Was a treatment applied to the sample
#                             Valid Values                                 No,YesUseTreatment
#
#                                                                                    new_term
# Attribute                   column
# measurementTechnique        Description   The measurement technique describing the assay...
#                             Ontology                               Sage Bionetworks,ImmPort
#                             Required                                                  False
#                             UsedIn                                         genotyping_assay
# reagentCatalogNumber        Module                                                 Metadata
# reagentContact              Module                                                 Metadata
# reagentLotNumber            Module                                                 Metadata
# reagentManufacturer         Module                                                 Metadata
# reagentName                 Module                                                 Metadata
# reagentWeblink              Module                                                 Metadata
# sampleType                  Description                        The type of sample collected
#                             Notes         The sample types are adopted from Uberon, Cell...
#                             Ontology                               Sage Bionetworks,ImmPort
#                             UsedIn                                         genotyping_assay
#                             Valid Values  Amniotic Fluid,Appendix,B cell,Basophils,Bone,...
# specifyMeasurementTechnique UsedIn                                         genotyping_assay
# specifySampleType           UsedIn                                         genotyping_assay
# specimenID                  Description   Identifying string linked to a particular samp...
#                             UsedIn                                         genotyping_assay
# useReagent                  Description                Was a reagent applied to the sample?
#                             Valid Values                                  No,YesUseReagent
# useTreatment                Description              Was a treatment applied to the sample?
#                             Valid Values                                No,YesUseTreatment

# %%
df = df.drop(columns=['new_term'])
df
# Out:
#                                                                                          dm
# Attribute                   column
# measurementTechnique        Description   The name of the measurement technique describi...
#                             Ontology                               ImmPort,Sage Bionetworks
#                             Required                                                   True
#                             UsedIn                 Metabolomics,genotyping_assay,proteomics
# reagentCatalogNumber        Module                                                    Assay
# reagentContact              Module                                                    Assay
# reagentLotNumber            Module                                                    Assay
# reagentManufacturer         Module                                                    Assay
# reagentName                 Module                                                    Assay
# reagentWeblink              Module                                                    Assay
# sampleType                  Description   The type of sample collected or the term used ...
#                             Notes         Cell and ChEBI ontologies.,A data contributor ...
#                             Ontology                               ImmPort,Sage Bionetworks
#                             UsedIn        Metabolomics,Microbiome,RNAseq,Whole Genome Se...
#                             Valid Values  Amniotic Fluid,Appendix,B cell,Basophils,Bone,...
# specifyMeasurementTechnique UsedIn        Metabolomics,Microbiome,RNAseq,Whole Genome Se...
# specifySampleType           UsedIn        Metabolomics,Microbiome,RNAseq,Whole Genome Se...
# specimenID                  Description   Identifying string linked to a particular samp...
#                             UsedIn        Biospecimen human,Biospecimen nonHuman,Metabol...
# useReagent                  Description                 Was a reagent applied to the sample
#                             Valid Values                                   No,YesUseReagent
# useTreatment                Description               Was a treatment applied to the sample
#                             Valid Values                                 No,YesUseTreatment

# %%
df['dm']
# Out:
# Attribute                    column
# measurementTechnique         Description     The name of the measurement technique describi...
#                              Ontology                                 ImmPort,Sage Bionetworks
#                              Required                                                     True
#                              UsedIn                   Metabolomics,genotyping_assay,proteomics
# reagentCatalogNumber         Module                                                      Assay
# reagentContact               Module                                                      Assay
# reagentLotNumber             Module                                                      Assay
# reagentManufacturer          Module                                                      Assay
# reagentName                  Module                                                      Assay
# reagentWeblink               Module                                                      Assay
# sampleType                   Description     The type of sample collected or the term used ...
#                              Notes           Cell and ChEBI ontologies.,A data contributor ...
#                              Ontology                                 ImmPort,Sage Bionetworks
#                              UsedIn          Metabolomics,Microbiome,RNAseq,Whole Genome Se...
#                              Valid Values    Amniotic Fluid,Appendix,B cell,Basophils,Bone,...
# specifyMeasurementTechnique  UsedIn          Metabolomics,Microbiome,RNAseq,Whole Genome Se...
# specifySampleType            UsedIn          Metabolomics,Microbiome,RNAseq,Whole Genome Se...
# specimenID                   Description     Identifying string linked to a particular samp...
#                              UsedIn          Biospecimen human,Biospecimen nonHuman,Metabol...
# useReagent                   Description                   Was a reagent applied to the sample
#                              Valid Values                                     No,YesUseReagent
# useTreatment                 Description                 Was a treatment applied to the sample
#                              Valid Values                                   No,YesUseTreatment
# Name: dm, dtype: object

# %%
dm_stacked = dm.set_index('Attribute').stack(future_stack=True)

# %%
dm_stacked.update(df['dm'])

# %%
dm_unstacked = dm_stacked.unstack()

# %%
dm_unstacked.loc["measurementTechnique"]
# Out:
# Description            The name of the measurement technique describi...
# Valid Values                                                         NaN
# DependsOn                                                            NaN
# Properties                                                ManifestColumn
# Required                                                            True
# Parent                                                               NaN
# DependsOn Component                                                  NaN
# Source                                                               NaN
# Validation Rules                                                     NaN
# Module                                                          Metadata
# Ontology                                        ImmPort,Sage Bionetworks
# UsedIn                          Metabolomics,genotyping_assay,proteomics
# columnType                                                        STRING
# Notes                  A data contributor should be able to write in ...
# multivalue                                                           NaN
# Name: measurementTechnique, dtype: object

# %%
# dm_unstacked = dm_unstacked.reset_index()
# dm_unstacked["Attribute"] = dm_unstacked["Attribute"].apply(lambda x: re.sub('\(|\)|\?', '', x))
# dm_unstacked = dm_unstacked.drop(columns=["index"], errors="ignore")
# dm_unstacked = dm_unstacked.set_index('Attribute')
# dm_unstacked

# %%
from pathlib import Path

# %%
dm_unstacked.to_csv(Path(ROOT_DIR, 'EL.data.model.csv'))

# %%
# choices: no change, update, merge

# %%
import subprocess

# %%
proc = subprocess.Popen(
    """ schematic schema convert EL.data.model.csv """, cwd=ROOT_DIR, shell = True
)

proc.communicate()

if proc.returncode == 0: 
    print('Success!')
else: 
    print('FAIL')
# Out:
# Starting schematic...
# Parsing data model.
# Generating data model graph.
# Validating the data model internally.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: DataType and Proteomics, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: DataType and Metabolomics, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: MetadataType and Assay, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: IndividualnonHuman and Component, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Genotyping and Component, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Genotyping and Component, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Genotyping and Component, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: BiospecimennonHuman and Component, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: WholeGenomeSequencing and Component, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Microbiome and Component, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Component and ScRNAseq, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Component and RNAseq, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Component and Proteomics, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Component and Metabolomics, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Component and IndividualHuman, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Component and FileAnnotationTemplate, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Component and ComputationalTools, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Component and BsSeq, please remove this loop from your model and submit again.
# warning: Schematic requires models be a directed acyclic graph (DAG). Your graph is not a DAG, we found a loop between: Component and Biospecimenhuman, please remove this loop from your model and submit again.
# error: Schematic requires models be a directed acyclic graph (DAG). Please inspect your model.
# warning: Node: Accel-NGS 2S Plus contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Accel-NGS Methyl-Seq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Affymetrix Genome-Wide Human SNP 5.0 Array contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Affymetrix Genome-Wide Human SNP 6.0 Array contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Affymetrix Human Gene 1.0 ST Array contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: Affymetrix Human Genome U133 Plus 2.0 Array contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: Genome-Wide Association contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: de-novo assembly contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: genome-wide pleiotropy contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: FIA-MSMS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: HI-C contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: HPLC-MSMS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: LC-MS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: LC-MSMS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: LC-SRM contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: MDMS-SL contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: NOMe-Seq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Ribo-Seq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: UPLC-ESI-QTOF-MS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: UPLC-MSMS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: anxiety-related behavior contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: liquid chromatography-electrochemical detection contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: long-read rnaSeq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: m6A-rnaSeq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: oxBS-Seq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: whole-cell patch clamp contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: BGISEQ-500 contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Cardiovascular Health Study (CHS) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: CCF-BSO contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CEL-seq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Astro L1 FGFR3 SERPINI2 primary motor cortex astrocyte (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Astro L1-6 FGFR3 AQP1 primary motor cortex astrocyte (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Astro L1-6 FGFR3 PLCG1 primary motor cortex astrocyte (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: CD14-low contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD14-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD14-positive monocyte contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD141-positive myeloid dendritic cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD16-low monocyte contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD16-negative contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD16-positive monocyte contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD19-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD1c-positive myeloid dendritic cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD4-negative contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD4-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD4-positive helper T cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD45RO-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD56-bright natural killer cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD8-alpha alpha positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD8-alpha-alpha-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD8-alpha-beta-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD8-negative contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD8-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD8aa(I) thymocyte contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: CD8aa(II) thymocyte contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: CD8alpha-negative thymic conventional dendritic cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: CD8alpha-positive thymic conventional dendritic cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Endo L2-5 NOSTRIN SRGN primary motor cortex endothelial cell (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L2 LAMP5 KCNG3 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L2 LINC00507 ATP7B primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L2 LINC00507 GLRA3 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L2-3 LINC00507 DSG3 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L2-3 RORB CCDC68 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L2-3 RORB PTPN3 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L2-3 RORB RTKN2 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L3 LAMP5 CARM1P1 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L3 RORB OTOGL primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L3 THEMIS ENPEP primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L3-5 FEZF2 ASGR2 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L3-5 FEZF2 LINC01107 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L3-5 RORB LAMA4 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L3-5 RORB LINC01202 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L3-5 RORB LNX2 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L3-5 RORB RPRM primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L3-5 RORB TNNT2 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 FEZF2 CSN1S1 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 FEZF2 NREP-AS1 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 FEZF2 PKD2L1 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 FEZF2 RNF144A-AS1 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 RORB MED8 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 THEMIS FGF10 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 THEMIS LINC01116 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 THEMIS RGPD6 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 THEMIS SLC22A18 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L5 THEMIS VILL primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L5-6 FEZF2 C9orf135-AS1 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5-6 FEZF2 CFTR primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5-6 FEZF2 FILIP1L primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5-6 FEZF2 IFNG-AS1 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5-6 FEZF2 LPO primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5-6 FEZF2 OR1L8 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5-6 FEZF2 SH2D1B primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5-6 THEMIS SMYD1 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L5-6 THEMIS TNFAIP6 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Exc L6 FEZF2 FFAR4 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L6 FEZF2 KLK7 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L6 FEZF2 PDYN primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L6 FEZF2 POGK primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L6 FEZF2 PROKR2 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L6 THEMIS LINC00343 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L6 THEMIS SLN primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Exc L6 THEMIS SNTG2 primary motor cortex glutamatergic neuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 LAMP5 BMP2 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 LAMP5 NMBR primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 LAMP5 PVRL2 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 LAMP5 RAB11FIP1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 PAX6 CHRFAM7A primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 PAX6 MIR101-1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 PVALB-like SST ASIC4 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 SST DEFB108B primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 SST P4HA3 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L1 VIP KLHDC8B primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-2 PVALB CDK20 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-2 SST CCNJL primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-2 SST CLIC6 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-2 SST PRRT4 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-2 VIP EXPH5 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-2 VIP HTR3A primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-2 VIP PTGER3 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-2 VIP SCML4 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-2 VIP WNT4 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-3 SST FAM20A primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-3 VIP CBLN1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-3 VIP CHRNA2 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-3 VIP FNDC1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-3 VIP HSPB6 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-5 VIP CD27-AS1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-5 VIP LINC01013 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-5 VIP PHLDB3 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-5 VIP SMOC1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-6 LAMP5 AARD primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-6 LAMP5 CA1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-6 LAMP5 NES primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-6 PVALB COL15A1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-6 SST NPY primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L1-6 VIP SLC7A6OS primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L2 PAX6 FREM2 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L2 PVALB FRZB primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L2 VIP SLC6A16 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L2-3 SST NMU primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L2-5 PVALB HHIPL1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L2-5 PVALB RPH3AL primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L2-5 VIP BSPRY primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L2-5 VIP SOX11 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3 PVALB SAMD13 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-5 PVALB ISG20 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-5 SST CDH3 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-5 SST GGTLC3 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-5 SST OR5AH1P primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-5 VIP HS3ST3A1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-5 VIP IGDCC3 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-5 VIP TAC3 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-6 PAX6 LINC01497 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-6 VIP UG0898H09 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L3-6 VIP ZIM2-AS1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5 PVALB LRIG3 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L5 SST RPL35AP11 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 LAMP5 CRABP1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 PVALB FAM150B primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 PVALB GAPDHP60 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 PVALB KCNIP2 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 PVALB MEPE primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 PVALB SST CRHR2 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 PVALB ZFPM2-AS1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 SST BEAN1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 SST C4orf26 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 SST DNAJC14 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 SST FBN2 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 SST ISX primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 SST KLHL1 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 SST PAWR primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 SST PIK3CD primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L5-6 VIP COL4A3 primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Inh L6 SST TH primary motor cortex GABAergic interneuron (Hsap) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Micro L1-6 TYROBP CD74 primary motor cortex microglial cell (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: OFF-bipolar cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: ON-bipolar cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: ON-blue cone bipolar cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: OPC L1-6 PDGFRA COL20A1 primary motor cortex oligodendrocyte precursor cell (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Oligo L2-6 OPALIN FTH1P3 primary motor cortex oligodendrocyte precursor cell (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Oligo L2-6 OPALIN MAP6D1 primary motor cortex oligodendrocyte precursor cell (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Oligo L3-6 OPALIN-like ENPP6 primary motor cortex oligodendrocyte precursor cell (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: Oligo L5-6 OPALIN LDLRAP1 primary motor cortex oligodendrocyte (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: T-helper 1 cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: T-helper 17 cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: T-helper 2 cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: VLMC L1-5 PDGFRA COLEC12 primary motor cortex vascular leptomeningeal cell (Hsap) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: a8 bistratified small-field cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: alpha-beta T cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: alpha-beta cytotoxic T cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: alpha-beta intraepithelial T cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: alpha-beta memory T cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: alpha-beta thymocyte contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: alveolar macrophage mt-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: amnion mesenchymal stromal cell (amsc) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: bche (butyrylcholinesterase) cell contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: camera-type eye photoreceptor cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: cd4+ t-cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: cd8 trm (residence memory) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: cd8+ t-cells contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: cell type (from CL) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: cell type (from LMHA) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: chorionic mesenchymal stromal cell (cmsc) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: committed double negative thymocyte (Homo sapiens) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: differentiation-committed oligodendrocyte precursor contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: double-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: ecto-epithelial cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: effector CD8-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: effector memory CD4-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: effector memory CD45RA-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: effector memory CD8-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: endo-epithelial cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: endocrine-paracrine cell of prostate gland contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: extratelencephalic-projecting glutamatergic cortical neuron contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: fibroblast-mesenchymal cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: gamma-delta T cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: gamma-delta intraepithelial T cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: hippocampal CA1-3 neuron contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: immature alpha-beta T cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: intratelencephalic-projecting glutamatergic cortical neuron contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: keratinocyte (onychocyte) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: kidney collecting duct alpha-intercalated cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: kidney connecting tubule alpha-intercalated cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: kidney connecting tubule beta-intercalated cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: lung resident memory CD4-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: lung resident memory CD8-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: lympho-myeloid progenitor cell (lmpp) contains a blacklisted character(s): (,),-, they will be striped if used in Synapse annotations.
# warning: Node: m1-like macrophage contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: m2-like macrophage contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: mature CD4 single-positive thymocyte contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: mature CD8 single-positive thymocyte contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: mature alpha-beta T cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: megakaryocyte-erythroid progenitor cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: meso-epithelial cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: midbrain-derived inhibitory neuron contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: monocyte-derived dendritic cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: myeloid progenitor (mop) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: myo-medullary thymic epithelial cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: naive thymus-derived CD4-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: naive thymus-derived CD8-positive contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: near-projecting glutamatergic cortical neuron contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: neurecto-epithelial cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: neuro-medullary thymic epithelial cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: neuron associated cell (sensu Vertebrata) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: non-classical monocyte contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: non-pigmented ciliary epithelial cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: non-terminally differentiated cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: pancreatic centro-acinar cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: placental stromal cell (psc) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: pre-antral follicle granulosa cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: pro-B cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: rearranging double negative thymocyte (Homo sapiens) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: renal alpha-intercalated cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: renal beta-intercalated cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: specified double negative thymocyte (Homo sapiens) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: transitional principal-intercalated cell contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Cerebrospinal Fluid (CSF) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Study of Osteoporotic Fractures (SOF) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: The Health and Aging and Body Composition Study (HealthABC) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: The Osteoporotic Fractures in Men (MrOS) Study contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: d.p.c. contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: MassBank of North America (MoNA) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: DDA-MS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: DIA-MS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: in-gel contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: in-solution contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Drop-Seq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Exploris 240Exploris 480quadrupole time-of-flight contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: reagentID(s) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: treatmentID(s) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Illumina Human660W-Quad v1.0 BeadChip contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Illumina_HumanOmni1-Quadv1.0 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Illumina HumanOmniExpress-24 v1.0 BeadChip contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Illumina HumanOmniExpress-24 v1.2 BeadChip contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Illumina Infinium MethylationEPIC BeadChip v1.0 (850k) contains a blacklisted character(s): (,),., they will be striped if used in Synapse annotations.
# warning: Node: Illumina Infinium MethylationEPIC BeadChip v2.0 (935k)Illumina MiSeq contains a blacklisted character(s): (,),., they will be striped if used in Synapse annotations.
# warning: Node: Illumina MouseWG-6 v2.0 expression BeadChip contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Label-free gene level quantitation contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Label-free peptide level quantitation contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Label-free protein group level quantitation contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Label-free protein level quantitation contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Label-free raw feature quantitation contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: LC-SRMOtherMsAssayTechnique contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: LI-COR Odyssey CLx contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Omni-ATAC contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Smart-seq1 contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Smart-seq2 contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Smart-seq4 contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Ultralow Methyl-Seq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: sac-seq contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Post-Juvenile contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: MIB-MS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: APPKM670-671NL-PSEN1deltaexon9 contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: APPS1_Plexin-B1-KO contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: B6.Clu contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: B6.Gfap-APOE4 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: BRI2-AB42 contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Bin1.B6 contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: Cd2ap.B6 contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: MAPT-P301K contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Plexin-B1-KO contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: TAUPS19_Plexin-B1-KO contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: TYROBP_KO.KO contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: TYROBP_WT.KO contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: 3xTg-AD contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Q Exactive HF-X contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Xevo TQ-S contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: time-of-flight contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: quadrupole time-of-flight contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Anterior Compartment Lymph Node Group (Level VI) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Extra-Abdominal Lymph Node contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Intra-Abdominal Lymph Node contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Lower Jugular Lymph Node Group (Level IV) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Middle Jugular Lymph Node Group (Level III) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Neck Lymph Node Boundary Levels I-IV contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Neck Lymph Node Boundary Levels II-IV contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Non-Glabrous Skin contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Posterior Triangle Lymph Node Group (Sublevels VA and VB) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Submandibular Lymph Node Group (Sublevel IB) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Submental Lymph Node Group (Sublevel IA) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Superior Mediastinal Lymph Node Group (Level VII) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Upper Jugular Lymph Node Group (Sublevels IIA and IIB) contains a blacklisted character(s): (,), they will be striped if used in Synapse annotations.
# warning: Node: Affy6.0 contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: Illumina MouseWG-6 v2.0 expression beadchip contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: IlluminaHumanHT-12_V3_0_R1 contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: IlluminaInfiniumGSAMD-24v2-0 contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Illumina_Infinium-HumanMethylation450-BeadChip contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Illumina_Omni2.5-8 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Illumina_Omni2.5-8_v1.1 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Illumina_Omni2.5-8_v1.3 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Illumina_Omni5-Quad contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Infinium Global Diversity Array-8 contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Infinium Omni2.5Exome-8 v1.1 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Infinium Omni2.5Exome-8 v1.3 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Infinium Omni2.5Exome-8 v1.4 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Infinium Omni2.5Exome-8 v1.5 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Simoa HD-1 Analyzer contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: ddSEQ Single-Cell Isolator contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: llumina Infinium General Screening Array 24-Kit v3.0 contains a blacklisted character(s): .,-, they will be striped if used in Synapse annotations.
# warning: Node: Affy5.0 contains a blacklisted character(s): ., they will be striped if used in Synapse annotations.
# warning: Node: Aging-PheWAS contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Bronchus-Associated Lymphoid Tissue contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Dermo-Epidermal Junction contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Gut-Associated Lymphoid Tissue contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Mucosa-Associated Lymphoid Tissue contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Non-Cellular Component contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Non-Valve Cardiac Conduit Tissue contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# warning: Node: Papillary-Reticular Dermal Interface contains a blacklisted character(s): -, they will be striped if used in Synapse annotations.
# Converting data model to JSON-LD
# By default, the JSON-LD output will be stored alongside the first input CSV or JSON-LD file. In this case, it will appear here: 'EL.data.model.jsonld'. You can use the `--output_jsonld` argument to specify another file path.
# The Data Model was created and saved to 'EL.data.model.jsonld' location.
# Execution time: 00:50 (M:S)
# (None, None)

# %%
# Out:
# 0

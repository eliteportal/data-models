# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path
import os

cwd = Path(os.getcwd())

ROOT_DIR_NAME = "ELITE-data-models"

for p in cwd.parents:
    if bool(re.search(ROOT_DIR_NAME + "$", str(p))):
        print(p)
        ROOT_DIR = p
# Out:
# /Users/nlee/Documents/Projects/ELITE/ELITE-data-models

# %%
from glob import glob

glob("data/RFC Tables/*.xlsx", root_dir=ROOT_DIR)
# Out:
# []

# %%
other_values = ["Other", "Unknown", "Not collected", "Not applicable", "Not specified"]

# %%
new_template_path = "data/rfc_tables_raw/EL RFC genotyping_assay.xlsx"

template_name = Path(new_template_path)
template_name = re.sub("EL|RFC", "", template_name.stem).strip()
print(template_name)

new_temp_df = pd.read_excel(Path(ROOT_DIR, new_template_path))

new_temp_df
# Out:
# genotyping_assay
#                             key  \
# 0                    specimenID
# 1                    sampleType
# 2             specifySampleType
# 3                   useReagent?
# 4                  reagentID(s)
# 5                   reagentName
# 6           reagentManufacturer
# 7          reagentCatalogNumber
# 8              reagentLotNumber
# 9                reagentWeblink
# 10               reagentContact
# 11                useTreatment?
# 12               treatmentID(s)
# 13                treatmentName
# 14         treatmentAmountValue
# 15          treatmentAmountUnit
# 16       treatmentDurationValue
# 17        treatmentDurationUnit
# 18    treatmentTemperatureValue
# 19     treatmentTemperatureUnit
# 20         measurementTechnique
# 21  specifyMeasurementTechnique
#
#                                           description  \
# 0   Identifying string linked to a particular samp...
# 1                        The type of sample collected
# 2      If "other" is selected list the type of sample
# 3                Was a reagent applied to the sample?
# 4   One or more identifiers, separated by a semico...
# 5   The reagent name is an alternative to the Reag...
# 6   The manufacturer is the source of a reagent an...
# 7   If the assay reagent is a commercial product, ...
# 8   The lot number is often provided by a reagent ...
# 9   An internet address that may provide details o...
# 10  The contact information is particularly helpfu...
# 11             Was a treatment applied to the sample?
# 12  One or more identifiers, separated by a semico...
# 13  Treatments refer to in vitro modifications of ...
# 14  The Amount Value indicates how much (concentra...
# 15                           Unit of treatment amount
# 16                              Duration of treatment
# 17                         Unit of treatment duration
# 18                     Value of treatment temperature
# 19                      Unit of treatment temperature
# 20  The measurement technique describing the assay...
# 21  If "other" is selected list the name of the me...
#
#                                          valid values  required  \
# 0               n/a (unique to each data contributor)       1.0
# 1   Amniotic Fluid,\nAppendix,\nB cell,\nBasophils...       1.0
# 2                                                 NaN       0.0
# 3                                            Yes,\nNo       1.0
# 4               n/a (unique to each data contributor)       0.0
# 5                                                 NaN       0.0
# 6                                                 NaN       0.0
# 7                                                 NaN       0.0
# 8                                                 NaN       0.0
# 9                                                 NaN       0.0
# 10                                                NaN       0.0
# 11                                           Yes,\nNo       1.0
# 12              n/a (unique to each data contributor)       0.0
# 13                                                NaN       0.0
# 14                                                NaN       0.0
# 15  AFU,\nAI,\nAU/ml,\nDK units/ml,\ng/dl,\ng/l,\n...       0.0
# 16                                                 \n       NaN
# 17  d.p.c.,\nDays,\nHours,\nMinutes,\nMonths,\nNot...       0.0
# 18                                                NaN       0.0
# 19                          C,\nF,\nK,\nNot Specified       0.0
# 20  16S rRNA gene sequencing,\n1D Gel,\n2D Gel,\nA...       0.0
# 21                                                NaN       0.0
#
#                                      requires  multivalue     type  \
# 0                   Biospecimen,\ngenotyping          0.0   string
# 1                                  genotyping         0.0   string
# 2             genotyping,\nsampleType = other         0.0   string
# 3                                  genotyping         0.0  boolean
# 4               genotyping,\nuseReagent = Yes         1.0   string
# 5               genotyping,\nuseReagent = Yes         1.0   string
# 6               genotyping,\nuseReagent = Yes         1.0   string
# 7               genotyping,\nuseReagent = Yes         1.0   string
# 8               genotyping,\nuseReagent = Yes         1.0   string
# 9               genotyping,\nuseReagent = Yes         1.0   string
# 10              genotyping,\nuseReagent = Yes         1.0   string
# 11                                genotyping          0.0  boolean
# 12           genotyping,\nuseTreatment? = Yes         1.0   string
# 13           genotyping,\nuseTreatment? = Yes         1.0   string
# 14           genotyping,\nuseTreatment? = Yes         1.0   string
# 15           genotyping,\nuseTreatment? = Yes         1.0   number
# 16                                        NaN         NaN   number
# 17           genotyping,\nuseTreatment? = Yes         0.0   string
# 18           genotyping,\nuseTreatment? = Yes         0.0   number
# 19           genotyping,\nuseTreatment? = Yes         0.0   string
# 20                                genotyping          0.0   string
# 21  genotyping,\nmeasurementTechnique = other         0.0   string
#
#        concept source ontology  \
# 0             Sage Bionetworks
# 1   Sage Bionetworks,\nImmPort
# 2             Sage Bionetworks
# 3   Sage Bionetworks,\nImmPort
# 4   Sage Bionetworks,\nImmPort
# 5   Sage Bionetworks,\nImmPort
# 6   Sage Bionetworks,\nImmPort
# 7   Sage Bionetworks,\nImmPort
# 8   Sage Bionetworks,\nImmPort
# 9   Sage Bionetworks,\nImmPort
# 10  Sage Bionetworks,\nImmPort
# 11  Sage Bionetworks,\nImmPort
# 12  Sage Bionetworks,\nImmPort
# 13  Sage Bionetworks,\nImmPort
# 14  Sage Bionetworks,\nImmPort
# 15  Sage Bionetworks,\nImmPort
# 16                         NaN
# 17  Sage Bionetworks,\nImmPort
# 18  Sage Bionetworks,\nImmPort
# 19  Sage Bionetworks,\nImmPort
# 20  Sage Bionetworks,\nImmPort
# 21            Sage Bionetworks
#
#                                                  note
# 0                                                 NaN
# 1   The sample types are adopted from Uberon, Cell...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN

# %%
new_temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   key                      22 non-null     object
#  1   description              22 non-null     object
#  2   valid values             11 non-null     object
#  3   required                 21 non-null     float64
#  4   requires                 21 non-null     object
#  5   multivalue               21 non-null     float64
#  6   type                     22 non-null     object
#  7   concept source ontology  21 non-null     object
#  8   note                     1 non-null      object
# dtypes: float64(2), object(7)
# memory usage: 1.7+ KB

# %%
new_temp_df.isna().sum()
# Out:
# key                         0
# description                 0
# valid values               11
# required                    1
# requires                    1
# multivalue                  1
# type                        0
# concept source ontology     1
# note                       21
# dtype: int64

# %% [markdown]
# # Cleanup

# %%
def remove_illegal_chars(x: str) -> str: 
    return re.sub("\(|\)|\?", "", x)

# %%
new_temp_df = new_temp_df.rename(
    columns={
        "key": "Attribute",
        "description": "Description",
        "required": "Required",
        "requires": "Module",
        "concept source ontology": "Ontology",
        "valid values": "Valid Values",
        "type": "columnType",
        "note": "Notes",
    }, errors='ignore'
)
new_temp_df = new_temp_df.fillna("")

# %%
# string clean up
# Do not need to explicitly add "other" type values. Will add back later for list type attributes
new_temp_df["Valid Values"] = (
    new_temp_df["Valid Values"]
    .replace("n/a (unique to each data contributor)", "", regex=False)
    .str.replace(
        "Other|Unknown|Not collected|Not applicable|Not specified", "", regex=True
    )
    .str.strip(",")
)

# replace note type values
new_temp_df["Valid Values"] = new_temp_df["Valid Values"].apply(
    lambda x: ",".join(
        [y.strip() for y in x.split(",") if not bool(re.search("Possible values", y))]
    ).strip(",")
)

new_temp_df = new_temp_df.replace(r"\n", ",", regex=True).replace(r",,", ",", regex=True)

# remove illegal characters from attributes
new_temp_df["Attribute"] = new_temp_df["Attribute"].apply(
    lambda x: re.sub("\(|\)|\?", "", x)
)

# %%
new_temp_df["Required"] = new_temp_df["Required"].astype(bool)

# new_temp_df["Required"] = (
#     new_temp_df["Required"]
#     .astype(str)
#     .apply(lambda x: False if bool(re.search("f", x)) else True)
#     .astype(bool)
# )

print(new_temp_df['Required'].unique())
# Out:
# [ True False]

# %%
new_temp_df = new_temp_df.drop(columns=["multivalue"], errors="ignore")

# %%
# split the values out and create new attributes to add to the model.
# These will be the intermediate attributes that will allow the original column i.e. SampleType to then have the user fill in specifySampleType
new_temp_df_others = new_temp_df.loc[new_temp_df["Module"].str.contains("=", na=False)].copy(deep=True)
new_temp_df_others["others"] = (
    new_temp_df_others["Module"]
    .str.split(",")
    .apply(lambda x: "".join([y.strip() for y in x if bool(re.search("=", y))]))
)

# in case there are multiple equals signs
new_temp_df_others = new_temp_df_others.explode("others")

new_temp_df_others["others"] = new_temp_df_others["others"].apply(remove_illegal_chars)

# set new parent values
new_temp_df_others["Parent"] = (
    new_temp_df_others["others"].str.split("=").apply(lambda x: x[0].strip())
)


# other value value used in valid values
new_temp_df_others["OtherValue"] = (
    new_temp_df_others["others"].str.split("=").apply(lambda x: x[1].strip())
)

new_temp_df_others["others"] = (
    new_temp_df_others["others"]
    .str.split("=")
    .apply(lambda x: x[1].strip().capitalize() + x[0][0].upper() + x[0][1:])
)

# Swap others -> Attribute and Attribute -> DependsOn
new_temp_df_others = new_temp_df_others.rename(
    columns={"Attribute": "DependsOn", "others": "Attribute"}
)

# hard coded values
new_temp_df_others["Required"] = False
new_temp_df_others["Module"] = "Other"
new_temp_df_others["Valid Values"] = ""

# Assign data modeling variables
new_temp_df_others = new_temp_df_others.assign(
    columnType="string",
    Ontology="Sage Bionetworks",
    Required=False,
    Properties="ValidValue",
)

for i in new_temp_df_others.index:
    new_temp_df_others.loc[i, "Description"] = (
        f"""When column = `{new_temp_df_others.loc[i, "OtherValue"]}`, add your custom value to the cell"""
    )

# remove illegal characters
new_temp_df_others[["Attribute", "Parent"]] = new_temp_df_others[
    ["Attribute", "Parent"]
].map(remove_illegal_chars)

new_temp_df_others
# Out:
#                       Attribute  \
# 2             specifySampleType
# 4                    reagentIDs
# 5                   reagentName
# 6           reagentManufacturer
# 7          reagentCatalogNumber
# 8              reagentLotNumber
# 9                reagentWeblink
# 10               reagentContact
# 12                 treatmentIDs
# 13                treatmentName
# 14         treatmentAmountValue
# 15          treatmentAmountUnit
# 17        treatmentDurationUnit
# 18    treatmentTemperatureValue
# 19     treatmentTemperatureUnit
# 21  specifyMeasurementTechnique
#
#                                           Description  \
# 2      If "other" is selected list the type of sample
# 4   One or more identifiers, separated by a semico...
# 5   The reagent name is an alternative to the Reag...
# 6   The manufacturer is the source of a reagent an...
# 7   If the assay reagent is a commercial product, ...
# 8   The lot number is often provided by a reagent ...
# 9   An internet address that may provide details o...
# 10  The contact information is particularly helpfu...
# 12  One or more identifiers, separated by a semico...
# 13  Treatments refer to in vitro modifications of ...
# 14  The Amount Value indicates how much (concentra...
# 15                           Unit of treatment amount
# 17                         Unit of treatment duration
# 18                     Value of treatment temperature
# 19                      Unit of treatment temperature
# 21  If "other" is selected list the name of the me...
#
#                                          Valid Values  Required  \
# 2                                                         False
# 4                                                         False
# 5                                                         False
# 6                                                         False
# 7                                                         False
# 8                                                         False
# 9                                                         False
# 10                                                        False
# 12                                                        False
# 13                                                        False
# 14                                                        False
# 15  AFU,AI,AU/ml,DK units/ml,g/dl,g/l,gm,HAU,IU,iu...     False
# 17  d.p.c.,Days,Hours,Minutes,Months,Not Specified...     False
# 18                                                        False
# 19                                C,F,K,Not Specified     False
# 21                                                        False
#
#                                      Module columnType  \
# 2             genotyping,sampleType = other     string
# 4               genotyping,useReagent = Yes     string
# 5               genotyping,useReagent = Yes     string
# 6               genotyping,useReagent = Yes     string
# 7               genotyping,useReagent = Yes     string
# 8               genotyping,useReagent = Yes     string
# 9               genotyping,useReagent = Yes     string
# 10              genotyping,useReagent = Yes     string
# 12           genotyping,useTreatment? = Yes     string
# 13           genotyping,useTreatment? = Yes     string
# 14           genotyping,useTreatment? = Yes     string
# 15           genotyping,useTreatment? = Yes     number
# 17           genotyping,useTreatment? = Yes     string
# 18           genotyping,useTreatment? = Yes     number
# 19           genotyping,useTreatment? = Yes     string
# 21  genotyping,measurementTechnique = other     string
#
#                     Ontology Notes                      others  \
# 2           Sage Bionetworks                  OtherSampleType
# 4   Sage Bionetworks,ImmPort                    YesUseReagent
# 5   Sage Bionetworks,ImmPort                    YesUseReagent
# 6   Sage Bionetworks,ImmPort                    YesUseReagent
# 7   Sage Bionetworks,ImmPort                    YesUseReagent
# 8   Sage Bionetworks,ImmPort                    YesUseReagent
# 9   Sage Bionetworks,ImmPort                    YesUseReagent
# 10  Sage Bionetworks,ImmPort                    YesUseReagent
# 12  Sage Bionetworks,ImmPort                  YesUseTreatment
# 13  Sage Bionetworks,ImmPort                  YesUseTreatment
# 14  Sage Bionetworks,ImmPort                  YesUseTreatment
# 15  Sage Bionetworks,ImmPort                  YesUseTreatment
# 17  Sage Bionetworks,ImmPort                  YesUseTreatment
# 18  Sage Bionetworks,ImmPort                  YesUseTreatment
# 19  Sage Bionetworks,ImmPort                  YesUseTreatment
# 21          Sage Bionetworks        OtherMeasurementTechnique
#
#                   Parent OtherValue
# 2             sampleType      other
# 4             useReagent        Yes
# 5             useReagent        Yes
# 6             useReagent        Yes
# 7             useReagent        Yes
# 8             useReagent        Yes
# 9             useReagent        Yes
# 10            useReagent        Yes
# 12          useTreatment        Yes
# 13          useTreatment        Yes
# 14          useTreatment        Yes
# 15          useTreatment        Yes
# 17          useTreatment        Yes
# 18          useTreatment        Yes
# 19          useTreatment        Yes
# 21  measurementTechnique      other

# %%
# Add other attributes to the list of valid values
new_temp_df.loc[
    ~new_temp_df.replace("", np.nan)["Valid Values"].isna(), "Valid Values"
] = new_temp_df.loc[~new_temp_df.replace("", np.nan)["Valid Values"].isna()].apply(
    lambda x: re.sub(
        ",+",
        ",",
        ",".join(
            [
                (
                    p
                    if p
                    not in new_temp_df_others.loc[
                        new_temp_df_others["Parent"] == x["Attribute"], "OtherValue"
                    ].values
                    else ""
                )
                for p in x["Valid Values"].split(",")
            ] + list(new_temp_df_others.loc[
                new_temp_df_others["Parent"] == x["Attribute"], "Attribute"
            ].values)
        ),
    ),
    axis=1,
)

# cleanup valid values
new_temp_df["Valid Values"] = (
    new_temp_df["Valid Values"]
    .str.split(",")
    .apply(lambda x: ",".join(list(np.unique(x))))
)

# Last bit of cleanup
new_temp_df["Properties"] = "ManifestColumn"
new_temp_df["Module"] = new_temp_df["Attribute"].apply(
    lambda x: "Other" if bool(re.search("specify", x)) else "Metadata"
)

new_temp_df
# Out:
#                       Attribute  \
# 0                    specimenID
# 1                    sampleType
# 2             specifySampleType
# 3                    useReagent
# 4                    reagentIDs
# 5                   reagentName
# 6           reagentManufacturer
# 7          reagentCatalogNumber
# 8              reagentLotNumber
# 9                reagentWeblink
# 10               reagentContact
# 11                 useTreatment
# 12                 treatmentIDs
# 13                treatmentName
# 14         treatmentAmountValue
# 15          treatmentAmountUnit
# 16       treatmentDurationValue
# 17        treatmentDurationUnit
# 18    treatmentTemperatureValue
# 19     treatmentTemperatureUnit
# 20         measurementTechnique
# 21  specifyMeasurementTechnique
#
#                                           Description  \
# 0   Identifying string linked to a particular samp...
# 1                        The type of sample collected
# 2      If "other" is selected list the type of sample
# 3                Was a reagent applied to the sample?
# 4   One or more identifiers, separated by a semico...
# 5   The reagent name is an alternative to the Reag...
# 6   The manufacturer is the source of a reagent an...
# 7   If the assay reagent is a commercial product, ...
# 8   The lot number is often provided by a reagent ...
# 9   An internet address that may provide details o...
# 10  The contact information is particularly helpfu...
# 11             Was a treatment applied to the sample?
# 12  One or more identifiers, separated by a semico...
# 13  Treatments refer to in vitro modifications of ...
# 14  The Amount Value indicates how much (concentra...
# 15                           Unit of treatment amount
# 16                              Duration of treatment
# 17                         Unit of treatment duration
# 18                     Value of treatment temperature
# 19                      Unit of treatment temperature
# 20  The measurement technique describing the assay...
# 21  If "other" is selected list the name of the me...
#
#                                          Valid Values  Required    Module  \
# 0                                                          True  Metadata
# 1   Amniotic Fluid,Appendix,B cell,Basophils,Bone,...      True  Metadata
# 2                                                         False     Other
# 3                                   No,YesUseReagent       True  Metadata
# 4                                                         False  Metadata
# 5                                                         False  Metadata
# 6                                                         False  Metadata
# 7                                                         False  Metadata
# 8                                                         False  Metadata
# 9                                                         False  Metadata
# 10                                                        False  Metadata
# 11                                No,YesUseTreatment       True  Metadata
# 12                                                        False  Metadata
# 13                                                        False  Metadata
# 14                                                        False  Metadata
# 15                                                        False  Metadata
# 16                                                        False  Metadata
# 17                                                        False  Metadata
# 18                                                        False  Metadata
# 19                                                        False  Metadata
# 20  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     False  Metadata
# 21                                                        False     Other
#
#    columnType                  Ontology  \
# 0      string          Sage Bionetworks
# 1      string  Sage Bionetworks,ImmPort
# 2      string          Sage Bionetworks
# 3     boolean  Sage Bionetworks,ImmPort
# 4      string  Sage Bionetworks,ImmPort
# 5      string  Sage Bionetworks,ImmPort
# 6      string  Sage Bionetworks,ImmPort
# 7      string  Sage Bionetworks,ImmPort
# 8      string  Sage Bionetworks,ImmPort
# 9      string  Sage Bionetworks,ImmPort
# 10     string  Sage Bionetworks,ImmPort
# 11    boolean  Sage Bionetworks,ImmPort
# 12     string  Sage Bionetworks,ImmPort
# 13     string  Sage Bionetworks,ImmPort
# 14     string  Sage Bionetworks,ImmPort
# 15     number  Sage Bionetworks,ImmPort
# 16     number
# 17     string  Sage Bionetworks,ImmPort
# 18     number  Sage Bionetworks,ImmPort
# 19     string  Sage Bionetworks,ImmPort
# 20     string  Sage Bionetworks,ImmPort
# 21     string          Sage Bionetworks
#
#                                                 Notes      Properties
# 0                                                      ManifestColumn
# 1   The sample types are adopted from Uberon, Cell...  ManifestColumn
# 2                                                      ManifestColumn
# 3                                                      ManifestColumn
# 4                                                      ManifestColumn
# 5                                                      ManifestColumn
# 6                                                      ManifestColumn
# 7                                                      ManifestColumn
# 8                                                      ManifestColumn
# 9                                                      ManifestColumn
# 10                                                     ManifestColumn
# 11                                                     ManifestColumn
# 12                                                     ManifestColumn
# 13                                                     ManifestColumn
# 14                                                     ManifestColumn
# 15                                                     ManifestColumn
# 16                                                     ManifestColumn
# 17                                                     ManifestColumn
# 18                                                     ManifestColumn
# 19                                                     ManifestColumn
# 20                                                     ManifestColumn
# 21                                                     ManifestColumn

# %%
print("Shape of original data frame:", new_temp_df.shape)
print("Shape of others data frame:", new_temp_df_others.shape)

new_temp_df_final = pd.concat([new_temp_df, new_temp_df_others]).reset_index(drop=True)
new_temp_df_final = new_temp_df_final.set_index("Attribute")

new_temp_df_final['columnType'] = new_temp_df_final['columnType'].str.upper()

new_temp_df_final = new_temp_df_final.drop(columns=['OtherValue'])

new_temp_df_final = new_temp_df_final.reset_index().replace("", np.nan)

# combine duplicated rows
new_temp_df_final = new_temp_df_final.fillna("").astype(str).groupby('Attribute').apply(
    lambda x: x.apply(lambda y: ",".join(np.unique(y)))
)
new_temp_df_final = new_temp_df_final.drop(columns = 'Attribute')

print("Shape of final data frame:", new_temp_df_final.shape)

new_temp_df_final.info()
# Out:
# Shape of original data frame: (22, 9)
# Shape of others data frame: (16, 12)
# Shape of final data frame: (26, 10)
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, OtherMeasurementTechnique  to useTreatment
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Description   26 non-null     object
#  1   Valid Values  26 non-null     object
#  2   Required      26 non-null     object
#  3   Module        26 non-null     object
#  4   columnType    26 non-null     object
#  5   Ontology      26 non-null     object
#  6   Notes         26 non-null     object
#  7   Properties    26 non-null     object
#  8   DependsOn     26 non-null     object
#  9   Parent        26 non-null     object
# dtypes: object(10)
# memory usage: 2.2+ KB
# /var/folders/p0/5m4pdsm55jn_d5nzbjv6bjf40000gq/T/ipykernel_43240/4026748114.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   new_temp_df_final = new_temp_df_final.fillna("").astype(str).groupby('Attribute').apply(

# %%
new_temp_attr =[{
"Attribute":template_name ,
"Description":f"Template for {template_name}" ,
"DependsOn": 'Component,Filename,' + ','.join(list(new_temp_df_final.index)),
"Valid Values":"" ,
"Required":False ,
"Module":"Template" ,
"columnType":"" ,
"Ontology":"Sage Bionetworks" ,
"Notes":"" ,
"Properties":"" ,
"Parent":"Component",
}]

new_temp_attr
# Out:
# [{'Attribute': 'genotyping_assay',
#   'Description': 'Template for genotyping_assay',
#   'DependsOn': 'Component,Filename,OtherMeasurementTechnique ,OtherSampleType ,YesUseReagent ,YesUseTreatment ,measurementTechnique,reagentCatalogNumber,reagentContact,reagentIDs,reagentLotNumber,reagentManufacturer,reagentName,reagentWeblink,sampleType,specifyMeasurementTechnique,specifySampleType,specimenID,treatmentAmountUnit,treatmentAmountValue,treatmentDurationUnit,treatmentDurationValue,treatmentIDs,treatmentName,treatmentTemperatureUnit,treatmentTemperatureValue,useReagent,useTreatment',
#   'Valid Values': '',
#   'Required': False,
#   'Module': 'Template',
#   'columnType': '',
#   'Ontology': 'Sage Bionetworks',
#   'Notes': '',
#   'Properties': '',
#   'Parent': 'Component'}]

# %%
new_temp_df_final["UsedIn"] = template_name
new_temp_df_final = pd.concat([new_temp_df_final, pd.DataFrame(new_temp_attr).set_index('Attribute')]).replace("", np.nan)
new_temp_df_final
# Out:
#                                                                    Description  \
# Attribute
# OtherMeasurementTechnique    When column = `other`, add your custom value t...
# OtherSampleType              When column = `other`, add your custom value t...
# YesUseReagent                When column = `Yes`, add your custom value to ...
# YesUseTreatment              When column = `Yes`, add your custom value to ...
# measurementTechnique         The measurement technique describing the assay...
# reagentCatalogNumber         If the assay reagent is a commercial product, ...
# reagentContact               The contact information is particularly helpfu...
# reagentIDs                   One or more identifiers, separated by a semico...
# reagentLotNumber             The lot number is often provided by a reagent ...
# reagentManufacturer          The manufacturer is the source of a reagent an...
# reagentName                  The reagent name is an alternative to the Reag...
# reagentWeblink               An internet address that may provide details o...
# sampleType                                        The type of sample collected
# specifyMeasurementTechnique  If "other" is selected list the name of the me...
# specifySampleType               If "other" is selected list the type of sample
# specimenID                   Identifying string linked to a particular samp...
# treatmentAmountUnit                                   Unit of treatment amount
# treatmentAmountValue         The Amount Value indicates how much (concentra...
# treatmentDurationUnit                               Unit of treatment duration
# treatmentDurationValue                                   Duration of treatment
# treatmentIDs                 One or more identifiers, separated by a semico...
# treatmentName                Treatments refer to in vitro modifications of ...
# treatmentTemperatureUnit                         Unit of treatment temperature
# treatmentTemperatureValue                       Value of treatment temperature
# useReagent                                Was a reagent applied to the sample?
# useTreatment                            Was a treatment applied to the sample?
# genotyping_assay                                 Template for genotyping_assay
#
#                                                                   Valid Values  \
# Attribute
# OtherMeasurementTechnique                                                  NaN
# OtherSampleType                                                            NaN
# YesUseReagent                                                              NaN
# YesUseTreatment                                                            NaN
# measurementTechnique         16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...
# reagentCatalogNumber                                                       NaN
# reagentContact                                                             NaN
# reagentIDs                                                                 NaN
# reagentLotNumber                                                           NaN
# reagentManufacturer                                                        NaN
# reagentName                                                                NaN
# reagentWeblink                                                             NaN
# sampleType                   Amniotic Fluid,Appendix,B cell,Basophils,Bone,...
# specifyMeasurementTechnique                                                NaN
# specifySampleType                                                          NaN
# specimenID                                                                 NaN
# treatmentAmountUnit                                                        NaN
# treatmentAmountValue                                                       NaN
# treatmentDurationUnit                                                      NaN
# treatmentDurationValue                                                     NaN
# treatmentIDs                                                               NaN
# treatmentName                                                              NaN
# treatmentTemperatureUnit                                                   NaN
# treatmentTemperatureValue                                                  NaN
# useReagent                                                   No,YesUseReagent
# useTreatment                                               No,YesUseTreatment
# genotyping_assay                                                           NaN
#
#                             Required    Module columnType  \
# Attribute
# OtherMeasurementTechnique      False     Other     STRING
# OtherSampleType                False     Other     STRING
# YesUseReagent                  False     Other     STRING
# YesUseTreatment                False     Other     STRING
# measurementTechnique           False  Metadata     STRING
# reagentCatalogNumber           False  Metadata     STRING
# reagentContact                 False  Metadata     STRING
# reagentIDs                     False  Metadata     STRING
# reagentLotNumber               False  Metadata     STRING
# reagentManufacturer            False  Metadata     STRING
# reagentName                    False  Metadata     STRING
# reagentWeblink                 False  Metadata     STRING
# sampleType                      True  Metadata     STRING
# specifyMeasurementTechnique    False     Other     STRING
# specifySampleType              False     Other     STRING
# specimenID                      True  Metadata     STRING
# treatmentAmountUnit            False  Metadata     NUMBER
# treatmentAmountValue           False  Metadata     STRING
# treatmentDurationUnit          False  Metadata     STRING
# treatmentDurationValue         False  Metadata     NUMBER
# treatmentIDs                   False  Metadata     STRING
# treatmentName                  False  Metadata     STRING
# treatmentTemperatureUnit       False  Metadata     STRING
# treatmentTemperatureValue      False  Metadata     NUMBER
# useReagent                      True  Metadata    BOOLEAN
# useTreatment                    True  Metadata    BOOLEAN
# genotyping_assay               False  Template        NaN
#
#                                              Ontology  \
# Attribute
# OtherMeasurementTechnique            Sage Bionetworks
# OtherSampleType                      Sage Bionetworks
# YesUseReagent                        Sage Bionetworks
# YesUseTreatment                      Sage Bionetworks
# measurementTechnique         Sage Bionetworks,ImmPort
# reagentCatalogNumber         Sage Bionetworks,ImmPort
# reagentContact               Sage Bionetworks,ImmPort
# reagentIDs                   Sage Bionetworks,ImmPort
# reagentLotNumber             Sage Bionetworks,ImmPort
# reagentManufacturer          Sage Bionetworks,ImmPort
# reagentName                  Sage Bionetworks,ImmPort
# reagentWeblink               Sage Bionetworks,ImmPort
# sampleType                   Sage Bionetworks,ImmPort
# specifyMeasurementTechnique          Sage Bionetworks
# specifySampleType                    Sage Bionetworks
# specimenID                           Sage Bionetworks
# treatmentAmountUnit          Sage Bionetworks,ImmPort
# treatmentAmountValue         Sage Bionetworks,ImmPort
# treatmentDurationUnit        Sage Bionetworks,ImmPort
# treatmentDurationValue                            NaN
# treatmentIDs                 Sage Bionetworks,ImmPort
# treatmentName                Sage Bionetworks,ImmPort
# treatmentTemperatureUnit     Sage Bionetworks,ImmPort
# treatmentTemperatureValue    Sage Bionetworks,ImmPort
# useReagent                   Sage Bionetworks,ImmPort
# useTreatment                 Sage Bionetworks,ImmPort
# genotyping_assay                     Sage Bionetworks
#
#                                                                          Notes  \
# Attribute
# OtherMeasurementTechnique                                                  NaN
# OtherSampleType                                                            NaN
# YesUseReagent                                                              NaN
# YesUseTreatment                                                            NaN
# measurementTechnique                                                       NaN
# reagentCatalogNumber                                                       NaN
# reagentContact                                                             NaN
# reagentIDs                                                                 NaN
# reagentLotNumber                                                           NaN
# reagentManufacturer                                                        NaN
# reagentName                                                                NaN
# reagentWeblink                                                             NaN
# sampleType                   The sample types are adopted from Uberon, Cell...
# specifyMeasurementTechnique                                                NaN
# specifySampleType                                                          NaN
# specimenID                                                                 NaN
# treatmentAmountUnit                                                        NaN
# treatmentAmountValue                                                       NaN
# treatmentDurationUnit                                                      NaN
# treatmentDurationValue                                                     NaN
# treatmentIDs                                                               NaN
# treatmentName                                                              NaN
# treatmentTemperatureUnit                                                   NaN
# treatmentTemperatureValue                                                  NaN
# useReagent                                                                 NaN
# useTreatment                                                               NaN
# genotyping_assay                                                           NaN
#
#                                  Properties  \
# Attribute
# OtherMeasurementTechnique        ValidValue
# OtherSampleType                  ValidValue
# YesUseReagent                    ValidValue
# YesUseTreatment                  ValidValue
# measurementTechnique         ManifestColumn
# reagentCatalogNumber         ManifestColumn
# reagentContact               ManifestColumn
# reagentIDs                   ManifestColumn
# reagentLotNumber             ManifestColumn
# reagentManufacturer          ManifestColumn
# reagentName                  ManifestColumn
# reagentWeblink               ManifestColumn
# sampleType                   ManifestColumn
# specifyMeasurementTechnique  ManifestColumn
# specifySampleType            ManifestColumn
# specimenID                   ManifestColumn
# treatmentAmountUnit          ManifestColumn
# treatmentAmountValue         ManifestColumn
# treatmentDurationUnit        ManifestColumn
# treatmentDurationValue       ManifestColumn
# treatmentIDs                 ManifestColumn
# treatmentName                ManifestColumn
# treatmentTemperatureUnit     ManifestColumn
# treatmentTemperatureValue    ManifestColumn
# useReagent                   ManifestColumn
# useTreatment                 ManifestColumn
# genotyping_assay                        NaN
#
#                                                                      DependsOn  \
# Attribute
# OtherMeasurementTechnique                          specifyMeasurementTechnique
# OtherSampleType                                              specifySampleType
# YesUseReagent                reagentCatalogNumber,reagentContact,reagentIDs...
# YesUseTreatment              treatmentAmountUnit,treatmentAmountValue,treat...
# measurementTechnique                                                       NaN
# reagentCatalogNumber                                                       NaN
# reagentContact                                                             NaN
# reagentIDs                                                                 NaN
# reagentLotNumber                                                           NaN
# reagentManufacturer                                                        NaN
# reagentName                                                                NaN
# reagentWeblink                                                             NaN
# sampleType                                                                 NaN
# specifyMeasurementTechnique                                                NaN
# specifySampleType                                                          NaN
# specimenID                                                                 NaN
# treatmentAmountUnit                                                        NaN
# treatmentAmountValue                                                       NaN
# treatmentDurationUnit                                                      NaN
# treatmentDurationValue                                                     NaN
# treatmentIDs                                                               NaN
# treatmentName                                                              NaN
# treatmentTemperatureUnit                                                   NaN
# treatmentTemperatureValue                                                  NaN
# useReagent                                                                 NaN
# useTreatment                                                               NaN
# genotyping_assay             Component,Filename,OtherMeasurementTechnique ,...
#
#                                            Parent            UsedIn
# Attribute
# OtherMeasurementTechnique    measurementTechnique  genotyping_assay
# OtherSampleType                        sampleType  genotyping_assay
# YesUseReagent                          useReagent  genotyping_assay
# YesUseTreatment                      useTreatment  genotyping_assay
# measurementTechnique                          NaN  genotyping_assay
# reagentCatalogNumber                          NaN  genotyping_assay
# reagentContact                                NaN  genotyping_assay
# reagentIDs                                    NaN  genotyping_assay
# reagentLotNumber                              NaN  genotyping_assay
# reagentManufacturer                           NaN  genotyping_assay
# reagentName                                   NaN  genotyping_assay
# reagentWeblink                                NaN  genotyping_assay
# sampleType                                    NaN  genotyping_assay
# specifyMeasurementTechnique                   NaN  genotyping_assay
# specifySampleType                             NaN  genotyping_assay
# specimenID                                    NaN  genotyping_assay
# treatmentAmountUnit                           NaN  genotyping_assay
# treatmentAmountValue                          NaN  genotyping_assay
# treatmentDurationUnit                         NaN  genotyping_assay
# treatmentDurationValue                        NaN  genotyping_assay
# treatmentIDs                                  NaN  genotyping_assay
# treatmentName                                 NaN  genotyping_assay
# treatmentTemperatureUnit                      NaN  genotyping_assay
# treatmentTemperatureValue                     NaN  genotyping_assay
# useReagent                                    NaN  genotyping_assay
# useTreatment                                  NaN  genotyping_assay
# genotyping_assay                        Component               NaN

# %%
# unique index
new_temp_df_final.index.is_unique
# Out:
# True

# %%
new_temp_df_final = new_temp_df_final.sort_index(key = lambda x: x.str.lower())
new_temp_df_final
# Out:
#                                                                    Description  \
# Attribute
# genotyping_assay                                 Template for genotyping_assay
# measurementTechnique         The measurement technique describing the assay...
# OtherMeasurementTechnique    When column = `other`, add your custom value t...
# OtherSampleType              When column = `other`, add your custom value t...
# reagentCatalogNumber         If the assay reagent is a commercial product, ...
# reagentContact               The contact information is particularly helpfu...
# reagentIDs                   One or more identifiers, separated by a semico...
# reagentLotNumber             The lot number is often provided by a reagent ...
# reagentManufacturer          The manufacturer is the source of a reagent an...
# reagentName                  The reagent name is an alternative to the Reag...
# reagentWeblink               An internet address that may provide details o...
# sampleType                                        The type of sample collected
# specifyMeasurementTechnique  If "other" is selected list the name of the me...
# specifySampleType               If "other" is selected list the type of sample
# specimenID                   Identifying string linked to a particular samp...
# treatmentAmountUnit                                   Unit of treatment amount
# treatmentAmountValue         The Amount Value indicates how much (concentra...
# treatmentDurationUnit                               Unit of treatment duration
# treatmentDurationValue                                   Duration of treatment
# treatmentIDs                 One or more identifiers, separated by a semico...
# treatmentName                Treatments refer to in vitro modifications of ...
# treatmentTemperatureUnit                         Unit of treatment temperature
# treatmentTemperatureValue                       Value of treatment temperature
# useReagent                                Was a reagent applied to the sample?
# useTreatment                            Was a treatment applied to the sample?
# YesUseReagent                When column = `Yes`, add your custom value to ...
# YesUseTreatment              When column = `Yes`, add your custom value to ...
#
#                                                                   Valid Values  \
# Attribute
# genotyping_assay                                                           NaN
# measurementTechnique         16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...
# OtherMeasurementTechnique                                                  NaN
# OtherSampleType                                                            NaN
# reagentCatalogNumber                                                       NaN
# reagentContact                                                             NaN
# reagentIDs                                                                 NaN
# reagentLotNumber                                                           NaN
# reagentManufacturer                                                        NaN
# reagentName                                                                NaN
# reagentWeblink                                                             NaN
# sampleType                   Amniotic Fluid,Appendix,B cell,Basophils,Bone,...
# specifyMeasurementTechnique                                                NaN
# specifySampleType                                                          NaN
# specimenID                                                                 NaN
# treatmentAmountUnit                                                        NaN
# treatmentAmountValue                                                       NaN
# treatmentDurationUnit                                                      NaN
# treatmentDurationValue                                                     NaN
# treatmentIDs                                                               NaN
# treatmentName                                                              NaN
# treatmentTemperatureUnit                                                   NaN
# treatmentTemperatureValue                                                  NaN
# useReagent                                                   No,YesUseReagent
# useTreatment                                               No,YesUseTreatment
# YesUseReagent                                                              NaN
# YesUseTreatment                                                            NaN
#
#                             Required    Module columnType  \
# Attribute
# genotyping_assay               False  Template        NaN
# measurementTechnique           False  Metadata     STRING
# OtherMeasurementTechnique      False     Other     STRING
# OtherSampleType                False     Other     STRING
# reagentCatalogNumber           False  Metadata     STRING
# reagentContact                 False  Metadata     STRING
# reagentIDs                     False  Metadata     STRING
# reagentLotNumber               False  Metadata     STRING
# reagentManufacturer            False  Metadata     STRING
# reagentName                    False  Metadata     STRING
# reagentWeblink                 False  Metadata     STRING
# sampleType                      True  Metadata     STRING
# specifyMeasurementTechnique    False     Other     STRING
# specifySampleType              False     Other     STRING
# specimenID                      True  Metadata     STRING
# treatmentAmountUnit            False  Metadata     NUMBER
# treatmentAmountValue           False  Metadata     STRING
# treatmentDurationUnit          False  Metadata     STRING
# treatmentDurationValue         False  Metadata     NUMBER
# treatmentIDs                   False  Metadata     STRING
# treatmentName                  False  Metadata     STRING
# treatmentTemperatureUnit       False  Metadata     STRING
# treatmentTemperatureValue      False  Metadata     NUMBER
# useReagent                      True  Metadata    BOOLEAN
# useTreatment                    True  Metadata    BOOLEAN
# YesUseReagent                  False     Other     STRING
# YesUseTreatment                False     Other     STRING
#
#                                              Ontology  \
# Attribute
# genotyping_assay                     Sage Bionetworks
# measurementTechnique         Sage Bionetworks,ImmPort
# OtherMeasurementTechnique            Sage Bionetworks
# OtherSampleType                      Sage Bionetworks
# reagentCatalogNumber         Sage Bionetworks,ImmPort
# reagentContact               Sage Bionetworks,ImmPort
# reagentIDs                   Sage Bionetworks,ImmPort
# reagentLotNumber             Sage Bionetworks,ImmPort
# reagentManufacturer          Sage Bionetworks,ImmPort
# reagentName                  Sage Bionetworks,ImmPort
# reagentWeblink               Sage Bionetworks,ImmPort
# sampleType                   Sage Bionetworks,ImmPort
# specifyMeasurementTechnique          Sage Bionetworks
# specifySampleType                    Sage Bionetworks
# specimenID                           Sage Bionetworks
# treatmentAmountUnit          Sage Bionetworks,ImmPort
# treatmentAmountValue         Sage Bionetworks,ImmPort
# treatmentDurationUnit        Sage Bionetworks,ImmPort
# treatmentDurationValue                            NaN
# treatmentIDs                 Sage Bionetworks,ImmPort
# treatmentName                Sage Bionetworks,ImmPort
# treatmentTemperatureUnit     Sage Bionetworks,ImmPort
# treatmentTemperatureValue    Sage Bionetworks,ImmPort
# useReagent                   Sage Bionetworks,ImmPort
# useTreatment                 Sage Bionetworks,ImmPort
# YesUseReagent                        Sage Bionetworks
# YesUseTreatment                      Sage Bionetworks
#
#                                                                          Notes  \
# Attribute
# genotyping_assay                                                           NaN
# measurementTechnique                                                       NaN
# OtherMeasurementTechnique                                                  NaN
# OtherSampleType                                                            NaN
# reagentCatalogNumber                                                       NaN
# reagentContact                                                             NaN
# reagentIDs                                                                 NaN
# reagentLotNumber                                                           NaN
# reagentManufacturer                                                        NaN
# reagentName                                                                NaN
# reagentWeblink                                                             NaN
# sampleType                   The sample types are adopted from Uberon, Cell...
# specifyMeasurementTechnique                                                NaN
# specifySampleType                                                          NaN
# specimenID                                                                 NaN
# treatmentAmountUnit                                                        NaN
# treatmentAmountValue                                                       NaN
# treatmentDurationUnit                                                      NaN
# treatmentDurationValue                                                     NaN
# treatmentIDs                                                               NaN
# treatmentName                                                              NaN
# treatmentTemperatureUnit                                                   NaN
# treatmentTemperatureValue                                                  NaN
# useReagent                                                                 NaN
# useTreatment                                                               NaN
# YesUseReagent                                                              NaN
# YesUseTreatment                                                            NaN
#
#                                  Properties  \
# Attribute
# genotyping_assay                        NaN
# measurementTechnique         ManifestColumn
# OtherMeasurementTechnique        ValidValue
# OtherSampleType                  ValidValue
# reagentCatalogNumber         ManifestColumn
# reagentContact               ManifestColumn
# reagentIDs                   ManifestColumn
# reagentLotNumber             ManifestColumn
# reagentManufacturer          ManifestColumn
# reagentName                  ManifestColumn
# reagentWeblink               ManifestColumn
# sampleType                   ManifestColumn
# specifyMeasurementTechnique  ManifestColumn
# specifySampleType            ManifestColumn
# specimenID                   ManifestColumn
# treatmentAmountUnit          ManifestColumn
# treatmentAmountValue         ManifestColumn
# treatmentDurationUnit        ManifestColumn
# treatmentDurationValue       ManifestColumn
# treatmentIDs                 ManifestColumn
# treatmentName                ManifestColumn
# treatmentTemperatureUnit     ManifestColumn
# treatmentTemperatureValue    ManifestColumn
# useReagent                   ManifestColumn
# useTreatment                 ManifestColumn
# YesUseReagent                    ValidValue
# YesUseTreatment                  ValidValue
#
#                                                                      DependsOn  \
# Attribute
# genotyping_assay             Component,Filename,OtherMeasurementTechnique ,...
# measurementTechnique                                                       NaN
# OtherMeasurementTechnique                          specifyMeasurementTechnique
# OtherSampleType                                              specifySampleType
# reagentCatalogNumber                                                       NaN
# reagentContact                                                             NaN
# reagentIDs                                                                 NaN
# reagentLotNumber                                                           NaN
# reagentManufacturer                                                        NaN
# reagentName                                                                NaN
# reagentWeblink                                                             NaN
# sampleType                                                                 NaN
# specifyMeasurementTechnique                                                NaN
# specifySampleType                                                          NaN
# specimenID                                                                 NaN
# treatmentAmountUnit                                                        NaN
# treatmentAmountValue                                                       NaN
# treatmentDurationUnit                                                      NaN
# treatmentDurationValue                                                     NaN
# treatmentIDs                                                               NaN
# treatmentName                                                              NaN
# treatmentTemperatureUnit                                                   NaN
# treatmentTemperatureValue                                                  NaN
# useReagent                                                                 NaN
# useTreatment                                                               NaN
# YesUseReagent                reagentCatalogNumber,reagentContact,reagentIDs...
# YesUseTreatment              treatmentAmountUnit,treatmentAmountValue,treat...
#
#                                            Parent            UsedIn
# Attribute
# genotyping_assay                        Component               NaN
# measurementTechnique                          NaN  genotyping_assay
# OtherMeasurementTechnique    measurementTechnique  genotyping_assay
# OtherSampleType                        sampleType  genotyping_assay
# reagentCatalogNumber                          NaN  genotyping_assay
# reagentContact                                NaN  genotyping_assay
# reagentIDs                                    NaN  genotyping_assay
# reagentLotNumber                              NaN  genotyping_assay
# reagentManufacturer                           NaN  genotyping_assay
# reagentName                                   NaN  genotyping_assay
# reagentWeblink                                NaN  genotyping_assay
# sampleType                                    NaN  genotyping_assay
# specifyMeasurementTechnique                   NaN  genotyping_assay
# specifySampleType                             NaN  genotyping_assay
# specimenID                                    NaN  genotyping_assay
# treatmentAmountUnit                           NaN  genotyping_assay
# treatmentAmountValue                          NaN  genotyping_assay
# treatmentDurationUnit                         NaN  genotyping_assay
# treatmentDurationValue                        NaN  genotyping_assay
# treatmentIDs                                  NaN  genotyping_assay
# treatmentName                                 NaN  genotyping_assay
# treatmentTemperatureUnit                      NaN  genotyping_assay
# treatmentTemperatureValue                     NaN  genotyping_assay
# useReagent                                    NaN  genotyping_assay
# useTreatment                                  NaN  genotyping_assay
# YesUseReagent                          useReagent  genotyping_assay
# YesUseTreatment                      useTreatment  genotyping_assay

# %%
# write out new cleaned template
new_temp_df_final.to_csv(Path(ROOT_DIR, 'data','rfc_tables_cleaned', template_name+'_cleaned_rfc.csv'))

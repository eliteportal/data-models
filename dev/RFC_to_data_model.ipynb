# %% [markdown]
# - Fix inconsistencies in parent column

# %%
import pandas as pd
import numpy as np
import os

from glob import glob
import yaml
import re
import copy
import json

# %% [markdown]
# # Hard Coded stuff

# %%
validation_coder = {
    "number": "regex search ([0-9]+\.[0-9]*.?)|([0-9]+)",
    "integer": "regex search ([0-9]+)",
    "string": "",
}

# %%
base_cols = [
    "Attribute",
    "Description",
    "Valid Values",
    "DependsOn",
    "Properties",
    "Required",
    "Parent",
    "DependsOn Component",
    "Source",
    "Validation Rules",
]

# %% [markdown]
# # Functions

# %%
# Clean list columns into single string
def join_strings(string):
    try:
        return ",".join(string)
    except:
        return ""

# %%
def search_df(df, pattern):
    mask = np.column_stack(
        [df[col].str.contains(pattern, na=False, flags=re.IGNORECASE) for col in df]
    )

    df = df.loc[mask.any(axis=1)]

    with pd.option_context("display.max_colwidth", None):
        display(df)

    return df

# %%
def find_row(df, attribute):
    """Get indexes of the dataframe"""
    indexes = df.index[
        df["Attribute"].str.contains(
            "(^" + re.escape(attribute) + "$)", flags=re.IGNORECASE
        )
    ].tolist()
    if len(indexes) != 0:
        return indexes
    else:
        print(attribute)
        return None


def replace_valid_value(df, indexes, regex_dict, attribute):
    """Alter the dataframe valid values with the replacement value"""
    if indexes == None:
        return df

    elif len(indexes) > 0:
        regex_dict = regex_dict[attribute]

        for index in indexes:
            df.loc[index, "Valid Values"] = re.sub(
                **regex_dict, string=df.loc[index, "Valid Values"]
            )

            # print(df.loc[index, 'Valid Values'])
        return df
    else:
        return df


def code_equals_values(df, regex_dict, attribute):
    print("attribute: ", attribute)

    indexes = find_row(df, attribute)

    print("Index: ", indexes)

    # regex = replace_value(df, replacements, indexes)

    # print("Regex: ", regex)
    if indexes == None:
        return df
    else:
        df = replace_valid_value(df, indexes, regex_dict, attribute)
        return df

# %%
# Unzip compressed folder if downloaded from Google Drive
# %unzip 'RFC Tables-20230620T181152Z-001.zip'

# %% [markdown]
# # Collect RFCs

# %%
with open("local_configs/notebook_config.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
# Get all the RFC file paths
file_paths = glob("../_data/RFC Tables/*")
file_paths
# Out:
# ['../_data/RFC Tables/EL Assay_ scRNAseq data model.xlsx',
#  '../_data/RFC Tables/EL RFC_ Individual_ Human data model.xlsx',
#  '../_data/RFC Tables/EL RFC_ Assay_proteomics Data Model.xlsx',
#  '../_data/RFC Tables/EL RFC Assay_Whole Genome Sequencing Data Model.xlsx',
#  '../_data/RFC Tables/EL RFC Microbiome Data Model.xlsx',
#  '../_data/RFC Tables/EL RFC_ Biospecimen_nonHuman data model.xlsx',
#  '../_data/RFC Tables/EL RFC_ Individual_ nonHuman data model.xlsx',
#  '../_data/RFC Tables/EL RFC Metabolomics Human Data Model.xlsx',
#  '../_data/RFC Tables/EL RFC genotyping_assay.xlsx',
#  '../_data/RFC Tables/EL RFC_ Biospecimen_human data model.xlsx',
#  '../_data/RFC Tables/EL Assay_ bsSeq (bisulfite-seq_WGBS_methylseq_methylomics) data model.xlsx',
#  '../_data/RFC Tables/EL Assay_ RNAseq data model.xlsx']

# %% [markdown]
# Create Data Model for Schematic

# %%
dm = pd.DataFrame()

# parse through files to create complete data model
for fp in file_paths:
    file_name = os.path.basename(fp)

    temp = pd.read_excel(fp)

    # Create file_name column to check
    temp.insert(loc=0, column="file_name", value=file_name)

    # Create new columnn for data model name
    temp.insert(
        loc=1,
        column="dm",
        value=re.sub(
            "\s\s+",
            " ",
            re.sub(
                "_",
                " ",
                re.sub(
                    "(EL)|(RFC)|(\.xlsx)|([Aa]ssay)|([Dd]ata [Mm]odel)", "", file_name
                ),
            ).strip(),
        ),
    )

    dm = pd.concat([dm, temp])

# %%
dm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 370 entries, 0 to 26
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   file_name                370 non-null    object
#  1   dm                       370 non-null    object
#  2   key                      370 non-null    object
#  3   description              370 non-null    object
#  4   valid values             221 non-null    object
#  5   required                 364 non-null    object
#  6   requires                 367 non-null    object
#  7   multivalue               365 non-null    object
#  8   type                     368 non-null    object
#  9   concept source ontology  367 non-null    object
#  10  note                     8 non-null      object
#  11  Unnamed: 9               0 non-null      float64
#  12  Unnamed: 10              2 non-null      object
#  13  ontology                 42 non-null     object
#  14  term id                  15 non-null     object
# dtypes: float64(1), object(14)
# memory usage: 46.2+ KB

# %%
# initial cleaning
dm[["required", "multivalue"]] = (
    dm[["required", "multivalue"]]
    .fillna(False)
    .astype(str)
    .replace({"1.0": True, "0.0": False})
)

dm.fillna("")
dm.reset_index(drop=True, inplace=True)
dm.head()
# Out:
#                             file_name        dm                          key  \
# 0  EL Assay_ scRNAseq data model.xlsx  scRNAseq                   specimenID
# 1  EL Assay_ scRNAseq data model.xlsx  scRNAseq                   sampleType
# 2  EL Assay_ scRNAseq data model.xlsx  scRNAseq            specifySampleType
# 3  EL Assay_ scRNAseq data model.xlsx  scRNAseq         measurementTechnique
# 4  EL Assay_ scRNAseq data model.xlsx  scRNAseq  specifyMeasurementTechnique
#
#                                          description  \
# 0  Identifying string linked to a particular samp...
# 1                       The type of sample collected
# 2     If "other" is selected list the type of sample
# 3  The measurement technique describing the assay...
# 4  If "other" is selected list the name of the me...
#
#                                         valid values required  \
# 0              n/a (unique to each data contributor)     True
# 1  Amniotic Fluid,\nAppendix,\nB cell,\nBasophils...     True
# 2                                                NaN    False
# 3  16S rRNA gene sequencing,\n1D Gel,\n2D Gel,\nA...     True
# 4                                                NaN    False
#
#                                   requires multivalue    type  \
# 0                    scRNAseq, Biospecimen      False  string
# 1                                 scRNAseq      False  string
# 2            scRNAseq,\nsampleType = other      False  string
# 3                                 scRNAseq      False  string
# 4  scRNAseq,\nmeasurementTechnique = other      False  string
#
#       concept source ontology  \
# 0            Sage Bionetworks
# 1  Sage Bionetworks,\nImmPort
# 2            Sage Bionetworks
# 3            Sage Bionetworks
# 4            Sage Bionetworks
#
#                                                 note  Unnamed: 9  \
# 0                                                NaN         NaN
# 1  The sample types are adopted from Uberon, Cell...         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#         Unnamed: 10 ontology term id
# 0  Sage Bionetworks      NaN     NaN
# 1               NaN      NaN     NaN
# 2               NaN      NaN     NaN
# 3               NaN      NaN     NaN
# 4               NaN      NaN     NaN

# %% [markdown]
# Data model clean up

# %%
# collapse presumed ontology columns and join with existing
dm.loc[:, "ontology"] = dm.iloc[:, 11:].bfill(axis=1).iloc[:, 0]
dm["ontology"] = (
    dm[["concept source ontology", "ontology"]]
    .fillna("")
    .apply(lambda x: ",".join([y.strip() for y in x.unique() if len(y) > 0]), axis=1)
)

# if unique values are provided by data contributor then add this note in the ontology

dm["ontology"] = (
    dm.loc[
        dm["valid values"].str.contains(
            "(n/a \(unique to each data contributor\))", na=False
        ),
        "ontology",
    ]
    + ","
    + "Data Contributor"
)
# Out:
# /var/folders/p0/5m4pdsm55jn_d5nzbjv6bjf40000gq/T/ipykernel_97139/1778036307.py:13: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   dm["valid values"].str.contains(

# %%
dm = dm.apply(
    lambda x: x.str.replace(
        pat="\n|(n/a \(unique to each data contributor\))", repl="", regex=True
    ).str.split(","),
    axis=1,
)

dm.head()
# Out:
#                               file_name          dm  \
# 0  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
# 1  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
# 2  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
# 3  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
# 4  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
#
#                              key  \
# 0                   [specimenID]
# 1                   [sampleType]
# 2            [specifySampleType]
# 3         [measurementTechnique]
# 4  [specifyMeasurementTechnique]
#
#                                          description  \
# 0  [Identifying string linked to a particular sam...
# 1                     [The type of sample collected]
# 2   [If "other" is selected list the type of sample]
# 3  [The measurement technique describing the assa...
# 4  [If "other" is selected list the name of the m...
#
#                                         valid values required  \
# 0                                                 []   [True]
# 1  [Amniotic Fluid, Appendix, B cell, Basophils, ...   [True]
# 2                                                NaN  [False]
# 3  [16S rRNA gene sequencing, 1D Gel, 2D Gel, Arr...   [True]
# 4                                                NaN  [False]
#
#                                    requires multivalue      type  \
# 0                  [scRNAseq,  Biospecimen]    [False]  [string]
# 1                                [scRNAseq]    [False]  [string]
# 2            [scRNAseq, sampleType = other]    [False]  [string]
# 3                                [scRNAseq]    [False]  [string]
# 4  [scRNAseq, measurementTechnique = other]    [False]  [string]
#
#        concept source ontology  \
# 0           [Sage Bionetworks]
# 1  [Sage Bionetworks, ImmPort]
# 2           [Sage Bionetworks]
# 3           [Sage Bionetworks]
# 4           [Sage Bionetworks]
#
#                                                 note  Unnamed: 9  \
# 0                                                NaN         NaN
# 1  [The sample types are adopted from Uberon,  Ce...         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#           Unnamed: 10                              ontology term id
# 0  [Sage Bionetworks]  [Sage Bionetworks, Data Contributor]     NaN
# 1                 NaN                                   NaN     NaN
# 2                 NaN                                   NaN     NaN
# 3                 NaN                                   NaN     NaN
# 4                 NaN                                   NaN     NaN

# %%
# revert lists back to strings
dm = dm.applymap(lambda x: join_strings(x))

# Rename columns with DCA standards
dm_schema_cols = {
    "dm": "Parent",
    "key": "Attribute",
    "description": "Description",
    "valid values": "Valid Values",
    "required": "Required",
    "requires": "DependsOn Component",
    "concept source ontology": "Source",
    "ontology": "Ontology",
    "type": "Type",
}

dm = dm.rename(dm_schema_cols, axis=1)

# drop unimportant columns
r = re.compile("Unnamed*", re.IGNORECASE)

# Add additional required columns for DCA
dm["Properties"] = ""
dm["Validation Rules"] = dm["Type"].map(validation_coder)
dm["DependsOn"] = ""
# dm['DependsOn Component'] = ""

keep_cols = [
    "Parent",
    "Attribute",
    "Description",
    "Valid Values",
    "Required",
    "DependsOn",
    "DependsOn Component",
    "Properties",
    "Validation Rules",
    "Source",
    "Type",
    "Ontology",
    "multivalue",
]

dm = dm[keep_cols]

dm.head()
# Out:
#      Parent                    Attribute  \
# 0  scRNAseq                   specimenID
# 1  scRNAseq                   sampleType
# 2  scRNAseq            specifySampleType
# 3  scRNAseq         measurementTechnique
# 4  scRNAseq  specifyMeasurementTechnique
#
#                                          Description  \
# 0  Identifying string linked to a particular samp...
# 1                       The type of sample collected
# 2     If "other" is selected list the type of sample
# 3  The measurement technique describing the assay...
# 4  If "other" is selected list the name of the me...
#
#                                         Valid Values Required DependsOn  \
# 0                                                        True
# 1  Amniotic Fluid,Appendix,B cell,Basophils,Bone,...     True
# 2                                                       False
# 3  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
# 4                                                       False
#
#                      DependsOn Component Properties Validation Rules  \
# 0                  scRNAseq, Biospecimen
# 1                               scRNAseq
# 2            scRNAseq,sampleType = other
# 3                               scRNAseq
# 4  scRNAseq,measurementTechnique = other
#
#                      Source    Type                           Ontology  \
# 0          Sage Bionetworks  string  Sage Bionetworks,Data Contributor
# 1  Sage Bionetworks,ImmPort  string
# 2          Sage Bionetworks  string
# 3          Sage Bionetworks  string
# 4          Sage Bionetworks  string
#
#   multivalue
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
dm.query('Attribute == "measurementTechnique"')
# Out:
#                                                Parent             Attribute  \
# 3                                            scRNAseq  measurementTechnique
# 56                                         proteomics  measurementTechnique
# 98                            Whole Genome Sequencing  measurementTechnique
# 130                                        Microbiome  measurementTechnique
# 195                                Metabolomics Human  measurementTechnique
# 279                                        genotyping  measurementTechnique
# 284                                 Biospecimen human  measurementTechnique
# 299  bsSeq (bisulfite-seq WGBS methylseq methylomics)  measurementTechnique
# 346                                            RNAseq  measurementTechnique
#
#                                            Description  \
# 3    The measurement technique describing the assay...
# 56   The measurement technique describing the assay...
# 98   The measurement technique describing the assay...
# 130  The measurement technique describing the assay...
# 195  The measurement technique describing the assay...
# 279  The measurement technique describing the assay...
# 284  The measurement technique describing the assay...
# 299  The measurement technique describing the assay...
# 346  The measurement technique describing the assay...
#
#                                           Valid Values Required DependsOn  \
# 3    16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
# 56   16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
# 98   16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
# 130  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
# 195  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
# 279  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...
# 284  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
# 299  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
# 346  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
#
#        DependsOn Component Properties Validation Rules  \
# 3                 scRNAseq
# 56    mass spec proteomics
# 98                     WGS
# 130             microbiome
# 195  mass spec metabolmics
# 279            genotyping
# 284            Biospecimen
# 299                 bsSeq
# 346                 RNAseq
#
#                        Source    Type Ontology multivalue
# 3            Sage Bionetworks  string               False
# 56           Sage Bionetworks  string               False
# 98           Sage Bionetworks  string               False
# 130          Sage Bionetworks  string               False
# 195          Sage Bionetworks  string
# 279  Sage Bionetworks,ImmPort  string
# 284          Sage Bionetworks  string               False
# 299          Sage Bionetworks  string               false
# 346          Sage Bionetworks  string               False

# %%
dm[dm.duplicated(subset="Attribute")].sort_values(by="Attribute")
# Out:
#                       Parent                  Attribute  \
# 215       Metabolomics Human            acquisitionMode
# 216       Metabolomics Human        acquisitionSoftware
# 217       Metabolomics Human  acquistionSoftwareVersion
# 293        Biospecimen human                   cellType
# 181      Individual nonHuman                     cohort
# ..                       ...                        ...
# 159               Microbiome                 totalReads
# 107  Whole Genome Sequencing             transcriptType
# 355                   RNAseq             transcriptType
# 358                   RNAseq              valueReported
# 110  Whole Genome Sequencing              valueReported
#
#                                            Description  \
# 215  The specific aspect of a mass spectrometer met...
# 216          The name of the acquisition software used
# 217                The version number of software used
# 293                           Indicate the cell type.
# 181       Name of the cohort the individual belongs to
# ..                                                 ...
# 159    Total number of sequencing reads from a library
# 107                    The type of transcript reported
# 355                    The type of transcript reported
# 358         The count or gene count for the transcript
# 110         The count or gene count for the transcript
#
#                                           Valid Values Required DependsOn  \
# 215  Unknown,Not collected,Not applicable,Not speci...     True
# 216  Unknown,Not collected,Not applicable,Not speci...     True
# 217                                                        True
# 293  CCF-BSO values (not listed for purposes of thi...     True
# 181        Other, Unknown,Not collected,Not applicable     True
# ..                                                 ...      ...       ...
# 159                                                        True
# 107  lincRNA,mRNA,snRNA,OtherUnknown,Not collected,...     True
# 355  lincRNA,mRNA,snRNA,OtherUnknown,Not collected,...     True
# 358                                                        True
# 110                                                        True
#
#        DependsOn Component Properties  \
# 215  mass spec metabolmics
# 216  mass spec metabolmics
# 217  mass spec metabolmics
# 293            Biospecimen
# 181             Individual
# ..                     ...        ...
# 159             microbiome
# 107                    WGS
# 355                 RNAseq
# 358                 RNAseq
# 110                    WGS
#
#                              Validation Rules  \
# 215
# 216
# 217  regex search ([0-9]+\.[0-9]*.?)|([0-9]+)
# 293
# 181
# ..                                        ...
# 159  regex search ([0-9]+\.[0-9]*.?)|([0-9]+)
# 107
# 355
# 358  regex search ([0-9]+\.[0-9]*.?)|([0-9]+)
# 110  regex search ([0-9]+\.[0-9]*.?)|([0-9]+)
#
#                                                 Source    Type Ontology  \
# 215  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...  string
# 216          http://purl.obolibrary.org/obo/MS_1001455  string
# 217                                   Sage Bionetworks  number
# 293  https://bioportal.bioontology.org/ontologies/C...  string
# 181                                   Sage Bionetworks  string
# ..                                                 ...     ...      ...
# 159                                   Sage Bionetworks  number
# 107                                            ImmPort  string
# 355                                            ImmPort  string
# 358                                   Sage Bionetworks  number
# 110                                   Sage Bionetworks  number
#
#     multivalue
# 215
# 216
# 217
# 293      False
# 181       True
# ..         ...
# 159      False
# 107      False
# 355      False
# 358      False
# 110      False
#
# [190 rows x 13 columns]

# %%
# combine duplicated attributes
dm = dm.groupby("Attribute").agg(lambda x: ",".join(set(x.astype(str)))).reset_index()

# %%
dm.head()
# Out:
#                   Attribute                         Parent  \
# 0        acquisitionBatchID             Metabolomics Human
# 1      acquisitionBatchSize             Metabolomics Human
# 2  acquisitionBatchSizeUnit             Metabolomics Human
# 3           acquisitionMode  proteomics,Metabolomics Human
# 4       acquisitionSoftware  proteomics,Metabolomics Human
#
#                                          Description  \
# 0  Acquisition batch identifier, provided by the ...
# 1                              The number of samples
# 2  The unit of measurement for number of samples ...
# 3  The specific aspect of a mass spectrometer met...
# 4          The name of the acquisition software used
#
#                                         Valid Values Required DependsOn  \
# 0                                                       False
# 1                                                       False
# 2  AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...    False
# 3  Unknown,Not collected,Not applicable,Not speci...     True
# 4  Unknown,Not collected,Not applicable,Not speci...     True
#
#                           DependsOn Component Properties Validation Rules  \
# 0                       mass spec metabolmics
# 1                       mass spec metabolmics
# 2  mass spec metabolmics,acquisitionBatchSize
# 3  mass spec proteomics,mass spec metabolmics
# 4  mass spec proteomics,mass spec metabolmics
#
#                                               Source    Type Ontology  \
# 0                                   Sage Bionetworks  string
# 1                                   Sage Bionetworks  string
# 2                                   Sage Bionetworks  string
# 3  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...  string
# 4          http://purl.obolibrary.org/obo/MS_1001455  string
#
#   multivalue
# 0
# 1
# 2
# 3     ,False
# 4     ,False

# %%
# # Dropping measurement technique
# dm = dm.drop(
#     index=dm.query('Attribute == "measurementTechnique"').index.values
# ).reset_index(drop=True)

# %%
# dm.reset_index(drop=True, inplace=True)

# # QA Check
# dm["Parent"].unique()

# %%
# QA Check
dm["Parent"].unique()
# Out:
# array(['Metabolomics Human', 'proteomics,Metabolomics Human',
#        'Individual Human', 'Biospecimen nonHuman', 'Individual nonHuman',
#        'Biospecimen nonHuman,Biospecimen human', 'proteomics',
#        'Individual nonHuman,Individual Human',
#        'bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Metabolomics Human,Microbiome',
#        'Individual nonHuman,Biospecimen nonHuman,Individual Human,Biospecimen human',
#        'Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq',
#        'Whole Genome Sequencing,scRNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Metabolomics Human,proteomics,Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq,Biospecimen human,genotyping',
#        'Metabolomics Human,proteomics,Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq',
#        'genotyping',
#        'Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq',
#        'Whole Genome Sequencing,scRNAseq,RNAseq',
#        'Whole Genome Sequencing,scRNAseq', 'scRNAseq',
#        'Metabolomics Human,proteomics,Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq,genotyping',
#        'scRNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome',
#        'Metabolomics Human,proteomics,Biospecimen nonHuman,Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq,Biospecimen human,genotyping'],
#       dtype=object)

# %%
display(dm.dtypes)
display(dm.head())
display(dm.Parent.unique())
# Out:
# Attribute              object
# Parent                 object
# Description            object
# Valid Values           object
# Required               object
# DependsOn              object
# DependsOn Component    object
# Properties             object
# Validation Rules       object
# Source                 object
# Type                   object
# Ontology               object
# multivalue             object
# dtype: object
#                   Attribute                         Parent  \
# 0        acquisitionBatchID             Metabolomics Human
# 1      acquisitionBatchSize             Metabolomics Human
# 2  acquisitionBatchSizeUnit             Metabolomics Human
# 3           acquisitionMode  proteomics,Metabolomics Human
# 4       acquisitionSoftware  proteomics,Metabolomics Human
#
#                                          Description  \
# 0  Acquisition batch identifier, provided by the ...
# 1                              The number of samples
# 2  The unit of measurement for number of samples ...
# 3  The specific aspect of a mass spectrometer met...
# 4          The name of the acquisition software used
#
#                                         Valid Values Required DependsOn  \
# 0                                                       False
# 1                                                       False
# 2  AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...    False
# 3  Unknown,Not collected,Not applicable,Not speci...     True
# 4  Unknown,Not collected,Not applicable,Not speci...     True
#
#                           DependsOn Component Properties Validation Rules  \
# 0                       mass spec metabolmics
# 1                       mass spec metabolmics
# 2  mass spec metabolmics,acquisitionBatchSize
# 3  mass spec proteomics,mass spec metabolmics
# 4  mass spec proteomics,mass spec metabolmics
#
#                                               Source    Type Ontology  \
# 0                                   Sage Bionetworks  string
# 1                                   Sage Bionetworks  string
# 2                                   Sage Bionetworks  string
# 3  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...  string
# 4          http://purl.obolibrary.org/obo/MS_1001455  string
#
#   multivalue
# 0
# 1
# 2
# 3     ,False
# 4     ,False
# array(['Metabolomics Human', 'proteomics,Metabolomics Human',
#        'Individual Human', 'Biospecimen nonHuman', 'Individual nonHuman',
#        'Biospecimen nonHuman,Biospecimen human', 'proteomics',
#        'Individual nonHuman,Individual Human',
#        'bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Metabolomics Human,Microbiome',
#        'Individual nonHuman,Biospecimen nonHuman,Individual Human,Biospecimen human',
#        'Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq',
#        'Whole Genome Sequencing,scRNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Metabolomics Human,proteomics,Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq,Biospecimen human,genotyping',
#        'Metabolomics Human,proteomics,Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq',
#        'genotyping',
#        'Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq',
#        'Whole Genome Sequencing,scRNAseq,RNAseq',
#        'Whole Genome Sequencing,scRNAseq', 'scRNAseq',
#        'Metabolomics Human,proteomics,Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq,genotyping',
#        'scRNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome',
#        'Metabolomics Human,proteomics,Biospecimen nonHuman,Microbiome,Whole Genome Sequencing,scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),RNAseq,Biospecimen human,genotyping'],
#       dtype=object)

# %%
 set(dm.columns.tolist())
# Out:
# {'Attribute',
#  'DependsOn',
#  'DependsOn Component',
#  'Description',
#  'Ontology',
#  'Parent',
#  'Properties',
#  'Required',
#  'Source',
#  'Type',
#  'Valid Values',
#  'Validation Rules',
#  'multivalue'}

# %%
test = set(base_cols)
test.update(set(dm.columns.tolist()))
test
# Out:
# {'Attribute',
#  'DependsOn',
#  'DependsOn Component',
#  'Description',
#  'Ontology',
#  'Parent',
#  'Properties',
#  'Required',
#  'Source',
#  'Type',
#  'Valid Values',
#  'Validation Rules',
#  'multivalue'}

# %%
test
# Out:
# {'Attribute',
#  'DependsOn',
#  'DependsOn Component',
#  'Description',
#  'Ontology',
#  'Parent',
#  'Properties',
#  'Required',
#  'Source',
#  'Type',
#  'Valid Values',
#  'Validation Rules',
#  'multivalue'}

# %%
# Reorder Columns based on DCA Standards
dm = dm.loc[:, base_cols]

# %%
dm
# Out:
#                     Attribute  \
# 0          acquisitionBatchID
# 1        acquisitionBatchSize
# 2    acquisitionBatchSizeUnit
# 3             acquisitionMode
# 4         acquisitionSoftware
# ..                        ...
# 175             useTreatment?
# 176            vacuumPressure
# 177        vacuumPressureUnit
# 178             valueReported
# 179                 visitCode
#
#                                            Description  \
# 0    Acquisition batch identifier, provided by the ...
# 1                                The number of samples
# 2    The unit of measurement for number of samples ...
# 3    The specific aspect of a mass spectrometer met...
# 4            The name of the acquisition software used
# ..                                                 ...
# 175             Was a treatment applied to the sample?
# 176                 The recorded vacuum pressure value
# 177                      Unit of vacuum pressure value
# 178         The count or gene count for the transcript
# 179  Indicate which longitudinal visit for the indi...
#
#                                           Valid Values DependsOn Properties  \
# 0
# 1
# 2    AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...
# 3    Unknown,Not collected,Not applicable,Not speci...
# 4    Unknown,Not collected,Not applicable,Not speci...
# ..                                                 ...       ...        ...
# 175                                             Yes,No
# 176
# 177  AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...
# 178
# 179        ,Other,Unknown,Not collected,Not applicable
#
#     Required                                   Parent  \
# 0      False                       Metabolomics Human
# 1      False                       Metabolomics Human
# 2      False                       Metabolomics Human
# 3       True            proteomics,Metabolomics Human
# 4       True            proteomics,Metabolomics Human
# ..       ...                                      ...
# 175                                        genotyping
# 176    False                       Metabolomics Human
# 177    False                       Metabolomics Human
# 178     True  Whole Genome Sequencing,scRNAseq,RNAseq
# 179     True                         Individual Human
#
#                                    DependsOn Component  \
# 0                                mass spec metabolmics
# 1                                mass spec metabolmics
# 2           mass spec metabolmics,acquisitionBatchSize
# 3           mass spec proteomics,mass spec metabolmics
# 4           mass spec proteomics,mass spec metabolmics
# ..                                                 ...
# 175                                        genotyping
# 176   mass spec metabolmics,hasIonizationSource? = Yes
# 177  mass spec metabolmics,hasIonizationSource? = Y...
# 178                                WGS,scRNAseq,RNAseq
# 179                                         Individual
#
#                                                 Source  \
# 0                                     Sage Bionetworks
# 1                                     Sage Bionetworks
# 2                                     Sage Bionetworks
# 3    https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 4            http://purl.obolibrary.org/obo/MS_1001455
# ..                                                 ...
# 175                           Sage Bionetworks,ImmPort
# 176  Sage Bionetworks,Proposed minimum metadata rel...
# 177  Sage Bionetworks,Proposed minimum metadata rel...
# 178                                   Sage Bionetworks
# 179                                   Sage Bionetworks
#
#                              Validation Rules
# 0
# 1
# 2
# 3
# 4
# ..                                        ...
# 175                                       nan
# 176  regex search ([0-9]+\.[0-9]*.?)|([0-9]+)
# 177
# 178  regex search ([0-9]+\.[0-9]*.?)|([0-9]+)
# 179  regex search ([0-9]+\.[0-9]*.?)|([0-9]+)
#
# [180 rows x 10 columns]

# %% [markdown]
# # Clean up
#
# - Cleanup `DependsOn Component`

# %%
recoder = {
    "metabolmics": "metabolomics",
    "(mass spec proteomics)": "Proteomics",
    "(mass spec metabolomics)": "Metabolomics Human",
    "(assay_otheruseTreatment? = Yes)": "assay_other, useTreatment? = Yes",
    "OtherUnknown": "Other, Unknown",
    "falseFalseFALSEtrueTrueTRUE": "TRUE, FALSE",
    re.compile("Forwardreverse", flags=re.IGNORECASE): "forward,reverse",
    re.compile("singleEndpairedEnd"): "singleEnd, pairedEnd",
    re.compile("(WGS)"): "Whole Genome Sequencing",
    re.compile("\?"): "",
    "Zeiss LSM 980Other": "Zeiss LSM 980",
    "bsSeqsampleType = other": "bsSeq, sampleType = other",
    re.compile(
        "HPO, MONDO, MAXO codes or labels (not listed for purposes of this RFC)"
    ): "HPO and MONDO and MAXO codes or labels (not listed for purposes of this RFC)",
}

# 'mass spec metabolomics,measurementTechnique = other'
# falseFalseFALSEtrueTrueTRUE

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm[dm["Valid Values"].str.contains("and Body Composition Study")])
# Out:
#     Attribute                                   Description  \
# 335    cohort  Name of the cohort the individual belongs to
#
#                                                                                                                                                                                                                                                                Valid Values  \
# 335  Centenarian, US Family, Denmark Family, The Osteoporotic Fractures in Men (MrOS) Study, Study of Osteoporotic Fractures (SOF), The Health, Aging, and Body Composition Study (HealthABC), Cardiovascular Health Study (CHS),Other,Unknown,Not collected,Not applicable
#
#     DependsOn Properties Required            Parent DependsOn Component  \
# 335                          True  Individual Human          Individual
#
#                Source Validation Rules
# 335  Sage Bionetworks

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm.query('Attribute == "ethnicity"'))
# Out:
#      Attribute              Description  \
# 344  ethnicity  Ethnicity of individual
#
#                                                                                                     Valid Values  \
# 344  Not Hispanic or Latino, Hispanic or Latino, Prefer not to answer,Other,Unknown,Not collected,Not applicable
#
#     DependsOn Properties Required            Parent DependsOn Component  \
# 344                          True  Individual Human          Individual
#
#                                                              Source  \
# 344  Sage Bionetworks,https://www.synapse.org/#!Synapse:syn25878249
#
#     Validation Rules
# 344

# %%
# Inconsistency with parent and depends on component
dm["DependsOn Component"] = dm["DependsOn Component"].replace(recoder, regex=True)

dm["Valid Values"] = dm["Valid Values"].replace(recoder, regex=True)

# %%
dm = dm.apply(lambda x: x.replace(recoder, regex=True), axis=1)

# %%
# QA check
dm[dm["DependsOn Component"].str.contains("metabolomics", case=False, na=False)]
# Out:
#                           Attribute  \
# 161                      specimenID
# 162                      sampleType
# 163               specifySampleType
# 164     specifyMeasurementTechnique
# 165       technologyPlatformVersion
# ..                              ...
# 222               processingBatchID
# 223             processingBatchSize
# 224         processingBatchSizeUnit
# 225  specifyProcessingBatchSizeUnit
# 226                               f
#
#                                            Description  \
# 161  Identifying string linked to a particular samp...
# 162                       The type of sample collected
# 163     If "other" is selected list the type of sample
# 164  If "other" is selected list the name of the me...
# 165  The specific version (application, manufacture...
# ..                                                 ...
# 222  Processing batch identifier, provided by the d...
# 223                              The number of samples
# 224  The unit of measurement for number of samples ...
# 225                   If "other" list units of measure
# 226  The data file provides the name of the raw fil...
#
#                                           Valid Values DependsOn Properties  \
# 161
# 162  Amniotic Fluid,Appendix,B cell,Basophils,Bone,...
# 163
# 164
# 165  Other, Unknown,Not collected,Not applicable,No...
# ..                                                 ...       ...        ...
# 222
# 223
# 224  AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...
# 225
# 226  Unknown,Not collected,Not applicable,Not speci...
#
#     Required              Parent  \
# 161     True  Metabolomics Human
# 162     True  Metabolomics Human
# 163    False  Metabolomics Human
# 164    False  Metabolomics Human
# 165     True  Metabolomics Human
# ..       ...                 ...
# 222    False  Metabolomics Human
# 223    False  Metabolomics Human
# 224    False  Metabolomics Human
# 225    False  Metabolomics Human
# 226     True  Metabolomics Human
#
#                                    DependsOn Component  \
# 161                     Biospecimen,Metabolomics Human
# 162                                 Metabolomics Human
# 163              Metabolomics Human,sampleType = other
# 164     Metabolomics HumanmeasurementTechnique = other
# 165                                 Metabolomics Human
# ..                                                 ...
# 222                                 Metabolomics Human
# 223                                 Metabolomics Human
# 224             Metabolomics Human,processingBatchSize
# 225  Metabolomics Human,ProcessingBatchSizeUnit = o...
# 226                                 Metabolomics Human
#
#                                          Source Validation Rules
# 161                            Sage Bionetworks
# 162                    Sage Bionetworks,ImmPort
# 163                            Sage Bionetworks
# 164                            Sage Bionetworks
# 165  http://purl.obolibrary.org/obo/NCIT_C45378
# ..                                          ...              ...
# 222                            Sage Bionetworks
# 223                            Sage Bionetworks
# 224                            Sage Bionetworks
# 225                            Sage Bionetworks
# 226                  Proteomics Sample Metadata
#
# [65 rows x 10 columns]

# %% [markdown]
# ## Cleaning other values and equal values
#
# Removing illegal characters

# %% [markdown]
# Remove any special characters

# %%
old_values = (
    dm[dm["Attribute"].astype(str).str.contains("\(|\)|\?", na=False)]["Attribute"]
    .unique()
    .tolist()
)

old_values
# Out:
# ['reagentID(s)', 'treatmentID(s)']

# %%
new_values = [re.sub("\(|\)|\?", "", t) for t in old_values]
new_values
# Out:
# ['reagentIDs', 'treatmentIDs']

# %%
# dictionary of replacement values for data model
old_values = [re.compile(re.escape(ov)) for ov in old_values]

original_recoder = dict(zip(old_values, new_values))

original_recoder
# Out:
# {re.compile(r'reagentID\(s\)', re.UNICODE): 'reagentIDs',
#  re.compile(r'treatmentID\(s\)', re.UNICODE): 'treatmentIDs'}

# %% [markdown]
# Clean up equals in depends on

# %%
# Split list to process other values
# Find the other columns in the data model
others = dm[dm["DependsOn Component"].str.contains("=", na=False)].copy()

# %%
others["DependsOn Component Original"] = others["DependsOn Component"].str.split(",")

# %%
# Create series of equals values to use for new attributes/ valid values relationship
others["equals_series"] = others["DependsOn Component Original"].apply(
    lambda x: [y for y in x if bool(re.search("=", y))][0]
)

others
# Out:
#                               Attribute  \
# 2                     specifySampleType
# 3           specifyMeasurementTechnique
# 5                specifyPlatformVersion
# 7               specifyPlatformLocation
# 13              specifyDNABatchSizeUnit
# ..                                  ...
# 294  specifyOtherModificationParameters
# 296           specifyOtherCleavageAgent
# 345                     ethnicGroupCode
# 348                           diagnosis
# 360                   captivityDuration
#
#                                            Description  \
# 2       If "other" is selected list the type of sample
# 3    If "other" is selected list the name of the me...
# 5     If "other" list the name of the platform version
# 7    If "other" list the name of the platform location
# 13                     If "other" list unit of measure
# ..                                                 ...
# 294  If "other" is selected, list the custom modifi...
# 296     If "other" is selected, list the enzyme name.
# 345  A coded value specifying the self-declared eth...
# 348                 Indicate the disease or condition.
# 360  The duration of captivity in months for the in...
#
#                                           Valid Values DependsOn Properties  \
# 2
# 3
# 5
# 7
# 13
# ..                                                 ...       ...        ...
# 294
# 296
# 345
# 348  HPO, MONDO, MAXO codes or labels (not listed f...
# 360               Unknown,Not collected,Not applicable
#
#     Required                                            Parent  \
# 2      False  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 3      False  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 5      False  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 7      False  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 13     False  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# ..       ...                                               ...
# 294    False                                        proteomics
# 296    False                                        proteomics
# 345    False                                  Individual Human
# 348    False                                  Individual Human
# 360    False                               Individual nonHuman
#
#                            DependsOn Component  \
# 2                    bsSeq, sampleType = other
# 3           bsSeq,measurementTechnique = other
# 5      bsSeq,technologyPlatformVersion = other
# 7               bsSeq,platformLocation = other
# 13              bsSeq,dnaBatchSizeUnit = other
# ..                                         ...
# 294  Proteomics,modificationParameters = other
# 296          Proteomics,cleavageAgents = other
# 345  Individual,ethnicity = Hispanic or Latino
# 348          Individual,diagnosisStatus = true
# 360       Individual,captivityStatus = captive
#
#                                                 Source Validation Rules  \
# 2                                     Sage Bionetworks
# 3                                     Sage Bionetworks
# 5                                     Sage Bionetworks
# 7                                     Sage Bionetworks
# 13                                    Sage Bionetworks
# ..                                                 ...              ...
# 294                                   Sage Bionetworks
# 296                                   Sage Bionetworks
# 345  https://ncithesaurus.nci.nih.gov/ncitbrowser/p...
# 348  https://www.ebi.ac.uk/ols/ontologies/mondo,htt...
# 360  https://www.animalaudiograms.org/audiogram_met...
#
#                      DependsOn Component Original  \
# 2                    [bsSeq,  sampleType = other]
# 3           [bsSeq, measurementTechnique = other]
# 5      [bsSeq, technologyPlatformVersion = other]
# 7               [bsSeq, platformLocation = other]
# 13              [bsSeq, dnaBatchSizeUnit = other]
# ..                                            ...
# 294  [Proteomics, modificationParameters = other]
# 296          [Proteomics, cleavageAgents = other]
# 345  [Individual, ethnicity = Hispanic or Latino]
# 348          [Individual, diagnosisStatus = true]
# 360       [Individual, captivityStatus = captive]
#
#                          equals_series
# 2                   sampleType = other
# 3         measurementTechnique = other
# 5    technologyPlatformVersion = other
# 7             platformLocation = other
# 13            dnaBatchSizeUnit = other
# ..                                 ...
# 294     modificationParameters = other
# 296             cleavageAgents = other
# 345     ethnicity = Hispanic or Latino
# 348             diagnosisStatus = true
# 360          captivityStatus = captive
#
# [117 rows x 12 columns]

# %%
def create_new_value(old_value):
    new_vals = old_value.split("=")
    new_vals = [nv.strip() for nv in new_vals]
    # convert to camel case
    nv = new_vals[1].capitalize() + new_vals[0][0].upper() + new_vals[0][1:]
    return nv

# %%
others["equals_attribute"] = others["equals_series"].apply(create_new_value)

# %%
others["DependsOn Component"] = ""

# %%
equals_df = others.copy()

# %%
equals_df = equals_df.drop(columns="DependsOn")

# %%
equals_df = equals_df.rename(
    {"Attribute": "DependsOn", "equals_attribute": "Attribute"}, axis=1
)[base_cols]

equals_df["DependsOn Component"] = ""

equals_df
# Out:
#                           Attribute  \
# 2                   OtherSampleType
# 3         OtherMeasurementTechnique
# 5    OtherTechnologyPlatformVersion
# 7             OtherPlatformLocation
# 13            OtherDnaBatchSizeUnit
# ..                              ...
# 294     OtherModificationParameters
# 296             OtherCleavageAgents
# 345     Hispanic or latinoEthnicity
# 348             TrueDiagnosisStatus
# 360          CaptiveCaptivityStatus
#
#                                            Description  \
# 2       If "other" is selected list the type of sample
# 3    If "other" is selected list the name of the me...
# 5     If "other" list the name of the platform version
# 7    If "other" list the name of the platform location
# 13                     If "other" list unit of measure
# ..                                                 ...
# 294  If "other" is selected, list the custom modifi...
# 296     If "other" is selected, list the enzyme name.
# 345  A coded value specifying the self-declared eth...
# 348                 Indicate the disease or condition.
# 360  The duration of captivity in months for the in...
#
#                                           Valid Values  \
# 2
# 3
# 5
# 7
# 13
# ..                                                 ...
# 294
# 296
# 345
# 348  HPO, MONDO, MAXO codes or labels (not listed f...
# 360               Unknown,Not collected,Not applicable
#
#                               DependsOn Properties Required  \
# 2                     specifySampleType               False
# 3           specifyMeasurementTechnique               False
# 5                specifyPlatformVersion               False
# 7               specifyPlatformLocation               False
# 13              specifyDNABatchSizeUnit               False
# ..                                  ...        ...      ...
# 294  specifyOtherModificationParameters               False
# 296           specifyOtherCleavageAgent               False
# 345                     ethnicGroupCode               False
# 348                           diagnosis               False
# 360                   captivityDuration               False
#
#                                                Parent DependsOn Component  \
# 2    bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 3    bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 5    bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 7    bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 13   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# ..                                                ...                 ...
# 294                                        proteomics
# 296                                        proteomics
# 345                                  Individual Human
# 348                                  Individual Human
# 360                               Individual nonHuman
#
#                                                 Source Validation Rules
# 2                                     Sage Bionetworks
# 3                                     Sage Bionetworks
# 5                                     Sage Bionetworks
# 7                                     Sage Bionetworks
# 13                                    Sage Bionetworks
# ..                                                 ...              ...
# 294                                   Sage Bionetworks
# 296                                   Sage Bionetworks
# 345  https://ncithesaurus.nci.nih.gov/ncitbrowser/p...
# 348  https://www.ebi.ac.uk/ols/ontologies/mondo,htt...
# 360  https://www.animalaudiograms.org/audiogram_met...
#
# [117 rows x 10 columns]

# %% [markdown]
# # Update base attribute equals values

# %%
others["base_attribute"] = others["equals_series"].str.split("=", expand=True)[0]

# %%
others["Properties"] = "dataProperty"

# %%
# dm[dm['Parent'].str.contains('bsSeq ', regex=True)]

# %%
temp = others["equals_series"].str.split("=", expand=True)
temp = temp.apply(lambda x: x.str.strip(), axis=1)
temp = temp.rename({0: "base_attribute", 1: "value_to_replace"}, axis=1)
temp["value_to_replace"] = temp["value_to_replace"].str.capitalize()

# new value
temp["new_value"] = others["equals_attribute"]

temp.reset_index(drop=True, inplace=True)

temp
# Out:
#                 base_attribute    value_to_replace  \
# 0                   sampleType               Other
# 1         measurementTechnique               Other
# 2    technologyPlatformVersion               Other
# 3             platformLocation               Other
# 4             dnaBatchSizeUnit               Other
# ..                         ...                 ...
# 112     modificationParameters               Other
# 113             cleavageAgents               Other
# 114                  ethnicity  Hispanic or latino
# 115            diagnosisStatus                True
# 116            captivityStatus             Captive
#
#                           new_value
# 0                   OtherSampleType
# 1         OtherMeasurementTechnique
# 2    OtherTechnologyPlatformVersion
# 3             OtherPlatformLocation
# 4             OtherDnaBatchSizeUnit
# ..                              ...
# 112     OtherModificationParameters
# 113             OtherCleavageAgents
# 114     Hispanic or latinoEthnicity
# 115             TrueDiagnosisStatus
# 116          CaptiveCaptivityStatus
#
# [117 rows x 3 columns]

# %%
temp = temp.drop_duplicates()

# %%
temp[temp["new_value"] == "YesHasIonizationSource?"]
# Out:
# Empty DataFrame
# Columns: [base_attribute, value_to_replace, new_value]
# Index: []

# %%
replacements = {}

for i, x in temp.iterrows():
    ba, vtr, nv = x
    replacements[ba] = {
        "pattern": re.compile("(" + vtr + ")", flags=re.IGNORECASE),
        "repl": nv,
    }

replacements
# Out:
# {'sampleType': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherSampleType'},
#  'measurementTechnique': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherMeasurementTechnique'},
#  'technologyPlatformVersion': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherTechnologyPlatformVersion'},
#  'platformLocation': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherPlatformLocation'},
#  'dnaBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherDnaBatchSizeUnit'},
#  'libraryPrep': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherLibraryPrep'},
#  'libraryPreparationMethod': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherLibraryPreparationMethod'},
#  'libraryVersion': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherLibraryVersion'},
#  'sequencingBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherSequencingBatchSizeUnit'},
#  'readLengthUnits': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherReadLengthUnits'},
#  'repositoryName': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherRepositoryName'},
#  'transcriptType': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherTranscriptType'},
#  'rnaBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherRnaBatchSizeUnit'},
#  'useReagent': {'pattern': re.compile(r'(Yes)', re.IGNORECASE|re.UNICODE),
#   'repl': 'YesUseReagent'},
#  'useTreatment': {'pattern': re.compile(r'(Yes)', re.IGNORECASE|re.UNICODE),
#   'repl': 'YesUseTreatment'},
#  'Metabolomics HumanmeasurementTechnique': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherMetabolomics HumanmeasurementTechnique'},
#  'msAnalyzerTypeMS1': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherMsAnalyzerTypeMS1'},
#  'msAnalyzerTypeMS2': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherMsAnalyzerTypeMS2'},
#  'msAssayTechnique': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherMsAssayTechnique'},
#  'msTarget': {'pattern': re.compile(r'(Targeted)', re.IGNORECASE|re.UNICODE),
#   'repl': 'TargetedMsTarget'},
#  'msAnalyteType': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherMsAnalyteType'},
#  'msInstrumentModel': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherMsInstrumentModel'},
#  'sampleIntdocution': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherSampleIntdocution'},
#  'databaseName': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherDatabaseName'},
#  'databaseSource': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherDatabaseSource'},
#  'hasIonizationSource': {'pattern': re.compile(r'(Yes)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'YesHasIonizationSource'},
#  'vaccumPressureUnits': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherVaccumPressureUnits'},
#  'lensVoltageUnits': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherLensVoltageUnits'},
#  'hasAssayControl': {'pattern': re.compile(r'(Yes)', re.IGNORECASE|re.UNICODE),
#   'repl': 'YesHasAssayControl'},
#  'controlType': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherControlType'},
#  'experimentalBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherExperimentalBatchSizeUnit'},
#  'batchSizeUnit': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherBatchSizeUnit'},
#  'sampleBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherSampleBatchSizeUnit'},
#  'acquisitionBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherAcquisitionBatchSizeUnit'},
#  'ProcessingBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherProcessingBatchSizeUnit'},
#  'extractionMethod': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherExtractionMethod'},
#  'proteomicsAssayType': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherProteomicsAssayType'},
#  'digestionMethod': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherDigestionMethod'},
#  'modificationParameters': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherModificationParameters'},
#  'cleavageAgents': {'pattern': re.compile(r'(Other)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'OtherCleavageAgents'},
#  'ethnicity': {'pattern': re.compile(r'(Hispanic or latino)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'Hispanic or latinoEthnicity'},
#  'diagnosisStatus': {'pattern': re.compile(r'(True)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'TrueDiagnosisStatus'},
#  'captivityStatus': {'pattern': re.compile(r'(Captive)',
#   re.IGNORECASE|re.UNICODE),
#   'repl': 'CaptiveCaptivityStatus'}}

# %%
for attribute in replacements.keys():
    dm = code_equals_values(dm, replacements, attribute)
    print("-" * 20)
# Out:
# attribute:  sampleType
# Index:  [1, 47, 73, 110, 141, 162, 228, 260]
# --------------------
# attribute:  measurementTechnique
# measurementTechnique
# Index:  None
# --------------------
# attribute:  technologyPlatformVersion
# Index:  [4, 50, 76, 113, 165, 231, 263]
# --------------------
# attribute:  platformLocation
# Index:  [6, 52, 78, 115, 167, 233, 265]
# --------------------
# attribute:  dnaBatchSizeUnit
# Index:  [12, 244]
# --------------------
# attribute:  libraryPrep
# Index:  [15, 96, 127, 246]
# --------------------
# attribute:  libraryPreparationMethod
# Index:  [17, 25, 61, 98, 129, 248]
# --------------------
# attribute:  libraryVersion
# Index:  [19, 27, 63, 100, 131, 250]
# --------------------
# attribute:  sequencingBatchSizeUnit
# Index:  [23, 94, 240]
# --------------------
# attribute:  readLengthUnits
# Index:  [32, 68, 105, 136, 255]
# --------------------
# attribute:  repositoryName
# Index:  [55, 81, 118]
# --------------------
# attribute:  transcriptType
# Index:  [57, 83, 120]
# --------------------
# attribute:  rnaBatchSizeUnit
# Index:  [89]
# --------------------
# attribute:  useReagent
# Index:  [143]
# --------------------
# attribute:  useTreatment
# Index:  [151]
# --------------------
# attribute:  Metabolomics HumanmeasurementTechnique
# Metabolomics HumanmeasurementTechnique
# Index:  None
# --------------------
# attribute:  msAnalyzerTypeMS1
# Index:  [170, 268]
# --------------------
# attribute:  msAnalyzerTypeMS2
# Index:  [172, 270]
# --------------------
# attribute:  msAssayTechnique
# Index:  [174, 272]
# --------------------
# attribute:  msTarget
# Index:  [169, 267]
# --------------------
# attribute:  msAnalyteType
# Index:  [176, 274]
# --------------------
# attribute:  msInstrumentModel
# Index:  [178, 278]
# --------------------
# attribute:  sampleIntdocution
# sampleIntdocution
# Index:  None
# --------------------
# attribute:  databaseName
# Index:  [187, 287]
# --------------------
# attribute:  databaseSource
# Index:  [189, 289]
# --------------------
# attribute:  hasIonizationSource
# Index:  [193]
# --------------------
# attribute:  vaccumPressureUnits
# vaccumPressureUnits
# Index:  None
# --------------------
# attribute:  lensVoltageUnits
# lensVoltageUnits
# Index:  None
# --------------------
# attribute:  hasAssayControl
# Index:  [203]
# --------------------
# attribute:  controlType
# Index:  [204]
# --------------------
# attribute:  experimentalBatchSizeUnit
# experimentalBatchSizeUnit
# Index:  None
# --------------------
# attribute:  batchSizeUnit
# Index:  [210]
# --------------------
# attribute:  sampleBatchSizeUnit
# Index:  [216]
# --------------------
# attribute:  acquisitionBatchSizeUnit
# Index:  [220]
# --------------------
# attribute:  ProcessingBatchSizeUnit
# Index:  [224]
# --------------------
# attribute:  extractionMethod
# Index:  [182, 235]
# --------------------
# attribute:  proteomicsAssayType
# proteomicsAssayType
# Index:  None
# --------------------
# attribute:  digestionMethod
# Index:  [280]
# --------------------
# attribute:  modificationParameters
# Index:  [293]
# --------------------
# attribute:  cleavageAgents
# Index:  [295]
# --------------------
# attribute:  ethnicity
# Index:  [344]
# --------------------
# attribute:  diagnosisStatus
# Index:  [347]
# --------------------
# attribute:  captivityStatus
# Index:  [359]
# --------------------
# c:\Users\nlee\anaconda3\envs\schematic\lib\site-packages\ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.

# %%
# with pd.option_context('display.max_rows', None, 'display.max_colwidth', 0):
#     display(
#         dm[dm['Attribute'].str.contains(
#             'proteomicsAssayType', flags=re.IGNORECASE)]
#     )

# %%
equals_df["Properties"] = "validValue"

# %% [markdown]
# # Add new attributes

# %%
dm["Properties"] = "dataProperty"

# %%
dm.update(others[base_cols])

# %%
dm = pd.concat([dm, equals_df], ignore_index=True)

# %%
# Do not need
dm["DependsOn Component"] = ""

# %% [markdown]
# # Clean Up Valid Values and Add New Attributes

# %%
# valid values that contain other
pure_others = dm[dm["Valid Values"].str.contains("([Oo]ther$)", flags=re.IGNORECASE)]
# Out:
# c:\Users\nlee\anaconda3\envs\schematic\lib\site-packages\ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
pure_others["replacement_value"] = pure_others["Attribute"].apply(
    lambda x: "Other" + (x[0].upper() + x[1:])
)
# Out:
# c:\Users\nlee\anaconda3\envs\schematic\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
regex_dict = {}

pattern = "([Oo]ther$)"

for i, r in pure_others.iterrows():
    regex_dict[r["Attribute"]] = {
        "pattern": re.compile(pattern, flags=re.IGNORECASE),
        "repl": r["replacement_value"],
    }

# %%
temp_dict = {}

for i, r in pure_others.iterrows():
    temp_dict[r["Attribute"]] = {
        "pattern": str(re.compile(pattern, flags=re.IGNORECASE)),
        "repl": r["replacement_value"],
    }

json_formatted = json.dumps(temp_dict, indent=4)
print(json_formatted)
# Out:
# {
#     "conversionRatioUnits": {
#         "pattern": "re.compile('([Oo]ther$)', re.IGNORECASE)",
#         "repl": "OtherConversionRatioUnits"
#     },
#     "vacuumPressureUnit": {
#         "pattern": "re.compile('([Oo]ther$)', re.IGNORECASE)",
#         "repl": "OtherVacuumPressureUnit"
#     },
#     "lensVoltagesUnit ": {
#         "pattern": "re.compile('([Oo]ther$)', re.IGNORECASE)",
#         "repl": "OtherLensVoltagesUnit "
#     },
#     "experiementalBatchSizeUnit": {
#         "pattern": "re.compile('([Oo]ther$)', re.IGNORECASE)",
#         "repl": "OtherExperiementalBatchSizeUnit"
#     },
#     "YesHasIonizationSource": {
#         "pattern": "re.compile('([Oo]ther$)', re.IGNORECASE)",
#         "repl": "OtherYesHasIonizationSource"
#     }
# }

# %%
for attribute in regex_dict.keys():
    dm = code_equals_values(dm, regex_dict, attribute)
    print("-" * 20)
# Out:
# attribute:  conversionRatioUnits
# Index:  [42]
# --------------------
# attribute:  vacuumPressureUnit
# Index:  [196]
# --------------------
# attribute:  lensVoltagesUnit
# Index:  [199]
# --------------------
# attribute:  experiementalBatchSizeUnit
# Index:  [207]
# --------------------
# attribute:  YesHasIonizationSource
# Index:  [432, 433, 434, 436, 437, 439, 440]
# --------------------
# c:\Users\nlee\anaconda3\envs\schematic\lib\site-packages\ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.

# %%
dm["Valid Values"] = dm["Valid Values"].str.replace(
    re.escape("(falseFalseFALSEtrueTrueTRUE)"), "", regex=True
)

# %%
# with pd.option_context('display.max_rows', None, 'display.max_colwidth', 0):
#     display(dm[dm['Valid Values'].str.contains(
#         re.escape('(not listed for purposes of this RFC)'))].sort_values(by='Source'))

# %%
def create_list_from_lists(main_list, new_list):
    try:
        main_list = main_list + list
    except:
        pass
    return main_list

# %%
split_valid_values = dm["Valid Values"].str.split(",")
new_valid_values = [i for i in split_valid_values]

# %%
test = []
for nv in new_valid_values:
    # print(nv)
    try:
        test = test + nv
    except:
        pass

test = list(np.unique(test))

# %%
valid_values = ",".join(dm["Valid Values"])
valid_values = valid_values.split(",")
valid_values = list(np.unique(valid_values))
valid_values = [v.strip() for v in valid_values if len(v) > 0]

# %%
# Fuzzy matching to find misspellings
# Fuzzy matching
from thefuzz import fuzz

scores = {}
for v in valid_values:
    scores[v] = {}
    for v2 in valid_values:
        if v == v2:
            next
        else:
            score = fuzz.ratio(v.lower(), v2.lower())
            if score == 100:
                scores[v][v2] = score
    if len(scores[v]) == 0:
        scores.pop(v)

scores
# Out:
# {'FALSE': {'False': 100},
#  'False': {'FALSE': 100},
#  'Lipid': {'lipid': 100},
#  'Not Specified': {'Not specified': 100},
#  'Not specified': {'Not Specified': 100},
#  'Plasma': {'plasma': 100},
#  'Protein': {'protein': 100},
#  'Saliva': {'saliva': 100},
#  'Serum': {'serum': 100},
#  'Sputum': {'sputum': 100},
#  'TRUE': {'True': 100},
#  'True': {'TRUE': 100},
#  'Urine': {'urine': 100},
#  'lipid': {'Lipid': 100},
#  'plasma': {'Plasma': 100},
#  'protein': {'Protein': 100},
#  'saliva': {'Saliva': 100},
#  'serum': {'Serum': 100},
#  'sputum': {'Sputum': 100},
#  'urine': {'Urine': 100}}

# %%
new_values_recoded = []
for v in scores.values():
    new_values_recoded.append(list(v.keys())[0].lower())

new_values_recoded = np.unique(new_values_recoded)

recoder_valid_values = []
for nv in new_values_recoded:
    value_add = {re.compile(nv, flags=re.IGNORECASE): nv}
    recoder_valid_values.append(value_add)

# %%
recoder_valid_values
# Out:
# [{re.compile(r'false', re.IGNORECASE|re.UNICODE): 'false'},
#  {re.compile(r'lipid', re.IGNORECASE|re.UNICODE): 'lipid'},
#  {re.compile(r'not specified', re.IGNORECASE|re.UNICODE): 'not specified'},
#  {re.compile(r'plasma', re.IGNORECASE|re.UNICODE): 'plasma'},
#  {re.compile(r'protein', re.IGNORECASE|re.UNICODE): 'protein'},
#  {re.compile(r'saliva', re.IGNORECASE|re.UNICODE): 'saliva'},
#  {re.compile(r'serum', re.IGNORECASE|re.UNICODE): 'serum'},
#  {re.compile(r'sputum', re.IGNORECASE|re.UNICODE): 'sputum'},
#  {re.compile(r'true', re.IGNORECASE|re.UNICODE): 'true'},
#  {re.compile(r'urine', re.IGNORECASE|re.UNICODE): 'urine'}]

# %% [markdown]
# # Cleanup valid values

# %%
def clean_list(x):
    try:
        result = ",".join([y.strip() for y in x])
        return result
    except:
        return ""

# %%
recoder_valid_values = {
    re.compile("Not Specified", flags=re.IGNORECASE): "Not Specified",
    re.compile("(Other$)", flags=re.IGNORECASE): "Other",
    re.compile("lipid", re.IGNORECASE): "Lipid",
    re.compile("plasma", re.IGNORECASE): "Plasma",
    re.compile("protein", re.IGNORECASE): "Protein",
    re.compile("saliva", re.IGNORECASE): "Saliva",
    re.compile("serum", re.IGNORECASE): "Serum",
    re.compile("sputum", re.IGNORECASE): "Sputum",
    re.compile("urine", re.IGNORECASE): "Urine",
    re.compile(
        "(^0x Visium Spatial Gene Expression)"
    ): "10x Visium Spatial Gene Expression",
    re.compile("falseFalseFALSEtrueTrueTRUE	"): "TRUE, FALSE",
    re.compile("TRUE|TRUEDiagnosisStatus", re.IGNORECASE): "TRUE",
    re.compile("TRUEDiagnosisStatus", re.IGNORECASE): "TRUE",
    re.compile("FALSE", re.IGNORECASE): "FALSE",
    re.compile("$f^", re.IGNORECASE): "F",
    re.compile("UnknownNot collected"): "Unknown, Not collected",
    re.compile(r"\u200b\u200b"): "",
    re.compile(
        "The Health,Aging,and Body Composition Study \(HealthABC\)"
    ): "The Health and Aging and Body Composition Study (HealthABC)",
    re.compile("Not Hispanic or latinoEthnicity"): "Not Hispanic or latino",
    re.compile("Hispanic or latinoEthnicity"): "Hispanic or latino",
    re.compile(
        "HPO, MONDO, MAXO codes or labels \(not listed for purposes of this RFC\)"
    ): "HPO and MONDO and MAXO codes or labels (not listed for purposes of this RFC)",
}

# %%
dm["Valid Values"] = (
    dm["Valid Values"]
    .replace(recoder_valid_values, regex=True)
    .str.split(",")
    .apply(lambda x: clean_list(x))
)

valid_values = list(np.unique(",".join(test).split(",")))

valid_values = [v.strip() for v in valid_values if len(v) > 0]

valid_values_df = pd.DataFrame(
    {
        "Attribute": pd.Series(valid_values),
        "Properties": pd.Series(["validValue" for v in valid_values]),
        "Required": pd.Series(["False" for v in valid_values]),
    }
)

valid_values_df = valid_values_df[
    ~valid_values_df["Attribute"].isin(dm["Attribute"].tolist())
]

valid_values_df
# Out:
#                                         Attribute  Properties Required
# 0                                           Aging  validValue    False
# 1                                      Baker pool  validValue    False
# 2               Cardiovascular Health Study (CHS)  validValue    False
# 3                                  Denmark Family  validValue    False
# 4                                           FALSE  validValue    False
# ..                                            ...         ...      ...
# 439                                            ul  validValue    False
# 440                                        umol/l  validValue    False
# 441                                      units/ml  validValue    False
# 442                                         urine  validValue    False
# 443  ​​Affymetrix Genome-Wide Human SNP 5.0 Array  validValue    False
#
# [414 rows x 3 columns]

# %%
# adding valid values found in attribute columns
dm2 = pd.concat([dm, valid_values_df], axis=0, ignore_index=True)

# %%
# Fuzzy matching to find misspellings
# Fuzzy matching

from thefuzz import fuzz

valid_values = dm2["Attribute"].replace(recoder_valid_values, regex=True).tolist()

scores = {}
for v in valid_values:
    scores[v] = {}
    for v2 in valid_values:
        if v == v2:
            next
        else:
            score = fuzz.ratio(v.lower(), v2.lower())
            if score == 100:
                scores[v][v2] = score
    if len(scores[v]) == 0:
        scores.pop(v)

scores
# Out:
# {'f': {'F': 100}, 'F': {'f': 100}}

# %%
dm2[["Attribute", "DependsOn"]] = dm2[["Attribute", "DependsOn"]].apply(
    lambda x: x.replace(recoder_valid_values, regex=True)
)

# %%
dm2[
    dm2.duplicated(subset=["Attribute", "Parent", "DependsOn"], keep=False)
].sort_values(by=["Parent", "Attribute"])
# Out:
#                               Attribute  \
# 367       OtherLibraryPreparationMethod
# 370       OtherLibraryPreparationMethod
# 368                 OtherLibraryVersion
# 371                 OtherLibraryVersion
# 9                            dnaBatchID
# 10                           dnaBatchID
# 17             libraryPreparationMethod
# 25             libraryPreparationMethod
# 19                       libraryVersion
# 27                       libraryVersion
# 18      specifyLibraryPreparationMethod
# 26      specifyLibraryPreparationMethod
# 20                specifyLibraryVersion
# 28                specifyLibraryVersion
# 495  10x Visium Spatial Gene Expression
# 497  10x Visium Spatial Gene Expression
# 482                               FALSE
# 483                               FALSE
# 568                               FALSE
# 639                               Lipid
# 825                               Lipid
# 687                       Not Specified
# 690                       Not Specified
# 721                              Plasma
# 857                              Plasma
# 486                Prefer not to answer
# 731                Prefer not to answer
# 734                             Protein
# 859                             Protein
# 749                              Saliva
# 864                              Saliva
# 752                               Serum
# 866                               Serum
# 760                              Sputum
# 873                              Sputum
# 771                                TRUE
# 778                                TRUE
# 491                             Unknown
# 788                             Unknown
# 791                               Urine
# 890                               Urine
# 493                           pairedEnd
# 850                           pairedEnd
#
#                                            Description  \
# 367  If "other" list the name of the library prepar...
# 370  If "other" list the name of the library prepar...
# 368    If "other" list the name of the library version
# 371    If "other" list the name of the library version
# 9                                  DNA isolation batch
# 10   DNA isolation batch identifier, provided by th...
# 17                Method by which library was prepared
# 25                Method by which library was prepared
# 19   Library Version: for example, rnaSeq 10x libra...
# 27   Library Version: for example, rnaSeq 10x libra...
# 18   If "other" list the name of the library prepar...
# 26   If "other" list the name of the library prepar...
# 20     If "other" list the name of the library version
# 28     If "other" list the name of the library version
# 495                                                NaN
# 497                                                NaN
# 482                                                NaN
# 483                                                NaN
# 568                                                NaN
# 639                                                NaN
# 825                                                NaN
# 687                                                NaN
# 690                                                NaN
# 721                                                NaN
# 857                                                NaN
# 486                                                NaN
# 731                                                NaN
# 734                                                NaN
# 859                                                NaN
# 749                                                NaN
# 864                                                NaN
# 752                                                NaN
# 866                                                NaN
# 760                                                NaN
# 873                                                NaN
# 771                                                NaN
# 778                                                NaN
# 491                                                NaN
# 788                                                NaN
# 791                                                NaN
# 890                                                NaN
# 493                                                NaN
# 850                                                NaN
#
#                                           Valid Values  \
# 367
# 370
# 368
# 371
# 9           Other,Unknown,Not collected,Not applicable
# 10   Unknown,Not collected,Not applicable,Not Speci...
# 17   10x,Accel-NGS 2S Plus,Accel-NGS Methyl-Seq,CEL...
# 25   10x,Accel-NGS 2S Plus,Accel-NGS Methyl-Seq,CEL...
# 19   OtherLibraryVersion,Unknown,Not collected,Not ...
# 27   OtherLibraryVersion,Unknown,Not collected,Not ...
# 18
# 26
# 20
# 28
# 495                                                NaN
# 497                                                NaN
# 482                                                NaN
# 483                                                NaN
# 568                                                NaN
# 639                                                NaN
# 825                                                NaN
# 687                                                NaN
# 690                                                NaN
# 721                                                NaN
# 857                                                NaN
# 486                                                NaN
# 731                                                NaN
# 734                                                NaN
# 859                                                NaN
# 749                                                NaN
# 864                                                NaN
# 752                                                NaN
# 866                                                NaN
# 760                                                NaN
# 873                                                NaN
# 771                                                NaN
# 778                                                NaN
# 491                                                NaN
# 788                                                NaN
# 791                                                NaN
# 890                                                NaN
# 493                                                NaN
# 850                                                NaN
#
#                            DependsOn    Properties Required  \
# 367  specifyLibraryPreparationMethod    validValue    False
# 370  specifyLibraryPreparationMethod    validValue    False
# 368            specifyLibraryVersion    validValue    False
# 371            specifyLibraryVersion    validValue    False
# 9                                     dataProperty     True
# 10                                    dataProperty     True
# 17                                    dataProperty     True
# 25                                    dataProperty     True
# 19                                    dataProperty     True
# 27                                    dataProperty     True
# 18                                    dataProperty    False
# 26                                    dataProperty    False
# 20                                    dataProperty    False
# 28                                    dataProperty    False
# 495                              NaN    validValue    False
# 497                              NaN    validValue    False
# 482                              NaN    validValue    False
# 483                              NaN    validValue    False
# 568                              NaN    validValue    False
# 639                              NaN    validValue    False
# 825                              NaN    validValue    False
# 687                              NaN    validValue    False
# 690                              NaN    validValue    False
# 721                              NaN    validValue    False
# 857                              NaN    validValue    False
# 486                              NaN    validValue    False
# 731                              NaN    validValue    False
# 734                              NaN    validValue    False
# 859                              NaN    validValue    False
# 749                              NaN    validValue    False
# 864                              NaN    validValue    False
# 752                              NaN    validValue    False
# 866                              NaN    validValue    False
# 760                              NaN    validValue    False
# 873                              NaN    validValue    False
# 771                              NaN    validValue    False
# 778                              NaN    validValue    False
# 491                              NaN    validValue    False
# 788                              NaN    validValue    False
# 791                              NaN    validValue    False
# 890                              NaN    validValue    False
# 493                              NaN    validValue    False
# 850                              NaN    validValue    False
#
#                                                Parent DependsOn Component  \
# 367  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 370  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 368  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 371  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 9    bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 10   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 17   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 25   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 19   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 27   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 18   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 26   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 20   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 28   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 495                                               NaN                 NaN
# 497                                               NaN                 NaN
# 482                                               NaN                 NaN
# 483                                               NaN                 NaN
# 568                                               NaN                 NaN
# 639                                               NaN                 NaN
# 825                                               NaN                 NaN
# 687                                               NaN                 NaN
# 690                                               NaN                 NaN
# 721                                               NaN                 NaN
# 857                                               NaN                 NaN
# 486                                               NaN                 NaN
# 731                                               NaN                 NaN
# 734                                               NaN                 NaN
# 859                                               NaN                 NaN
# 749                                               NaN                 NaN
# 864                                               NaN                 NaN
# 752                                               NaN                 NaN
# 866                                               NaN                 NaN
# 760                                               NaN                 NaN
# 873                                               NaN                 NaN
# 771                                               NaN                 NaN
# 778                                               NaN                 NaN
# 491                                               NaN                 NaN
# 788                                               NaN                 NaN
# 791                                               NaN                 NaN
# 890                                               NaN                 NaN
# 493                                               NaN                 NaN
# 850                                               NaN                 NaN
#
#                Source Validation Rules
# 367  Sage Bionetworks
# 370  Sage Bionetworks
# 368  Sage Bionetworks
# 371  Sage Bionetworks
# 9    Sage Bionetworks
# 10   Sage Bionetworks
# 17   Sage Bionetworks
# 25   Sage Bionetworks
# 19   Sage Bionetworks
# 27   Sage Bionetworks
# 18   Sage Bionetworks
# 26   Sage Bionetworks
# 20   Sage Bionetworks
# 28   Sage Bionetworks
# 495               NaN              NaN
# 497               NaN              NaN
# 482               NaN              NaN
# 483               NaN              NaN
# 568               NaN              NaN
# 639               NaN              NaN
# 825               NaN              NaN
# 687               NaN              NaN
# 690               NaN              NaN
# 721               NaN              NaN
# 857               NaN              NaN
# 486               NaN              NaN
# 731               NaN              NaN
# 734               NaN              NaN
# 859               NaN              NaN
# 749               NaN              NaN
# 864               NaN              NaN
# 752               NaN              NaN
# 866               NaN              NaN
# 760               NaN              NaN
# 873               NaN              NaN
# 771               NaN              NaN
# 778               NaN              NaN
# 491               NaN              NaN
# 788               NaN              NaN
# 791               NaN              NaN
# 890               NaN              NaN
# 493               NaN              NaN
# 850               NaN              NaN

# %%
dm2.query('Attribute == "UnknownNot collected"')
# Out:
# Empty DataFrame
# Columns: [Attribute, Description, Valid Values, DependsOn, Properties, Required, Parent, DependsOn Component, Source, Validation Rules]
# Index: []

# %%
# print(dm2.shape)

# dm2 = dm2.drop_duplicates(
#     subset=['Attribute', 'Parent', 'DependsOn']).reset_index(drop=True)

# display(dm2.shape)

# %%
# with pd.option_context('display.max_rows', None, 'display.max_colwidth', 0):
#     display(dm[dm['Attribute'] == 'sampleType'])

# %% [markdown]
# # Check columns for Speical Characters

# %%
check_cols = ["Attribute"]

mask = np.column_stack(
    [dm2[col].str.contains("\(|\)", na=False) for col in dm2[check_cols]]
)

with pd.option_context("display.max_colwidth", None):
    display(dm2[check_cols].loc[mask.any(axis=1)])
# Out:
#                                                                 Attribute
# 144                                                          reagentID(s)
# 152                                                        treatmentID(s)
# 480                                     Cardiovascular Health Study (CHS)
# 484            MAXO codes or labels (not listed for purposes of this RFC)
# 487                                 Study of Osteoporotic Fractures (SOF)
# 489                        The Osteoporotic Fractures in Men (MrOS) Study
# 492                                and Body Composition Study (HealthABC)
# 531                  CCF-BSO values (not listed for purposes of this RFC)
# 537                                             Cerebrospinal Fluid (CSF)
# 578     Genbank common names (not listed for purposes of this RFC)Unknown
# 586    Human Reference Atlas values (not listed for purposes of this RFC)
# 606                Illumina Infinium MethylationEPIC BeadChip v1.0 (850k)
# 607  Illumina Infinium MethylationEPIC BeadChip v2.0 (935k)Illumina MiSeq
# 654                                      MassBank of North America (MoNA)
# 666            NCBI taxonomy values (not listed for purposes of this RFC)
# 667                      NCI values (not listed for purposes of this RFC)
# 799        World Bank country codes (not listed for purposes of this RFC)

# %% [markdown]
# # Create Manifests in data model

# %%
# with pd.option_context('display.max_rows', None, 'display.max_colwidth', 0):
#     display(dm2.query('Properties == "dataProperty"').groupby(
#         'Parent').agg({'Attribute': list}).reset_index())

# %%
# Create the manifest templates based on the tables
manifests = (
    dm2.query('Properties == "dataProperty"')
    .groupby("Parent")
    .agg({"Attribute": list})
    .reset_index()
)

manifests["Attribute"] = manifests["Attribute"].apply(lambda x: x + ["Component"])

manifests["Required"] = "True"
manifests["Properties"] = "dataType"

manifests = manifests.rename({"Attribute": "DependsOn", "Parent": "Attribute"}, axis=1)
manifests["DependsOn"] = manifests["DependsOn"].apply(lambda x: ",".join(x))


# Store the data types in a list
dataTypes = manifests["Attribute"].tolist()

# %%
dm2 = dm2[~dm2["Attribute"].isin(dataTypes)]

dm2 = pd.concat([dm2, manifests], axis=0, ignore_index=True)

print(dm2.shape)
# Out:
# (904, 10)

# %%
dm2[
    dm2.duplicated(
        subset=["Attribute", "DependsOn", "Properties", "Parent"], keep=False
    )
].sort_values(by="Attribute")
# Out:
#                               Attribute  \
# 497  10x Visium Spatial Gene Expression
# 495  10x Visium Spatial Gene Expression
# 568                               FALSE
# 483                               FALSE
# 482                               FALSE
# 825                               Lipid
# 639                               Lipid
# 690                       Not Specified
# 687                       Not Specified
# 367       OtherLibraryPreparationMethod
# 370       OtherLibraryPreparationMethod
# 368                 OtherLibraryVersion
# 371                 OtherLibraryVersion
# 721                              Plasma
# 857                              Plasma
# 731                Prefer not to answer
# 486                Prefer not to answer
# 734                             Protein
# 859                             Protein
# 749                              Saliva
# 864                              Saliva
# 752                               Serum
# 866                               Serum
# 760                              Sputum
# 873                              Sputum
# 771                                TRUE
# 778                                TRUE
# 788                             Unknown
# 491                             Unknown
# 791                               Urine
# 890                               Urine
# 10                           dnaBatchID
# 9                            dnaBatchID
# 25             libraryPreparationMethod
# 17             libraryPreparationMethod
# 27                       libraryVersion
# 19                       libraryVersion
# 850                           pairedEnd
# 493                           pairedEnd
# 26      specifyLibraryPreparationMethod
# 18      specifyLibraryPreparationMethod
# 28                specifyLibraryVersion
# 20                specifyLibraryVersion
#
#                                            Description  \
# 497                                                NaN
# 495                                                NaN
# 568                                                NaN
# 483                                                NaN
# 482                                                NaN
# 825                                                NaN
# 639                                                NaN
# 690                                                NaN
# 687                                                NaN
# 367  If "other" list the name of the library prepar...
# 370  If "other" list the name of the library prepar...
# 368    If "other" list the name of the library version
# 371    If "other" list the name of the library version
# 721                                                NaN
# 857                                                NaN
# 731                                                NaN
# 486                                                NaN
# 734                                                NaN
# 859                                                NaN
# 749                                                NaN
# 864                                                NaN
# 752                                                NaN
# 866                                                NaN
# 760                                                NaN
# 873                                                NaN
# 771                                                NaN
# 778                                                NaN
# 788                                                NaN
# 491                                                NaN
# 791                                                NaN
# 890                                                NaN
# 10   DNA isolation batch identifier, provided by th...
# 9                                  DNA isolation batch
# 25                Method by which library was prepared
# 17                Method by which library was prepared
# 27   Library Version: for example, rnaSeq 10x libra...
# 19   Library Version: for example, rnaSeq 10x libra...
# 850                                                NaN
# 493                                                NaN
# 26   If "other" list the name of the library prepar...
# 18   If "other" list the name of the library prepar...
# 28     If "other" list the name of the library version
# 20     If "other" list the name of the library version
#
#                                           Valid Values  \
# 497                                                NaN
# 495                                                NaN
# 568                                                NaN
# 483                                                NaN
# 482                                                NaN
# 825                                                NaN
# 639                                                NaN
# 690                                                NaN
# 687                                                NaN
# 367
# 370
# 368
# 371
# 721                                                NaN
# 857                                                NaN
# 731                                                NaN
# 486                                                NaN
# 734                                                NaN
# 859                                                NaN
# 749                                                NaN
# 864                                                NaN
# 752                                                NaN
# 866                                                NaN
# 760                                                NaN
# 873                                                NaN
# 771                                                NaN
# 778                                                NaN
# 788                                                NaN
# 491                                                NaN
# 791                                                NaN
# 890                                                NaN
# 10   Unknown,Not collected,Not applicable,Not Speci...
# 9           Other,Unknown,Not collected,Not applicable
# 25   10x,Accel-NGS 2S Plus,Accel-NGS Methyl-Seq,CEL...
# 17   10x,Accel-NGS 2S Plus,Accel-NGS Methyl-Seq,CEL...
# 27   OtherLibraryVersion,Unknown,Not collected,Not ...
# 19   OtherLibraryVersion,Unknown,Not collected,Not ...
# 850                                                NaN
# 493                                                NaN
# 26
# 18
# 28
# 20
#
#                            DependsOn    Properties Required  \
# 497                              NaN    validValue    False
# 495                              NaN    validValue    False
# 568                              NaN    validValue    False
# 483                              NaN    validValue    False
# 482                              NaN    validValue    False
# 825                              NaN    validValue    False
# 639                              NaN    validValue    False
# 690                              NaN    validValue    False
# 687                              NaN    validValue    False
# 367  specifyLibraryPreparationMethod    validValue    False
# 370  specifyLibraryPreparationMethod    validValue    False
# 368            specifyLibraryVersion    validValue    False
# 371            specifyLibraryVersion    validValue    False
# 721                              NaN    validValue    False
# 857                              NaN    validValue    False
# 731                              NaN    validValue    False
# 486                              NaN    validValue    False
# 734                              NaN    validValue    False
# 859                              NaN    validValue    False
# 749                              NaN    validValue    False
# 864                              NaN    validValue    False
# 752                              NaN    validValue    False
# 866                              NaN    validValue    False
# 760                              NaN    validValue    False
# 873                              NaN    validValue    False
# 771                              NaN    validValue    False
# 778                              NaN    validValue    False
# 788                              NaN    validValue    False
# 491                              NaN    validValue    False
# 791                              NaN    validValue    False
# 890                              NaN    validValue    False
# 10                                    dataProperty     True
# 9                                     dataProperty     True
# 25                                    dataProperty     True
# 17                                    dataProperty     True
# 27                                    dataProperty     True
# 19                                    dataProperty     True
# 850                              NaN    validValue    False
# 493                              NaN    validValue    False
# 26                                    dataProperty    False
# 18                                    dataProperty    False
# 28                                    dataProperty    False
# 20                                    dataProperty    False
#
#                                                Parent DependsOn Component  \
# 497                                               NaN                 NaN
# 495                                               NaN                 NaN
# 568                                               NaN                 NaN
# 483                                               NaN                 NaN
# 482                                               NaN                 NaN
# 825                                               NaN                 NaN
# 639                                               NaN                 NaN
# 690                                               NaN                 NaN
# 687                                               NaN                 NaN
# 367  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 370  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 368  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 371  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 721                                               NaN                 NaN
# 857                                               NaN                 NaN
# 731                                               NaN                 NaN
# 486                                               NaN                 NaN
# 734                                               NaN                 NaN
# 859                                               NaN                 NaN
# 749                                               NaN                 NaN
# 864                                               NaN                 NaN
# 752                                               NaN                 NaN
# 866                                               NaN                 NaN
# 760                                               NaN                 NaN
# 873                                               NaN                 NaN
# 771                                               NaN                 NaN
# 778                                               NaN                 NaN
# 788                                               NaN                 NaN
# 491                                               NaN                 NaN
# 791                                               NaN                 NaN
# 890                                               NaN                 NaN
# 10   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 9    bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 25   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 17   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 27   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 19   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 850                                               NaN                 NaN
# 493                                               NaN                 NaN
# 26   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 18   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 28   bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 20   bsSeq (bisulfite-seq WGBS methylseq methylomics)
#
#                Source Validation Rules
# 497               NaN              NaN
# 495               NaN              NaN
# 568               NaN              NaN
# 483               NaN              NaN
# 482               NaN              NaN
# 825               NaN              NaN
# 639               NaN              NaN
# 690               NaN              NaN
# 687               NaN              NaN
# 367  Sage Bionetworks
# 370  Sage Bionetworks
# 368  Sage Bionetworks
# 371  Sage Bionetworks
# 721               NaN              NaN
# 857               NaN              NaN
# 731               NaN              NaN
# 486               NaN              NaN
# 734               NaN              NaN
# 859               NaN              NaN
# 749               NaN              NaN
# 864               NaN              NaN
# 752               NaN              NaN
# 866               NaN              NaN
# 760               NaN              NaN
# 873               NaN              NaN
# 771               NaN              NaN
# 778               NaN              NaN
# 788               NaN              NaN
# 491               NaN              NaN
# 791               NaN              NaN
# 890               NaN              NaN
# 10   Sage Bionetworks
# 9    Sage Bionetworks
# 25   Sage Bionetworks
# 17   Sage Bionetworks
# 27   Sage Bionetworks
# 19   Sage Bionetworks
# 850               NaN              NaN
# 493               NaN              NaN
# 26   Sage Bionetworks
# 18   Sage Bionetworks
# 28   Sage Bionetworks
# 20   Sage Bionetworks

# %%
# Another typo
dm2["Valid Values"] = dm2["Valid Values"].str.replace(
    "falseFalseFALSEtrueTrueTRUE", "TRUE,FALSE"
)

# %%
dm2[dm2["Attribute"] == "RNAseq"]["DependsOn"].values[0].split(",")
# Out:
# ['specimenID',
#  'sampleType',
#  'specifySampleType',
#  'specifyMeasurementTechnique',
#  'technologyPlatformVersion',
#  'specifyPlatformVersion',
#  'platformLocation',
#  'specifyPlatformLocation',
#  'referenceTranscriptID',
#  'repositoryName',
#  'specifyRepositoryName',
#  'transcriptType',
#  'specifyTranscriptType',
#  'resultUnit',
#  'valueReported',
#  'libraryPreparationMethod',
#  'specifyLibraryPreparationMethod',
#  'libraryVersion',
#  'specifyLibraryVersion',
#  'isStranded',
#  'readStrandOrigin',
#  'readLength',
#  'readLengthUnits',
#  'specifyReadLengthUnits',
#  'runType',
#  'totalReads',
#  'Component']

# %%
temp = dm2.drop_duplicates(subset=["Attribute", "Parent"]).reset_index(drop=True)

# %%
temp[temp["Attribute"] == "RNAseq"]["DependsOn"].values[0].split(",")
# Out:
# ['specimenID',
#  'sampleType',
#  'specifySampleType',
#  'specifyMeasurementTechnique',
#  'technologyPlatformVersion',
#  'specifyPlatformVersion',
#  'platformLocation',
#  'specifyPlatformLocation',
#  'referenceTranscriptID',
#  'repositoryName',
#  'specifyRepositoryName',
#  'transcriptType',
#  'specifyTranscriptType',
#  'resultUnit',
#  'valueReported',
#  'libraryPreparationMethod',
#  'specifyLibraryPreparationMethod',
#  'libraryVersion',
#  'specifyLibraryVersion',
#  'isStranded',
#  'readStrandOrigin',
#  'readLength',
#  'readLengthUnits',
#  'specifyReadLengthUnits',
#  'runType',
#  'totalReads',
#  'Component']

# %%
print(dm2.shape)

dm2 = dm2.drop_duplicates(subset=["Attribute"]).reset_index(
    drop=True
)  # 'DependsOn', 'Properties',

display(dm2.shape)
# Out:
# (904, 10)
# (632, 10)

# %%
# Recode required columns and fix spelling mistakes
required_recoder = {"0.0": "False", "1.0": "True", "FASLSE": "False"}
dm2["Required"] = dm2["Required"].replace(required_recoder)

dm2[~dm2["Required"].str.contains("True|False", regex=True)]
# Out:
# Empty DataFrame
# Columns: [Attribute, Description, Valid Values, DependsOn, Properties, Required, Parent, DependsOn Component, Source, Validation Rules]
# Index: []

# %%
search_df(dm2, "measurementTechnique")
# Out:
#                                             Attribute  \
# 3                         specifyMeasurementTechnique
# 180                         OtherMeasurementTechnique
# 194       OtherMetabolomics HumanmeasurementTechnique
# 624                                Metabolomics Human
# 625                                        Microbiome
# 626                                            RNAseq
# 627                           Whole Genome Sequencing
# 628  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 629                                        genotyping
# 630                                        proteomics
# 631                                          scRNAseq
#
#                                                                 Description  \
# 3    If "other" is selected list the name of the measurement technique used
# 180  If "other" is selected list the name of the measurement technique used
# 194  If "other" is selected list the name of the measurement technique used
# 624                                                                     NaN
# 625                                                                     NaN
# 626                                                                     NaN
# 627                                                                     NaN
# 628                                                                     NaN
# 629                                                                     NaN
# 630                                                                     NaN
# 631                                                                     NaN
#
#     Valid Values  \
# 3
# 180
# 194
# 624          NaN
# 625          NaN
# 626          NaN
# 627          NaN
# 628          NaN
# 629          NaN
# 630          NaN
# 631          NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      DependsOn  \
# 3
# 180                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                specifyMeasurementTechnique
# 194                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                specifyMeasurementTechnique
# 624  specimenID,sampleType,specifySampleType,specifyMeasurementTechnique,technologyPlatformVersion,specifyPlatformVersion,platformLocation,specifyPlatformLocation,msTarget,msAnalyzerTypeMS1,specifyMSAnalyzerTypeMS1,msAnalyzerTypeMS2,specifyMSAnalyzerTypeMS2,msAssayTechnique,specifyMSAssayTechnique,msAnalyteType,specifyMSAnalyteType,msInstrumentModel,specifyMSInstrumentModel,sampleIntroduction,specifySampleIntroduction,extractionMethod,acquisitionMode,acquisitionSoftware,acquistionSoftwareVersion,samplePrepProtocol,databaseName,specifyDatabaseName,databaseSource,specifyDatabaseSource,databaseWeblink,spectrometerFrequency,hasIonizationSource,ionProperty,vacuumPressure,vacuumPressureUnit,specifyVacuumPressueUnits,lensVoltages ,lensVoltagesUnit ,specifyLensVoltageUnits,gasFlowTemperature,gasFlowTemperatureUnit,hasAssayControl,controlType,specifyControlType,experiementalBatchSize,experiementalBatchSizeUnit,specifyExperimentalBatchSizeUnits,batchSize,batchSizeUnit,specifyBatchSizeUnits,batchID,batchLabel,sampleBatchID,sampleBatchSize,sampleBatchSizeUnit,specifySampleBatchSizeUnits,acquisitionBatchID,acquisitionBatchSize,acquisitionBatchSizeUnit,specifyAcquisitionBatchSizeUnits,processingBatchID,processingBatchSize,processingBatchSizeUnit,specifyProcessingBatchSizeUnit,f,Component
# 625                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                specimenID,sampleType,specifySampleType,specifyMeasurementTechnique,technologyPlatformVersion,specifyPlatformVersion,platformLocation,specifyPlatformLocation,extractionMethod,specifyExtractionMethod,libraryBatchID,sequencingBatchID,sequencingBatchSize,sequencingBatchSizeUnit,specifySequencingBatchSizeUnit,dnaBatchID,dnaBatchSize,dnaBatchSizeUnit,specifyDNABatchSizeUnit,libraryPrep,specifyLibraryPrep,libraryPreparationMethod,specifyLibraryPreparationMethod,libraryVersion,specifyLibraryVersion,isStranded,readStrandOrigin,readLength,readLengthUnits,specifyReadLengthUnits,runType,totalReads,Component
# 626                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            specimenID,sampleType,specifySampleType,specifyMeasurementTechnique,technologyPlatformVersion,specifyPlatformVersion,platformLocation,specifyPlatformLocation,referenceTranscriptID,repositoryName,specifyRepositoryName,transcriptType,specifyTranscriptType,resultUnit,valueReported,libraryPreparationMethod,specifyLibraryPreparationMethod,libraryVersion,specifyLibraryVersion,isStranded,readStrandOrigin,readLength,readLengthUnits,specifyReadLengthUnits,runType,totalReads,Component
# 627                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 specimenID,sampleType,specifySampleType,specifyMeasurementTechnique,technologyPlatformVersion,specifyPlatformVersion,platformLocation,specifyPlatformLocation,referenceTranscriptID,repositoryName,specifyRepositoryName,transcriptType,specifyTranscriptType,resultUnit,valueReported,rnaBatchID,libraryBatchID,sequencingBatchID,libraryPrep,specifyLibraryPrep,libraryPreparationMethod,specifyLibraryPreparationMethod,libraryVersion,specifyLibraryVersion,isStranded,readStrandOrigin,readLength,readLengthUnits,specifyReadLengthUnits,runType,totalReads,Component
# 628                                                                                                                                                                                                                                                                                                                                                                                                                                           specimenID,sampleType,specifySampleType,specifyMeasurementTechnique,technologyPlatformVersion,specifyPlatformVersion,platformLocation,specifyPlatformLocation,referenceTranscriptID,dnaBatchID,dnaBatchID,dnaBatchSize,dnaBatchSizeUnit,specifyDNABatchSizeUnit,libraryBatchID,libraryPrep,specifyLibraryPrep,libraryPreparationMethod,specifyLibraryPreparationMethod,libraryVersion,specifyLibraryVersion,sequencingBatchID,sequencingBatchSize,sequencingBatchSizeUnit,specifySequencingBatchSizeUnit,libraryPreparationMethod,specifyLibraryPreparationMethod,libraryVersion,specifyLibraryVersion,isStranded,readStrandOrigin,readLength,readLengthUnits,specifyReadLengthUnits,runType,totalReads,directionalBSseqLibrary,gDNAconc,lambdaDNAconc,pcrCycles,meanCoverage,conversionRatio,conversionRatioUnits,specifyConversionRatioUnit,enrichmentMethod,specifyEnrichmentMethod,Component
# 629                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               specimenID,sampleType,specifySampleType,useReagent,reagentID(s),reagentName,reagentManufacturer,reagentCatalogNumber,reagentLotNumber,reagentWeblink,reagentContact,useTreatment,treatmentID(s),treatmentName,treatmentAmountValue,treatmentAmountUnit,treatmentDurationValue,treatmentDurationUnit,treatmentTemperatureValue,treatmentTemperatureUnit,specifyMeasurementTechnique,Component
# 630                                                                                                                                                                                                                                                                                                                                                                                                                                                                               specimenID,sampleType,specifySampleType,specifyMeasurementTechnique,technologyPlatformVersion,specifyPlatformVersion,platformLocation,specifyPlatformLocation,msTarget,msAnalyzerTypeMS1,specifyMSAnalyzerTypeMS1,msAnalyzerTypeMS2,specifyMSAnalyzerTypeMS2,msAssayTechnique,specifyMSAssayTechnique,msAnalyteType,specifyMSAnalyteType,protoemicsAssayType,specifyProteomicsAssayType,msInstrumentModel,specifyMSInstrumentModel,digestionMethod,specifyDigestionMethod,fractionIdentifier,acquisitionMode,acquisitionSoftware,acquistionSoftwareVersion,samplePrepProtocol,databaseName,specifyDatabaseName,databaseSource,specifyDatabaseSource,databaseWeblink,spectrometerFrequency,modificationParameters,specifyOtherModificationParameters,cleavageAgents,specifyOtherCleavageAgent,fragmentMassTolerance,precursorMassTolerance,dataFile,Component
# 631                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                specimenID,sampleType,specifySampleType,specifyMeasurementTechnique,technologyPlatformVersion,specifyPlatformVersion,platformLocation,specifyPlatformLocation,referenceTranscriptID,repositoryName,specifyRepositoryName,transcriptType,specifyTranscriptType,resultUnit,valueReported,rnaBatchID,rnaBatchSize,rnaBatchSizeUnit,specifyRNABatchSizeUnit,libraryBatchID,sequencingBatchID,sequencingBatchSize,sequencingBatchSizeUnit,specifySequencingBatchSizeUnit,libraryPrep,specifyLibraryPrep,libraryPreparationMethod,specifyLibraryPreparationMethod,libraryVersion,specifyLibraryVersion,isStranded,readStrandOrigin,readLength,readLengthUnits,specifyReadLengthUnits,runType,totalReads,Component
#
#        Properties Required                                            Parent  \
# 3    dataProperty    False  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 180    validValue    False  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 194    validValue    False                                Metabolomics Human
# 624      dataType     True                                               NaN
# 625      dataType     True                                               NaN
# 626      dataType     True                                               NaN
# 627      dataType     True                                               NaN
# 628      dataType     True                                               NaN
# 629      dataType     True                                               NaN
# 630      dataType     True                                               NaN
# 631      dataType     True                                               NaN
#
#     DependsOn Component            Source Validation Rules
# 3                        Sage Bionetworks
# 180                      Sage Bionetworks
# 194                      Sage Bionetworks
# 624                 NaN               NaN              NaN
# 625                 NaN               NaN              NaN
# 626                 NaN               NaN              NaN
# 627                 NaN               NaN              NaN
# 628                 NaN               NaN              NaN
# 629                 NaN               NaN              NaN
# 630                 NaN               NaN              NaN
# 631                 NaN               NaN              NaN
#                                             Attribute  \
# 3                         specifyMeasurementTechnique
# 180                         OtherMeasurementTechnique
# 194       OtherMetabolomics HumanmeasurementTechnique
# 624                                Metabolomics Human
# 625                                        Microbiome
# 626                                            RNAseq
# 627                           Whole Genome Sequencing
# 628  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 629                                        genotyping
# 630                                        proteomics
# 631                                          scRNAseq
#
#                                            Description Valid Values  \
# 3    If "other" is selected list the name of the me...
# 180  If "other" is selected list the name of the me...
# 194  If "other" is selected list the name of the me...
# 624                                                NaN          NaN
# 625                                                NaN          NaN
# 626                                                NaN          NaN
# 627                                                NaN          NaN
# 628                                                NaN          NaN
# 629                                                NaN          NaN
# 630                                                NaN          NaN
# 631                                                NaN          NaN
#
#                                              DependsOn    Properties Required  \
# 3                                                       dataProperty    False
# 180                        specifyMeasurementTechnique    validValue    False
# 194                        specifyMeasurementTechnique    validValue    False
# 624  specimenID,sampleType,specifySampleType,specif...      dataType     True
# 625  specimenID,sampleType,specifySampleType,specif...      dataType     True
# 626  specimenID,sampleType,specifySampleType,specif...      dataType     True
# 627  specimenID,sampleType,specifySampleType,specif...      dataType     True
# 628  specimenID,sampleType,specifySampleType,specif...      dataType     True
# 629  specimenID,sampleType,specifySampleType,useRea...      dataType     True
# 630  specimenID,sampleType,specifySampleType,specif...      dataType     True
# 631  specimenID,sampleType,specifySampleType,specif...      dataType     True
#
#                                                Parent DependsOn Component  \
# 3    bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 180  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 194                                Metabolomics Human
# 624                                               NaN                 NaN
# 625                                               NaN                 NaN
# 626                                               NaN                 NaN
# 627                                               NaN                 NaN
# 628                                               NaN                 NaN
# 629                                               NaN                 NaN
# 630                                               NaN                 NaN
# 631                                               NaN                 NaN
#
#                Source Validation Rules
# 3    Sage Bionetworks
# 180  Sage Bionetworks
# 194  Sage Bionetworks
# 624               NaN              NaN
# 625               NaN              NaN
# 626               NaN              NaN
# 627               NaN              NaN
# 628               NaN              NaN
# 629               NaN              NaN
# 630               NaN              NaN
# 631               NaN              NaN

# %% [markdown]
# Last bit of cleanup

# %%
# Remove measurement technique dependency from biospecimen human
dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"] = (
    dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"]
    .values[0]
    .replace("measurementTechnique,", "")
)
bio_measure_technique_index = dm2.query(
    'Attribute == "measurementTechnique" and Parent == "Biospecimen human"'
)

if len(bio_measure_technique_index.index) > 0:
    dm2 = dm2.drop(index=bio_measure_technique_index.index[0]).reset_index(drop=True)

# %%
# Remove measurement technique dependency from biospecimen human
dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"] = (
    dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"]
    .values[0]
    .replace("specifyMeasurementTechnique,", "")
)
bio_measure_technique_index = dm2.query(
    'Attribute == "specifyMeasurementTechnique" and Parent == "Biospecimen human"'
)


if len(bio_measure_technique_index.index) > 0:
    dm2 = dm2.drop(index=bio_measure_technique_index.index[0]).reset_index(drop=True)

# %%
# Remove measurement technique dependency from biospecimen human
dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"] = (
    dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"]
    .values[0]
    .replace("OtherMeasurementTechnique,", "")
)
bio_measure_technique_index = dm2.query('Attribute == "OtherMeasurementTechnique"')


if len(bio_measure_technique_index.index) > 0:
    dm2 = dm2.drop(index=bio_measure_technique_index.index[0]).reset_index(drop=True)

# %%
dm2.loc[
    dm2[dm2["Attribute"] == "visitCode"].index.values[0], "Valid Values"
] = "1,2,Other,Unknown,Not collected,Not applicable"

dm2.loc[dm2[dm2["Attribute"] == "visitCode"].index.values[0], "Validation Rules"] = ""

# %% [markdown]
# Extra comma at beginning of valid values

# %% [markdown]
# # Validation Rules

# %%
mixed_attrs = [
    {"attribute": "tissueWeight", "val_type": "mixed float", "regex": "regex search"},
    {"attribute": "tissueVolume", "val_type": "mixed float", "regex": "regex search"},
    {"attribute": "specimenAge", "val_type": "mixed integer", "regex": "regex search"},
    {"attribute": "samplingAge", "val_type": "mixed integer", "regex": "regex search"},
    {"attribute": "age", "val_type": "mixed integer", "regex": "regex search"},
]

for ma in mixed_attrs:
    attribute = ma["attribute"]
    val_type = ma["val_type"]

    # get indexes for new validation rules based on attribute
    indexes = dm2[dm2["Attribute"] == attribute].index.tolist()

    for i in indexes:
        if val_type == "integer":
            first_part = "[0-9]+"
        elif val_type == "float":
            first_part = "^\d*?\.?\d$"
        elif val_type == "mixed integer":
            regex = "regex search"
            num_match = "^\d*?"
        elif val_type == "mixed float":
            regex = "regex search"
            num_match = "^\d*?\.?\d$"
            # All valid values are applicable
            new_string = (
                regex
                + num_match
                + "|"
                + ""
                + "|".join(dm2.loc[i, "Valid Values"].split(","))
            )

        dm2.loc[i, "Validation Rules"] = new_string

# %%
dm2["Validation Rules"].unique().tolist()
# Out:
# ['',
#  'regex search ([0-9]+\\.[0-9]*.)|([0-9]+)',
#  nan,
#  'regex search^\\d*?\\.?\\d$|Unknown|Not collected|Not applicable',
#  'regex search ([0-9]+)']

# %% [markdown]
# ## Building Dependencies

# %%
dependencies = {
    "specimenID": "matchAtLeastOne Biospecimenhuman.specimenID value",
    "individualID": "matchExactlyOne IndividualHuman.individualID set",
}

# %%
for k, v in dependencies.items():
    indexes = dm2[dm2["Attribute"] == k]["Validation Rules"].index.values
    dm2.loc[indexes, "Validation Rules"] = v

# %%
dm2.loc[3, "Valid Values"] = dm2.loc[3, "Valid Values"].replace(
    ",Whole Genome Sequencing", ""
)

# %% [markdown]
# # Create File Annotations Attributes

# %%
# base file annotations
base_file_annotations = {"resourceType": "", "isReleased": False, "fileType": ""}

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm2.query('Attribute == "visitCode"'))
# Out:
#      Attribute  \
# 161  visitCode
#
#                                                                                                                       Description  \
# 161  Indicate which longitudinal visit for the individual the data comes from, provided by the data contributor's data dictionary
#
#                                        Valid Values DependsOn    Properties  \
# 161  1,2,Other,Unknown,Not collected,Not applicable            dataProperty
#
#     Required            Parent DependsOn Component            Source  \
# 161     True  Individual Human                      Sage Bionetworks
#
#     Validation Rules
# 161

# %% [markdown]
# # Write out new data model

# %%
hard_coded_valid_values = [
    {
        "attribute": "visitCode",
        "valid_value": "1,2,Other,Unknown,Not collected,Not applicable",
    },
    {"attribute": "consentGroupID", "valid_value": "1,2,3"},
    {"attribute": "samplingAge", "valid_value": ""},
    {"attribute": "specimenAge", "valid_value": ""},
    {"attribute": "age", "valid_value": ""},
]

# %%
for h in hard_coded_valid_values:
    dm2.loc[
        dm2[dm2["Attribute"] == h["attribute"]].index.values[0], "Valid Values"
    ] = h["valid_value"]

# %%
checks = [c["attribute"] for c in hard_coded_valid_values]

with pd.option_context("display.max_colwidth", None):
    display(dm2.query(f"Attribute in @checks"))
# Out:
#           Attribute  \
# 141     specimenAge
# 142     samplingAge
# 161       visitCode
# 163  consentGroupID
# 169             age
#
#                                                                                                                                                           Description  \
# 141  The subject's age at the time of specimen extraction is the individual's age (since birth) at the time a given specimen was extracted. Measured as age in years.
# 142                                                                    The calculated age of the sample, measurement is determined or coded by the data contributor.
# 161                                      Indicate which longitudinal visit for the individual the data comes from, provided by the data contributor's data dictionary
# 163                                                                 Indicate the consent group for the individual, provided by the data contributor's data dictionary
# 169  Age of the individual (age in years of the individual at first recorded study event (enrollment, visit, observation, sample collection, survey completion, etc.)
#
#                                        Valid Values DependsOn    Properties  \
# 141                                                            dataProperty
# 142                                                            dataProperty
# 161  1,2,Other,Unknown,Not collected,Not applicable            dataProperty
# 163                                           1,2,3            dataProperty
# 169                                                            dataProperty
#
#     Required             Parent DependsOn Component             Source  \
# 141     True  Biospecimen human                       Sage Bionetworks
# 142     True  Biospecimen human                       Sage Bionetworks
# 161     True   Individual Human                       Sage Bionetworks
# 163     True   Individual Human                       Sage Bionetworks
# 169     True   Individual Human                      Sage Bionetworks,
#
#                                                  Validation Rules
# 141  regex search^\d*?\.?\d$|Unknown|Not collected|Not applicable
# 142  regex search^\d*?\.?\d$|Unknown|Not collected|Not applicable
# 161
# 163
# 169  regex search^\d*?\.?\d$|Unknown|Not collected|Not applicable

# %%
import yaml

# %%
with open("../configs/notebook_config.yaml", "r") as f:
    config = yaml.safe_load(f)

# paths to import files
root_path = config["paths"]["root"]
schematic_config = config["paths"]["schematic"]
csv_model = config["file_names"]["csv_model"]
json_model = config["file_names"]["json_model"]

print(
    "Schematic config: ",
    schematic_config,
    "\n",
    "CSV model: ",
    csv_model,
    "\n",
    "JSON LD Model: ",
    json_model,
)
# Out:
# Schematic config:  C:/Users/nlee/Documents/Projects/schematic/schematic/config.yml
#  CSV model:  C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.1.0.csv
#  JSON LD Model:  C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.jsonld

# %%
dm2.columns.tolist()
# Out:
# ['Attribute',
#  'Description',
#  'Valid Values',
#  'DependsOn',
#  'Properties',
#  'Required',
#  'Parent',
#  'DependsOn Component',
#  'Source',
#  'Validation Rules']

# %%
# write out data model into csv
dm2.to_csv(csv_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3212\809299604.py in <module>
#       1 # write out data model into csv
# ----> 2 dm2.to_csv(csv_model)
#
# NameError: name 'dm2' is not defined

# %% [markdown]
# # Convert CSV to JSON LD

# %%
print(f'schematic schema convert {csv_model} --output_jsonld {json_model}')

# !schematic schema convert {csv_model} --output_jsonld {json_model}
# Out:
# schematic schema convert C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.1.0.csv --output_jsonld C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.1.0.jsonld
# ^C
# The Data Model was created and saved to 'C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.1.0.jsonld' location.
# Starting schematic...
# Done adding requirements and value ranges to attributes

# %% [markdown]
# ## Get manifest names to generate manifests

# %%
import json

with open(json_model, "r") as jf:
    jo = json.load(jf)

# %%
# Manifest names in data model
manifest_names_extracted = []

for i in jo["@graph"]:
    if i["@id"] == "bts:dataType":
        manifest_names_extracted.append(
            i["schema:domainIncludes"]["@id"].replace("bts:", "")
        )

# display names extracted
manifest_display_names_extracted = []

for i in jo["@graph"]:
    if i["@id"].replace("bts:", "") in (manifest_names_extracted):
        manifest_display_names_extracted.append(i["sms:displayName"])
manifest_display_names_extracted

# Create dictionary for lookup later
manifest_name_relationships = dict(
    zip(manifest_names_extracted, manifest_display_names_extracted)
)

manifest_name_relationships
# Out:
# {'Biospecimenhuman': 'Biospecimen human',
#  'BiospecimennonHuman': 'Biospecimen nonHuman',
#  'IndividualHuman': 'Individual Human',
#  'IndividualnonHuman': 'Individual nonHuman',
#  'MetabolomicsHuman': 'Metabolomics Human',
#  'Microbiome': 'Microbiome',
#  'RNAseq': 'RNAseq',
#  'WholeGenomeSequencing': 'Whole Genome Sequencing',
#  'BsSeq(bisulfite-seqWGBSmethylseqmethylomics)': 'bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#  'Genotyping': 'genotyping',
#  'Proteomics': 'proteomics',
#  'ScRNAseq': 'scRNAseq'}

# %% [markdown]
# # Create dca template configuration

# %%
def manifest_template(k, v, t="file"):
    manifest_template = {"display_name": v, "schema_name": k, "type": t}
    return manifest_template


dca_template = {
    "manifest_schemas": [],
    "service_version": "v23.1.1",
    "schema_version": "v1.2",
}

records = [
    "IndividualHuman",
    "IndividualnonHuman",
    "Biospecimenhuman",
    "BiospecimennonHuman",
]


for k, v in manifest_name_relationships.items():
    if k in records:
        t = "records"
    else:
        t = "file"
    dca_template["manifest_schemas"].append(manifest_template(k, v, t))

json_formatted_str = json.dumps(dca_template, indent=2)
print(json_formatted_str)

with open(
    "C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/manifests/dca_template.json",
    "w",
) as f:
    f.write(json_formatted_str)
# Out:
# {
#   "manifest_schemas": [
#     {
#       "display_name": "Biospecimen human",
#       "schema_name": "Biospecimenhuman",
#       "type": "records"
#     },
#     {
#       "display_name": "Biospecimen nonHuman",
#       "schema_name": "BiospecimennonHuman",
#       "type": "records"
#     },
#     {
#       "display_name": "Individual Human",
#       "schema_name": "IndividualHuman",
#       "type": "records"
#     },
#     {
#       "display_name": "Individual nonHuman",
#       "schema_name": "IndividualnonHuman",
#       "type": "records"
#     },
#     {
#       "display_name": "Metabolomics Human",
#       "schema_name": "MetabolomicsHuman",
#       "type": "file"
#     },
#     {
#       "display_name": "Microbiome",
#       "schema_name": "Microbiome",
#       "type": "file"
#     },
#     {
#       "display_name": "RNAseq",
#       "schema_name": "RNAseq",
#       "type": "file"
#     },
#     {
#       "display_name": "Whole Genome Sequencing",
#       "schema_name": "WholeGenomeSequencing",
#       "type": "file"
#     },
#     {
#       "display_name": "bsSeq (bisulfite-seq WGBS methylseq methylomics)",
#       "schema_name": "BsSeq(bisulfite-seqWGBSmethylseqmethylomics)",
#       "type": "file"
#     },
#     {
#       "display_name": "genotyping",
#       "schema_name": "Genotyping",
#       "type": "file"
#     },
#     {
#       "display_name": "proteomics",
#       "schema_name": "Proteomics",
#       "type": "file"
#     },
#     {
#       "display_name": "scRNAseq",
#       "schema_name": "ScRNAseq",
#       "type": "file"
#     }
#   ],
#   "service_version": "v23.1.1",
#   "schema_version": "v1.2"
# }

# %%
# old_schema = {
#     "manifest_schemas": [
#         {
#             "display_name": "Biospecimen human",
#             "schema_name": "Biospecimenhuman",
#             "type": "record"
#         },
#         {
#             "display_name": "Biospecimen nonHuman",
#             "schema_name": "BiospecimennonHuman",
#             "type": "record"
#         },
#         {
#             "display_name": "Individual Human",
#             "schema_name": "IndividualHuman",
#             "type": "record"
#         },
#         {
#             "display_name": "Individual nonHuman",
#             "schema_name": "IndividualnonHuman",
#             "type": "record"
#         },
#         {
#             "display_name": "Metabolomics Human",
#             "schema_name": "MetabolomicsHuman",
#             "type": "file"
#         },
#         {
#             "display_name": "Microbiome",
#             "schema_name": "Microbiome",
#             "type": "file"
#         },
#         {
#             "display_name": "RNAseq",
#             "schema_name": "RNAseq",
#             "type": "file"
#         },
#         {
#             "display_name": "Study",
#             "schema_name": "Study",
#             "type": "file"
#         },
#         {
#             "display_name": "Whole Genome Sequencing",
#             "schema_name": "WholeGenomeSequencing",
#             "type": "file"
#         },
#         {
#             "display_name": "'bsSeq (bisulfite-seq WGBS methylseq methylomics)",
#             "schema_name": "'BsSeq(bisulfite-seqWGBSmethylseqmethylomics)",
#             "type": "file"
#         },
#         {
#             "display_name": "scRNAseq",
#             "schema_name": "ScRNAseq",
#             "type": "file"
#         },
#         {
#             "display_name": "Genotyping",
#             "schema_name": "Genotyping",
#             "type": "file"
#         },
#         {
#             "display_name": "Proteomics",
#             "schema_name": "Proteomics",
#             "type": "file"
#         }
#     ],
#     "service_version": "v23.1.1",
#     "schema_version": "v1.2"
# }

# %%
len(dca_template["manifest_schemas"])

# %%
# len(old_schema['manifest_schemas'])

# %% [markdown]
# ## Generate Manifests

# %%
output_path = "C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/manifests/"

# %% [markdown]
# - valueErrors =
#   - BsSeq(bisulfite-seqWGBSmethylseqmethylomics): [valueReported]
#   - "RNAseq": [rnaBatchID, specifyLibraryPrep]
#   - 'MetabolomicsHuman': ['specifyLibraryVersion']
#   - Proteomics : ['specifyTranscriptType']

# %% [markdown]
# - Remove `(not listed for purposes of this RFC)`
# - Change Assay to be blank or list of values
# - Weight needs to be blank
# - Uknown spelling error
# - 'False / 'True -> remove '

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm2.query('Attribute == "ethnicity"'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3212\2652145402.py in <module>
# ----> 1 with pd.option_context("display.max_colwidth", None):
#       2     display(dm2.query('Attribute == "ethnicity"'))
#
# NameError: name 'pd' is not defined

# %%
import os

# %%
manifest = 'IndividualHuman'

print(f"schematic manifest --config {schematic_config} get -dt {manifest} --output_csv {os.path.join(output_path, manifest + '.csv')} --title {'EL_Manifest_' + manifest} --sheet_url 2>&1 >> manifest_generation_results.txt")

# !echo '{manifest}:' >> manifest_generation_results.txt
# !schematic manifest --config {schematic_config} get -dt {manifest} --output_csv {os.path.join(output_path, manifest + '.xlsx')} --title {'EL_Manifest_' + manifest} --sheet_url 2>&1 >> manifest_generation_results.txt
# Out:
# schematic manifest --config C:/Users/nlee/Documents/Projects/schematic/schematic/config.yml get -dt IndividualHuman --output_csv C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/manifests/IndividualHuman.csv --title EL_Manifest_IndividualHuman --sheet_url 2>&1 >> manifest_generation_results.txt
# Starting schematic...
# The (model > input > location) argument with value 'C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.1.0.jsonld' is being read from the config file.
# The '--jsonld' argument is being taken from configuration file (model > input > location), i.e., 'C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.1.0.jsonld'.
# JSON schema successfully generated from schema.org schema!
# JSON schema file log stored as C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.1.0.IndividualHuman.schema.json
# Permission Id: anyoneWithLink
# Find the manifest template using this Google Sheet URL:
# Find the manifest template using this CSV file path: C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/manifests/IndividualHuman.xlsx

# %%
# !echo ----- newly_generated_manifests ------- 2>&1 >> manifest_generation_links.txt
for manifest in manifest_names_extracted:
    print(manifest)
    # !echo {manifest}: >> manifest_generation_results.txt
    # !schematic manifest --config {schematic_config} get -dt {manifest} --output_xlsx {os.path.join(output_path, manifest + '.xlsx')} --title {'EL_Manifest_' + manifest} --sheet_url 2>&1 >> manifest_generation_results.txt
    # !echo ----------------------------------------------------------------

# %% [markdown]
# Add validation rules

# %%
def mixed_validation_rule(df, attribute):
    ...

# %% [markdown]
# # Validation of manifests

# %%
import random
import string
from pathlib import Path
import lorem

# %% [markdown]
# Hard coded variables

# %%
# number of rows to fill in
nrows = 10
random.seed = 27

# last minute chaos
chaos = False

# %% [markdown]
# Functions

# %%
def valid_values_to_list(df, attribute):
    valid_values = (
        df.query(f'Attribute == "{attribute}"')["Valid Values"].str.split(",").values[0]
    )

    return valid_values

# %%
def get_random_value(list_of_vv):
    return random.choice(list_of_vv)

# %%
def get_rand_integer(min=0, max=100):
    return random.randint(min, max)

# %%
def get_rand_float(min=0, max=100):
    return round(random.uniform(0.0, 100.0), 2)

# %%
def get_random_string():
    t = lorem.sentence().split(" ")[0]
    return t

# %%
def introduce_random_NAs(df, N=5):
    """Another test to see if columns can handle empty values or if they will flag the empty value"""

    rows, cols = df.shape

    row_index = [get_rand_integer(max=rows - 1) for _ in range(N)]

    col_index = [get_rand_integer(max=cols - 1) for _ in range(N)]

    indexes = list(zip(row_index, col_index))

    # Print indexes to check where values got replaced
    print(indexes)
    # for i in indexes
    df.iloc[row_index, col_index] = np.NaN

    return df

# %%
# find attribute column, fill in with value
def fill_in_attribute(df, index, attribute, value):
    df.loc[index, attribute] = value
    return df

# %%
def gen_mixed_string_with_length(N=12):
    # initializing size of string

    # using random.choices()
    # generating random strings
    res = "".join(random.choices(string.ascii_uppercase + string.digits, k=N))

    # print result
    return res

# %%
def random_change():
    # list of functions to choose from
    choices = [
        introduce_random_NAs,
        gen_mixed_string_with_length,
        get_rand_integer,
        get_random_string,
        get_rand_float,
    ]

    choice = random.choice(choices)

    print(choice.__name__)

    return choice()

# %%
def partition(list_in, n):
    random.shuffle(list_in)
    return [list_in[i::n] for i in range(n)]

# %% [markdown]
# Create individual and biospecimen ids from random text

# %%
# for individaul IDs and specimenIDs
individaulIds = [gen_mixed_string_with_length(N=5) for _ in range(1, 100)]
specimenIds = [gen_mixed_string_with_length() for _ in range(1, 1000)]

# %%
specimenIds_partitioned = partition(specimenIds, 100)

# %%
ind_bio_map = []

for i, v in enumerate(individaulIds):
    for s in specimenIds_partitioned[i]:
        ind_bio_map.append({"individualID": v, "specimenID": s})

ind_bio_map = pd.DataFrame(ind_bio_map)

# %%
# Manifests
# Get all the RFC file paths
manifest_paths = glob(
    r"C:\Users\nlee\Documents\Projects\ELITE-DCC\ELITE-data-models\manifests\*.csv"
)
manifest_paths

# %% [markdown]
# Tested:
#
# - scRNAseq : Passed (Need to add validation for biospecimenId)

# %%
# load data model
data_model_path = r"C:\Users\nlee\Documents\Projects\ELITE-DCC\ELITE-data-models\models\EL_data_model_v3.csv"

dm = pd.read_csv(data_model_path).iloc[:, 1:].fillna("")

dm.head()

# %%
# load manifest
manifest_path = "C:\\Users\\nlee\\Documents\\Projects\\ELITE-DCC\\ELITE-data-models\\manifests\\WholeGenomeSequencing.csv"

df = pd.read_csv(manifest_path)

df.head()

# %%
manifest_name = Path(manifest_path).stem

parent_name = manifest_name_relationships[manifest_name]

df["Component"] = manifest_name

# %%
# Attributes from data model
attrs_to_fill = dm[dm["Attribute"] == (parent_name)]["DependsOn"].values[0].split(",")

attrs_to_fill

# %%
dm_attrs = (
    dm[(dm["Attribute"].isin(attrs_to_fill))]
    .drop_duplicates(subset=["Attribute"])
    .copy()
)

dm_attrs

# %%
# find values in dm_attrrs with valid values filled in
vv_attrs = dm_attrs[dm_attrs["Valid Values"] != ""]["Attribute"].tolist()

# %%
# fill in values for the mainfest with the data model
for attribute in vv_attrs:
    for i in range(nrows):
        index = i
        temp_vv = valid_values_to_list(dm_attrs, attribute)
        new_val = get_random_value(temp_vv)
        df = fill_in_attribute(df, index, attribute, new_val)

# %%
# update df with sample of individual and biospecimen sample ids
ind_sample = ind_bio_map.sample(nrows, replace=True)[
    ["individualID", "specimenID"]
].reset_index(drop=True)

df.update(ind_sample)

# %%
swap_validation_coder = {v: k for k, v in validation_coder.items()}

# column coding for values
dm_attrs["swapper"] = (
    dm_attrs["Validation Rules"].fillna("number").replace(swap_validation_coder)
)

dm_attrs["swapper"] = dm_attrs["swapper"].apply(
    lambda x: re.sub("^\d*?\.?\d$", "number", x)
)

# need a better regex later
dm_attrs["swapper"] = dm_attrs["swapper"].apply(
    lambda x: re.sub(
        "number numbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumber",
        "number",
        x,
    )
)

print(dm_attrs["swapper"].unique())

dm_attrs.head()

# %%
free_form_attrs = dm_attrs[
    (dm_attrs["Valid Values"] == "")
    & (~dm_attrs["Attribute"].isin(["individualID", "specimenID"]))
]

free_form_attrs

# %%
def generate_values(value):
    if value == 'string':
        # generate string
        return get_random_string()
    elif value == 'number':
        # generate random number
        return get_rand_integer()
    elif value == 'mixed'
        # split string into regex expressions i.e. numbers and valid values
        choices = ['string', 'number']
        # chose random to fill in cell

# %%
test = "([0-9]+\\.[0-9]*.)|([0-9]+)"
test2 = "^\\d*?\\.?\\d$|Other|Unknown|Not collected|Not applicable"

# def match_pattern(rule):

pattern_checker = {
    "strip_patterns": "regex|search|match",
    "number": "(?![a-zA-Z]+)(\[0-9\])",
    "string": "([a-zA-Z]+)(?!\[0-9\])",
    "mixed": "(?:[a-zA-Z]+\d+)",
}

result = False

while result == False:
    for k, v in pattern_checker.items():
        result = bool(re.search(pattern=v, string=test))
        print(pattern)
        print(result)


# pattern = '(?![a-zA-Z]+)(\[0-9\])'
# results = bool(re.search(pattern = pattern, string = test))
# results

# %%
for attribute in free_form_attrs["Attribute"].tolist():
    for i in range(nrows):
        index = i
        test = free_form_attrs.query(f'Attribute == "{attribute}"')
        new_val = test["swapper"].apply(generate_values).values[0]
        df = fill_in_attribute(df, index, attribute, new_val)

# %%
# write out test manifest to file for testing in DCA
df["Component"] = manifest_name

if chaos:
    df = introduce_random_NAs(df)

# %%
# Write out manifest
csv_path = os.path.join(
    r"C:\Users\nlee\Documents\Projects\ELITE-DCC\ELITE-data-models\test_manifests",
    manifest_name + "_test.csv",
)

df.to_csv(csv_path)

# %% [markdown]
# # Run Validation Test

# %%
# manifest_path = "C:/Users/nlee/Documents/Projects/schematic/schematic/tests/data/mock_manifests/example_biospecimen_test.csv"
print(
    f"schematic model --config {schematic_config} validate --manifest_path {csv_path} --data_type {manifest_name}")
# !schematic model --config {schematic_config} validate --manifest_path {csv_path} --data_type {manifest_name}

# %% [markdown]
# # Submit Manifest

# %%
print(csv_path)
print(schematic_config)
print(manifest_name)
dataset_id = "syn51753850"

# %% [markdown]
# - d option is the project

# %%
dataset_id = 'syn51753844'

# !schematic model --config C:/Users/nlee/Documents/Projects/schematic/schematic/config.yml submit -mp C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/test_manifests/WholeGenomeSequencing_test.csv -d syn51753850 -vc WholeGenomeSequencing -mrt both

# %%
search_df(dm2, "valueReported")

# %% [markdown]
# # Store Manifest In Dataset For Testing

# %%
import synapseclient
from synapseclient import File

manifest_folder_id = 'syn51728840'

# %run C:\Users\nlee\Documents\Projects\utils\syanpse_login.py

# %%
csv_entity = File(
    csv_path,
    description=f"Test manifest for {manifest_name}",
    parent=data_folder,
    annotations={"resourceType": "manifest", "manifestType": {manifest_name}},
)

csv_entity = syn.store(csv_entity)

# %%
s = syn.getColumns("syn51748558")

# %%
for i in s:
    print(i)

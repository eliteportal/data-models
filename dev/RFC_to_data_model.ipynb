# %% [markdown]
# - Fix inconsistencies in parent column

# %%
import pandas as pd
import numpy as np
import os

from glob import glob
import yaml
import re
import copy
import json

# %% [markdown]
# # Hard Coded stuff

# %%
validation_coder = {
    "number": "regex search ([0-9]+\.[0-9]*.?)|([0-9]+)",
    "integer": "regex search ([0-9]+)",
    "string": "",
}

# %%
base_cols = [
    "Attribute",
    "Description",
    "Valid Values",
    "DependsOn",
    "Properties",
    "Required",
    "Template",
    "Parent",
    "DependsOn Component",
    "Source",
    "Validation Rules",
]

keep_cols = [
    "Attribute",
    "Description",
    "Valid Values",
    "Required",
    "DependsOn",
    "DependsOn Component",
    "Properties",
    "Validation Rules",
    "Template",
    "Parent",
    "Source",
    "Type",
    "Ontology",
    "multivalue",
]

# %% [markdown]
# # Functions

# %%
# Clean list columns into single string
def join_strings(string):
    try:
        return ",".join(string)
    except:
        return ""

# %%
def search_df(df, pattern):
    mask = np.column_stack(
        [df[col].str.contains(pattern, na=False, flags=re.IGNORECASE)
         for col in df]
    )

    df = df.loc[mask.any(axis=1)]

    with pd.option_context("display.max_colwidth", None):
        display(df)

    return df

# %%
def find_row(df, attribute):
    """Get indexes of the dataframe"""
    indexes = df.index[
        df["Attribute"].str.contains(
            "(^" + re.escape(attribute) + "$)", flags=re.IGNORECASE
        )
    ].tolist()
    if len(indexes) != 0:
        return indexes
    else:
        print(attribute)
        return None


def replace_valid_value(df, indexes, regex_dict, attribute):
    """Alter the dataframe valid values with the replacement value"""
    if indexes == None:
        return df

    elif len(indexes) > 0:
        regex_dict = regex_dict[attribute]

        for index in indexes:
            df.loc[index, "Valid Values"] = re.sub(
                **regex_dict, string=df.loc[index, "Valid Values"]
            )

            # print(df.loc[index, 'Valid Values'])
        return df
    else:
        return df


def code_equals_values(df, regex_dict, attribute):
    print("attribute: ", attribute)

    indexes = find_row(df, attribute)

    print("Index: ", indexes)

    # regex = replace_value(df, replacements, indexes)

    # print("Regex: ", regex)
    if indexes == None:
        return df
    else:
        df = replace_valid_value(df, indexes, regex_dict, attribute)
        return df

# %%
# Unzip compressed folder if downloaded from Google Drive
# %unzip 'RFC Tables-20230620T181152Z-001.zip'

# %% [markdown]
# # Collect RFCs

# %%
with open("local_configs/notebook_config.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
# Get all the RFC file paths
file_paths = glob("../_data/RFC Tables/*")
file_paths
# Out:
# ['../_data/RFC Tables/EL Assay_ scRNAseq data model.xlsx',
#  '../_data/RFC Tables/EL RFC_ Individual_ Human data model.xlsx',
#  '../_data/RFC Tables/EL RFC_ Assay_proteomics Data Model.xlsx',
#  '../_data/RFC Tables/EL RFC Assay_Whole Genome Sequencing Data Model.xlsx',
#  '../_data/RFC Tables/EL RFC Microbiome Data Model.xlsx',
#  '../_data/RFC Tables/EL RFC_ Biospecimen_nonHuman data model.xlsx',
#  '../_data/RFC Tables/EL RFC_ Individual_ nonHuman data model.xlsx',
#  '../_data/RFC Tables/EL RFC Metabolomics Human Data Model.xlsx',
#  '../_data/RFC Tables/EL RFC genotyping_assay.xlsx',
#  '../_data/RFC Tables/EL RFC_ Biospecimen_human data model.xlsx',
#  '../_data/RFC Tables/EL Assay_ bsSeq (bisulfite-seq_WGBS_methylseq_methylomics) data model.xlsx',
#  '../_data/RFC Tables/EL Assay_ RNAseq data model.xlsx']

# %% [markdown]
# Create Data Model for Schematic

# %%
dm = pd.DataFrame()

# parse through files to create complete data model
for fp in file_paths:
    file_name = os.path.basename(fp)

    temp = pd.read_excel(fp)

    # Create file_name column to check
    temp.insert(loc=0, column="file_name", value=file_name)

    # Create new columnn for data model name
    temp.insert(
        loc=1,
        column="dm",
        value=re.sub(
            "\s\s+",
            " ",
            re.sub(
                "_",
                " ",
                re.sub(
                    "(EL)|(RFC)|(\.xlsx)|([Aa]ssay)|([Dd]ata [Mm]odel)", "", file_name
                ),
            ).strip(),
        ),
    )

    dm = pd.concat([dm, temp])

# %%
# initial cleaning
dm[["required", "multivalue"]] = (
    dm[["required", "multivalue"]]
    .fillna(False)
    .astype(str)
    .replace({"1.0": True, "0.0": False})
)

dm.fillna("")
dm.reset_index(drop=True, inplace=True)
dm.head()
# Out:
#                             file_name        dm                          key  \
# 0  EL Assay_ scRNAseq data model.xlsx  scRNAseq                   specimenID
# 1  EL Assay_ scRNAseq data model.xlsx  scRNAseq                   sampleType
# 2  EL Assay_ scRNAseq data model.xlsx  scRNAseq            specifySampleType
# 3  EL Assay_ scRNAseq data model.xlsx  scRNAseq         measurementTechnique
# 4  EL Assay_ scRNAseq data model.xlsx  scRNAseq  specifyMeasurementTechnique
#
#                                          description  \
# 0  Identifying string linked to a particular samp...
# 1                       The type of sample collected
# 2     If "other" is selected list the type of sample
# 3  The measurement technique describing the assay...
# 4  If "other" is selected list the name of the me...
#
#                                         valid values required  \
# 0              n/a (unique to each data contributor)     True
# 1  Amniotic Fluid,\nAppendix,\nB cell,\nBasophils...     True
# 2                                                NaN    False
# 3  16S rRNA gene sequencing,\n1D Gel,\n2D Gel,\nA...     True
# 4                                                NaN    False
#
#                                   requires multivalue    type  \
# 0                    scRNAseq, Biospecimen      False  string
# 1                                 scRNAseq      False  string
# 2            scRNAseq,\nsampleType = other      False  string
# 3                                 scRNAseq      False  string
# 4  scRNAseq,\nmeasurementTechnique = other      False  string
#
#       concept source ontology  \
# 0            Sage Bionetworks
# 1  Sage Bionetworks,\nImmPort
# 2            Sage Bionetworks
# 3            Sage Bionetworks
# 4            Sage Bionetworks
#
#                                                 note  Unnamed: 9  \
# 0                                                NaN         NaN
# 1  The sample types are adopted from Uberon, Cell...         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#         Unnamed: 10 ontology term id
# 0  Sage Bionetworks      NaN     NaN
# 1               NaN      NaN     NaN
# 2               NaN      NaN     NaN
# 3               NaN      NaN     NaN
# 4               NaN      NaN     NaN

# %% [markdown]
# Data model clean up

# %%
# collapse presumed ontology columns and join with existing
dm.loc[:, "ontology"] = dm.iloc[:, 11:].bfill(axis=1).iloc[:, 0]

dm["ontology"] = (
    dm[["concept source ontology", "ontology"]]
    .fillna("")
    .apply(lambda x: ",".join([y.strip() for y in x.unique() if len(y) > 0]), axis=1)
)

# if unique values are provided by data contributor then add this note in the ontology

dm["ontology"] = (
    dm.loc[
        dm["valid values"].str.contains(
            "(n/a \(unique to each data contributor\))", na=False
        ),
        "ontology",
    ]
    + ","
    + "Data Contributor"
)
# Out:
# /var/folders/p0/5m4pdsm55jn_d5nzbjv6bjf40000gq/T/ipykernel_56852/2830742079.py:14: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   dm["valid values"].str.contains(

# %%
# new ontologies:
ontology_list = []
for i, v in dm[["concept source ontology", "ontology"]].fillna("").iterrows():
    ontology_list.append(",".join(v))

dm["ontology"] = ontology_list
dm["ontology"] = dm["ontology"].str.strip(",")

# %%
dm = dm.apply(
    lambda x: x.str.replace(
        pat="\n|(n/a \(unique to each data contributor\))", repl="", regex=True
    ).str.split(","),
    axis=1,
)

dm.head()
# Out:
#                               file_name          dm  \
# 0  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
# 1  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
# 2  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
# 3  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
# 4  [EL Assay_ scRNAseq data model.xlsx]  [scRNAseq]
#
#                              key  \
# 0                   [specimenID]
# 1                   [sampleType]
# 2            [specifySampleType]
# 3         [measurementTechnique]
# 4  [specifyMeasurementTechnique]
#
#                                          description  \
# 0  [Identifying string linked to a particular sam...
# 1                     [The type of sample collected]
# 2   [If "other" is selected list the type of sample]
# 3  [The measurement technique describing the assa...
# 4  [If "other" is selected list the name of the m...
#
#                                         valid values required  \
# 0                                                 []   [True]
# 1  [Amniotic Fluid, Appendix, B cell, Basophils, ...   [True]
# 2                                                NaN  [False]
# 3  [16S rRNA gene sequencing, 1D Gel, 2D Gel, Arr...   [True]
# 4                                                NaN  [False]
#
#                                    requires multivalue      type  \
# 0                  [scRNAseq,  Biospecimen]    [False]  [string]
# 1                                [scRNAseq]    [False]  [string]
# 2            [scRNAseq, sampleType = other]    [False]  [string]
# 3                                [scRNAseq]    [False]  [string]
# 4  [scRNAseq, measurementTechnique = other]    [False]  [string]
#
#        concept source ontology  \
# 0           [Sage Bionetworks]
# 1  [Sage Bionetworks, ImmPort]
# 2           [Sage Bionetworks]
# 3           [Sage Bionetworks]
# 4           [Sage Bionetworks]
#
#                                                 note  Unnamed: 9  \
# 0                                                NaN         NaN
# 1  [The sample types are adopted from Uberon,  Ce...         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#           Unnamed: 10                                           ontology  \
# 0  [Sage Bionetworks]  [Sage Bionetworks, Sage Bionetworks, Data Cont...
# 1                 NaN                        [Sage Bionetworks, ImmPort]
# 2                 NaN                                 [Sage Bionetworks]
# 3                 NaN                                 [Sage Bionetworks]
# 4                 NaN                                 [Sage Bionetworks]
#
#   term id
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# revert lists back to strings
dm = dm.applymap(lambda x: join_strings(x))

# Rename columns with DCA standards
dm_schema_cols = {
    "dm": "Template",
    "key": "Attribute",
    "description": "Description",
    "valid values": "Valid Values",
    "required": "Required",
    "requires": "DependsOn Component",
    "concept source ontology": "Source",
    "ontology": "Ontology",
    "type": "Type",
}

dm = dm.rename(dm_schema_cols, axis=1)

# drop unimportant columns
r = re.compile("Unnamed*", re.IGNORECASE)

# Add additional required columns for DCA
dm["Properties"] = ""
dm["Validation Rules"] = dm["Type"].map(validation_coder)
dm["DependsOn"] = ""
dm["Parent"] = ""
# dm['DependsOn Component'] = ""

dm = dm[keep_cols]

dm.head()
# Out:
#                      Attribute  \
# 0                   specimenID
# 1                   sampleType
# 2            specifySampleType
# 3         measurementTechnique
# 4  specifyMeasurementTechnique
#
#                                          Description  \
# 0  Identifying string linked to a particular samp...
# 1                       The type of sample collected
# 2     If "other" is selected list the type of sample
# 3  The measurement technique describing the assay...
# 4  If "other" is selected list the name of the me...
#
#                                         Valid Values Required DependsOn  \
# 0                                                        True
# 1  Amniotic Fluid,Appendix,B cell,Basophils,Bone,...     True
# 2                                                       False
# 3  16S rRNA gene sequencing,1D Gel,2D Gel,Array,B...     True
# 4                                                       False
#
#                      DependsOn Component Properties Validation Rules  \
# 0                  scRNAseq, Biospecimen
# 1                               scRNAseq
# 2            scRNAseq,sampleType = other
# 3                               scRNAseq
# 4  scRNAseq,measurementTechnique = other
#
#    Template Parent                    Source    Type  \
# 0  scRNAseq                 Sage Bionetworks  string
# 1  scRNAseq         Sage Bionetworks,ImmPort  string
# 2  scRNAseq                 Sage Bionetworks  string
# 3  scRNAseq                 Sage Bionetworks  string
# 4  scRNAseq                 Sage Bionetworks  string
#
#                                             Ontology multivalue
# 0  Sage Bionetworks,Sage Bionetworks,Data Contrib...      False
# 1                           Sage Bionetworks,ImmPort      False
# 2                                   Sage Bionetworks      False
# 3                                   Sage Bionetworks      False
# 4                                   Sage Bionetworks      False

# %%
# fixing "not listed" columns
dm["Valid Values"] = dm["Valid Values"].str.replace(
    "Genbank common names (not listed for purposes of this RFC)Unknown",
    "Genbank common names (not listed for purposes of this RFC),Unknown",
    regex=False,
)

dm.loc[dm["Valid Values"].str.contains("not listed"), "Valid Values"] = (
    dm.loc[dm["Valid Values"].str.contains("not listed"), "Valid Values"]
    .str.split(")")
    .apply(
        lambda x: ",".join(
            [y.strip(",") for y in x if not bool(re.search("not listed", y))]
        )
    )
)

# QC
dm.loc[dm["Valid Values"].str.contains("not listed", na=False), "Valid Values"]
# Out:
# Series([], Name: Valid Values, dtype: object)

# %%
# Dropping measurement technique
dm = dm.drop(
    index=dm.query('Attribute == "measurementTechnique"').index.values
).reset_index(drop=True)

# %%
# combine duplicated attributes
dm = dm.groupby("Attribute").agg(lambda x: ",".join(set(x.astype(str)))).reset_index()

# found extra commas in strings at beginning and end
dm = dm.applymap(lambda x: x.strip(","))

# %%
# QA Check
dm["Template"].unique()
# Out:
# array(['Metabolomics Human', 'proteomics,Metabolomics Human',
#        'Individual Human', 'Biospecimen nonHuman', 'Individual nonHuman',
#        'Biospecimen nonHuman,Biospecimen human', 'proteomics',
#        'Individual Human,Individual nonHuman',
#        'bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome,Metabolomics Human',
#        'Individual Human,Biospecimen human,Biospecimen nonHuman,Individual nonHuman',
#        'Whole Genome Sequencing,RNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics),scRNAseq',
#        'scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),Microbiome,Whole Genome Sequencing',
#        'Whole Genome Sequencing,proteomics,RNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics),Metabolomics Human,scRNAseq',
#        'genotyping',
#        'scRNAseq,RNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),Whole Genome Sequencing',
#        'scRNAseq,RNAseq,Whole Genome Sequencing',
#        'scRNAseq,Whole Genome Sequencing', 'scRNAseq',
#        'Whole Genome Sequencing,proteomics,RNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics),Metabolomics Human,scRNAseq,genotyping',
#        'scRNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome',
#        'Biospecimen nonHuman,Whole Genome Sequencing,proteomics,RNAseq,Microbiome,Biospecimen human,bsSeq (bisulfite-seq WGBS methylseq methylomics),Metabolomics Human,scRNAseq,genotyping'],
#       dtype=object)

# %%
display(dm.dtypes)
display(dm.head())
display(dm.Template.unique())
# Out:
# Attribute              object
# Description            object
# Valid Values           object
# Required               object
# DependsOn              object
# DependsOn Component    object
# Properties             object
# Validation Rules       object
# Template               object
# Parent                 object
# Source                 object
# Type                   object
# Ontology               object
# multivalue             object
# dtype: object
#                   Attribute  \
# 0        acquisitionBatchID
# 1      acquisitionBatchSize
# 2  acquisitionBatchSizeUnit
# 3           acquisitionMode
# 4       acquisitionSoftware
#
#                                          Description  \
# 0  Acquisition batch identifier, provided by the ...
# 1                              The number of samples
# 2  The unit of measurement for number of samples ...
# 3  The specific aspect of a mass spectrometer met...
# 4          The name of the acquisition software used
#
#                                         Valid Values Required DependsOn  \
# 0                                                       False
# 1                                                       False
# 2  AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...    False
# 3  Unknown,Not collected,Not applicable,Not speci...     True
# 4  Unknown,Not collected,Not applicable,Not speci...     True
#
#                           DependsOn Component Properties Validation Rules  \
# 0                       mass spec metabolmics
# 1                       mass spec metabolmics
# 2  mass spec metabolmics,acquisitionBatchSize
# 3  mass spec metabolmics,mass spec proteomics
# 4  mass spec metabolmics,mass spec proteomics
#
#                         Template Parent  \
# 0             Metabolomics Human
# 1             Metabolomics Human
# 2             Metabolomics Human
# 3  proteomics,Metabolomics Human
# 4  proteomics,Metabolomics Human
#
#                                               Source    Type  \
# 0                                   Sage Bionetworks  string
# 1                                   Sage Bionetworks  string
# 2                                   Sage Bionetworks  string
# 3  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...  string
# 4          http://purl.obolibrary.org/obo/MS_1001455  string
#
#                                             Ontology multivalue
# 0                                   Sage Bionetworks
# 1                                   Sage Bionetworks
# 2                                   Sage Bionetworks
# 3  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...      False
# 4          http://purl.obolibrary.org/obo/MS_1001455      False
# array(['Metabolomics Human', 'proteomics,Metabolomics Human',
#        'Individual Human', 'Biospecimen nonHuman', 'Individual nonHuman',
#        'Biospecimen nonHuman,Biospecimen human', 'proteomics',
#        'Individual Human,Individual nonHuman',
#        'bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome,Metabolomics Human',
#        'Individual Human,Biospecimen human,Biospecimen nonHuman,Individual nonHuman',
#        'Whole Genome Sequencing,RNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics),scRNAseq',
#        'scRNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),Microbiome,Whole Genome Sequencing',
#        'Whole Genome Sequencing,proteomics,RNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics),Metabolomics Human,scRNAseq',
#        'genotyping',
#        'scRNAseq,RNAseq,bsSeq (bisulfite-seq WGBS methylseq methylomics),Whole Genome Sequencing',
#        'scRNAseq,RNAseq,Whole Genome Sequencing',
#        'scRNAseq,Whole Genome Sequencing', 'scRNAseq',
#        'Whole Genome Sequencing,proteomics,RNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics),Metabolomics Human,scRNAseq,genotyping',
#        'scRNAseq,Microbiome,bsSeq (bisulfite-seq WGBS methylseq methylomics)',
#        'Microbiome',
#        'Biospecimen nonHuman,Whole Genome Sequencing,proteomics,RNAseq,Microbiome,Biospecimen human,bsSeq (bisulfite-seq WGBS methylseq methylomics),Metabolomics Human,scRNAseq,genotyping'],
#       dtype=object)

# %%
# Reorder Columns based on DCA Standards
dm = dm.loc[:, keep_cols]

# %% [markdown]
# # Clean up
#
# - Cleanup `DependsOn Component`

# %%
recoder = {
    "metabolmics": "metabolomics",
    "(mass spec proteomics)": "Proteomics",
    "(mass spec metabolomics)": "Metabolomics Human",
    "(assay_otheruseTreatment? = Yes)": "assay_other, useTreatment? = Yes",
    "OtherUnknown": "Other, Unknown",
    "falseFalseFALSEtrueTrueTRUE": "TRUE, FALSE",
    "Hispanic or latinoEthnicity": "Hispanic or Latino",
    re.compile("Forwardreverse", flags=re.IGNORECASE): "forward,reverse",
    re.compile("singleEndpairedEnd"): "singleEnd, pairedEnd",
    re.compile("(WGS)"): "Whole Genome Sequencing",
    re.compile("\?"): "",
    "Zeiss LSM 980Other": "Zeiss LSM 980,Other",
    "bsSeqsampleType = other": "bsSeq, sampleType = other",
    re.compile(
        "HPO, MONDO, MAXO codes or labels \(not listed for purposes of this RFC\)"
    ): "HPO and MONDO and MAXO codes or labels (not listed for purposes of this RFC)",
    "The Health, Aging, and Body Composition Study \(HealthABC\)": "The Health and Aging and Body Composition Study (HealthABC)",
}

# 'mass spec metabolomics,measurementTechnique = other'
# falseFalseFALSEtrueTrueTRUE

# %%
dm = dm.apply(lambda x: x.replace(recoder, regex=True), axis=1)

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm[dm["Valid Values"].str.contains("and Body Composition Study")])
# Out:
#    Attribute                                   Description  \
# 16    cohort  Name of the cohort the individual belongs to
#
#                                                                                                                                                                                                                                                                                                             Valid Values  \
# 16  Centenarian, US Family, Denmark Family, The Osteoporotic Fractures in Men (MrOS) Study, Study of Osteoporotic Fractures (SOF), The Health and Aging and Body Composition Study (HealthABC), Cardiovascular Health Study (CHS),Other,Unknown,Not collected,Not applicable,Other, Unknown,Not collected,Not applicable
#
#    Required DependsOn DependsOn Component Properties Validation Rules  \
# 16     True                    Individual
#
#                                 Template Parent            Source    Type  \
# 16  Individual Human,Individual nonHuman         Sage Bionetworks  string
#
#             Ontology multivalue
# 16  Sage Bionetworks       True

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm.query('Attribute == "ethnicity"'))
# Out:
#     Attribute              Description  \
# 37  ethnicity  Ethnicity of individual
#
#                                                                                                    Valid Values  \
# 37  Not Hispanic or Latino, Hispanic or Latino, Prefer not to answer,Other,Unknown,Not collected,Not applicable
#
#    Required DependsOn DependsOn Component Properties Validation Rules  \
# 37     True                    Individual
#
#             Template Parent  \
# 37  Individual Human
#
#                                                             Source    Type  \
# 37  Sage Bionetworks,https://www.synapse.org/#!Synapse:syn25878249  string
#
#                                                           Ontology multivalue
# 37  Sage Bionetworks,https://www.synapse.org/#!Synapse:syn25878249      False

# %%
# QA check
dm[dm["DependsOn Component"].str.contains(
    "metabolomics", case=False, na=False)]
# Out:
#                      Attribute  \
# 0           acquisitionBatchID
# 1         acquisitionBatchSize
# 2     acquisitionBatchSizeUnit
# 3              acquisitionMode
# 4          acquisitionSoftware
# ..                         ...
# 152                 specimenID
# 156      spectrometerFrequency
# 159  technologyPlatformVersion
# 175             vacuumPressure
# 176         vacuumPressureUnit
#
#                                            Description  \
# 0    Acquisition batch identifier, provided by the ...
# 1                                The number of samples
# 2    The unit of measurement for number of samples ...
# 3    The specific aspect of a mass spectrometer met...
# 4            The name of the acquisition software used
# ..                                                 ...
# 152  Identifying string linked to a particular samp...
# 156  The frequency at which a spectrometer causes h...
# 159  The specific version (application, manufacture...
# 175                 The recorded vacuum pressure value
# 176                      Unit of vacuum pressure value
#
#                                           Valid Values Required DependsOn  \
# 0                                                         False
# 1                                                         False
# 2    AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...    False
# 3    Unknown,Not collected,Not applicable,Not speci...     True
# 4    Unknown,Not collected,Not applicable,Not speci...     True
# ..                                                 ...      ...       ...
# 152                                                        True
# 156                                                        True
# 159  Other, Unknown,Not collected,Not applicable,No...     True
# 175                                                       False
# 176  AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...    False
#
#                                    DependsOn Component Properties  \
# 0                               mass spec metabolomics
# 1                               mass spec metabolomics
# 2          mass spec metabolomics,acquisitionBatchSize
# 3                    mass spec metabolomics,Proteomics
# 4                    mass spec metabolomics,Proteomics
# ..                                                 ...        ...
# 152  Biospecimen,genotyping ,Biospecimen,microbiome...
# 156                  mass spec metabolomics,Proteomics
# 159  mass spec metabolomics,bsSeq,RNAseq,microbiome...
# 175   mass spec metabolomics,hasIonizationSource = Yes
# 176  mass spec metabolomics,hasIonizationSource = Y...
#
#                             Validation Rules  \
# 0
# 1
# 2
# 3
# 4
# ..                                       ...
# 152
# 156  regex search ([0-9]+\.[0-9]*.)|([0-9]+)
# 159
# 175  regex search ([0-9]+\.[0-9]*.)|([0-9]+)
# 176
#
#                                               Template Parent  \
# 0                                   Metabolomics Human
# 1                                   Metabolomics Human
# 2                                   Metabolomics Human
# 3                        proteomics,Metabolomics Human
# 4                        proteomics,Metabolomics Human
# ..                                                 ...    ...
# 152  Biospecimen nonHuman,Whole Genome Sequencing,p...
# 156                      proteomics,Metabolomics Human
# 159  Whole Genome Sequencing,proteomics,RNAseq,Micr...
# 175                                 Metabolomics Human
# 176                                 Metabolomics Human
#
#                                                 Source    Type  \
# 0                                     Sage Bionetworks  string
# 1                                     Sage Bionetworks  string
# 2                                     Sage Bionetworks  string
# 3    https://www.ebi.ac.uk/ols/ontologies/ms/termsi...  string
# 4            http://purl.obolibrary.org/obo/MS_1001455  string
# ..                                                 ...     ...
# 152                                   Sage Bionetworks  string
# 156            Sage Bionetworks,Sage Bionetworks,DSLWG  number
# 159  Sage Bionetworks,http://purl.obolibrary.org/ob...  string
# 175  Sage Bionetworks,Proposed minimum metadata rel...  number
# 176  Sage Bionetworks,Proposed minimum metadata rel...  string
#
#                                               Ontology   multivalue
# 0                                     Sage Bionetworks
# 1                                     Sage Bionetworks
# 2                                     Sage Bionetworks
# 3    https://www.ebi.ac.uk/ols/ontologies/ms/termsi...        False
# 4            http://purl.obolibrary.org/obo/MS_1001455        False
# ..                                                 ...          ...
# 152  Sage Bionetworks,Sage Bionetworks,Data Contrib...  False,false
# 156            Sage Bionetworks,Sage Bionetworks,DSLWG        False
# 159  Sage Bionetworks,http://purl.obolibrary.org/ob...   False,true
# 175  Sage Bionetworks,Proposed minimum metadata rel...
# 176  Sage Bionetworks,Proposed minimum metadata rel...
#
# [65 rows x 14 columns]

# %% [markdown]
# ## Cleaning other values and equal values
#
# Removing illegal characters

# %% [markdown]
# Remove any special characters

# %%
dm["Attribute"] = dm["Attribute"].str.replace("\(|\)|\?", "", regex=True)

# %% [markdown]
# Clean up equals in depends on

# %%
def create_new_value(old_value):
    new_vals = old_value.split("=")
    new_vals = [nv.strip() for nv in new_vals]
    # convert to camel case
    nv = new_vals[1].capitalize() + new_vals[0][0].upper() + new_vals[0][1:]
    return nv

# %%
def recode_yes_no(v):
    if v.lower() == "yes":
        return "TRUE"
    elif v.lower() == "no":
        return "FALSE"
    else:
        return v


dm["Valid Values"] = (
    dm["Valid Values"]
    .apply(lambda x: x.split(","))
    .apply(lambda x: ",".join([recode_yes_no(y) for y in x]))
)

# %%
# Split list to process other values
# Find the other columns in the data model
others = dm[dm["DependsOn Component"].str.contains("=", na=False)].copy()
others["DependsOn Component Original"] = others["DependsOn Component"].str.split(",")

# Create series of equals values to use for new attributes/ valid values relationship
others["equals_series"] = others["DependsOn Component Original"].apply(
    lambda x: [y for y in x if bool(re.search("=", y))][0]
)

# others["equals_attribute"] = others["equals_series"].apply(create_new_value)

others[["baseAttribute", "equalsValue"]] = (
    others["equals_series"]
    .str.split("=", expand=True)
    .apply(lambda x: [y.strip() for y in x])
    .rename({0: "base_attribute", 1: "equalsValue"}, axis=1)
)

# Deciding to use true and false for all yes/no values
recoder = {
    re.compile("^[Yy]es", flags=re.IGNORECASE): "TRUE",
    re.compile("true", flags=re.IGNORECASE): "TRUE",
    re.compile("^[Nn]o", flags=re.IGNORECASE): "FALSE",
}

others["equalsValue"] = others["equalsValue"].replace(recoder, regex=True)

others["newDescription"] = others[["baseAttribute", "equalsValue"]].apply(
    lambda x: f"When {x[0].strip()} = {x[1].strip()}", axis=1
)

others["equalsAttribute"] = others[["baseAttribute", "equalsValue"]].apply(
    lambda x: f"{x[1].strip()}{x[0].strip()[0].upper()+x[0].strip()[1:]}", axis=1
)
others["DependsOn Component"] = ""
others["Properties"] = "dataProperty"
others.loc[others["equalsValue"] == "other", "Parent"] = "Specification"

# %%
equals_df = others.copy()
equals_df = equals_df.drop(columns=["DependsOn", "Description"])

equals_df = equals_df.rename(
    {
        "Attribute": "DependsOn",
        "newDescription": "Description",
        "equalsAttribute": "Attribute",
    },
    axis=1,
)[base_cols]

equals_df["DependsOn Component"] = ""

equals_df["Valid Values"] = ""

equals_df["Properties"] = "ValidValue"

# %% [markdown]
# Update base attribute equals values

# %%
# Create mapping
temp = others["equals_series"].str.split("=", expand=True)
temp = temp.apply(lambda x: x.str.strip(), axis=1)
temp = temp.rename({0: "base_attribute", 1: "value_to_replace"}, axis=1)
temp["value_to_replace"] = temp["value_to_replace"].str.capitalize()

# new value
temp["new_value"] = others["equalsAttribute"]
temp.reset_index(drop=True, inplace=True)

temp = temp.drop_duplicates()

# %%
replacements = {}

for i, x in temp.iterrows():
    ba, vtr, nv = x
    replacements[ba] = {
        "pattern": re.compile("(" + vtr + ")", flags=re.IGNORECASE),
        "repl": nv,
    }

replacements
# Out:
# {'captivityStatus': {'pattern': re.compile(r'(Captive)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'captiveCaptivityStatus'},
#  'hasAssayControl': {'pattern': re.compile(r'(Yes)', re.IGNORECASE|re.UNICODE),
#   'repl': 'TRUEHasAssayControl'},
#  'diagnosisStatus': {'pattern': re.compile(r'(True)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'TRUEDiagnosisStatus'},
#  'ethnicity': {'pattern': re.compile(r'(Hispanic or latino)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'Hispanic or LatinoEthnicity'},
#  'hasIonizationSource': {'pattern': re.compile(r'(Yes)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'TRUEHasIonizationSource'},
#  'msTarget': {'pattern': re.compile(r'(Targeted)', re.IGNORECASE|re.UNICODE),
#   'repl': 'TargetedMsTarget'},
#  'useReagent': {'pattern': re.compile(r'(Yes)', re.IGNORECASE|re.UNICODE),
#   'repl': 'TRUEUseReagent'},
#  'acquisitionBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherAcquisitionBatchSizeUnit'},
#  'batchSizeUnit': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'otherBatchSizeUnit'},
#  'controlType': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'otherControlType'},
#  'dnaBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherDnaBatchSizeUnit'},
#  'databaseName': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'otherDatabaseName'},
#  'databaseSource': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherDatabaseSource'},
#  'digestionMethod': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherDigestionMethod'},
#  'experimentalBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherExperimentalBatchSizeUnit'},
#  'extractionMethod': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherExtractionMethod'},
#  'lensVoltageUnits': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherLensVoltageUnits'},
#  'libraryPrep': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'otherLibraryPrep'},
#  'libraryPreparationMethod': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherLibraryPreparationMethod'},
#  'libraryVersion': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherLibraryVersion'},
#  'msAnalyteType': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'otherMsAnalyteType'},
#  'msAnalyzerTypeMS1': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherMsAnalyzerTypeMS1'},
#  'msAnalyzerTypeMS2': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherMsAnalyzerTypeMS2'},
#  'msAssayTechnique': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherMsAssayTechnique'},
#  'msInstrumentModel': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherMsInstrumentModel'},
#  'measurementTechnique': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherMeasurementTechnique'},
#  'cleavageAgents': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherCleavageAgents'},
#  'modificationParameters': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherModificationParameters'},
#  'platformLocation': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherPlatformLocation'},
#  'technologyPlatformVersion': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherTechnologyPlatformVersion'},
#  'ProcessingBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherProcessingBatchSizeUnit'},
#  'proteomicsAssayType': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherProteomicsAssayType'},
#  'rnaBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherRnaBatchSizeUnit'},
#  'readLengthUnits': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherReadLengthUnits'},
#  'repositoryName': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherRepositoryName'},
#  'sampleBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherSampleBatchSizeUnit'},
#  'sampleIntdocution': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherSampleIntdocution'},
#  'sampleType': {'pattern': re.compile(r'(Other)', re.IGNORECASE|re.UNICODE),
#   'repl': 'otherSampleType'},
#  'sequencingBatchSizeUnit': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherSequencingBatchSizeUnit'},
#  'transcriptType': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherTranscriptType'},
#  'vaccumPressureUnits': {'pattern': re.compile(r'(Other)',
#              re.IGNORECASE|re.UNICODE),
#   'repl': 'otherVaccumPressureUnits'},
#  'useTreatment': {'pattern': re.compile(r'(Yes)', re.IGNORECASE|re.UNICODE),
#   'repl': 'TRUEUseTreatment'}}

# %%
for attribute in replacements.keys():
    dm = code_equals_values(dm, replacements, attribute)
    print("-" * 20)
# Out:
# attribute:  captivityStatus
# Index:  [13]
# --------------------
# attribute:  hasAssayControl
# Index:  [49]
# --------------------
# attribute:  diagnosisStatus
# Index:  [29]
# --------------------
# attribute:  ethnicity
# Index:  [37]
# --------------------
# attribute:  hasIonizationSource
# Index:  [50]
# --------------------
# attribute:  msTarget
# Index:  [71]
# --------------------
# attribute:  useReagent
# Index:  [173]
# --------------------
# attribute:  acquisitionBatchSizeUnit
# Index:  [2]
# --------------------
# attribute:  batchSizeUnit
# Index:  [11]
# --------------------
# attribute:  controlType
# Index:  [19]
# --------------------
# attribute:  dnaBatchSizeUnit
# Index:  [34]
# --------------------
# attribute:  databaseName
# Index:  [25]
# --------------------
# attribute:  databaseSource
# Index:  [26]
# --------------------
# attribute:  digestionMethod
# Index:  [30]
# --------------------
# attribute:  experimentalBatchSizeUnit
# experimentalBatchSizeUnit
# Index:  None
# --------------------
# attribute:  extractionMethod
# Index:  [40]
# --------------------
# attribute:  lensVoltageUnits
# lensVoltageUnits
# Index:  None
# --------------------
# attribute:  libraryPrep
# Index:  [60]
# --------------------
# attribute:  libraryPreparationMethod
# Index:  [61]
# --------------------
# attribute:  libraryVersion
# Index:  [62]
# --------------------
# attribute:  msAnalyteType
# Index:  [66]
# --------------------
# attribute:  msAnalyzerTypeMS1
# Index:  [67]
# --------------------
# attribute:  msAnalyzerTypeMS2
# Index:  [68]
# --------------------
# attribute:  msAssayTechnique
# Index:  [69]
# --------------------
# attribute:  msInstrumentModel
# Index:  [70]
# --------------------
# attribute:  measurementTechnique
# measurementTechnique
# Index:  None
# --------------------
# attribute:  cleavageAgents
# Index:  [15]
# --------------------
# attribute:  modificationParameters
# Index:  [65]
# --------------------
# attribute:  platformLocation
# Index:  [77]
# --------------------
# attribute:  technologyPlatformVersion
# Index:  [159]
# --------------------
# attribute:  ProcessingBatchSizeUnit
# Index:  [81]
# --------------------
# attribute:  proteomicsAssayType
# proteomicsAssayType
# Index:  None
# --------------------
# attribute:  rnaBatchSizeUnit
# Index:  [99]
# --------------------
# attribute:  readLengthUnits
# Index:  [85]
# --------------------
# attribute:  repositoryName
# Index:  [95]
# --------------------
# attribute:  sampleBatchSizeUnit
# Index:  [103]
# --------------------
# attribute:  sampleIntdocution
# sampleIntdocution
# Index:  None
# --------------------
# attribute:  sampleType
# Index:  [106]
# --------------------
# attribute:  sequencingBatchSizeUnit
# Index:  [110]
# --------------------
# attribute:  transcriptType
# Index:  [164]
# --------------------
# attribute:  vaccumPressureUnits
# vaccumPressureUnits
# Index:  None
# --------------------
# attribute:  useTreatment
# Index:  [174]
# --------------------
# /var/folders/p0/5m4pdsm55jn_d5nzbjv6bjf40000gq/T/ipykernel_56852/2963712766.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df["Attribute"].str.contains(

# %% [markdown]
# # Add new attributes

# %%
# dm["Properties"] = "dataProperty"
dm.update(others[base_cols])
dm = pd.concat([dm, equals_df], ignore_index=True)

# %%
# Do not need
dm["DependsOn Component"] = ""

# %% [markdown]
# # Clean up Valid Values and add them as new Attributes

# %%
# valid values that contain other
pure_others = dm[
    dm["Valid Values"].str.contains(
        "([Oo]ther$)", flags=re.IGNORECASE, regex=True)
]
# Out:
# /var/folders/p0/5m4pdsm55jn_d5nzbjv6bjf40000gq/T/ipykernel_56852/2172924589.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   dm["Valid Values"].str.contains(

# %%
pure_others.loc[:, "replacement_value"] = pure_others.loc[:, "Attribute"].apply(
    lambda x: "Other" + (x[0].upper() + x[1:])
)
# Out:
# /var/folders/p0/5m4pdsm55jn_d5nzbjv6bjf40000gq/T/ipykernel_56852/2918759120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pure_others.loc[:, "replacement_value"] = pure_others.loc[:, "Attribute"].apply(

# %%
regex_dict = {}

pattern = "([Oo]ther$)"

for i, r in pure_others.iterrows():
    regex_dict[r["Attribute"]] = {
        "pattern": re.compile(pattern, flags=re.IGNORECASE),
        "repl": r["replacement_value"],
    }

# %%
temp_dict = {}

for i, r in pure_others.iterrows():
    temp_dict[r["Attribute"]] = {
        "pattern": str(re.compile(pattern, flags=re.IGNORECASE)),
        "repl": r["replacement_value"],
    }

json_formatted = json.dumps(temp_dict, indent=4)
print(json_formatted)
# Out:
# {
#     "conversionRatioUnits": {
#         "pattern": "re.compile('([Oo]ther$)', re.IGNORECASE)",
#         "repl": "OtherConversionRatioUnits"
#     },
#     "experiementalBatchSizeUnit": {
#         "pattern": "re.compile('([Oo]ther$)', re.IGNORECASE)",
#         "repl": "OtherExperiementalBatchSizeUnit"
#     },
#     "lensVoltagesUnit ": {
#         "pattern": "re.compile('([Oo]ther$)', re.IGNORECASE)",
#         "repl": "OtherLensVoltagesUnit "
#     },
#     "vacuumPressureUnit": {
#         "pattern": "re.compile('([Oo]ther$)', re.IGNORECASE)",
#         "repl": "OtherVacuumPressureUnit"
#     }
# }

# %%
for attribute in regex_dict.keys():
    dm = code_equals_values(dm, regex_dict, attribute)
    print("-" * 20)
# Out:
# attribute:  conversionRatioUnits
# Index:  [21]
# --------------------
# attribute:  experiementalBatchSizeUnit
# Index:  [39]
# --------------------
# attribute:  lensVoltagesUnit
# Index:  [58]
# --------------------
# attribute:  vacuumPressureUnit
# Index:  [176]
# --------------------
# /var/folders/p0/5m4pdsm55jn_d5nzbjv6bjf40000gq/T/ipykernel_56852/2963712766.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df["Attribute"].str.contains(

# %%
# Not sure what happened here in the RFCs
dm["Valid Values"] = dm["Valid Values"].str.replace(
    re.escape("(falseFalseFALSEtrueTrueTRUE)"), "TRUE,FALSE", regex=True
)

# %%
valid_values = ",".join(dm["Valid Values"])
valid_values = valid_values.split(",")
valid_values = list(np.unique(valid_values))
valid_values = [v.strip() for v in valid_values if len(v) > 0]

# %%
# Fuzzy matching to find misspellings
# Fuzzy matching
from thefuzz import fuzz

scores = {}
for v in valid_values:
    scores[v] = {}
    for v2 in valid_values:
        if v == v2:
            next
        else:
            score = fuzz.ratio(v.lower(), v2.lower())
            if score == 100:
                scores[v][v2] = score
    if len(scores[v]) == 0:
        scores.pop(v)

scores
# Out:
# {'FALSE': {'False': 100},
#  'False': {'FALSE': 100},
#  'Lipid': {'lipid': 100},
#  'Not Specified': {'Not specified': 100},
#  'Not specified': {'Not Specified': 100},
#  'Plasma': {'plasma': 100},
#  'Protein': {'protein': 100},
#  'Saliva': {'saliva': 100},
#  'Serum': {'serum': 100},
#  'Sputum': {'sputum': 100},
#  'TRUE': {'True': 100},
#  'True': {'TRUE': 100},
#  'Urine': {'urine': 100},
#  'lipid': {'Lipid': 100},
#  'plasma': {'Plasma': 100},
#  'protein': {'Protein': 100},
#  'saliva': {'Saliva': 100},
#  'serum': {'Serum': 100},
#  'sputum': {'Sputum': 100},
#  'urine': {'Urine': 100}}

# %%
# create recoding variables off fuzzy matching
new_values_recoded = []
for v in scores.values():
    new_values_recoded.append(list(v.keys())[0].lower())

new_values_recoded = np.unique(new_values_recoded)

recoder_valid_values = []
for nv in new_values_recoded:
    value_add = {re.compile(nv, flags=re.IGNORECASE): nv}
    recoder_valid_values.append(value_add)


recoder_valid_values
# Out:
# [{re.compile(r'false', re.IGNORECASE|re.UNICODE): 'false'},
#  {re.compile(r'lipid', re.IGNORECASE|re.UNICODE): 'lipid'},
#  {re.compile(r'not specified', re.IGNORECASE|re.UNICODE): 'not specified'},
#  {re.compile(r'plasma', re.IGNORECASE|re.UNICODE): 'plasma'},
#  {re.compile(r'protein', re.IGNORECASE|re.UNICODE): 'protein'},
#  {re.compile(r'saliva', re.IGNORECASE|re.UNICODE): 'saliva'},
#  {re.compile(r'serum', re.IGNORECASE|re.UNICODE): 'serum'},
#  {re.compile(r'sputum', re.IGNORECASE|re.UNICODE): 'sputum'},
#  {re.compile(r'true', re.IGNORECASE|re.UNICODE): 'true'},
#  {re.compile(r'urine', re.IGNORECASE|re.UNICODE): 'urine'}]

# %% [markdown]
# # Cleanup valid values

# %%
def clean_list(x):
    try:
        result = ",".join([y.strip() for y in x])
        return result
    except:
        return ""

# %%
# hard coded dictionary
recoder_valid_values = {
    re.compile("Not Specified", flags=re.IGNORECASE): "Not Specified",
    re.compile("(Other$)", flags=re.IGNORECASE): "Other",
    re.compile("lipid", re.IGNORECASE): "Lipid",
    re.compile("plasma", re.IGNORECASE): "Plasma",
    re.compile("protein", re.IGNORECASE): "Protein",
    re.compile("saliva", re.IGNORECASE): "Saliva",
    re.compile("serum", re.IGNORECASE): "Serum",
    re.compile("sputum", re.IGNORECASE): "Sputum",
    re.compile("urine", re.IGNORECASE): "Urine",
    re.compile(
        "(^0x Visium Spatial Gene Expression)"
    ): "10x Visium Spatial Gene Expression",
    re.compile("falseFalseFALSEtrueTrueTRUE	"): "TRUE, FALSE",
    re.compile("TRUE|TRUEDiagnosisStatus", re.IGNORECASE): "TRUE",
    re.compile("TRUEDiagnosisStatus", re.IGNORECASE): "TRUE",
    re.compile("FALSE", re.IGNORECASE): "FALSE",
    re.compile("$f^", re.IGNORECASE): "F",
    re.compile("UnknownNot collected"): "Unknown, Not collected",
    re.compile(r"\u200b\u200b"): "",
    re.compile(
        "The Health,Aging,and Body Composition Study \(HealthABC\)"
    ): "The Health and Aging and Body Composition Study (HealthABC)",
    re.compile("Not Hispanic or latinoEthnicity"): "Not Hispanic or latino",
    re.compile("Hispanic or latinoEthnicity"): "Hispanic or latino",
    re.compile(
        "HPO, MONDO, MAXO codes or labels \(not listed for purposes of this RFC\)"
    ): "HPO and MONDO and MAXO codes or labels (not listed for purposes of this RFC)",
}

# %%
dm["Valid Values"] = (
    dm["Valid Values"]
    .replace(recoder_valid_values, regex=True)
    .str.split(",")
    .apply(lambda x: clean_list(x))
)

valid_values = list(np.unique(",".join(dm["Valid Values"]).split(",")))

valid_values = [v.strip() for v in valid_values if len(v) > 0]

valid_values_df = pd.DataFrame({"Attribute": pd.Series(valid_values)})

valid_values_df["Properties"] = "validValue"
valid_values_df["Required"] = "False"

valid_values_df = valid_values_df[
    ~valid_values_df["Attribute"].isin(dm["Attribute"].tolist())
]

valid_values_df
# Out:
#                               Attribute  Properties Required
# 0     0x Visium Spatial Gene Expression  validValue    False
# 1                                   10x  validValue    False
# 2    10x Visium Spatial Gene Expression  validValue    False
# 3                                   AFU  validValue    False
# 4                                    AI  validValue    False
# ..                                  ...         ...      ...
# 406                              uiu/ml  validValue    False
# 407                                  ul  validValue    False
# 408                              umol/l  validValue    False
# 409                            units/ml  validValue    False
# 410               water plus Baker ISTD  validValue    False
#
# [386 rows x 3 columns]

# %%
r = re.compile("(^Other)")

measurement_units = np.unique(
    ",".join(
        dm.loc[
            dm["Valid Values"].str.contains("units", regex=True), "Valid Values"
        ].values.tolist()
    ).split(",")
)
measurement_units = [
    x
    for x in measurement_units
    if x not in ["Not Specified", "Other", "Unknown", "Not Available"]
    and not bool(r.search(x))
]

# %%
# adding valid values found in attribute columns
dm2 = pd.concat([dm, valid_values_df], axis=0, ignore_index=True)

# %%
# Create measurement unit attributes
dm2.loc[dm2["Attribute"].isin(measurement_units), "Parent"] = "MeasurementUnit"
dm2.loc[dm2["Attribute"].isin(measurement_units),
        "Description"] = "Measurement unit"
dm2.loc[dm2["Attribute"].isin(measurement_units), "Type"] = "STRING"
dm2.loc[dm2["Attribute"].isin(measurement_units), "multivalue"] = False

# %%
dm2.loc[
    dm2["Valid Values"].str.contains("10x Visium Spatial Gene Expression", na=False),
]
# Out:
#                      Attribute  \
# 77            platformLocation
# 159  technologyPlatformVersion
#
#                                            Description  \
# 77   The name of the laboratory, facility, vendor, ...
# 159  The specific version (application, manufacture...
#
#                                           Valid Values Required DependsOn  \
# 77   otherPlatformLocation,Unknown,Not collected,No...     True
# 159  otherTechnologyPlatformVersion,Unknown,Not col...     True
#
#     DependsOn Component Properties Validation Rules  \
# 77
# 159
#
#                                               Template Parent  \
# 77   Whole Genome Sequencing,proteomics,RNAseq,Micr...
# 159  Whole Genome Sequencing,proteomics,RNAseq,Micr...
#
#                                                 Source    Type  \
# 77             Sage Bionetworks,Sage Bionetworks,DSLWG  string
# 159  Sage Bionetworks,http://purl.obolibrary.org/ob...  string
#
#                                               Ontology   multivalue
# 77             Sage Bionetworks,Sage Bionetworks,DSLWG  False,false
# 159  Sage Bionetworks,http://purl.obolibrary.org/ob...   False,true

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm2.loc[dm2["Attribute"].str.contains("Possible values"),])
# Out:
#                                                                              Attribute  \
# 465                           Possible values are listed under modification parameters
# 466        Possible values are listed under the cleavage agent nameotherCleavageAgents
# 467  Possible values are listed under the instrument model term.otherMsInstrumentModel
#
#     Description Valid Values Required DependsOn DependsOn Component  \
# 465         NaN          NaN    False       NaN                 NaN
# 466         NaN          NaN    False       NaN                 NaN
# 467         NaN          NaN    False       NaN                 NaN
#
#      Properties Validation Rules Template Parent Source Type Ontology  \
# 465  validValue              NaN      NaN    NaN    NaN  NaN      NaN
# 466  validValue              NaN      NaN    NaN    NaN  NaN      NaN
# 467  validValue              NaN      NaN    NaN    NaN  NaN      NaN
#
#     multivalue
# 465        NaN
# 466        NaN
# 467        NaN

# %%
# Nonsense attributes
dm2 = dm2.drop(
    index=dm2.loc[dm2["Attribute"].str.contains(
        "Possible values"),].index.tolist()
)

# %%
vv_recoder = {
    "Possible values are listed under the instrument model term.OtherMsInstrumentModel": "Other",
    "Possible values are listed under the cleavage agent nameOtherCleavageAgents": "Other",
    "Possible values are listed under modification parameters": "",
}

# %%
dm2[["Attribute", "Valid Values"]] = dm2[["Attribute", "Valid Values"]].apply(
    lambda x: x.replace(vv_recoder, regex=True)
)

# %%
# Fuzzy matching to find misspellings
# Fuzzy matching

from thefuzz import fuzz

valid_values = dm2["Attribute"].replace(
    recoder_valid_values, regex=True).tolist()

scores = {}
for v in valid_values:
    scores[v] = {}
    for v2 in valid_values:
        if v == v2:
            next
        else:
            score = fuzz.ratio(v.lower(), v2.lower())
            if score == 100:
                scores[v][v2] = score
    if len(scores[v]) == 0:
        scores.pop(v)

scores
# Out:
# {'f': {'F': 100}, 'F': {'f': 100}}

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm2[dm2["Attribute"] == "f"])
# Out:
#    Attribute  \
# 41         f
#
#                                                                                                                                                                                                 Description  \
# 41  The data file provides the name of the raw file generated by the instrument. The data files can be instrument raw files but also converted peak lists such as mzML, MGF or result files like mzIdentML.
#
#                                           Valid Values Required DependsOn  \
# 41  Unknown,Not collected,Not applicable,Not Specified     True
#
#    DependsOn Component Properties Validation Rules            Template Parent  \
# 41                                                  Metabolomics Human
#
#                         Source    Type                    Ontology multivalue
# 41  Proteomics Sample Metadata  string  Proteomics Sample Metadata

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm2.loc[dm2["Valid Values"].str.contains("f", na=False),])
# Out:
#                       Attribute  \
# 2      acquisitionBatchSizeUnit
# 3               acquisitionMode
# 4           acquisitionSoftware
# 11                batchSizeUnit
# 15               cleavageAgents
# 16                       cohort
# 19                  controlType
# 21         conversionRatioUnits
# 23                     dataFile
# 25                 databaseName
# 26               databaseSource
# 32                   dnaBatchID
# 34             dnaBatchSizeUnit
# 37                    ethnicity
# 39   experiementalBatchSizeUnit
# 40             extractionMethod
# 41                            f
# 48       gasFlowTemperatureUnit
# 58            lensVoltagesUnit
# 59               libraryBatchID
# 60                  libraryPrep
# 61     libraryPreparationMethod
# 62               libraryVersion
# 65       modificationParameters
# 66                msAnalyteType
# 67            msAnalyzerTypeMS1
# 68            msAnalyzerTypeMS2
# 69             msAssayTechnique
# 70            msInstrumentModel
# 71                     msTarget
# 77             platformLocation
# 81      processingBatchSizeUnit
# 83                         race
# 85              readLengthUnits
# 86             readStrandOrigin
# 94        referenceTranscriptID
# 95               repositoryName
# 96                   resultUnit
# 97                   rnaBatchID
# 99             rnaBatchSizeUnit
# 103         sampleBatchSizeUnit
# 104          sampleIntroduction
# 106                  sampleType
# 108           sequencingBatchID
# 110     sequencingBatchSizeUnit
# 159   technologyPlatformVersion
# 164              transcriptType
# 165         treatmentAmountUnit
# 167       treatmentDurationUnit
# 171    treatmentTemperatureUnit
# 176          vacuumPressureUnit
#
#                                                                                                                                                                                                                                                                                                                                                       Description  \
# 2                                                                                                                                                                                                                                                                                                        The unit of measurement for number of samples in a batch
# 3                                                                                                                                                                                                                  The specific aspect of a mass spectrometer method by which mass ranges are selected and possibly dissociated (full scan, MSn, SIM, MRM, etc.).
# 4                                                                                                                                                                                                                                                                                                                       The name of the acquisition software used
# 11                                                                                                                                                                                                                                                                                                       The unit of measurement for number of samples in a batch
# 15                                                                                                                                                                                                                                                                                                                                     Name(s) of the enzyme used
# 16                                                                                                                                                                                                                                                                                                                   Name of the cohort the individual belongs to
# 19                                                                                                                                                                                                                                                                                                Control samples suitable for normalization and batch correction
# 21                                                                                                                                                                                                                                                                                                                                      The units of measurement.
# 23                                                                                                                                                        The data file provides the name of the raw file generated by the instrument. The data files can be instrument raw files but also converted peak lists such as mzML, MGF or result files like mzIdentML.
# 25                                                                                                                                                                                                                                                                    The name of the search database (nr, SwissProt or est_human, and/or mass spectral library).
# 26                                                                                                                                                                                                                                          The name of the organization, project, or laboratory from where the database is obtained (UniProt, NCBI, EBI, other).
# 32                                                                                                                                                            DNA isolation batch identifier, provided by the data contributor to Sage Bionetworks. The batch identifier(s) must be stored in a data dictionary .csv file uploaded to Synapse,DNA isolation batch
# 34                                                                                                                                                                                                                                                                                                       The unit of measurement for number of samples in a batch
# 37                                                                                                                                                                                                                                                                                                                                        Ethnicity of individual
# 39                                                                                                                                                                                                                                                                                          The unit of measurement for number of samples in a experimental batch
# 40                                                                                                                                                                                                                                                           The name of the process used to separate a desired component of an input material from the remainder
# 41                                                                                                                                                        The data file provides the name of the raw file generated by the instrument. The data files can be instrument raw files but also converted peak lists such as mzML, MGF or result files like mzIdentML.
# 48                                                                                                                                                                                                                                                                                                                                   Unit of gas flow temperature
# 58                                                                                                                                                                                                                                                                                                                                          Unit of lens voltages
# 59                                                                                                                                                                                      Library batch identifier, provided by the data contributor to Sage Bionetworks. The batch identifier(s) must be stored in a data dictionary .csv file uploaded to Synapse
# 60                                                                                                                                                                                                                                                                                                         The general strategy by which the library was prepared
# 61                                                                                                                                                                                                                                                                                                                           Method by which library was prepared
# 62                                                                                                                                                                                                                                                                                                       Library Version: for example, rnaSeq 10x library version
# 65                                                                                                                                                                                                                                                             Modification parameters for the search engine run. [ PSI: PI http://www.w3.org/2002/07/owl#Axiom ]
# 66                                                                                                                                                                                                                                                                                                                  the type of biospecimen subjected to analysis
# 67                                                                                                                                                                                   Describes the mass spectrometer analyzer used to read out parent ions (quadrupole, ion-trap, time-of-flight, FT-ICR, including combinations of these for hybrid instruments)
# 68   Describes the mass spectrometer analyzer used to read out fragment ions(quadrupole, ion-trap, time-of-flight, FT-ICR, including combinations of these for hybrid instruments),Describes the mass spectrometer analyzer used to read out fragment ions (quadrupole, ion-trap, time-of-flight, FT-ICR, including combinations of these for hybrid instruments)
# 69                                                                                                                                                                                                               Specified the mass spectrometer technique used or the name of the proteomics assay used (ex. DDA),Specified the mass spectrometer technique used
# 70                                                                                                                                                                                                                                                                                                                       The model of the mass spectrometer  used
# 71                                                                                                                                                  specifies whether or not a specific molecule(s) is/are targeted for detection/measurement by the assay,Specifies whether or not a specific molecule(s) is/are targeted for detection/measurement by the assay
# 77                                                                                                                                                                                                            The name of the laboratory, facility, vendor, company, or location where the data generation platform was located, provided by the data contributor
# 81                                                                                                                                                                                                                                                                                                       The unit of measurement for number of samples in a batch
# 83                                                                                                                                                                                                                                                                                                                                             Race of individual
# 85                                                                                                                                                                                                                                                                                                                                      The units of measurement.
# 86                                                                                                                                                                                                                                                                                        The strand from which the read originates in a strand-specific protocol
# 94                                                                                                                                                                                                                                                                          The ID for the transcript/gene. Either the NCBI ID or the Ensembl ID must be provided
# 95                                                                                                                                                                                                                                                                              The public repository name for the transcript (for example, Ensembl or NCBI Gene)
# 96                                                                                                                                                                                                                                                                                                                                  The unit for the result value
# 97    RNA isolation batch identifier, provided by the data contributor to Sage Bionetworks. The batch identifier(s) must be stored in a data dictionary .csv file uploaded to Synapse,Isolation batch identifier, provided by the data contributor to Sage Bionetworks. The batch identifier(s) must be stored in a data dictionary .csv file uploaded to Synapse
# 99                                                                                                                                                                                                                                                                                                       The unit of measurement for number of samples in a batch
# 103                                                                                                                                                                                                                                                                                                      The unit of measurement for number of samples in a batch
# 104                                                                                                                                                                                                        The sample introduction and delivery. From GC, from LC, direct infusion without chromatography, direct infusion using dedicated autosampler flow rate.
# 106                                                                                                                                                                                                                                                                                                                                  The type of sample collected
# 108                                                                                                                                                                                  Sequencing batch identifier, provided by the data contributor to Sage Bionetworks. The batch identifier(s) must be stored in a data dictionary .csv file uploaded to Synapse
# 110                                                                                                                                                                                                                                                                                                      The unit of measurement for number of samples in a batch
# 159                                                                                                                                                                                                        The specific version (application, manufacturer, model, lab, etc.) of a technology that is used to carry out a laboratory or computational experiment.
# 164                                                                                                                                                                                                                                                                                                                               The type of transcript reported
# 165                                                                                                                                                                                                                                                                                                                                      Unit of treatment amount
# 167                                                                                                                                                                                                                                                                                                                                    Unit of treatment duration
# 171                                                                                                                                                                                                                                                                                                                                 Unit of treatment temperature
# 176                                                                                                                                                                                                                                                                                                                                 Unit of vacuum pressure value
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Valid Values  \
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,iu/l,IU/ml,Kallikrein Inactivator Unit per Milliliter,kg,l,M,mg,mg/dl,mg/l,mg/ml,miu/ml,ml,mM,MOI,ng,ng/dl,ng/ml,ng/nl,ng/ul,nl,nM,Not Specified,NPX,optical density,PFU,PFUe,pg,pg/mg creatinine,pg/ml,pg/nl,pg/ul,pl,pM,Pound,TCID50,ug,ug/dl,ug/l,ug/ml,ug/ul,uiu/ml,ul,uM,umol/l,units/ml,otherAcquisitionBatchSizeUnit
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Unknown,Not collected,Not applicable,Not Specified
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Unknown,Not collected,Not applicable,Not Specified
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,iu/l,IU/ml,Kallikrein Inactivator Unit per Milliliter,kg,l,M,mg,mg/dl,mg/l,mg/ml,miu/ml,ml,mM,MOI,ng,ng/dl,ng/ml,ng/nl,ng/ul,nl,nM,Not Specified,NPX,optical density,PFU,PFUe,pg,pg/mg creatinine,pg/ml,pg/nl,pg/ul,pl,pM,Pound,TCID50,ug,ug/dl,ug/l,ug/ml,ug/ul,uiu/ml,ul,uM,umol/l,units/ml,otherBatchSizeUnit
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Possible values are listed under the cleavage agent nameotherCleavageAgents,Unknown,Not collected,Not applicable,Not Specified
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Centenarian,US Family,Denmark Family,The Osteoporotic Fractures in Men (MrOS) Study,Study of Osteoporotic Fractures (SOF),The Health and Aging and Body Composition Study (HealthABC),Cardiovascular Health Study (CHS),Other,Unknown,Not collected,Not applicable,Other,Unknown,Not collected,Not applicable
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   GIS,GoldenWest,NIST SRM 1950,AIBL pool,Baker pool,water plus Baker ISTD,study pool,internal standards,Other,Unknown,Not collected,Not applicable,Not Specified
# ...
# 77                                                                                                                                                 Sage Bionetworks,Sage Bionetworks,DSLWG
# 81                                                                                                                                                                        Sage Bionetworks
# 83   Sage Bionetworks,https://www.synapse.org/#!Synapse:syn25878249,https://jamanetwork.com/pages/inclusive-language,https://thesaurus.cancer.gov/ncitbrowser/pages/home.jsfversion=23.04d
# 85                                                                                                                                                                        Sage Bionetworks
# 86                                                                                                                                                                        Sage Bionetworks
# 94                                                                                                                                                                        Sage Bionetworks
# 95                                                                                                                                                                        Sage Bionetworks
# 96                                                                                                                                                                        Sage Bionetworks
# 97                                                                                                                                                                        Sage Bionetworks
# 99                                                                                                                                                                        Sage Bionetworks
# 103                                                                                                                                                                       Sage Bionetworks
# 104                                                                                                             Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry
# 106                                                                                                                                                               Sage Bionetworks,ImmPort
# 108                                                                                                                                                                       Sage Bionetworks
# 110                                                                                                                                                                       Sage Bionetworks
# 159                                                                                                                            Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C45378
# 164                                                                                                                                                                                ImmPort
# 165                                                                                                                                                               Sage Bionetworks,ImmPort
# 167                                                                                                                                                               Sage Bionetworks,ImmPort
# 171                                                                                                                                                               Sage Bionetworks,ImmPort
# 176                                                                                                              Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry
#
#        Type  \
# 2    string
# 3    string
# 4    string
# 11   string
# 15   string
# 16   string
# 19   string
# 21   string
# 23   string
# 25   string
# 26   string
# 32   string
# 34   string
# 37   string
# 39   string
# 40   string
# 41   string
# 48   string
# 58   string
# 59   string
# 60   string
# 61   string
# 62   string
# 65   string
# 66   string
# 67   string
# 68   string
# 69   string
# 70   string
# 71   string
# 77   string
# 81   string
# 83   string
# 85   string
# 86   string
# 94   string
# 95   string
# 96   string
# 97   string
# 99   string
# 103  string
# 104  string
# 106  string
# 108  string
# 110  string
# 159  string
# 164  string
# 165  number
# 167  string
# 171  string
# 176  string
#
#                                                                                                                                                                                   Ontology  \
# 2                                                                                                                                                                         Sage Bionetworks
# 3                                                                                     https://www.ebi.ac.uk/ols/ontologies/ms/termsiri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMS_1003213
# 4                                                                                                                                                http://purl.obolibrary.org/obo/MS_1001455
# 11                                                                                                                                                                        Sage Bionetworks
# 15                                                                                                                                                              Proteomics Sample Metadata
# 16                                                                                                                                                                        Sage Bionetworks
# 19                               https://doi.org/10.1101/2020.05.19.105197https://doi.org/10.1038/sdata.2017.140https://www-s.nist.gov/srmors/view_detail.cfmsrm=1950Sage BionetworksDSLWG
# 21                                                                                                                                                                        Sage Bionetworks
# 23                                                                                                                                                              Proteomics Sample Metadata
# 25                                                                                                                                               http://purl.obolibrary.org/obo/MS_1001013
# 26                                                                                                                                               http://purl.obolibrary.org/obo/MS_1001012
# 32                                                                                                                                                                        Sage Bionetworks
# 34                                                                                                                                                                        Sage Bionetworks
# 37                                                                                                                          Sage Bionetworks,https://www.synapse.org/#!Synapse:syn25878249
# 39                                                                                                                                                                        Sage Bionetworks
# 40                                                                                                                                              http://purl.obolibrary.org/obo/OBI_0302884
# 41                                                                                                                                                              Proteomics Sample Metadata
# 48                                                                                                               Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry
# 58                                                                                                               Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry
# 59                                                                                                                                                                        Sage Bionetworks
# 60                                                                                                                                                                        Sage Bionetworks
# 61                                                                                                                                                                        Sage Bionetworks
# 62                                                                                                                                                                        Sage Bionetworks
# 65                                                                                    https://www.ebi.ac.uk/ols/ontologies/ms/termsiri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMS_1001055
# 66                                                                                                                                             http://purl.obolibrary.org/obo/NCIT_C156434
# 67                                                                                                               Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry
# 68                                                                                                               Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry
# 69                                                                                                                                                                  Sage Bionetworks,DSLWG
# 70                             Sage Bionetworks,DSLWG,Proposed minimum metadata relative to mass spectrometry  ,Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry
# 71                                                                                                                                                 Sage Bionetworks,Sage Bionetworks,DSLWG
# 77                                                                                                                                                 Sage Bionetworks,Sage Bionetworks,DSLWG
# 81                                                                                                                                                                        Sage Bionetworks
# 83   Sage Bionetworks,https://www.synapse.org/#!Synapse:syn25878249,https://jamanetwork.com/pages/inclusive-language,https://thesaurus.cancer.gov/ncitbrowser/pages/home.jsfversion=23.04d
# 85                                                                                                                                                                        Sage Bionetworks
# 86                                                                                                                                                                        Sage Bionetworks
# 94                                                                                                                                                                        Sage Bionetworks
# 95                                                                                                                                                                        Sage Bionetworks
# 96                                                                                                                                                                        Sage Bionetworks
# 97                                                                                                                                                                        Sage Bionetworks
# 99                                                                                                                                                                        Sage Bionetworks
# 103                                                                                                                                                                       Sage Bionetworks
# 104                                                                                                             Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry
# 106                                                                                                                                                               Sage Bionetworks,ImmPort
# 108                                                                                                                                                                       Sage Bionetworks
# 110                                                                                                                                                                       Sage Bionetworks
# 159                                                                                                                            Sage Bionetworks,http://purl.obolibrary.org/obo/NCIT_C45378
# 164                                                                                                                                                                                ImmPort
# 165                                                                                                                                                               Sage Bionetworks,ImmPort
# 167                                                                                                                                                               Sage Bionetworks,ImmPort
# 171                                                                                                                                                               Sage Bionetworks,ImmPort
# 176                                                                                                              Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry
#
#            multivalue
# 2
# 3               False
# 4               False
# 11
# 15               True
# 16               True
# 19
# 21              false
# 23              False
# 25              False
# 26              False
# 32   False,false,true
# 34        False,false
# 37              False
# 39
# 40              False
# 41
# 48
# 58
# 59        False,false
# 60        False,false
# 61        False,false
# 62        False,false
# 65              False
# 66              False
# 67              False
# 68              False
# 69              False
# 70              False
# 71              False
# 77        False,false
# 81
# 83               True
# 85        False,false
# 86        False,false
# 94        False,false
# 95              False
# 96              False
# 97              False
# 99              False
# 103
# 104
# 106      False,string
# 108       False,false
# 110       False,false
# 159        False,true
# 164             False
# 165
# 167
# 171
# 176

# %%
dm2[["Attribute", "DependsOn"]] = dm2[["Attribute", "DependsOn"]].apply(
    lambda x: x.replace(recoder_valid_values, regex=True)
)

# %%
dm2[
    dm2.duplicated(subset=["Attribute", "Parent", "DependsOn"], keep=False)
].sort_values(by=["Parent", "Attribute"])
# Out:
#                               Attribute Description Valid Values Required  \
# 239  10x Visium Spatial Gene Expression         NaN          NaN    False
# 241  10x Visium Spatial Gene Expression         NaN          NaN    False
#
#     DependsOn DependsOn Component  Properties Validation Rules Template  \
# 239       NaN                 NaN  validValue              NaN      NaN
# 241       NaN                 NaN  validValue              NaN      NaN
#
#     Parent Source Type Ontology multivalue
# 239    NaN    NaN  NaN      NaN        NaN
# 241    NaN    NaN  NaN      NaN        NaN

# %% [markdown]
# # Check columns for Speical Characters

# %%
check_cols = ["Attribute"]

mask = np.column_stack(
    [dm2[col].str.contains("\(|\)", na=False) for col in dm2[check_cols]]
)

with pd.option_context("display.max_colwidth", None):
    display(dm2[check_cols].loc[mask.any(axis=1)])
# Out:
#                                                                 Attribute
# 279                                     Cardiovascular Health Study (CHS)
# 283                                             Cerebrospinal Fluid (CSF)
# 350                Illumina Infinium MethylationEPIC BeadChip v1.0 (850k)
# 351  Illumina Infinium MethylationEPIC BeadChip v2.0 (935k)Illumina MiSeq
# 398                                      MassBank of North America (MoNA)
# 502                                 Study of Osteoporotic Fractures (SOF)
# 513           The Health and Aging and Body Composition Study (HealthABC)
# 514                        The Osteoporotic Fractures in Men (MrOS) Study

# %% [markdown]
# # Create Manifests in data model

# %%
unique_templates = np.unique(
    ",".join(dm2["Template"].dropna().values.tolist()).split(",")
)
templates = pd.DataFrame({"Attribute": unique_templates})
templates["Required"] = "True"
templates["Properties"] = "dataType"
templates["Parent"] = "Template"
templates["Description"] = templates["Attribute"].apply(
    lambda x: f"Metadata template for {x}"
)

# Adjust bseq
templates.loc[
    templates["Attribute"] == "bsSeq (bisulfite-seq WGBS methylseq methylomics)",
    "Description",
] = "Template for bisulfite-seq WGBS methylseq methylomics"
templates.loc[
    templates["Attribute"] == "bsSeq (bisulfite-seq WGBS methylseq methylomics)",
    "Attribute",
] = "bsSeq"

# update templates column for other attributes
dm2["Template"] = dm2["Template"].str.replace(
    "bsSeq (bisulfite-seq WGBS methylseq methylomics)", "bsSeq", regex=False
)

# create depends On column for templates
for i, m in enumerate(templates["Attribute"]):
    dm2["Template"].str.contains(m)
    templates.loc[i, "DependsOn"] = ",".join(
        dm2.loc[
            dm2["Template"].str.contains(m, regex=False, na=False), "Attribute"
        ].tolist()
    )

# %%
dm2 = pd.concat([dm2, templates], axis=0, ignore_index=True)

print(dm2.shape)
# Out:
# (634, 14)

# %%
dm2.sample(20)
# Out:
#                                              Attribute  \
# 297                                                DNA
# 187                            TRUEHasIonizationSource
# 321                                                GIS
# 540                                      Zeiss LSM 980
# 190                                     TRUEUseReagent
# 510  The Health and Aging and Body Composition Stud...
# 592                                                 pl
# 456                                           Pancreas
# 624                                   Individual Human
# 588                                   pg/mg creatinine
# 534                                              White
# 519                                          UPLC-MSMS
# 202                               otherDigestionMethod
# 137                 specifyOtherModificationParameters
# 72                                   nucleicAcidSource
# 414                                                NPX
# 347                       Illumina HumanOmni1-Quadv1.0
# 249         Affymetrix Genome-Wide Human SNP 5.0 Array
# 513                                             Tonsil
# 550                                              dbGAP
#
#                                            Description  \
# 297                                                NaN
# 187                    When hasIonizationSource = TRUE
# 321                                                NaN
# 540                                                NaN
# 190                             When useReagent = TRUE
# 510                                                NaN
# 592                                   Measurement unit
# 456                                                NaN
# 624             Metadata template for Individual Human
# 588                                   Measurement unit
# 534                                                NaN
# 519                                                NaN
# 202                       When digestionMethod = other
# 137  If "other" is selected, list the custom modifi...
# 72   Specifies the type of nucleic acid (DNA, RNA, ...
# 414                                   Measurement unit
# 347                                                NaN
# 249                                                NaN
# 513                                                NaN
# 550                                                NaN
#
#                                           Valid Values Required  \
# 297                                                NaN    False
# 187                                                       False
# 321                                                NaN    False
# 540                                                NaN    False
# 190
# 510                                                NaN    False
# 592                                                NaN    False
# 456                                                NaN    False
# 624                                                NaN     True
# 588                                                NaN    False
# 534                                                NaN    False
# 519                                                NaN    False
# 202                                                       False
# 137                                                       False
# 72   bulk cell,single cell,bulk nuclei,single nucle...     True
# 414                                                NaN    False
# 347                                                NaN    False
# 249                                                NaN    False
# 513                                                NaN    False
# 550                                                NaN    False
#
#                                              DependsOn DependsOn Component  \
# 297                                                NaN                 NaN
# 187                                  lensVoltagesUnit
# 321                                                NaN                 NaN
# 540                                                NaN                 NaN
# 190                                     reagentContact
# 510                                                NaN                 NaN
# 592                                                NaN                 NaN
# 456                                                NaN                 NaN
# 624  age,cohort,consentGroupID,countryCode,diagnosi...                 NaN
# 588                                                NaN                 NaN
# 534                                                NaN                 NaN
# 519                                                NaN                 NaN
# 202                             specifyDigestionMethod
# 137
# 72
# 414                                                NaN                 NaN
# 347                                                NaN                 NaN
# 249                                                NaN                 NaN
# 513                                                NaN                 NaN
# 550                                                NaN                 NaN
#
#        Properties Validation Rules                                Template  \
# 297    validValue              NaN                                     NaN
# 187    ValidValue                                       Metabolomics Human
# 321    validValue              NaN                                     NaN
# 540    validValue              NaN                                     NaN
# 190    ValidValue                                               genotyping
# 510    validValue              NaN                                     NaN
# 592    validValue              NaN                                     NaN
# 456    validValue              NaN                                     NaN
# 624      dataType              NaN                                     NaN
# 588    validValue              NaN                                     NaN
# 534    validValue              NaN                                     NaN
# 519    validValue              NaN                                     NaN
# 202    ValidValue                                               proteomics
# 137  dataProperty                                               proteomics
# 72                                  Biospecimen nonHuman,Biospecimen human
# 414    validValue              NaN                                     NaN
# 347    validValue              NaN                                     NaN
# 249    validValue              NaN                                     NaN
# 513    validValue              NaN                                     NaN
# 550    validValue              NaN                                     NaN
#
#               Parent                                             Source  \
# 297              NaN                                                NaN
# 187                   Sage Bionetworks,Proposed minimum metadata rel...
# 321              NaN                                                NaN
# 540              NaN                                                NaN
# 190                                            Sage Bionetworks,ImmPort
# 510              NaN                                                NaN
# 592  MeasurementUnit                                                NaN
# 456              NaN                                                NaN
# 624         Template                                                NaN
# 588  MeasurementUnit                                                NaN
# 534              NaN                                                NaN
# 519              NaN                                                NaN
# 202    Specification                                   Sage Bionetworks
# 137    Specification                                   Sage Bionetworks
# 72                    https://ncithesaurus.nci.nih.gov/ncitbrowser/C...
# 414  MeasurementUnit                                                NaN
# 347              NaN                                                NaN
# 249              NaN                                                NaN
# 513              NaN                                                NaN
# 550              NaN                                                NaN
#
#        Type                                           Ontology multivalue
# 297     NaN                                                NaN        NaN
# 187     NaN                                                NaN        NaN
# 321     NaN                                                NaN        NaN
# 540     NaN                                                NaN        NaN
# 190     NaN                                                NaN        NaN
# 510     NaN                                                NaN        NaN
# 592  STRING                                                NaN      False
# 456     NaN                                                NaN        NaN
# 624     NaN                                                NaN        NaN
# 588  STRING                                                NaN      False
# 534     NaN                                                NaN        NaN
# 519     NaN                                                NaN        NaN
# 202     NaN                                                NaN        NaN
# 137  string                                   Sage Bionetworks      False
# 72   string  https://ncithesaurus.nci.nih.gov/ncitbrowser/C...      False
# 414  STRING                                                NaN      False
# 347     NaN                                                NaN        NaN
# 249     NaN                                                NaN        NaN
# 513     NaN                                                NaN        NaN
# 550     NaN                                                NaN        NaN

# %%
def clean_list_col(row):
    # cleanup list columns
    # split list
    # strip white space
    # only unique values
    # sorted alphabetically

    row = [y.strip() for y in row.split(",")]
    row = sorted(np.unique(row))
    row = ",".join(row)
    row = row.strip(",")

    return row


dm2[["Valid Values", "Template", "Ontology", "Source"]] = (
    dm2[["Valid Values", "Template", "Ontology", "Source"]]
    .fillna("")
    .applymap(clean_list_col)
)

# %%
dm2 = dm2.drop(
    index=dm2.loc[(dm2["Attribute"] == "f") | (
        dm2["Attribute"] == "F"),].index.tolist()
).reset_index(drop=True)

# %%
# Recode required columns and fix spelling mistakes
required_recoder = {"0.0": "False", "1.0": "True", "FASLSE": "False"}

dm2["Required"] = dm2["Required"].replace(required_recoder)

# dm2[~dm2["Required"].str.contains("True|False", regex=True)]

# %% [markdown]
# Last bit of cleanup

# %%
# Remove measurement technique dependency from biospecimen human
dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"] = (
    dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"]
    .values[0]
    .replace("measurementTechnique,", "")
)
bio_measure_technique_index = dm2.query(
    'Attribute == "measurementTechnique" and Parent == "Biospecimen human"'
)

if len(bio_measure_technique_index.index) > 0:
    dm2 = dm2.drop(
        index=bio_measure_technique_index.index[0]).reset_index(drop=True)

# %%
# Remove measurement technique dependency from biospecimen human
dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"] = (
    dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"]
    .values[0]
    .replace("specifyMeasurementTechnique,", "")
)
bio_measure_technique_index = dm2.query(
    'Attribute == "specifyMeasurementTechnique" and Parent == "Biospecimen human"'
)


if len(bio_measure_technique_index.index) > 0:
    dm2 = dm2.drop(
        index=bio_measure_technique_index.index[0]).reset_index(drop=True)

# %%
# Remove measurement technique dependency from biospecimen human
dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"] = (
    dm2.loc[dm2["Attribute"] == "Biospecimen human", "DependsOn"]
    .values[0]
    .replace("OtherMeasurementTechnique,", "")
)
bio_measure_technique_index = dm2.query(
    'Attribute == "OtherMeasurementTechnique"')


if len(bio_measure_technique_index.index) > 0:
    dm2 = dm2.drop(
        index=bio_measure_technique_index.index[0]).reset_index(drop=True)

# %%
dm2.loc[dm2[dm2["Attribute"] == "visitCode"].index.values[0], "Valid Values"] = ""

dm2.loc[dm2[dm2["Attribute"] == "visitCode"].index.values[0],
        "Validation Rules"] = ""

# %% [markdown]
# Extra comma at beginning of valid values

# %% [markdown]
# # Validation Rules

# %%
mixed_attrs = [
    {"attribute": "tissueWeight", "val_type": "mixed float", "regex": "regex search"},
    {"attribute": "tissueVolume", "val_type": "mixed float", "regex": "regex search"},
    {"attribute": "specimenAge", "val_type": "mixed integer", "regex": "regex search"},
    {"attribute": "samplingAge", "val_type": "mixed integer", "regex": "regex search"},
    {"attribute": "age", "val_type": "mixed integer", "regex": "regex search"},
]

for ma in mixed_attrs:
    attribute = ma["attribute"]
    val_type = ma["val_type"]

    # get indexes for new validation rules based on attribute
    indexes = dm2[dm2["Attribute"] == attribute].index.tolist()

    for i in indexes:
        if val_type == "integer":
            first_part = "[0-9]+"
        elif val_type == "float":
            first_part = "^\d*?\.?\d$"
        elif val_type == "mixed integer":
            regex = "regex search"
            num_match = "^\d*?"
        elif val_type == "mixed float":
            regex = "regex search"
            num_match = "^\d*?\.?\d$"
            # All valid values are applicable
            new_string = (
                regex
                + num_match
                + "|"
                + ""
                + "|".join(dm2.loc[i, "Valid Values"].split(","))
            )

        dm2.loc[i, "Validation Rules"] = new_string

# %%
dm2["Validation Rules"].unique().tolist()
# Out:
# ['',
#  'regex search ([0-9]+\\.[0-9]*.)|([0-9]+)',
#  'regex search^\\d*?\\.?\\d$|Not applicable|Not collected|Unknown',
#  'regex search ([0-9]+)',
#  'nan',
#  nan]

# %% [markdown]
# ## Building Dependencies

# %%
dependencies = {
    "specimenID": "matchAtLeastOne Biospecimenhuman.specimenID value",
    "individualID": "matchExactlyOne IndividualHuman.individualID set",
}

# %%
for k, v in dependencies.items():
    indexes = dm2[dm2["Attribute"] == k]["Validation Rules"].index.values
    dm2.loc[indexes, "Validation Rules"] = v

# %%
dm2.loc[3, "Valid Values"] = dm2.loc[3, "Valid Values"].replace(
    ",Whole Genome Sequencing", ""
)

# %% [markdown]
# # Create File Annotations Attributes

# %%
# base file annotations
base_file_annotations = {"resourceType": "",
                         "isReleased": False, "fileType": ""}

# %%
with pd.option_context("display.max_colwidth", None):
    display(dm2.query('Attribute == "visitCode"'))
# Out:
#      Attribute  \
# 177  visitCode
#
#                                                                                                                       Description  \
# 177  Indicate which longitudinal visit for the individual the data comes from, provided by the data contributor's data dictionary
#
#     Valid Values Required DependsOn DependsOn Component Properties  \
# 177                  True
#
#     Validation Rules          Template Parent            Source    Type  \
# 177                   Individual Human         Sage Bionetworks  number
#
#                               Ontology multivalue
# 177  Data Contributor,Sage Bionetworks      False

# %% [markdown]
# # Write out new data model

# %%
hard_coded_valid_values = [
    {
        "attribute": "visitCode",
        "valid_value": "1,2,Other,Unknown,Not collected,Not applicable",
    },
    {"attribute": "consentGroupID", "valid_value": "1,2,3"},
    {"attribute": "samplingAge", "valid_value": ""},
    {"attribute": "specimenAge", "valid_value": ""},
    {"attribute": "age", "valid_value": ""},
]

# %%
for h in hard_coded_valid_values:
    dm2.loc[
        dm2[dm2["Attribute"] == h["attribute"]].index.values[0], "Valid Values"
    ] = h["valid_value"]

# %%
checks = [c["attribute"] for c in hard_coded_valid_values]

with pd.option_context("display.max_colwidth", None):
    display(dm2.query(f"Attribute in @checks"))
# Out:
#           Attribute  \
# 6               age
# 18   consentGroupID
# 106     samplingAge
# 150     specimenAge
# 177       visitCode
#
#                                                                                                                                                           Description  \
# 6    Age of the individual (age in years of the individual at first recorded study event (enrollment, visit, observation, sample collection, survey completion, etc.)
# 18                                                                  Indicate the consent group for the individual, provided by the data contributor's data dictionary
# 106                                                                    The calculated age of the sample, measurement is determined or coded by the data contributor.
# 150  The subject's age at the time of specimen extraction is the individual's age (since birth) at the time a given specimen was extracted. Measured as age in years.
# 177                                      Indicate which longitudinal visit for the individual the data comes from, provided by the data contributor's data dictionary
#
#                                        Valid Values Required DependsOn  \
# 6                                                       True
# 18                                            1,2,3     True
# 106                                                     True
# 150                                                     True
# 177  1,2,Other,Unknown,Not collected,Not applicable     True
#
#     DependsOn Component Properties  \
# 6
# 18
# 106
# 150
# 177
#
#                                                  Validation Rules  \
# 6    regex search^\d*?\.?\d$|Not applicable|Not collected|Unknown
# 18
# 106  regex search^\d*?\.?\d$|Not applicable|Not collected|Unknown
# 150  regex search^\d*?\.?\d$|Not applicable|Not collected|Unknown
# 177
#
#                                    Template Parent            Source    Type  \
# 6                          Individual Human         Sage Bionetworks  string
# 18                         Individual Human         Sage Bionetworks  string
# 106  Biospecimen human,Biospecimen nonHuman         Sage Bionetworks  string
# 150  Biospecimen human,Biospecimen nonHuman         Sage Bionetworks  string
# 177                        Individual Human         Sage Bionetworks  number
#
#                               Ontology multivalue
# 6                     Sage Bionetworks      False
# 18   Data Contributor,Sage Bionetworks      False
# 106                   Sage Bionetworks      False
# 150                   Sage Bionetworks      False
# 177  Data Contributor,Sage Bionetworks      False

# %%
import yaml

with open("./local_configs/notebook_config.yaml", "r") as f:
    config = yaml.safe_load(f)

# paths to import files
schematic_config = config["paths"]["schematic"]
csv_model = config["file_names"]["csv_model"]
json_model = config["file_names"]["json_model"]

print(
    "Schematic config: ",
    schematic_config,
    "\n",
    "CSV model: ",
    csv_model,
    "\n",
    "JSON LD Model: ",
    json_model,
)
# Out:
# Schematic config:  ./config.yml
#  CSV model:  EL.data.model.csv
#  JSON LD Model:  EL.data.model.jsonld

# %%
# Attribute,Description,Valid Values,DependsOn,Properties,Required,Parent,DependsOn Component,Source,Validation Rules,Module,Type,Ontology,UsedIn

# %%
print(dm2.columns.tolist())
# Out:
# ['Attribute', 'Description', 'Valid Values', 'Required', 'DependsOn', 'DependsOn Component', 'Properties', 'Validation Rules', 'Template', 'Parent', 'Source', 'Type', 'Ontology', 'multivalue']

# %%
dm2 = dm2.rename({"Template": "UsedIn"}, axis=1)

# %%
print(dm2.shape)

dm2 = (
    dm2.fillna("").drop_duplicates(subset=["Attribute"]).reset_index(drop=True)
)  # 'DependsOn', 'Properties',

display(dm2.shape)
# Out:
# (632, 14)
# (612, 14)

# %%
from utils import utils

# %%
dm_old = utils.load_and_backup_dm("../EL.data.model.csv", "../backups")
dm2 = dm2.replace(r"^\s*$", np.nan, regex=True)
new_dm = pd.concat([dm2, dm_old])

# %%
test_dm = (
    new_dm.fillna("")
    .groupby("Attribute")
    .agg(lambda x: ",".join(set(x.astype(str))))
    .reset_index()
)
test_dm = test_dm.applymap(lambda x: x.strip(","))
test_dm = test_dm.replace(r"^\s*$", np.nan, regex=True)
test_dm[["Module", "Properties", "Parent", "Type", "Ontology", "Source"]] = test_dm[
    ["Module", "Properties", "Parent", "Type", "Ontology", "Source"]
].fillna("Unspecified")

test_dm["Properties"] = test_dm["Properties"].apply(
    lambda x: x[0].upper() + x[1:])
test_dm["Type"] = test_dm["Type"].str.upper()
more_recoding = {"ValidValue,MeasurementUnit": "MeasurementUnit"}
test_dm["Parent"] = test_dm["Parent"].replace(more_recoding)
test_dm.loc[test_dm["Attribute"] == "visitCode", "Valid Values"] = ""

# %%
test_dm["Validation Rules"] = test_dm["Validation Rules"].replace(
    "regex search^\d*?\.?\d$|Unknown|Not collected|Not applicable,regex search^\d*?\.?\d$|Not applicable|Not collected|Unknown",
    "regex search^\d*?\.?\d$|Unknown|Not collected|Not applicable",
)

# %%
# write out data model into csv
test_dm.to_csv(csv_model)

# %%
# Convert CSV to JSON LD
print(f'schematic schema convert {csv_model} --output_jsonld {json_model}')

# !schematic schema convert {csv_model} --output_jsonld {json_model}
# Out:
# schematic schema convert EL.data.model.csv --output_jsonld EL.data.model.jsonld
# Starting schematic...
# Done adding requirements and value ranges to attributes
# The Data Model was created and saved to 'EL.data.model.jsonld' location.

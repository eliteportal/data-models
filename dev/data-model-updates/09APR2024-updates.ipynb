# %%
import pandas as pd

# %%
# get the data model
dm = pd.read_csv('../../EL.data.model.csv')

# %%
dm
# Out:
#                               Attribute  \
# 0                                   10x
# 1    10x Visium Spatial Gene Expression
# 2                     Accel-NGS 2S Plus
# 3                  Accel-NGS Methyl-Seq
# 4                    acquisitionBatchID
# ..                                  ...
# 725              YesHasIonizationSource
# 726             YesHasIonizationSource?
# 727                       YesUseReagent
# 728                     YesUseTreatment
# 729                       Zeiss LSM 980
#
#                                            Description       Valid Values  \
# 0                                                  NaN                NaN
# 1                                Instrument Model Name                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4    Acquisition batch identifier, provided by the ...                NaN
# ...

# %%
# get manifest columns
dm.loc[
    (dm["Properties"].str.contains("ManifestColumn", na=False))
    & (dm['columnType'].isna()),
    :,
]
# Out:
# Empty DataFrame
# Columns: [Attribute, Description, Valid Values, DependsOn, Properties, Required, Parent, DependsOn Component, Source, Validation Rules, Module, Ontology, UsedIn, columnType, Notes, multivalue]
# Index: []

# %%
# get manifest columns
dm.loc[ (dm['columnType'].isna()),
    :,
]
# Out:
#                               Attribute  \
# 0                                   10x
# 1    10x Visium Spatial Gene Expression
# 2                     Accel-NGS 2S Plus
# 3                  Accel-NGS Methyl-Seq
# 10                                Adult
# ..                                  ...
# 724                  YesHasAssayControl
# 725              YesHasIonizationSource
# 727                       YesUseReagent
# 728                     YesUseTreatment
# 729                       Zeiss LSM 980
#
#                                            Description  \
# 0                                                  NaN
# 1                                Instrument Model Name
# 2                                                  NaN
# 3                                                  NaN
# 10                                                 NaN
# ..                                                 ...
# 724  Control samples suitable for normalization and...
# ...

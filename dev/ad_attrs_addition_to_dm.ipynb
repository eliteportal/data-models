# %%
import pandas as pd
import numpy as np
import os

from glob import glob
import yaml
import re

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/adknowledgeportal/data-models/main/AD.model.csv")

# preprocess AD data model to remove duplicates
df = df.sort_values(by=['Attribute', 'Valid Values']).reset_index(drop=True)
df = df.drop_duplicates(keep='first', subset=['Attribute'])

# %%
df.loc[df.query('Attribute.str.contains("template")',
                engine='python').index.tolist(), 'Properties'] = 'template'

# %%
attrs_interest = [
    'analysisType',
    'analysisType',
    'analytical covariates',
    'assay',
    'assay',
    'biospecimen',
    'consortium',
    'data dictionary',
    'dataSubtype',
    'dataType',
    'fileFormat',
    'grant',
    'ID mapping',
    'individual',
    'isConsortiumAnalysis',
    'isModelSystem',
    'isMultiSpecimen',
    'libraryPrep',
    'libraryType',
    'manifest',
    'manifest',
    'metadata',
    'metadataType',
    'modelSystemName',
    'modelSystemType',
    'platform',
    'project',
    'protocol',
    'protocol',
    'resourceType',
    'type'
]

# %%
metadataTypes = [
    'analytical covariates',
    'assay',
    'biospecimen',
    'data dictionary',
    'ID mapping',
    'individual',
    'manifest',
    'protocol'
]

# %%
df_new_attrs = df.query('Attribute in @attrs_interest').copy()

# %%
df_new_attrs['Properties'] = 'BaseAnnotation'

# %%
# get existing annotations from ELITE portal

# %% [markdown]
# # Cleanup data model attributes to fit ELITE data model

# %%
def rewrite_df_value(df, col_name, search_term, col_value, new_value):
    try:
        df.loc[df[df[col_name] ==
                  search_term].index[0], col_value] = new_value
        return df
    except:
        return df

# %%
df_new_attrs = rewrite_df_value(
    df_new_attrs,
    'Attribute',
    'study',
    'Valid Values',
    'LLFS,ILO,LG,LC')

df_new_attrs = rewrite_df_value(
    df_new_attrs,
    'Attribute',
    'consortium',
    'Valid Values',
    'ELITE')

df_new_attrs = rewrite_df_value(
    df_new_attrs,
    'Attribute',
    'metadataType',
    'Valid Values',
    'analytical covariates, assay, biospecimen, data dictionary, ID mapping, individual, manifest, protocol')

# %%
# recode Parent
recoder = {
    'ValidValue': 'validValue',
    'DataProperty': 'dataProperty',
    'DataType': 'dataType'
}

df_new_attrs = df_new_attrs.replace(recoder)

# %% [markdown]
# # Merge new attributes with existiing data model

# %%
dm_elite = pd.read_csv(
    "C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.csv").iloc[:, 1:]

dm_elite = dm_elite.replace({"", np.nan})

# %%
dm_elite.query(
    'Attribute in @attrs_interest')
# Out:
#        Attribute                                        Description  \
# 14   libraryPrep  The general strategy by which the library was ...
# 154        assay  The analysis or technology used to generate th...
#
#                                           Valid Values DependsOn  \
# 14   amplicon,cellHashing,Chromium Single Cell 3',D...       NaN
# 154                                                TBD       NaN
#
#        Properties  Required                                            Parent  \
# 14   dataProperty      True  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 154  dataProperty      True                              Biospecimen nonHuman
#
#      DependsOn Component            Source Validation Rules
# 14                   NaN  Sage Bionetworks              NaN
# 154                  NaN  Sage Bionetworks              NaN

# %%
# # Only needed for the first time since the Valid values were TBD
dm_elite = rewrite_df_value(
    dm_elite,
    'Attribute',
    'assay',
    'Valid Values',
    np.nan)

# %%
# Add valid values from the AD model
dm_elite['Valid Values'] = dm_elite['Valid Values'].fillna(
    dm_elite['Attribute'].map(df_new_attrs.set_index('Attribute')['Valid Values']))

# %%
# Add new attributes from AD model
dm_new = pd.concat([dm_elite, df_new_attrs])

# %%
dm_new['Parent'] = dm_new['Properties']
dm_new['Properties'] = np.nan

# %%
dm_new.query('Parent == "dataType"')
# Out:
#                                             Attribute Description  \
# 619                                 Biospecimen human         NaN
# 620                              Biospecimen nonHuman         NaN
# 621                                  Individual Human         NaN
# 622                               Individual nonHuman         NaN
# 623                                Metabolomics Human         NaN
# 624                                        Microbiome         NaN
# 625                                            RNAseq         NaN
# 626                           Whole Genome Sequencing         NaN
# 627  bsSeq (bisulfite-seq WGBS methylseq methylomics)         NaN
# 628                                        genotyping         NaN
# 629                                        proteomics         NaN
# 630                                          scRNAseq         NaN
#
#     Valid Values                                          DependsOn  \
# 619          NaN  individualID,specimenID,specimenType,specimenA...
# 620          NaN  individualID,specimenID,specimenIdSource,dataG...
# 621          NaN  individualID,cohort,studyCode,fieldCenterCode,...
# 622          NaN  individualID,cohort,studyCode,taxon,speciesGro...
# 623          NaN  specimenID,sampleType,specifySampleType,specif...
# 624          NaN  specimenID,sampleType,specifySampleType,specif...
# 625          NaN  specimenID,sampleType,specifySampleType,specif...
# 626          NaN  specimenID,sampleType,specifySampleType,specif...
# 627          NaN  specimenID,sampleType,specifySampleType,specif...
# 628          NaN  specimenID,sampleType,specifySampleType,useRea...
# 629          NaN  specimenID,sampleType,specifySampleType,specif...
# 630          NaN  specimenID,sampleType,specifySampleType,specif...
#
#      Properties Required    Parent  DependsOn Component Source  \
# 619         NaN     True  dataType                  NaN    NaN
# 620         NaN     True  dataType                  NaN    NaN
# 621         NaN     True  dataType                  NaN    NaN
# 622         NaN     True  dataType                  NaN    NaN
# 623         NaN     True  dataType                  NaN    NaN
# 624         NaN     True  dataType                  NaN    NaN
# 625         NaN     True  dataType                  NaN    NaN
# 626         NaN     True  dataType                  NaN    NaN
# 627         NaN     True  dataType                  NaN    NaN
# 628         NaN     True  dataType                  NaN    NaN
# 629         NaN     True  dataType                  NaN    NaN
# 630         NaN     True  dataType                  NaN    NaN
#
#     Validation Rules
# 619              NaN
# 620              NaN
# 621              NaN
# 622              NaN
# 623              NaN
# 624              NaN
# 625              NaN
# 626              NaN
# 627              NaN
# 628              NaN
# 629              NaN
# 630              NaN

# %%
dm_new.query('Attribute == "studyCode"')
# Out:
#      Attribute                                        Description  \
# 159  studyCode  Unique identifier for the study, assigned by t...
#
#        Valid Values DependsOn  Properties Required Parent  \
# 159  LC,LG,ILO,LLFS       NaN         NaN     True
#
#      DependsOn Component            Source Validation Rules
# 159                  NaN  Sage Bionetworks              NaN

# %%
# write out versioned data model
dm_new.to_csv(
    'C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/old_models/EL_data_model_v3.2.0.csv')

# write out versioned data model
dm_new.to_csv(
    'C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/models/EL_data_model_v3.csv')

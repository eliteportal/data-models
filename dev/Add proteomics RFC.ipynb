# %%
import pandas as pd
import numpy as np
import re

# %%
dm = pd.read_csv('../EL.data.model.csv').drop(columns = ['Unnamed: 0'], errors = 'ignore')

# %%
dm['Parent'].unique()
# Out:
# array(['ValidValue', 'Component', 'AnalysisType', 'MeasurementUnit',
#        'ManifestColumn', 'Ontology', 'Repository', 'Demographics',
#        'BaseAnnotation'], dtype=object)

# %%
other_values = ["Other","Unknown","Not collected","Not applicable","Not specified"]

# %%
p_df = pd.read_excel("../_data/RFC Tables/EL RFC_ Assay_proteomics Data Model.xlsx")

p_df = p_df.rename(
    columns={
        "key": "Attribute",
        "description": "Description",
        "required": "Required",
        "requires": "Module",
        "concept source ontology": "Ontology",
        "valid values": "Valid Values",
        "type": "columnType",
        "note": "Notes",
    }
)
p_df = p_df.fillna("")

# %%
p_df
# Out:
#                              Attribute  \
# 0                           specimenID
# 1                           sampleType
# 2                    specifySampleType
# 3                       experimentType
# 4                 measurementTechnique
# 5          specifyMeasurementTechnique
# 6            technologyPlatformVersion
# 7               specifyPlatformVersion
# 8                     platformLocation
# 9              specifyPlatformLocation
# 10                     instrumentModel
# 11                  samplePrepProtocol
# 12                            dataFile
# 13                      databaseSource
# 14                     databaseWeblink
# 15                        databaseName
# 16              modificationParameters
# 17                  quantationStrategy
# 18                   labelQuantitation
# 19               labelFreeQuantitation
# 20        specifyLabelFreeQuantitation
# 21             isobaricLabelingReagent
# 22                            msTarget
# 23                   msAnalyzerTypeMS1
# 24            specifyMSAnalyzerTypeMS1
# 25                   msAnalyzerTypeMS2
# 26            specifyMSAnalyzerTypeMS2
# 27                    msAssayTechnique
# 28             specifyMSAssayTechnique
# 29                       msAnalyteType
# 30                specifyMSAnalyteType
# 31          specifyProteomicsAssayType
# 32            specifyMSInstrumentModel
# 33                     digestionMethod
# 34              specifyDigestionMethod
# 35                    digestionReagent
# 36             specifyDigestionReagent
# 37                  fractionIdentifier
# 38                  enrichmentStrategy
# 39           specifyEnrichmentStrategy
# 40                          enrichment
# 41                  fractionIdentifier
# 42                     acquisitionMode
# 43                 acquisitionSoftware
# 44           acquistionSoftwareVersion
# 45                        databaseName
# 46                 specifyDatabaseName
# 47                      databaseSource
# 48               specifyDatabaseSource
# 49               spectrometerFrequency
# 50                specifyOtherDataFile
# 51  specifyOtherModificationParameters
# 52                      cleavageAgents
# 53           specifyOtherCleavageAgent
# 54               fragmentMassTolerance
# 55              precursorMassTolerance
#
#                                           Description  \
# 0   Identifying string linked to a particular samp...
# 1   The type of sample collected or the term used ...
# 2      If "other" is selected list the type of sample
# 3   The type of experiment used.\n\nProvide a valu...
# 4   The name of the measurement technique describi...
# 5   If "other" is selected list the name of the me...
# 6   The specific version (application, manufacture...
# 7    If "other" list the name of the platform version
# 8   The name of the laboratory, facility, vendor, ...
# 9   If "other" list the name of the platform location
# 10  The model of the instrument used.\n\nProvide a...
# 11  An internet address that may provide more deta...
# 12  Name of additional file(s) accompanying the da...
# 13  The name of the organization, project, or labo...
# 14  An internet address that may provide details o...
# 15  The name of the search database (nr, SwissProt...
# 16  Modification parameters for a search engine ru...
# 17  The general strategy used for differential ana...
# 18  Type of labeling used \n\nProvide a value OR p...
# 19  Type of label-free data analysis strategy \n\n...
# 20              If "other" is selected please specify
# 21  Reagent set used for isobaric labeling.\n\nExa...
# 22  Specifies whether or not a specific molecule(s...
# 23  Describes the mass spectrometer analyzer used ...
# 24  If "other" is selected list the name of the ma...
# 25  Describes the mass spectrometer analyzer used ...
# 26  If "other" is selected list the name of the ma...
# 27  Specified the mass spectrometer technique used...
# 28  If "other" is selected list the name of the ma...
# 29  The type of biospecimen subjected to analysis ...
# 30               If "other" list the type of analyte
# 31  List the name of the type of peptide quantific...
# 32              List the name of the instrument model
# 33  The type of digestion (ex. in-solution, in-gel...
# 34              If "other" list the type of digestion
# 35       Enzymes or reagents used for digestion. \n\n
# 36  If "other" is selected specify the name of the...
# 37  Number of fractions in the experimental run\n\...
# 38          Type of peptide or protein enrichment\n\n
# 39            If "other" is selected specify the name
# 40  Protocol or reagent used for enrichment (ex. F...
# 41  An identifier string that describes the sample...
# 42  The specific aspect of a mass spectrometer met...
# 43          The name of the acquisition software used
# 44                The version number of software used
# 45  The name of the search database (nr, SwissProt...
# 46    If "other" list the name of the search database
# 47  The name of the organization, project, or labo...
# 48    If "other" list the name of the database source
# 49  The frequency at which a spectrometer causes h...
# 50  If "other" is selected, list the name of the d...
# 51  If "other" is selected, list the custom modifi...
# 52  Name(s) of the enzyme used (possible values ar...
# 53     If "other" is selected, list the enzyme name.
# 54  Units of measure are Da or ppm (ex. "0.6 Da" o...
# 55  Units of measure are Da or ppm (ex. "0.6 Da" o...
#
#                                          Valid Values  Required  \
# 0                                                          True
# 1                                                          True
# 2                                                         False
# 3                                                          True
# 4                                                          True
# 5                                                         False
# 6                                                  \n      True
# 7                                                         False
# 8                                                  \n      True
# 9                                                         False
# 10                                                         True
# 11                                                         True
# 12                                                         True
# 13                                                         True
# 14                                                         True
# 15                                                         True
# 16                                                         True
# 17                                                         True
# 18  AminoxyTMT,\nDiART,\nDiLeu,\nGlyco-TMT,\nHydra...      True
# 19  Label-free protein level quantitation,\nLabel-...      True
# 20                                                        False
# 21                                                         True
# 22  Targeted,\nUntargeted\nUnknown,\nNot collected...      True
# 23  LTQ Orbitrap XL,\nOrbitrap Fusion,\nOrbitrap F...      True
# 24                                                         True
# 25  LTQ Orbitrap XL,\nOrbitrap Fusion,\nOrbitrap F...      True
# 26                                                         True
# 27                                                         True
# 28                                                         True
# 29                                                         True
# 30                                                         True
# 31                                                         True
# 32                                                         True
# 33                                                         True
# 34                                                         True
# 35  2-iodobenzoate,\nArg-C, Asp-N,\nAsp-N_ambic,\n...      True
# 36                                                        False
# 37                                                         True
# 38  Acetylome\nProteome,\nPhosphoproteome,\nGlycop...      True
# 39                                                        False
# 40                                                         True
# 41                                                         True
# 42  Unknown,\nNot collected,\nNot applicable,\nNot...      True
# 43  Unknown,\nNot collected,\nNot applicable,\nNot...      True
# 44                                                         True
# 45  MassBank of North America (MoNA),\nNIST17,\nMe...      True
# 46                                                         True
# 47  Other\nUnknown,\nNot collected,\nNot applicabl...      True
# 48                                                         True
# 49                                                 \n      True
# 50                                                         True
# 51                                                         True
# 52                                                         True
# 53                                                         True
# 54                                                         True
# 55                                                         True
#
#                                               Module  multivalue columnType  \
# 0                           Biospecimen,\nproteomics       False     string
# 1                                         proteomics       False     string
# 2                    proteomics,\nsampleType = other       False     string
# 3                                         proteomics        True     string
# 4                                         proteomics        True     string
# 5          proteomics,\nmeasurementTechnique = other        True     string
# 6                                         proteomics        True     string
# 7     proteomics,\ntechnologyPlatformVersion = other        True     string
# 8                                         proteomics        True     string
# 9              proteomics,\nplatformLocation = other        True     string
# 10                                        proteomics        True     string
# 11                                        proteomics        True     string
# 12                                        proteomics        True     string
# 13                                        proteomics        True     string
# 14                                        proteomics        True     string
# 15                                        proteomics        True     string
# 16                                        proteomics        True     string
# 17                                        proteomics        True     string
# 18                                        proteomics        True     string
# 19         proteomics\nlabelQuantiation = Label Free        True     string
# 20         proteomics\nlabelFreeQuantitation = other       False     string
# 21                                        proteomics        True     string
# 22                                        proteomics        True     string
# 23                              mass spec proteomics        True     string
# 24  mass spec proteomics,\nmsAnalyzerTypeMS1 = other        True     string
# 25                              mass spec proteomics        True     string
# 26  mass spec proteomics,\nmsAnalyzerTypeMS2 = other        True     string
# 27                                        proteomics        True     string
# 28             proteomics,\nmsAssayTechnique = other        True     string
# 29                                     proteomics,\n        True     string
# 30                proteomics,\nmsAnalyteType = other        True     string
# 31          proteomics,\nproteomicsAssayType = other        True     string
# 32            proteomics,\nmsInstrumentModel = other        True     string
# 33                                        proteomics        True     string
# 34              proteomics,\ndigestionMethod = other       False     string
# 35                                        proteomics        True     string
# 36                 proteomics digestionReagent=other       False     string
# 37                                        proteomics        True     string
# 38                                        proteomics        True     string
# 39                                        proteomics        True     string
# 40                                        proteomics        True     string
# 41                                        proteomics       False     number
# 42                              mass spec proteomics       False     string
# 43                              mass spec proteomics       False     string
# 44        mass spec proteomics,\nacquisitionSoftware       False     number
# 45                              mass spec proteomics       False     string
# 46       mass spec proteomics,\ndatabaseName = other       False     string
# 47                              mass spec proteomics       False     string
# 48     mass spec proteomics,\ndatabaseSource = other       False     string
# 49                              mass spec proteomics       False     number
# 50                      proteomics, dataFile = other       False     string
# 51       proteomics,\nmodificationParameters = other       False     string
# 52                                        proteomics        True     string
# 53               proteomics,\ncleavageAgents = other        True     string
# 54                                        proteomics       False     string
# 55                                        proteomics       False     string
#
#                                              Ontology  \
# 0                                    Sage Bionetworks
# 1                                 Sage Bionetworks,\n
# 2                                    Sage Bionetworks
# 3                              Proteomic Data Commons
# 4                                    Sage Bionetworks
# 5                                    Sage Bionetworks
# 6          http://purl.obolibrary.org/obo/NCIT_C45378
# 7                                    Sage Bionetworks
# 8                            Sage Bionetworks,\nDSLWG
# 9                                    Sage Bionetworks
# 10  Sage Bionetworks,\nDSLWG,\nProposed minimum me...
# 11                           Sage Bionetworks,\nDSLWG
# 12                         Proteomics Sample Metadata
# 13          http://purl.obolibrary.org/obo/MS_1001012
# 14                           Sage Bionetworks,\nDSLWG
# 15          http://purl.obolibrary.org/obo/MS_1001013
# 16  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 17                                   Sage Bionetworks
# 18  Sage Bionetworks,\nDSLWG,\nhttps://www.ebi.ac....
# 19                            Proteomics Data Commons
# 20                                   Sage Bionetworks
# 21                            Proteomics Data Commons
# 22                           Sage Bionetworks,\nDSLWG
# 23  Sage Bionetworks,\nProposed minimum metadata r...
# 24                                   Sage Bionetworks
# 25  Sage Bionetworks,\nProposed minimum metadata r...
# 26                                   Sage Bionetworks
# 27                           Sage Bionetworks,\nDSLWG
# 28                                   Sage Bionetworks
# 29  http://purl.obolibrary.org/obo/NCIT_C156434\nP...
# 30                                   Sage Bionetworks
# 31                                   Sage Bionetworks
# 32                                   Sage Bionetworks
# 33                           Sage Bionetworks,\nDSLWG
# 34                                   Sage Bionetworks
# 35                            Proteomics Data Commons
# 36                                   Sage Bionetworks
# 37  Sage Bionetworks,\nThe Proteomics Sample Metad...
# 38                             Proteomic Data Commons
# 39                             Proteomic Data Commons
# 40                             Proteomic Data Commons
# 41  Sage Bionetworks,\nThe Proteomics Sample Metad...
# 42  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 43          http://purl.obolibrary.org/obo/MS_1001455
# 44                           Sage Bionetworks,\nDSLWG
# 45          http://purl.obolibrary.org/obo/MS_1001013
# 46                                   Sage Bionetworks
# 47          http://purl.obolibrary.org/obo/MS_1001012
# 48                                   Sage Bionetworks
# 49                           Sage Bionetworks,\nDSLWG
# 50                                   Sage Bionetworks
# 51                                   Sage Bionetworks
# 52                         Proteomics Sample Metadata
# 53                                   Sage Bionetworks
# 54                         Proteomics Sample Metadata
# 55                         Proteomics Sample Metadata
#
#                                                 Notes
# 0             values unique to each data contributor)
# 1   A data contributor should be able to write in ...
# 2
# 3   A data contributor should be able to write in ...
# 4   A data contributor should be able to write in ...
# 5   A data contributor should be able to write in ...
# 6   A data contributor should be able to write in ...
# 7   A data contributor should be able to write in ...
# 8   A data contributor should be able to write in ...
# 9
# 10  A data contributor should be able to write in ...
# 11  A data contributor should be able to write in ...
# 12  A data contributor should be able to write in ...
# 13  A data contributor should be able to write in ...
# 14  A data contributor should be able to write in ...
# 15  A data contributor should be able to write in ...
# 16  Possible values are listed under modification ...
# 17  A data contributor should be able to write in ...
# 18
# 19
# 20
# 21  A data contributor should be able to write in ...
# 22
# 23
# 24
# 25
# 26
# 27  A data contributor should be able to write in ...
# 28
# 29  A data contributor should be able to write in ...
# 30  A data contributor should be able to write in ...
# 31
# 32
# 33  A data contributor should be able to write in ...
# 34  A data contributor should be able to write in ...
# 35
# 36
# 37  A data contributor should be able to write in ...
# 38  A data contributor should be able to write in ...
# 39
# 40  A data contributor should be able to write in ...
# 41  A data contributor should be able to write in ...
# 42  A data contributor should be able to write in ...
# 43  A data contributor should be able to write in ...
# 44  A data contributor should be able to write in ...
# 45  A data contributor should be able to write in ...
# 46  A data contributor should be able to write in ...
# 47  A data contributor should be able to write in ...
# 48  A data contributor should be able to write in ...
# 49  A data contributor should be able to write in ...
# 50
# 51
# 52  A data contributor should be able to write in ...
# 53
# 54
# 55

# %%
# string clean up
# Do not need to explicitly add "other" type values. Will add back later for list type attributes
p_df["Valid Values"] = (
    p_df["Valid Values"]
    .replace("n/a (unique to each data contributor)", "", regex=False)
    .str.replace(
        "Other|Unknown|Not collected|Not applicable|Not specified", "", regex=True
    )
    .str.strip(",")
)

# replace note type values
p_df["Valid Values"] = p_df["Valid Values"].apply(
    lambda x: ",".join(
        [y.strip() for y in x.split(",") if not bool(re.search("Possible values", y))]
    ).strip(",")
)

p_df = p_df.replace(r"\n", ",", regex=True).replace(r",,", ",", regex=True)

# %%
p_df
# Out:
#                              Attribute  \
# 0                           specimenID
# 1                           sampleType
# 2                    specifySampleType
# 3                       experimentType
# 4                 measurementTechnique
# 5          specifyMeasurementTechnique
# 6            technologyPlatformVersion
# 7               specifyPlatformVersion
# 8                     platformLocation
# 9              specifyPlatformLocation
# 10                     instrumentModel
# 11                  samplePrepProtocol
# 12                            dataFile
# 13                      databaseSource
# 14                     databaseWeblink
# 15                        databaseName
# 16              modificationParameters
# 17                  quantationStrategy
# 18                   labelQuantitation
# 19               labelFreeQuantitation
# 20        specifyLabelFreeQuantitation
# 21             isobaricLabelingReagent
# 22                            msTarget
# 23                   msAnalyzerTypeMS1
# 24            specifyMSAnalyzerTypeMS1
# 25                   msAnalyzerTypeMS2
# 26            specifyMSAnalyzerTypeMS2
# 27                    msAssayTechnique
# 28             specifyMSAssayTechnique
# 29                       msAnalyteType
# 30                specifyMSAnalyteType
# 31          specifyProteomicsAssayType
# 32            specifyMSInstrumentModel
# 33                     digestionMethod
# 34              specifyDigestionMethod
# 35                    digestionReagent
# 36             specifyDigestionReagent
# 37                  fractionIdentifier
# 38                  enrichmentStrategy
# 39           specifyEnrichmentStrategy
# 40                          enrichment
# 41                  fractionIdentifier
# 42                     acquisitionMode
# 43                 acquisitionSoftware
# 44           acquistionSoftwareVersion
# 45                        databaseName
# 46                 specifyDatabaseName
# 47                      databaseSource
# 48               specifyDatabaseSource
# 49               spectrometerFrequency
# 50                specifyOtherDataFile
# 51  specifyOtherModificationParameters
# 52                      cleavageAgents
# 53           specifyOtherCleavageAgent
# 54               fragmentMassTolerance
# 55              precursorMassTolerance
#
#                                           Description  \
# 0   Identifying string linked to a particular samp...
# 1   The type of sample collected or the term used ...
# 2      If "other" is selected list the type of sample
# 3   The type of experiment used.,Provide a value O...
# 4   The name of the measurement technique describi...
# 5   If "other" is selected list the name of the me...
# 6   The specific version (application, manufacture...
# 7    If "other" list the name of the platform version
# 8   The name of the laboratory, facility, vendor, ...
# 9   If "other" list the name of the platform location
# 10  The model of the instrument used.,Provide a va...
# 11  An internet address that may provide more deta...
# 12  Name of additional file(s) accompanying the da...
# 13  The name of the organization, project, or labo...
# 14  An internet address that may provide details o...
# 15  The name of the search database (nr, SwissProt...
# 16  Modification parameters for a search engine ru...
# 17  The general strategy used for differential ana...
# 18  Type of labeling used ,Provide a value OR prov...
# 19  Type of label-free data analysis strategy ,Pro...
# 20              If "other" is selected please specify
# 21  Reagent set used for isobaric labeling.,Exampl...
# 22  Specifies whether or not a specific molecule(s...
# 23  Describes the mass spectrometer analyzer used ...
# 24  If "other" is selected list the name of the ma...
# 25  Describes the mass spectrometer analyzer used ...
# 26  If "other" is selected list the name of the ma...
# 27  Specified the mass spectrometer technique used...
# 28  If "other" is selected list the name of the ma...
# 29  The type of biospecimen subjected to analysis ...
# 30               If "other" list the type of analyte
# 31  List the name of the type of peptide quantific...
# 32              List the name of the instrument model
# 33  The type of digestion (ex. in-solution, in-gel...
# 34              If "other" list the type of digestion
# 35          Enzymes or reagents used for digestion. ,
# 36  If "other" is selected specify the name of the...
# 37  Number of fractions in the experimental run,Pr...
# 38             Type of peptide or protein enrichment,
# 39            If "other" is selected specify the name
# 40  Protocol or reagent used for enrichment (ex. F...
# 41  An identifier string that describes the sample...
# 42  The specific aspect of a mass spectrometer met...
# 43          The name of the acquisition software used
# 44                The version number of software used
# 45  The name of the search database (nr, SwissProt...
# 46    If "other" list the name of the search database
# 47  The name of the organization, project, or labo...
# 48    If "other" list the name of the database source
# 49  The frequency at which a spectrometer causes h...
# 50  If "other" is selected, list the name of the d...
# 51  If "other" is selected, list the custom modifi...
# 52  Name(s) of the enzyme used (possible values ar...
# 53     If "other" is selected, list the enzyme name.
# 54  Units of measure are Da or ppm (ex. "0.6 Da" o...
# 55  Units of measure are Da or ppm (ex. "0.6 Da" o...
#
#                                          Valid Values  Required  \
# 0                                                          True
# 1                                                          True
# 2                                                         False
# 3                                                          True
# 4                                                          True
# 5                                                         False
# 6                                                          True
# 7                                                         False
# 8                                                          True
# 9                                                         False
# 10                                                         True
# 11                                                         True
# 12                                                         True
# 13                                                         True
# 14                                                         True
# 15                                                         True
# 16                                                         True
# 17                                                         True
# 18  AminoxyTMT,DiART,DiLeu,Glyco-TMT,Hydrazide TMT...      True
# 19  Label-free protein level quantitation,Label-fr...      True
# 20                                                        False
# 21                                                         True
# 22                                Targeted,Untargeted      True
# 23  LTQ Orbitrap XL,Orbitrap Fusion,Orbitrap Fusio...      True
# 24                                                         True
# 25  LTQ Orbitrap XL,Orbitrap Fusion,Orbitrap Fusio...      True
# 26                                                         True
# 27                                                         True
# 28                                                         True
# 29                                                         True
# 30                                                         True
# 31                                                         True
# 32                                                         True
# 33                                                         True
# 34                                                         True
# 35  2-iodobenzoate,Arg-C,Asp-N,Asp-N_ambic,Chymotr...      True
# 36                                                        False
# 37                                                         True
# 38  Acetylome,Proteome,Phosphoproteome,Glycoproteo...      True
# 39                                                        False
# 40                                                         True
# 41                                                         True
# 42                                                         True
# 43                                                         True
# 44                                                         True
# 45  MassBank of North America (MoNA),NIST17,Metlin...      True
# 46                                                         True
# 47                                                         True
# 48                                                         True
# 49                                                         True
# 50                                                         True
# 51                                                         True
# 52                                                         True
# 53                                                         True
# 54                                                         True
# 55                                                         True
#
#                                             Module  multivalue columnType  \
# 0                           Biospecimen,proteomics       False     string
# 1                                       proteomics       False     string
# 2                    proteomics,sampleType = other       False     string
# 3                                       proteomics        True     string
# 4                                       proteomics        True     string
# 5          proteomics,measurementTechnique = other        True     string
# 6                                       proteomics        True     string
# 7     proteomics,technologyPlatformVersion = other        True     string
# 8                                       proteomics        True     string
# 9              proteomics,platformLocation = other        True     string
# 10                                      proteomics        True     string
# 11                                      proteomics        True     string
# 12                                      proteomics        True     string
# 13                                      proteomics        True     string
# 14                                      proteomics        True     string
# 15                                      proteomics        True     string
# 16                                      proteomics        True     string
# 17                                      proteomics        True     string
# 18                                      proteomics        True     string
# 19        proteomics,labelQuantiation = Label Free        True     string
# 20        proteomics,labelFreeQuantitation = other       False     string
# 21                                      proteomics        True     string
# 22                                      proteomics        True     string
# 23                            mass spec proteomics        True     string
# 24  mass spec proteomics,msAnalyzerTypeMS1 = other        True     string
# 25                            mass spec proteomics        True     string
# 26  mass spec proteomics,msAnalyzerTypeMS2 = other        True     string
# 27                                      proteomics        True     string
# 28             proteomics,msAssayTechnique = other        True     string
# 29                                     proteomics,        True     string
# 30                proteomics,msAnalyteType = other        True     string
# 31          proteomics,proteomicsAssayType = other        True     string
# 32            proteomics,msInstrumentModel = other        True     string
# 33                                      proteomics        True     string
# 34              proteomics,digestionMethod = other       False     string
# 35                                      proteomics        True     string
# 36               proteomics digestionReagent=other       False     string
# 37                                      proteomics        True     string
# 38                                      proteomics        True     string
# 39                                      proteomics        True     string
# 40                                      proteomics        True     string
# 41                                      proteomics       False     number
# 42                            mass spec proteomics       False     string
# 43                            mass spec proteomics       False     string
# 44        mass spec proteomics,acquisitionSoftware       False     number
# 45                            mass spec proteomics       False     string
# 46       mass spec proteomics,databaseName = other       False     string
# 47                            mass spec proteomics       False     string
# 48     mass spec proteomics,databaseSource = other       False     string
# 49                            mass spec proteomics       False     number
# 50                    proteomics, dataFile = other       False     string
# 51       proteomics,modificationParameters = other       False     string
# 52                                      proteomics        True     string
# 53               proteomics,cleavageAgents = other        True     string
# 54                                      proteomics       False     string
# 55                                      proteomics       False     string
#
#                                              Ontology  \
# 0                                    Sage Bionetworks
# 1                                   Sage Bionetworks,
# 2                                    Sage Bionetworks
# 3                              Proteomic Data Commons
# 4                                    Sage Bionetworks
# 5                                    Sage Bionetworks
# 6          http://purl.obolibrary.org/obo/NCIT_C45378
# 7                                    Sage Bionetworks
# 8                              Sage Bionetworks,DSLWG
# 9                                    Sage Bionetworks
# 10  Sage Bionetworks,DSLWG,Proposed minimum metada...
# 11                             Sage Bionetworks,DSLWG
# 12                         Proteomics Sample Metadata
# 13          http://purl.obolibrary.org/obo/MS_1001012
# 14                             Sage Bionetworks,DSLWG
# 15          http://purl.obolibrary.org/obo/MS_1001013
# 16  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 17                                   Sage Bionetworks
# 18  Sage Bionetworks,DSLWG,https://www.ebi.ac.uk/o...
# 19                            Proteomics Data Commons
# 20                                   Sage Bionetworks
# 21                            Proteomics Data Commons
# 22                             Sage Bionetworks,DSLWG
# 23  Sage Bionetworks,Proposed minimum metadata rel...
# 24                                   Sage Bionetworks
# 25  Sage Bionetworks,Proposed minimum metadata rel...
# 26                                   Sage Bionetworks
# 27                             Sage Bionetworks,DSLWG
# 28                                   Sage Bionetworks
# 29  http://purl.obolibrary.org/obo/NCIT_C156434,Pr...
# 30                                   Sage Bionetworks
# 31                                   Sage Bionetworks
# 32                                   Sage Bionetworks
# 33                             Sage Bionetworks,DSLWG
# 34                                   Sage Bionetworks
# 35                            Proteomics Data Commons
# 36                                   Sage Bionetworks
# 37  Sage Bionetworks,The Proteomics Sample Metadat...
# 38                             Proteomic Data Commons
# 39                             Proteomic Data Commons
# 40                             Proteomic Data Commons
# 41  Sage Bionetworks,The Proteomics Sample Metadat...
# 42  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 43          http://purl.obolibrary.org/obo/MS_1001455
# 44                             Sage Bionetworks,DSLWG
# 45          http://purl.obolibrary.org/obo/MS_1001013
# 46                                   Sage Bionetworks
# 47          http://purl.obolibrary.org/obo/MS_1001012
# 48                                   Sage Bionetworks
# 49                             Sage Bionetworks,DSLWG
# 50                                   Sage Bionetworks
# 51                                   Sage Bionetworks
# 52                         Proteomics Sample Metadata
# 53                                   Sage Bionetworks
# 54                         Proteomics Sample Metadata
# 55                         Proteomics Sample Metadata
#
#                                                 Notes
# 0             values unique to each data contributor)
# 1   A data contributor should be able to write in ...
# 2
# 3   A data contributor should be able to write in ...
# 4   A data contributor should be able to write in ...
# 5   A data contributor should be able to write in ...
# 6   A data contributor should be able to write in ...
# 7   A data contributor should be able to write in ...
# 8   A data contributor should be able to write in ...
# 9
# 10  A data contributor should be able to write in ...
# 11  A data contributor should be able to write in ...
# 12  A data contributor should be able to write in ...
# 13  A data contributor should be able to write in ...
# 14  A data contributor should be able to write in ...
# 15  A data contributor should be able to write in ...
# 16  Possible values are listed under modification ...
# 17  A data contributor should be able to write in ...
# 18
# 19
# 20
# 21  A data contributor should be able to write in ...
# 22
# 23
# 24
# 25
# 26
# 27  A data contributor should be able to write in ...
# 28
# 29  A data contributor should be able to write in ...
# 30  A data contributor should be able to write in ...
# 31
# 32
# 33  A data contributor should be able to write in ...
# 34  A data contributor should be able to write in ...
# 35
# 36
# 37  A data contributor should be able to write in ...
# 38  A data contributor should be able to write in ...
# 39
# 40  A data contributor should be able to write in ...
# 41  A data contributor should be able to write in ...
# 42  A data contributor should be able to write in ...
# 43  A data contributor should be able to write in ...
# 44  A data contributor should be able to write in ...
# 45  A data contributor should be able to write in ...
# 46  A data contributor should be able to write in ...
# 47  A data contributor should be able to write in ...
# 48  A data contributor should be able to write in ...
# 49  A data contributor should be able to write in ...
# 50
# 51
# 52  A data contributor should be able to write in ...
# 53
# 54
# 55

# %%
p_df["Required"] = (
    p_df["Required"].astype(str)
    .apply(lambda x: False if bool(re.search("f", x)) else True)
    .astype(bool)
)

p_df = p_df.drop(columns=["multivalue"])

p_df
# Out:
#                              Attribute  \
# 0                           specimenID
# 1                           sampleType
# 2                    specifySampleType
# 3                       experimentType
# 4                 measurementTechnique
# 5          specifyMeasurementTechnique
# 6            technologyPlatformVersion
# 7               specifyPlatformVersion
# 8                     platformLocation
# 9              specifyPlatformLocation
# 10                     instrumentModel
# 11                  samplePrepProtocol
# 12                            dataFile
# 13                      databaseSource
# 14                     databaseWeblink
# 15                        databaseName
# 16              modificationParameters
# 17                  quantationStrategy
# 18                   labelQuantitation
# 19               labelFreeQuantitation
# 20        specifyLabelFreeQuantitation
# 21             isobaricLabelingReagent
# 22                            msTarget
# 23                   msAnalyzerTypeMS1
# 24            specifyMSAnalyzerTypeMS1
# 25                   msAnalyzerTypeMS2
# 26            specifyMSAnalyzerTypeMS2
# 27                    msAssayTechnique
# 28             specifyMSAssayTechnique
# 29                       msAnalyteType
# 30                specifyMSAnalyteType
# 31          specifyProteomicsAssayType
# 32            specifyMSInstrumentModel
# 33                     digestionMethod
# 34              specifyDigestionMethod
# 35                    digestionReagent
# 36             specifyDigestionReagent
# 37                  fractionIdentifier
# 38                  enrichmentStrategy
# 39           specifyEnrichmentStrategy
# 40                          enrichment
# 41                  fractionIdentifier
# 42                     acquisitionMode
# 43                 acquisitionSoftware
# 44           acquistionSoftwareVersion
# 45                        databaseName
# 46                 specifyDatabaseName
# 47                      databaseSource
# 48               specifyDatabaseSource
# 49               spectrometerFrequency
# 50                specifyOtherDataFile
# 51  specifyOtherModificationParameters
# 52                      cleavageAgents
# 53           specifyOtherCleavageAgent
# 54               fragmentMassTolerance
# 55              precursorMassTolerance
#
#                                           Description  \
# 0   Identifying string linked to a particular samp...
# 1   The type of sample collected or the term used ...
# 2      If "other" is selected list the type of sample
# 3   The type of experiment used.,Provide a value O...
# 4   The name of the measurement technique describi...
# 5   If "other" is selected list the name of the me...
# 6   The specific version (application, manufacture...
# 7    If "other" list the name of the platform version
# 8   The name of the laboratory, facility, vendor, ...
# 9   If "other" list the name of the platform location
# 10  The model of the instrument used.,Provide a va...
# 11  An internet address that may provide more deta...
# 12  Name of additional file(s) accompanying the da...
# 13  The name of the organization, project, or labo...
# 14  An internet address that may provide details o...
# 15  The name of the search database (nr, SwissProt...
# 16  Modification parameters for a search engine ru...
# 17  The general strategy used for differential ana...
# 18  Type of labeling used ,Provide a value OR prov...
# 19  Type of label-free data analysis strategy ,Pro...
# 20              If "other" is selected please specify
# 21  Reagent set used for isobaric labeling.,Exampl...
# 22  Specifies whether or not a specific molecule(s...
# 23  Describes the mass spectrometer analyzer used ...
# 24  If "other" is selected list the name of the ma...
# 25  Describes the mass spectrometer analyzer used ...
# 26  If "other" is selected list the name of the ma...
# 27  Specified the mass spectrometer technique used...
# 28  If "other" is selected list the name of the ma...
# 29  The type of biospecimen subjected to analysis ...
# 30               If "other" list the type of analyte
# 31  List the name of the type of peptide quantific...
# 32              List the name of the instrument model
# 33  The type of digestion (ex. in-solution, in-gel...
# 34              If "other" list the type of digestion
# 35          Enzymes or reagents used for digestion. ,
# 36  If "other" is selected specify the name of the...
# 37  Number of fractions in the experimental run,Pr...
# 38             Type of peptide or protein enrichment,
# 39            If "other" is selected specify the name
# 40  Protocol or reagent used for enrichment (ex. F...
# 41  An identifier string that describes the sample...
# 42  The specific aspect of a mass spectrometer met...
# 43          The name of the acquisition software used
# 44                The version number of software used
# 45  The name of the search database (nr, SwissProt...
# 46    If "other" list the name of the search database
# 47  The name of the organization, project, or labo...
# 48    If "other" list the name of the database source
# 49  The frequency at which a spectrometer causes h...
# 50  If "other" is selected, list the name of the d...
# 51  If "other" is selected, list the custom modifi...
# 52  Name(s) of the enzyme used (possible values ar...
# 53     If "other" is selected, list the enzyme name.
# 54  Units of measure are Da or ppm (ex. "0.6 Da" o...
# 55  Units of measure are Da or ppm (ex. "0.6 Da" o...
#
#                                          Valid Values  Required  \
# 0                                                          True
# 1                                                          True
# 2                                                          True
# 3                                                          True
# 4                                                          True
# 5                                                          True
# 6                                                          True
# 7                                                          True
# 8                                                          True
# 9                                                          True
# 10                                                         True
# 11                                                         True
# 12                                                         True
# 13                                                         True
# 14                                                         True
# 15                                                         True
# 16                                                         True
# 17                                                         True
# 18  AminoxyTMT,DiART,DiLeu,Glyco-TMT,Hydrazide TMT...      True
# 19  Label-free protein level quantitation,Label-fr...      True
# 20                                                         True
# 21                                                         True
# 22                                Targeted,Untargeted      True
# 23  LTQ Orbitrap XL,Orbitrap Fusion,Orbitrap Fusio...      True
# 24                                                         True
# 25  LTQ Orbitrap XL,Orbitrap Fusion,Orbitrap Fusio...      True
# 26                                                         True
# 27                                                         True
# 28                                                         True
# 29                                                         True
# 30                                                         True
# 31                                                         True
# 32                                                         True
# 33                                                         True
# 34                                                         True
# 35  2-iodobenzoate,Arg-C,Asp-N,Asp-N_ambic,Chymotr...      True
# 36                                                         True
# 37                                                         True
# 38  Acetylome,Proteome,Phosphoproteome,Glycoproteo...      True
# 39                                                         True
# 40                                                         True
# 41                                                         True
# 42                                                         True
# 43                                                         True
# 44                                                         True
# 45  MassBank of North America (MoNA),NIST17,Metlin...      True
# 46                                                         True
# 47                                                         True
# 48                                                         True
# 49                                                         True
# 50                                                         True
# 51                                                         True
# 52                                                         True
# 53                                                         True
# 54                                                         True
# 55                                                         True
#
#                                             Module columnType  \
# 0                           Biospecimen,proteomics     string
# 1                                       proteomics     string
# 2                    proteomics,sampleType = other     string
# 3                                       proteomics     string
# 4                                       proteomics     string
# 5          proteomics,measurementTechnique = other     string
# 6                                       proteomics     string
# 7     proteomics,technologyPlatformVersion = other     string
# 8                                       proteomics     string
# 9              proteomics,platformLocation = other     string
# 10                                      proteomics     string
# 11                                      proteomics     string
# 12                                      proteomics     string
# 13                                      proteomics     string
# 14                                      proteomics     string
# 15                                      proteomics     string
# 16                                      proteomics     string
# 17                                      proteomics     string
# 18                                      proteomics     string
# 19        proteomics,labelQuantiation = Label Free     string
# 20        proteomics,labelFreeQuantitation = other     string
# 21                                      proteomics     string
# 22                                      proteomics     string
# 23                            mass spec proteomics     string
# 24  mass spec proteomics,msAnalyzerTypeMS1 = other     string
# 25                            mass spec proteomics     string
# 26  mass spec proteomics,msAnalyzerTypeMS2 = other     string
# 27                                      proteomics     string
# 28             proteomics,msAssayTechnique = other     string
# 29                                     proteomics,     string
# 30                proteomics,msAnalyteType = other     string
# 31          proteomics,proteomicsAssayType = other     string
# 32            proteomics,msInstrumentModel = other     string
# 33                                      proteomics     string
# 34              proteomics,digestionMethod = other     string
# 35                                      proteomics     string
# 36               proteomics digestionReagent=other     string
# 37                                      proteomics     string
# 38                                      proteomics     string
# 39                                      proteomics     string
# 40                                      proteomics     string
# 41                                      proteomics     number
# 42                            mass spec proteomics     string
# 43                            mass spec proteomics     string
# 44        mass spec proteomics,acquisitionSoftware     number
# 45                            mass spec proteomics     string
# 46       mass spec proteomics,databaseName = other     string
# 47                            mass spec proteomics     string
# 48     mass spec proteomics,databaseSource = other     string
# 49                            mass spec proteomics     number
# 50                    proteomics, dataFile = other     string
# 51       proteomics,modificationParameters = other     string
# 52                                      proteomics     string
# 53               proteomics,cleavageAgents = other     string
# 54                                      proteomics     string
# 55                                      proteomics     string
#
#                                              Ontology  \
# 0                                    Sage Bionetworks
# 1                                   Sage Bionetworks,
# 2                                    Sage Bionetworks
# 3                              Proteomic Data Commons
# 4                                    Sage Bionetworks
# 5                                    Sage Bionetworks
# 6          http://purl.obolibrary.org/obo/NCIT_C45378
# 7                                    Sage Bionetworks
# 8                              Sage Bionetworks,DSLWG
# 9                                    Sage Bionetworks
# 10  Sage Bionetworks,DSLWG,Proposed minimum metada...
# 11                             Sage Bionetworks,DSLWG
# 12                         Proteomics Sample Metadata
# 13          http://purl.obolibrary.org/obo/MS_1001012
# 14                             Sage Bionetworks,DSLWG
# 15          http://purl.obolibrary.org/obo/MS_1001013
# 16  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 17                                   Sage Bionetworks
# 18  Sage Bionetworks,DSLWG,https://www.ebi.ac.uk/o...
# 19                            Proteomics Data Commons
# 20                                   Sage Bionetworks
# 21                            Proteomics Data Commons
# 22                             Sage Bionetworks,DSLWG
# 23  Sage Bionetworks,Proposed minimum metadata rel...
# 24                                   Sage Bionetworks
# 25  Sage Bionetworks,Proposed minimum metadata rel...
# 26                                   Sage Bionetworks
# 27                             Sage Bionetworks,DSLWG
# 28                                   Sage Bionetworks
# 29  http://purl.obolibrary.org/obo/NCIT_C156434,Pr...
# 30                                   Sage Bionetworks
# 31                                   Sage Bionetworks
# 32                                   Sage Bionetworks
# 33                             Sage Bionetworks,DSLWG
# 34                                   Sage Bionetworks
# 35                            Proteomics Data Commons
# 36                                   Sage Bionetworks
# 37  Sage Bionetworks,The Proteomics Sample Metadat...
# 38                             Proteomic Data Commons
# 39                             Proteomic Data Commons
# 40                             Proteomic Data Commons
# 41  Sage Bionetworks,The Proteomics Sample Metadat...
# 42  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 43          http://purl.obolibrary.org/obo/MS_1001455
# 44                             Sage Bionetworks,DSLWG
# 45          http://purl.obolibrary.org/obo/MS_1001013
# 46                                   Sage Bionetworks
# 47          http://purl.obolibrary.org/obo/MS_1001012
# 48                                   Sage Bionetworks
# 49                             Sage Bionetworks,DSLWG
# 50                                   Sage Bionetworks
# 51                                   Sage Bionetworks
# 52                         Proteomics Sample Metadata
# 53                                   Sage Bionetworks
# 54                         Proteomics Sample Metadata
# 55                         Proteomics Sample Metadata
#
#                                                 Notes
# 0             values unique to each data contributor)
# 1   A data contributor should be able to write in ...
# 2
# 3   A data contributor should be able to write in ...
# 4   A data contributor should be able to write in ...
# 5   A data contributor should be able to write in ...
# 6   A data contributor should be able to write in ...
# 7   A data contributor should be able to write in ...
# 8   A data contributor should be able to write in ...
# 9
# 10  A data contributor should be able to write in ...
# 11  A data contributor should be able to write in ...
# 12  A data contributor should be able to write in ...
# 13  A data contributor should be able to write in ...
# 14  A data contributor should be able to write in ...
# 15  A data contributor should be able to write in ...
# 16  Possible values are listed under modification ...
# 17  A data contributor should be able to write in ...
# 18
# 19
# 20
# 21  A data contributor should be able to write in ...
# 22
# 23
# 24
# 25
# 26
# 27  A data contributor should be able to write in ...
# 28
# 29  A data contributor should be able to write in ...
# 30  A data contributor should be able to write in ...
# 31
# 32
# 33  A data contributor should be able to write in ...
# 34  A data contributor should be able to write in ...
# 35
# 36
# 37  A data contributor should be able to write in ...
# 38  A data contributor should be able to write in ...
# 39
# 40  A data contributor should be able to write in ...
# 41  A data contributor should be able to write in ...
# 42  A data contributor should be able to write in ...
# 43  A data contributor should be able to write in ...
# 44  A data contributor should be able to write in ...
# 45  A data contributor should be able to write in ...
# 46  A data contributor should be able to write in ...
# 47  A data contributor should be able to write in ...
# 48  A data contributor should be able to write in ...
# 49  A data contributor should be able to write in ...
# 50
# 51
# 52  A data contributor should be able to write in ...
# 53
# 54
# 55

# %%
# split the values out and create new attributes to add to the model.
# These will be the intermediate attributes that will allow the original column i.e. SampleType to then have the user fill in specifySampleType
p_df_others = p_df.loc[p_df["Module"].str.contains("=", na=False)].copy(deep=True)
p_df_others["others"] = (
    p_df_others["Module"]
    .str.split(",")
    .apply(lambda x: "".join([y.strip() for y in x if bool(re.search("=", y))]))
)

# in case there are multiple equals signs
p_df_others = p_df_others.explode("others")

p_df_others["Parent"] = (
    p_df_others["others"].str.split("=").apply(lambda x: x[0].strip())
)
p_df_others["OtherValue"] = (
    p_df_others["others"].str.split("=").apply(lambda x: x[1].strip())
)

p_df_others["others"] = (
    p_df_others["others"]
    .str.split("=")
    .apply(lambda x: x[1].strip().capitalize() + x[0][0].upper() + x[0][1:])
)
# Swap others -> Attribute and Attribute -> DependsOn
p_df_others = p_df_others.rename(
    columns={"Attribute": "DependsOn", "others": "Attribute"}
)
p_df_others["Required"] = False
p_df_others["Module"] = "Other"
p_df_others["Valid Values"] = ""
p_df_others
# Out:
#                              DependsOn  \
# 2                    specifySampleType
# 5          specifyMeasurementTechnique
# 7               specifyPlatformVersion
# 9              specifyPlatformLocation
# 19               labelFreeQuantitation
# 20        specifyLabelFreeQuantitation
# 24            specifyMSAnalyzerTypeMS1
# 26            specifyMSAnalyzerTypeMS2
# 28             specifyMSAssayTechnique
# 30                specifyMSAnalyteType
# 31          specifyProteomicsAssayType
# 32            specifyMSInstrumentModel
# 34              specifyDigestionMethod
# 36             specifyDigestionReagent
# 46                 specifyDatabaseName
# 48               specifyDatabaseSource
# 50                specifyOtherDataFile
# 51  specifyOtherModificationParameters
# 53           specifyOtherCleavageAgent
#
#                                           Description Valid Values  Required  \
# 2      If "other" is selected list the type of sample                  False
# 5   If "other" is selected list the name of the me...                  False
# 7    If "other" list the name of the platform version                  False
# 9   If "other" list the name of the platform location                  False
# 19  Type of label-free data analysis strategy ,Pro...                  False
# 20              If "other" is selected please specify                  False
# 24  If "other" is selected list the name of the ma...                  False
# 26  If "other" is selected list the name of the ma...                  False
# 28  If "other" is selected list the name of the ma...                  False
# 30               If "other" list the type of analyte                   False
# 31  List the name of the type of peptide quantific...                  False
# 32              List the name of the instrument model                  False
# 34              If "other" list the type of digestion                  False
# 36  If "other" is selected specify the name of the...                  False
# 46    If "other" list the name of the search database                  False
# 48    If "other" list the name of the database source                  False
# 50  If "other" is selected, list the name of the d...                  False
# 51  If "other" is selected, list the custom modifi...                  False
# 53     If "other" is selected, list the enzyme name.                   False
#
#    Module columnType                 Ontology  \
# 2   Other     string         Sage Bionetworks
# 5   Other     string         Sage Bionetworks
# 7   Other     string         Sage Bionetworks
# 9   Other     string         Sage Bionetworks
# 19  Other     string  Proteomics Data Commons
# 20  Other     string         Sage Bionetworks
# 24  Other     string         Sage Bionetworks
# 26  Other     string         Sage Bionetworks
# 28  Other     string         Sage Bionetworks
# 30  Other     string         Sage Bionetworks
# 31  Other     string         Sage Bionetworks
# 32  Other     string         Sage Bionetworks
# 34  Other     string         Sage Bionetworks
# 36  Other     string         Sage Bionetworks
# 46  Other     string         Sage Bionetworks
# 48  Other     string         Sage Bionetworks
# 50  Other     string         Sage Bionetworks
# 51  Other     string         Sage Bionetworks
# 53  Other     string         Sage Bionetworks
#
#                                                 Notes  \
# 2
# 5   A data contributor should be able to write in ...
# 7   A data contributor should be able to write in ...
# 9
# 19
# 20
# 24
# 26
# 28
# 30  A data contributor should be able to write in ...
# 31
# 32
# 34  A data contributor should be able to write in ...
# 36
# 46  A data contributor should be able to write in ...
# 48  A data contributor should be able to write in ...
# 50
# 51
# 53
#
#                            Attribute                       Parent  OtherValue
# 2                   OtherSampleType                    sampleType       other
# 5         OtherMeasurementTechnique          measurementTechnique       other
# 7    OtherTechnologyPlatformVersion     technologyPlatformVersion       other
# 9             OtherPlatformLocation              platformLocation       other
# 19       Label freeLabelQuantiation              labelQuantiation  Label Free
# 20       OtherLabelFreeQuantitation         labelFreeQuantitation       other
# 24           OtherMsAnalyzerTypeMS1             msAnalyzerTypeMS1       other
# 26           OtherMsAnalyzerTypeMS2             msAnalyzerTypeMS2       other
# 28            OtherMsAssayTechnique              msAssayTechnique       other
# 30               OtherMsAnalyteType                 msAnalyteType       other
# 31         OtherProteomicsAssayType           proteomicsAssayType       other
# 32           OtherMsInstrumentModel             msInstrumentModel       other
# 34             OtherDigestionMethod               digestionMethod       other
# 36  OtherProteomics digestionReagent  proteomics digestionReagent       other
# 46                OtherDatabaseName                  databaseName       other
# 48              OtherDatabaseSource                databaseSource       other
# 50                    OtherDataFile                      dataFile       other
# 51      OtherModificationParameters        modificationParameters       other
# 53              OtherCleavageAgents                cleavageAgents       other

# %%
# Assign data modeling variables
p_df_others = p_df_others.assign(
    Description=p_df_others["DependsOn"].apply(
        lambda x: f"When {re.sub('specify|other', '',x, flags=re.IGNORECASE)} = `other`, add your custom value to the cell"
    ),
    columnType="string",
    Ontology="Sage Bionetworks",
    Required=False,
    Properties="ValidValue",
)

# %%
p_df_others
# Out:
#                              DependsOn  \
# 2                    specifySampleType
# 5          specifyMeasurementTechnique
# 7               specifyPlatformVersion
# 9              specifyPlatformLocation
# 19               labelFreeQuantitation
# 20        specifyLabelFreeQuantitation
# 24            specifyMSAnalyzerTypeMS1
# 26            specifyMSAnalyzerTypeMS2
# 28             specifyMSAssayTechnique
# 30                specifyMSAnalyteType
# 31          specifyProteomicsAssayType
# 32            specifyMSInstrumentModel
# 34              specifyDigestionMethod
# 36             specifyDigestionReagent
# 46                 specifyDatabaseName
# 48               specifyDatabaseSource
# 50                specifyOtherDataFile
# 51  specifyOtherModificationParameters
# 53           specifyOtherCleavageAgent
#
#                                           Description Valid Values  Required  \
# 2   When SampleType = `other`, add your custom val...                  False
# 5   When MeasurementTechnique = `other`, add your ...                  False
# 7   When PlatformVersion = `other`, add your custo...                  False
# 9   When PlatformLocation = `other`, add your cust...                  False
# 19  When labelFreeQuantitation = `other`, add your...                  False
# 20  When LabelFreeQuantitation = `other`, add your...                  False
# 24  When MSAnalyzerTypeMS1 = `other`, add your cus...                  False
# 26  When MSAnalyzerTypeMS2 = `other`, add your cus...                  False
# 28  When MSAssayTechnique = `other`, add your cust...                  False
# 30  When MSAnalyteType = `other`, add your custom ...                  False
# 31  When ProteomicsAssayType = `other`, add your c...                  False
# 32  When MSInstrumentModel = `other`, add your cus...                  False
# 34  When DigestionMethod = `other`, add your custo...                  False
# 36  When DigestionReagent = `other`, add your cust...                  False
# 46  When DatabaseName = `other`, add your custom v...                  False
# 48  When DatabaseSource = `other`, add your custom...                  False
# 50  When DataFile = `other`, add your custom value...                  False
# 51  When ModificationParameters = `other`, add you...                  False
# 53  When CleavageAgent = `other`, add your custom ...                  False
#
#    Module columnType          Ontology  \
# 2   Other     string  Sage Bionetworks
# 5   Other     string  Sage Bionetworks
# 7   Other     string  Sage Bionetworks
# 9   Other     string  Sage Bionetworks
# 19  Other     string  Sage Bionetworks
# 20  Other     string  Sage Bionetworks
# 24  Other     string  Sage Bionetworks
# 26  Other     string  Sage Bionetworks
# 28  Other     string  Sage Bionetworks
# 30  Other     string  Sage Bionetworks
# 31  Other     string  Sage Bionetworks
# 32  Other     string  Sage Bionetworks
# 34  Other     string  Sage Bionetworks
# 36  Other     string  Sage Bionetworks
# 46  Other     string  Sage Bionetworks
# 48  Other     string  Sage Bionetworks
# 50  Other     string  Sage Bionetworks
# 51  Other     string  Sage Bionetworks
# 53  Other     string  Sage Bionetworks
#
#                                                 Notes  \
# 2
# 5   A data contributor should be able to write in ...
# 7   A data contributor should be able to write in ...
# 9
# 19
# 20
# 24
# 26
# 28
# 30  A data contributor should be able to write in ...
# 31
# 32
# 34  A data contributor should be able to write in ...
# 36
# 46  A data contributor should be able to write in ...
# 48  A data contributor should be able to write in ...
# 50
# 51
# 53
#
#                            Attribute                       Parent  OtherValue  \
# 2                   OtherSampleType                    sampleType       other
# 5         OtherMeasurementTechnique          measurementTechnique       other
# 7    OtherTechnologyPlatformVersion     technologyPlatformVersion       other
# 9             OtherPlatformLocation              platformLocation       other
# 19       Label freeLabelQuantiation              labelQuantiation  Label Free
# 20       OtherLabelFreeQuantitation         labelFreeQuantitation       other
# 24           OtherMsAnalyzerTypeMS1             msAnalyzerTypeMS1       other
# 26           OtherMsAnalyzerTypeMS2             msAnalyzerTypeMS2       other
# 28            OtherMsAssayTechnique              msAssayTechnique       other
# 30               OtherMsAnalyteType                 msAnalyteType       other
# 31         OtherProteomicsAssayType           proteomicsAssayType       other
# 32           OtherMsInstrumentModel             msInstrumentModel       other
# 34             OtherDigestionMethod               digestionMethod       other
# 36  OtherProteomics digestionReagent  proteomics digestionReagent       other
# 46                OtherDatabaseName                  databaseName       other
# 48              OtherDatabaseSource                databaseSource       other
# 50                    OtherDataFile                      dataFile       other
# 51      OtherModificationParameters        modificationParameters       other
# 53              OtherCleavageAgents                cleavageAgents       other
#
#     Properties
# 2   ValidValue
# 5   ValidValue
# 7   ValidValue
# 9   ValidValue
# 19  ValidValue
# 20  ValidValue
# 24  ValidValue
# 26  ValidValue
# 28  ValidValue
# 30  ValidValue
# 31  ValidValue
# 32  ValidValue
# 34  ValidValue
# 36  ValidValue
# 46  ValidValue
# 48  ValidValue
# 50  ValidValue
# 51  ValidValue
# 53  ValidValue

# %%
# Add other attributes to the list of valid values
p_df.loc[~p_df.replace("", np.nan)["Valid Values"].isna(), 'Valid Values'] = p_df.loc[~p_df.replace("", np.nan)["Valid Values"].isna()].apply(lambda x: re.sub(',+', ',', ','.join(x['Valid Values'] + ',' + p_df_others.loc[p_df_others['Parent'] == x['Attribute'], 'Attribute'].values)), axis = 1)

# %%
# Last bit of cleanup
p_df["Properties"] = "ManifestColumn"
p_df["Module"] = p_df["Attribute"].apply(
    lambda x: "Other" if bool(re.search("specify", x)) else "Metadata"
)

# %%
p_df
# Out:
#                              Attribute  \
# 0                           specimenID
# 1                           sampleType
# 2                    specifySampleType
# 3                       experimentType
# 4                 measurementTechnique
# 5          specifyMeasurementTechnique
# 6            technologyPlatformVersion
# 7               specifyPlatformVersion
# 8                     platformLocation
# 9              specifyPlatformLocation
# 10                     instrumentModel
# 11                  samplePrepProtocol
# 12                            dataFile
# 13                      databaseSource
# 14                     databaseWeblink
# 15                        databaseName
# 16              modificationParameters
# 17                  quantationStrategy
# 18                   labelQuantitation
# 19               labelFreeQuantitation
# 20        specifyLabelFreeQuantitation
# 21             isobaricLabelingReagent
# 22                            msTarget
# 23                   msAnalyzerTypeMS1
# 24            specifyMSAnalyzerTypeMS1
# 25                   msAnalyzerTypeMS2
# 26            specifyMSAnalyzerTypeMS2
# 27                    msAssayTechnique
# 28             specifyMSAssayTechnique
# 29                       msAnalyteType
# 30                specifyMSAnalyteType
# 31          specifyProteomicsAssayType
# 32            specifyMSInstrumentModel
# 33                     digestionMethod
# 34              specifyDigestionMethod
# 35                    digestionReagent
# 36             specifyDigestionReagent
# 37                  fractionIdentifier
# 38                  enrichmentStrategy
# 39           specifyEnrichmentStrategy
# 40                          enrichment
# 41                  fractionIdentifier
# 42                     acquisitionMode
# 43                 acquisitionSoftware
# 44           acquistionSoftwareVersion
# 45                        databaseName
# 46                 specifyDatabaseName
# 47                      databaseSource
# 48               specifyDatabaseSource
# 49               spectrometerFrequency
# 50                specifyOtherDataFile
# 51  specifyOtherModificationParameters
# 52                      cleavageAgents
# 53           specifyOtherCleavageAgent
# 54               fragmentMassTolerance
# 55              precursorMassTolerance
#
#                                           Description  \
# 0   Identifying string linked to a particular samp...
# 1   The type of sample collected or the term used ...
# 2      If "other" is selected list the type of sample
# 3   The type of experiment used.,Provide a value O...
# 4   The name of the measurement technique describi...
# 5   If "other" is selected list the name of the me...
# 6   The specific version (application, manufacture...
# 7    If "other" list the name of the platform version
# 8   The name of the laboratory, facility, vendor, ...
# 9   If "other" list the name of the platform location
# 10  The model of the instrument used.,Provide a va...
# 11  An internet address that may provide more deta...
# 12  Name of additional file(s) accompanying the da...
# 13  The name of the organization, project, or labo...
# 14  An internet address that may provide details o...
# 15  The name of the search database (nr, SwissProt...
# 16  Modification parameters for a search engine ru...
# 17  The general strategy used for differential ana...
# 18  Type of labeling used ,Provide a value OR prov...
# 19  Type of label-free data analysis strategy ,Pro...
# 20              If "other" is selected please specify
# 21  Reagent set used for isobaric labeling.,Exampl...
# 22  Specifies whether or not a specific molecule(s...
# 23  Describes the mass spectrometer analyzer used ...
# 24  If "other" is selected list the name of the ma...
# 25  Describes the mass spectrometer analyzer used ...
# 26  If "other" is selected list the name of the ma...
# 27  Specified the mass spectrometer technique used...
# 28  If "other" is selected list the name of the ma...
# 29  The type of biospecimen subjected to analysis ...
# 30               If "other" list the type of analyte
# 31  List the name of the type of peptide quantific...
# 32              List the name of the instrument model
# 33  The type of digestion (ex. in-solution, in-gel...
# 34              If "other" list the type of digestion
# 35          Enzymes or reagents used for digestion. ,
# 36  If "other" is selected specify the name of the...
# 37  Number of fractions in the experimental run,Pr...
# 38             Type of peptide or protein enrichment,
# 39            If "other" is selected specify the name
# 40  Protocol or reagent used for enrichment (ex. F...
# 41  An identifier string that describes the sample...
# 42  The specific aspect of a mass spectrometer met...
# 43          The name of the acquisition software used
# 44                The version number of software used
# 45  The name of the search database (nr, SwissProt...
# 46    If "other" list the name of the search database
# 47  The name of the organization, project, or labo...
# 48    If "other" list the name of the database source
# 49  The frequency at which a spectrometer causes h...
# 50  If "other" is selected, list the name of the d...
# 51  If "other" is selected, list the custom modifi...
# 52  Name(s) of the enzyme used (possible values ar...
# 53     If "other" is selected, list the enzyme name.
# 54  Units of measure are Da or ppm (ex. "0.6 Da" o...
# 55  Units of measure are Da or ppm (ex. "0.6 Da" o...
#
#                                          Valid Values  Required    Module  \
# 0                                                          True  Metadata
# 1                                                          True  Metadata
# 2                                                          True     Other
# 3                                                          True  Metadata
# 4                                                          True  Metadata
# 5                                                          True     Other
# 6                                                          True  Metadata
# 7                                                          True     Other
# 8                                                          True  Metadata
# 9                                                          True     Other
# 10                                                         True  Metadata
# 11                                                         True  Metadata
# 12                                                         True  Metadata
# 13                                                         True  Metadata
# 14                                                         True  Metadata
# 15                                                         True  Metadata
# 16                                                         True  Metadata
# 17                                                         True  Metadata
# 18                                                         True  Metadata
# 19  Label-free protein level quantitation,Label-fr...      True  Metadata
# 20                                                         True     Other
# 21                                                         True  Metadata
# 22                                                         True  Metadata
# 23  LTQ Orbitrap XL,Orbitrap Fusion,Orbitrap Fusio...      True  Metadata
# 24                                                         True     Other
# 25  LTQ Orbitrap XL,Orbitrap Fusion,Orbitrap Fusio...      True  Metadata
# 26                                                         True     Other
# 27                                                         True  Metadata
# 28                                                         True     Other
# 29                                                         True  Metadata
# 30                                                         True     Other
# 31                                                         True     Other
# 32                                                         True     Other
# 33                                                         True  Metadata
# 34                                                         True     Other
# 35                                                         True  Metadata
# 36                                                         True     Other
# 37                                                         True  Metadata
# 38                                                         True  Metadata
# 39                                                         True     Other
# 40                                                         True  Metadata
# 41                                                         True  Metadata
# 42                                                         True  Metadata
# 43                                                         True  Metadata
# 44                                                         True  Metadata
# 45  MassBank of North America (MoNA),NIST17,Metlin...      True  Metadata
# 46                                                         True     Other
# 47                                                         True  Metadata
# 48                                                         True     Other
# 49                                                         True  Metadata
# 50                                                         True     Other
# 51                                                         True     Other
# 52                                                         True  Metadata
# 53                                                         True     Other
# 54                                                         True  Metadata
# 55                                                         True  Metadata
#
#    columnType                                           Ontology  \
# 0      string                                   Sage Bionetworks
# 1      string                                  Sage Bionetworks,
# 2      string                                   Sage Bionetworks
# 3      string                             Proteomic Data Commons
# 4      string                                   Sage Bionetworks
# 5      string                                   Sage Bionetworks
# 6      string         http://purl.obolibrary.org/obo/NCIT_C45378
# 7      string                                   Sage Bionetworks
# 8      string                             Sage Bionetworks,DSLWG
# 9      string                                   Sage Bionetworks
# 10     string  Sage Bionetworks,DSLWG,Proposed minimum metada...
# 11     string                             Sage Bionetworks,DSLWG
# 12     string                         Proteomics Sample Metadata
# 13     string          http://purl.obolibrary.org/obo/MS_1001012
# 14     string                             Sage Bionetworks,DSLWG
# 15     string          http://purl.obolibrary.org/obo/MS_1001013
# 16     string  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 17     string                                   Sage Bionetworks
# 18     string  Sage Bionetworks,DSLWG,https://www.ebi.ac.uk/o...
# 19     string                            Proteomics Data Commons
# 20     string                                   Sage Bionetworks
# 21     string                            Proteomics Data Commons
# 22     string                             Sage Bionetworks,DSLWG
# 23     string  Sage Bionetworks,Proposed minimum metadata rel...
# 24     string                                   Sage Bionetworks
# 25     string  Sage Bionetworks,Proposed minimum metadata rel...
# 26     string                                   Sage Bionetworks
# 27     string                             Sage Bionetworks,DSLWG
# 28     string                                   Sage Bionetworks
# 29     string  http://purl.obolibrary.org/obo/NCIT_C156434,Pr...
# 30     string                                   Sage Bionetworks
# 31     string                                   Sage Bionetworks
# 32     string                                   Sage Bionetworks
# 33     string                             Sage Bionetworks,DSLWG
# 34     string                                   Sage Bionetworks
# 35     string                            Proteomics Data Commons
# 36     string                                   Sage Bionetworks
# 37     string  Sage Bionetworks,The Proteomics Sample Metadat...
# 38     string                             Proteomic Data Commons
# 39     string                             Proteomic Data Commons
# 40     string                             Proteomic Data Commons
# 41     number  Sage Bionetworks,The Proteomics Sample Metadat...
# 42     string  https://www.ebi.ac.uk/ols/ontologies/ms/terms?...
# 43     string          http://purl.obolibrary.org/obo/MS_1001455
# 44     number                             Sage Bionetworks,DSLWG
# 45     string          http://purl.obolibrary.org/obo/MS_1001013
# 46     string                                   Sage Bionetworks
# 47     string          http://purl.obolibrary.org/obo/MS_1001012
# 48     string                                   Sage Bionetworks
# 49     number                             Sage Bionetworks,DSLWG
# 50     string                                   Sage Bionetworks
# 51     string                                   Sage Bionetworks
# 52     string                         Proteomics Sample Metadata
# 53     string                                   Sage Bionetworks
# 54     string                         Proteomics Sample Metadata
# 55     string                         Proteomics Sample Metadata
#
#                                                 Notes      Properties
# 0             values unique to each data contributor)  ManifestColumn
# 1   A data contributor should be able to write in ...  ManifestColumn
# 2                                                      ManifestColumn
# 3   A data contributor should be able to write in ...  ManifestColumn
# 4   A data contributor should be able to write in ...  ManifestColumn
# 5   A data contributor should be able to write in ...  ManifestColumn
# 6   A data contributor should be able to write in ...  ManifestColumn
# 7   A data contributor should be able to write in ...  ManifestColumn
# 8   A data contributor should be able to write in ...  ManifestColumn
# 9                                                      ManifestColumn
# 10  A data contributor should be able to write in ...  ManifestColumn
# 11  A data contributor should be able to write in ...  ManifestColumn
# 12  A data contributor should be able to write in ...  ManifestColumn
# 13  A data contributor should be able to write in ...  ManifestColumn
# 14  A data contributor should be able to write in ...  ManifestColumn
# 15  A data contributor should be able to write in ...  ManifestColumn
# 16  Possible values are listed under modification ...  ManifestColumn
# 17  A data contributor should be able to write in ...  ManifestColumn
# 18                                                     ManifestColumn
# 19                                                     ManifestColumn
# 20                                                     ManifestColumn
# 21  A data contributor should be able to write in ...  ManifestColumn
# 22                                                     ManifestColumn
# 23                                                     ManifestColumn
# 24                                                     ManifestColumn
# 25                                                     ManifestColumn
# 26                                                     ManifestColumn
# 27  A data contributor should be able to write in ...  ManifestColumn
# 28                                                     ManifestColumn
# 29  A data contributor should be able to write in ...  ManifestColumn
# 30  A data contributor should be able to write in ...  ManifestColumn
# 31                                                     ManifestColumn
# 32                                                     ManifestColumn
# 33  A data contributor should be able to write in ...  ManifestColumn
# 34  A data contributor should be able to write in ...  ManifestColumn
# 35                                                     ManifestColumn
# 36                                                     ManifestColumn
# 37  A data contributor should be able to write in ...  ManifestColumn
# 38  A data contributor should be able to write in ...  ManifestColumn
# 39                                                     ManifestColumn
# 40  A data contributor should be able to write in ...  ManifestColumn
# 41  A data contributor should be able to write in ...  ManifestColumn
# 42  A data contributor should be able to write in ...  ManifestColumn
# 43  A data contributor should be able to write in ...  ManifestColumn
# 44  A data contributor should be able to write in ...  ManifestColumn
# 45  A data contributor should be able to write in ...  ManifestColumn
# 46  A data contributor should be able to write in ...  ManifestColumn
# 47  A data contributor should be able to write in ...  ManifestColumn
# 48  A data contributor should be able to write in ...  ManifestColumn
# 49  A data contributor should be able to write in ...  ManifestColumn
# 50                                                     ManifestColumn
# 51                                                     ManifestColumn
# 52  A data contributor should be able to write in ...  ManifestColumn
# 53                                                     ManifestColumn
# 54                                                     ManifestColumn
# 55                                                     ManifestColumn

# %%
print("Shape of original data frame:", p_df.shape)
print("Shape of others data frame:", p_df_others.shape)

p_df_final = pd.concat([p_df, p_df_others]).reset_index(drop=True).replace("", np.nan)
p_df_final = p_df_final.set_index("Attribute")

print("Shape of final data frame:", p_df_final.shape)

p_df_final.info()
# Out:
# Shape of original data frame: (56, 9)
# Shape of others data frame: (19, 12)
# Shape of final data frame: (75, 11)
# <class 'pandas.core.frame.DataFrame'>
# Index: 75 entries, specimenID to OtherCleavageAgents
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Description   75 non-null     object
#  1   Valid Values  4 non-null      object
#  2   Required      75 non-null     bool
#  3   Module        75 non-null     object
#  4   columnType    75 non-null     object
#  5   Ontology      75 non-null     object
#  6   Notes         41 non-null     object
#  7   Properties    75 non-null     object
#  8   DependsOn     19 non-null     object
#  9   Parent        19 non-null     object
#  10  OtherValue    19 non-null     object
# dtypes: bool(1), object(10)
# memory usage: 6.5+ KB

# %%
p_df_final['UsedIn'] = 'proteomics'

# %%
# Add proteomics template to the data model updated with the attributes in DependsOn
dm.loc[dm["Attribute"] == "proteomics", "DependsOn"] = (
    "Component," + "Filename," + ",".join(p_df["Attribute"])
)

dm.loc[dm["Attribute"] == "proteomics"]
# Out:
#      Attribute                                        Description  \
# 38  proteomics  Template used for contributing metadata to the...
#
#    Valid Values                                          DependsOn  \
# 38          NaN  Component,Filename,specimenID,sampleType,speci...
#
#     Properties Required     Parent  DependsOn Component Source  \
# 38         NaN     True  Component                  NaN    NaN
#
#    Validation Rules    Module Ontology UsedIn columnType
# 38              NaN  Template      NaN    NaN        NaN

# %%
dm['Module'].unique()
# Out:
# array(['Instrument', 'Template', 'Analysis', 'ValidValues', 'Assay',
#        'Other', 'Consortium', 'Ontology', 'Repository', 'SampleType',
#        'Unspecified', 'Unit', 'Metadata', 'Model Organism',
#        'BaseAnnotation'], dtype=object)

# %%
dm["Parent"].unique()
# Out:
# array(['ValidValue', 'Component', 'AnalysisType', 'MeasurementUnit',
#        'ManifestColumn', 'Ontology', 'Repository', 'Demographics',
#        'BaseAnnotation'], dtype=object)

# %%
dm = dm.set_index('Attribute')

# %%
dm.shape
# Out:
# (700, 13)

# %%
pd.concat([dm, p_df_final])
# Out:
#                                                                                          Description  \
# Attribute
# 10x Visium Spatial Gene Expression                                             Instrument Model Name
# EnVision 2103 Multiplate Reader                                                Instrument Model Name
# Exploris 240Exploris 480quadrupole time-of-flight                              Instrument Model Name
# FIA-MSMS                                                                       Instrument Model Name
# Illumina 1M                                                                    Instrument Model Name
# ...                                                                                              ...
# OtherDatabaseName                                  When DatabaseName = `other`, add your custom v...
# OtherDatabaseSource                                When DatabaseSource = `other`, add your custom...
# OtherDataFile                                      When DataFile = `other`, add your custom value...
# OtherModificationParameters                        When ModificationParameters = `other`, add you...
# OtherCleavageAgents                                When CleavageAgent = `other`, add your custom ...
#
#                                                   Valid Values  \
# Attribute
# 10x Visium Spatial Gene Expression                         NaN
# EnVision 2103 Multiplate Reader                            NaN
# Exploris 240Exploris 480quadrupole time-of-flight          NaN
# FIA-MSMS                                                   NaN
# Illumina 1M                                                NaN
# ...                                                        ...
# OtherDatabaseName                                          NaN
# OtherDatabaseSource                                        NaN
# OtherDataFile                                              NaN
# OtherModificationParameters                                NaN
# OtherCleavageAgents                                        NaN
#
#                                                                             DependsOn  \
# Attribute
# 10x Visium Spatial Gene Expression                                                NaN
# EnVision 2103 Multiplate Reader                                                   NaN
# Exploris 240Exploris 480quadrupole time-of-flight                                 NaN
# FIA-MSMS                                                                          NaN
# Illumina 1M                                                                       NaN
# ...                                                                               ...
# OtherDatabaseName                                                 specifyDatabaseName
# OtherDatabaseSource                                             specifyDatabaseSource
# OtherDataFile                                                    specifyOtherDataFile
# OtherModificationParameters                        specifyOtherModificationParameters
# OtherCleavageAgents                                         specifyOtherCleavageAgent
#
#                                                    Properties Required  \
# Attribute
# 10x Visium Spatial Gene Expression                        NaN    False
# EnVision 2103 Multiplate Reader                           NaN    False
# Exploris 240Exploris 480quadrupole time-of-flight         NaN    False
# FIA-MSMS                                                  NaN    False
# Illumina 1M                                               NaN    False
# ...                                                       ...      ...
# OtherDatabaseName                                  ValidValue    False
# OtherDatabaseSource                                ValidValue    False
# OtherDataFile                                      ValidValue    False
# OtherModificationParameters                        ValidValue    False
# OtherCleavageAgents                                ValidValue    False
#
#                                                                    Parent  \
# Attribute
# 10x Visium Spatial Gene Expression                             ValidValue
# EnVision 2103 Multiplate Reader                                ValidValue
# Exploris 240Exploris 480quadrupole time-of-flight              ValidValue
# FIA-MSMS                                                       ValidValue
# Illumina 1M                                                    ValidValue
# ...                                                                   ...
# OtherDatabaseName                                            databaseName
# OtherDatabaseSource                                        databaseSource
# OtherDataFile                                                    dataFile
# OtherModificationParameters                        modificationParameters
# OtherCleavageAgents                                        cleavageAgents
#
#                                                    DependsOn Component Source  \
# Attribute
# 10x Visium Spatial Gene Expression                                 NaN    NaN
# EnVision 2103 Multiplate Reader                                    NaN    NaN
# Exploris 240Exploris 480quadrupole time-of-flight                  NaN    NaN
# FIA-MSMS                                                           NaN    NaN
# Illumina 1M                                                        NaN    NaN
# ...                                                                ...    ...
# OtherDatabaseName                                                  NaN    NaN
# OtherDatabaseSource                                                NaN    NaN
# OtherDataFile                                                      NaN    NaN
# OtherModificationParameters                                        NaN    NaN
# OtherCleavageAgents                                                NaN    NaN
#
#                                                   Validation Rules  \
# Attribute
# 10x Visium Spatial Gene Expression                             NaN
# EnVision 2103 Multiplate Reader                                NaN
# Exploris 240Exploris 480quadrupole time-of-flight              NaN
# FIA-MSMS                                                       NaN
# Illumina 1M                                                    NaN
# ...                                                            ...
# OtherDatabaseName                                              NaN
# OtherDatabaseSource                                            NaN
# OtherDataFile                                                  NaN
# OtherModificationParameters                                    NaN
# OtherCleavageAgents                                            NaN
#
#                                                        Module  \
# Attribute
# 10x Visium Spatial Gene Expression                 Instrument
# EnVision 2103 Multiplate Reader                    Instrument
# Exploris 240Exploris 480quadrupole time-of-flight  Instrument
# FIA-MSMS                                           Instrument
# Illumina 1M                                        Instrument
# ...                                                       ...
# OtherDatabaseName                                       Other
# OtherDatabaseSource                                     Other
# OtherDataFile                                           Other
# OtherModificationParameters                             Other
# OtherCleavageAgents                                     Other
#
#                                                            Ontology  \
# Attribute
# 10x Visium Spatial Gene Expression                              NaN
# EnVision 2103 Multiplate Reader                                 NaN
# Exploris 240Exploris 480quadrupole time-of-flight               NaN
# FIA-MSMS                                                        NaN
# Illumina 1M                                                     NaN
# ...                                                             ...
# OtherDatabaseName                                  Sage Bionetworks
# OtherDatabaseSource                                Sage Bionetworks
# OtherDataFile                                      Sage Bionetworks
# OtherModificationParameters                        Sage Bionetworks
# OtherCleavageAgents                                Sage Bionetworks
#
#                                                        UsedIn columnType  \
# Attribute
# 10x Visium Spatial Gene Expression                        NaN        NaN
# EnVision 2103 Multiplate Reader                           NaN        NaN
# Exploris 240Exploris 480quadrupole time-of-flight         NaN        NaN
# FIA-MSMS                                                  NaN        NaN
# Illumina 1M                                               NaN        NaN
# ...                                                       ...        ...
# OtherDatabaseName                                  proteomics     string
# OtherDatabaseSource                                proteomics     string
# OtherDataFile                                      proteomics     string
# OtherModificationParameters                        proteomics     string
# OtherCleavageAgents                                proteomics     string
#
#                                                                                                Notes  \
# Attribute
# 10x Visium Spatial Gene Expression                                                               NaN
# EnVision 2103 Multiplate Reader                                                                  NaN
# Exploris 240Exploris 480quadrupole time-of-flight                                                NaN
# FIA-MSMS                                                                                         NaN
# Illumina 1M                                                                                      NaN
# ...                                                                                              ...
# OtherDatabaseName                                  A data contributor should be able to write in ...
# OtherDatabaseSource                                A data contributor should be able to write in ...
# OtherDataFile                                                                                    NaN
# OtherModificationParameters                                                                      NaN
# OtherCleavageAgents                                                                              NaN
#
#                                                   OtherValue
# Attribute
# 10x Visium Spatial Gene Expression                       NaN
# EnVision 2103 Multiplate Reader                          NaN
# Exploris 240Exploris 480quadrupole time-of-flight        NaN
# FIA-MSMS                                                 NaN
# Illumina 1M                                              NaN
# ...                                                      ...
# OtherDatabaseName                                      other
# OtherDatabaseSource                                    other
# OtherDataFile                                          other
# OtherModificationParameters                            other
# OtherCleavageAgents                                    other
#
# [775 rows x 15 columns]

# %%
dm.loc[dm['UsedIn'].str.contains('proteomics', na = False)]
# Out:
#                                                                           Description  \
# Attribute
# platformLocation                    The name of the laboratory, facility, vendor, ...
# technologyPlatformVersion           The specific version (application, manufacture...
# specifyDatabaseName                       Value is determined by the data contributor
# specifyDatabaseSource                     Value is determined by the data contributor
# specifyDigestionMethod                    Value is determined by the data contributor
# specifyMeasurementTechnique               Value is determined by the data contributor
# specifyMSAnalyteType                      Value is determined by the data contributor
# specifyMSAnalyzerTypeMS1                  Value is determined by the data contributor
# specifyMSAnalyzerTypeMS2                  Value is determined by the data contributor
# specifyMSAssayTechnique                   Value is determined by the data contributor
# specifyMSInstrumentModel                  Value is determined by the data contributor
# specifyOtherCleavageAgent                 Value is determined by the data contributor
# specifyOtherModificationParameters        Value is determined by the data contributor
# specifyPlatformLocation                   Value is determined by the data contributor
# specifyPlatformVersion                    Value is determined by the data contributor
# specifyProteomicsAssayType                Value is determined by the data contributor
# specifySampleType                         Value is determined by the data contributor
# acquisitionMode                     The specific aspect of a mass spectrometer met...
# acquisitionSoftware                         The name of the acquisition software used
# acquistionSoftwareVersion                         The version number of software used
# cleavageAgents                                             Name(s) of the enzyme used
# databaseName                        The name of the search database (nr, SwissProt...
# databaseSource                      The name of the organization, project, or labo...
# databaseWeblink                     An internet address that may provide details o...
# digestionMethod                     The type of digestion - in-solution, in-gel, e...
# fractionIdentifier                  Identifier string that describes the sample fr...
# fragmentMassTolerance               Units of measure are Da or ppm (ex. "0.6 Da" o...
# modificationParameters              Modification parameters for the search engine ...
# msAnalyteType                           the type of biospecimen subjected to analysis
# msAnalyzerTypeMS1                   Describes the mass spectrometer analyzer used ...
# msAnalyzerTypeMS2                   Describes the mass spectrometer analyzer used ...
# msAssayTechnique                       Specified the mass spectrometer technique used
# msInstrumentModel                            The model of the mass spectrometer  used
# msTarget                            specifies whether or not a specific molecule(s...
# precursorMassTolerance              Units of measure are Da or ppm (ex. "0.6 Da" o...
# protoemicsAssayType                 Type of peptide quantification used (ex. Label...
# samplePrepProtocol                  An internet address that may provide more deta...
# sampleType                                               The type of sample collected
# spectrometerFrequency               The frequency at which a spectrometer causes h...
# dataFile                            The data file provides the name of the raw fil...
# specimenID                          Identifying string linked to a particular samp...
#
#                                                                          Valid Values  \
# Attribute
# platformLocation                    OtherPlatformLocation, Unknown, Not collected,...
# technologyPlatformVersion           10x Visium Spatial Gene Expression, Affymetrix...
# specifyDatabaseName                                                               NaN
# specifyDatabaseSource                                                             NaN
# specifyDigestionMethod                                                            NaN
# specifyMeasurementTechnique                                                       NaN
# specifyMSAnalyteType                                                              NaN
# specifyMSAnalyzerTypeMS1                                                          NaN
# specifyMSAnalyzerTypeMS2                                                          NaN
# specifyMSAssayTechnique                                                           NaN
# specifyMSInstrumentModel                                                          NaN
# specifyOtherCleavageAgent                                                         NaN
# specifyOtherModificationParameters                                                NaN
# specifyPlatformLocation                                                           NaN
# specifyPlatformVersion                                                            NaN
# specifyProteomicsAssayType                                                        NaN
# specifySampleType                                                                 NaN
# acquisitionMode                     Unknown, Not collected, Not applicable, Not Sp...
# acquisitionSoftware                 Unknown, Not collected, Not applicable, Not Sp...
# acquistionSoftwareVersion                                                         NaN
# cleavageAgents                                                                    NaN
# databaseName                        MassBank of North America (MoNA), NIST17, Metl...
# databaseSource                      OtherDatabaseSource, Unknown, Not collected, N...
# databaseWeblink                                                                   NaN
# digestionMethod                     in-solution, in-gel, OtherDigestionMethod, Unk...
# fractionIdentifier                                                                NaN
# fragmentMassTolerance                                                             NaN
# modificationParameters                                                            NaN
# msAnalyteType                       Protein, metabolite, Lipid, Other, Unknown, No...
# msAnalyzerTypeMS1                   LTQ Orbitrap XL, Orbitrap Fusion, Orbitrap Fus...
# msAnalyzerTypeMS2                   LTQ Orbitrap XL, Orbitrap Fusion, Orbitrap Fus...
# msAssayTechnique                    DDA-MS, DIA-MS, FIA-MSMS, HPLC-MSMS, LC-MS, LC...
# msInstrumentModel                                                                 NaN
# msTarget                            TargetedMsTarget, UnTargetedMsTarget, Unknown,...
# precursorMassTolerance                                                            NaN
# protoemicsAssayType                 Label Free, TMT, ITRAQ, SILAC, Targeted Absolu...
# samplePrepProtocol                                                                NaN
# sampleType                          Amniotic Fluid, Appendix, B cell, Basophils, B...
# spectrometerFrequency                                                             NaN
# dataFile                            Unknown, Not collected, Not applicable, Not Sp...
# specimenID                                                                        NaN
#
#                                    DependsOn  Properties Required  \
# Attribute
# platformLocation                         NaN         NaN     True
# technologyPlatformVersion                NaN         NaN     True
# specifyDatabaseName                      NaN         NaN    False
# specifyDatabaseSource                    NaN         NaN    False
# specifyDigestionMethod                   NaN         NaN    False
# specifyMeasurementTechnique              NaN         NaN    False
# specifyMSAnalyteType                     NaN         NaN    False
# specifyMSAnalyzerTypeMS1                 NaN         NaN    False
# specifyMSAnalyzerTypeMS2                 NaN         NaN    False
# specifyMSAssayTechnique                  NaN         NaN    False
# specifyMSInstrumentModel                 NaN         NaN    False
# specifyOtherCleavageAgent                NaN         NaN    False
# specifyOtherModificationParameters       NaN         NaN    False
# specifyPlatformLocation                  NaN         NaN    False
# specifyPlatformVersion                   NaN         NaN    False
# specifyProteomicsAssayType               NaN         NaN    False
# specifySampleType                        NaN         NaN    False
# acquisitionMode                          NaN         NaN     True
# acquisitionSoftware                      NaN         NaN     True
# acquistionSoftwareVersion                NaN         NaN     True
# cleavageAgents                           NaN         NaN     True
# databaseName                             NaN         NaN     True
# databaseSource                           NaN         NaN    False
# databaseWeblink                          NaN         NaN    False
# digestionMethod                          NaN         NaN     True
# fractionIdentifier                       NaN         NaN     True
# fragmentMassTolerance                    NaN         NaN     True
# modificationParameters                   NaN         NaN     True
# msAnalyteType                            NaN         NaN    False
# msAnalyzerTypeMS1                        NaN         NaN     True
# msAnalyzerTypeMS2                        NaN         NaN     True
# msAssayTechnique                         NaN         NaN     True
# msInstrumentModel                        NaN         NaN     True
# msTarget                                 NaN         NaN     True
# precursorMassTolerance                   NaN         NaN     True
# protoemicsAssayType                      NaN         NaN     True
# samplePrepProtocol                       NaN         NaN    False
# sampleType                               NaN         NaN     True
# spectrometerFrequency                    NaN         NaN     True
# dataFile                                 NaN         NaN     True
# specimenID                               NaN         NaN     True
#
#                                             Parent  DependsOn Component  \
# Attribute
# platformLocation                    ManifestColumn                  NaN
# technologyPlatformVersion           ManifestColumn                  NaN
# specifyDatabaseName                 ManifestColumn                  NaN
# specifyDatabaseSource               ManifestColumn                  NaN
# specifyDigestionMethod              ManifestColumn                  NaN
# specifyMeasurementTechnique         ManifestColumn                  NaN
# specifyMSAnalyteType                ManifestColumn                  NaN
# specifyMSAnalyzerTypeMS1            ManifestColumn                  NaN
# specifyMSAnalyzerTypeMS2            ManifestColumn                  NaN
# specifyMSAssayTechnique             ManifestColumn                  NaN
# specifyMSInstrumentModel            ManifestColumn                  NaN
# specifyOtherCleavageAgent           ManifestColumn                  NaN
# specifyOtherModificationParameters  ManifestColumn                  NaN
# specifyPlatformLocation             ManifestColumn                  NaN
# specifyPlatformVersion              ManifestColumn                  NaN
# specifyProteomicsAssayType          ManifestColumn                  NaN
# specifySampleType                   ManifestColumn                  NaN
# acquisitionMode                     ManifestColumn                  NaN
# acquisitionSoftware                 ManifestColumn                  NaN
# acquistionSoftwareVersion           ManifestColumn                  NaN
# cleavageAgents                      ManifestColumn                  NaN
# databaseName                        ManifestColumn                  NaN
# databaseSource                      ManifestColumn                  NaN
# databaseWeblink                     ManifestColumn                  NaN
# digestionMethod                     ManifestColumn                  NaN
# fractionIdentifier                  ManifestColumn                  NaN
# fragmentMassTolerance               ManifestColumn                  NaN
# modificationParameters              ManifestColumn                  NaN
# msAnalyteType                       ManifestColumn                  NaN
# msAnalyzerTypeMS1                   ManifestColumn                  NaN
# msAnalyzerTypeMS2                   ManifestColumn                  NaN
# msAssayTechnique                    ManifestColumn                  NaN
# msInstrumentModel                   ManifestColumn                  NaN
# msTarget                            ManifestColumn                  NaN
# precursorMassTolerance              ManifestColumn                  NaN
# protoemicsAssayType                 ManifestColumn                  NaN
# samplePrepProtocol                  ManifestColumn                  NaN
# sampleType                          ManifestColumn                  NaN
# spectrometerFrequency               ManifestColumn                  NaN
# dataFile                            ManifestColumn                  NaN
# specimenID                          ManifestColumn                  NaN
#
#                                                                                Source  \
# Attribute
# platformLocation                                                     Sage Bionetworks
# technologyPlatformVersion                                            Sage Bionetworks
# specifyDatabaseName                                                  Sage Bionetworks
# specifyDatabaseSource                                                Sage Bionetworks
# specifyDigestionMethod                                               Sage Bionetworks
# specifyMeasurementTechnique                                          Sage Bionetworks
# specifyMSAnalyteType                                                 Sage Bionetworks
# specifyMSAnalyzerTypeMS1                                             Sage Bionetworks
# specifyMSAnalyzerTypeMS2                                             Sage Bionetworks
# specifyMSAssayTechnique                                              Sage Bionetworks
# specifyMSInstrumentModel                                             Sage Bionetworks
# specifyOtherCleavageAgent                                            Sage Bionetworks
# specifyOtherModificationParameters                                   Sage Bionetworks
# specifyPlatformLocation                                              Sage Bionetworks
# specifyPlatformVersion                                               Sage Bionetworks
# specifyProteomicsAssayType                                           Sage Bionetworks
# specifySampleType                                                    Sage Bionetworks
# acquisitionMode                     https://www.ebi.ac.uk/ols/ontologies/ms/termsi...
# acquisitionSoftware                         http://purl.obolibrary.org/obo/MS_1001455
# acquistionSoftwareVersion                                            Sage Bionetworks
# cleavageAgents                                             Proteomics Sample Metadata
# databaseName                                http://purl.obolibrary.org/obo/MS_1001013
# databaseSource                              http://purl.obolibrary.org/obo/MS_1001012
# databaseWeblink                                                DSLWG,Sage Bionetworks
# digestionMethod                                                DSLWG,Sage Bionetworks
# fractionIdentifier                  MS Ontology,Sage Bionetworks,The Proteomics Sa...
# fragmentMassTolerance                                      Proteomics Sample Metadata
# modificationParameters              https://www.ebi.ac.uk/ols/ontologies/ms/termsi...
# msAnalyteType                             http://purl.obolibrary.org/obo/NCIT_C156434
# msAnalyzerTypeMS1                   Proposed minimum metadata relative to mass spe...
# msAnalyzerTypeMS2                   Proposed minimum metadata relative to mass spe...
# msAssayTechnique                                               DSLWG,Sage Bionetworks
# msInstrumentModel                   Proposed minimum metadata relative to mass spe...
# msTarget                                                             Sage Bionetworks
# precursorMassTolerance                                     Proteomics Sample Metadata
# protoemicsAssayType                 DSLWG,Sage Bionetworks,https://www.ebi.ac.uk/o...
# samplePrepProtocol                                                   Sage Bionetworks
# sampleType                                                   ImmPort,Sage Bionetworks
# spectrometerFrequency                                                Sage Bionetworks
# dataFile                                                   Proteomics Sample Metadata
# specimenID                                                           Sage Bionetworks
#
#                                    Validation Rules       Module Ontology  \
# Attribute
# platformLocation                                NaN        Assay      NaN
# technologyPlatformVersion                       NaN        Assay      NaN
# specifyDatabaseName                             NaN        Other      NaN
# specifyDatabaseSource                           NaN        Other      NaN
# specifyDigestionMethod                          NaN        Other      NaN
# specifyMeasurementTechnique                     NaN        Other      NaN
# specifyMSAnalyteType                            NaN        Other      NaN
# specifyMSAnalyzerTypeMS1                        NaN        Other      NaN
# specifyMSAnalyzerTypeMS2                        NaN        Other      NaN
# specifyMSAssayTechnique                         NaN        Other      NaN
# specifyMSInstrumentModel                        NaN        Other      NaN
# specifyOtherCleavageAgent                       NaN        Other      NaN
# specifyOtherModificationParameters              NaN        Other      NaN
# specifyPlatformLocation                         NaN        Other      NaN
# specifyPlatformVersion                          NaN        Other      NaN
# specifyProteomicsAssayType                      NaN        Other      NaN
# specifySampleType                               NaN        Other      NaN
# acquisitionMode                                 NaN  Unspecified      NaN
# acquisitionSoftware                             NaN  Unspecified      NaN
# acquistionSoftwareVersion                       NaN  Unspecified      NaN
# cleavageAgents                                  str  Unspecified      NaN
# databaseName                                    NaN  Unspecified      NaN
# databaseSource                                  NaN  Unspecified      NaN
# databaseWeblink                                 NaN  Unspecified      NaN
# digestionMethod                                 NaN  Unspecified      NaN
# fractionIdentifier                              NaN  Unspecified      NaN
# fragmentMassTolerance                           NaN  Unspecified      NaN
# modificationParameters                          str  Unspecified      NaN
# msAnalyteType                                   NaN  Unspecified      NaN
# msAnalyzerTypeMS1                               NaN  Unspecified      NaN
# msAnalyzerTypeMS2                               NaN  Unspecified      NaN
# msAssayTechnique                                NaN  Unspecified      NaN
# msInstrumentModel                               str  Unspecified      NaN
# msTarget                                        NaN  Unspecified      NaN
# precursorMassTolerance                          NaN  Unspecified      NaN
# protoemicsAssayType                             NaN  Unspecified      NaN
# samplePrepProtocol                              NaN  Unspecified      NaN
# sampleType                                      NaN  Unspecified      NaN
# spectrometerFrequency                           NaN  Unspecified      NaN
# dataFile                                        NaN     Metadata      NaN
# specimenID                                      NaN     Metadata      NaN
#
#                                                                                UsedIn  \
# Attribute
# platformLocation                    Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# technologyPlatformVersion           Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# specifyDatabaseName                                     Metabolomics Human,proteomics
# specifyDatabaseSource                                   Metabolomics Human,proteomics
# specifyDigestionMethod                                                     proteomics
# specifyMeasurementTechnique         Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# specifyMSAnalyteType                                    Metabolomics Human,proteomics
# specifyMSAnalyzerTypeMS1                                Metabolomics Human,proteomics
# specifyMSAnalyzerTypeMS2                                Metabolomics Human,proteomics
# specifyMSAssayTechnique                                 Metabolomics Human,proteomics
# specifyMSInstrumentModel                                Metabolomics Human,proteomics
# specifyOtherCleavageAgent                                                  proteomics
# specifyOtherModificationParameters                                         proteomics
# specifyPlatformLocation             Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# specifyPlatformVersion              Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# specifyProteomicsAssayType                                                 proteomics
# specifySampleType                   Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# acquisitionMode                                         Metabolomics Human,proteomics
# acquisitionSoftware                                     Metabolomics Human,proteomics
# acquistionSoftwareVersion                               Metabolomics Human,proteomics
# cleavageAgents                                                             proteomics
# databaseName                                            Metabolomics Human,proteomics
# databaseSource                                          Metabolomics Human,proteomics
# databaseWeblink                                         Metabolomics Human,proteomics
# digestionMethod                                                            proteomics
# fractionIdentifier                                                         proteomics
# fragmentMassTolerance                                                      proteomics
# modificationParameters                                                     proteomics
# msAnalyteType                                           Metabolomics Human,proteomics
# msAnalyzerTypeMS1                                       Metabolomics Human,proteomics
# msAnalyzerTypeMS2                                       Metabolomics Human,proteomics
# msAssayTechnique                                        Metabolomics Human,proteomics
# msInstrumentModel                                       Metabolomics Human,proteomics
# msTarget                                                Metabolomics Human,proteomics
# precursorMassTolerance                                                     proteomics
# protoemicsAssayType                                                        proteomics
# samplePrepProtocol                                      Metabolomics Human,proteomics
# sampleType                          Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# spectrometerFrequency                                   Metabolomics Human,proteomics
# dataFile                                                                   proteomics
# specimenID                          Biospecimen human,Biospecimen nonHuman,Metabol...
#
#                                    columnType
# Attribute
# platformLocation                          NaN
# technologyPlatformVersion                 NaN
# specifyDatabaseName                    String
# specifyDatabaseSource                  String
# specifyDigestionMethod                 String
# specifyMeasurementTechnique            String
# specifyMSAnalyteType                   String
# specifyMSAnalyzerTypeMS1               String
# specifyMSAnalyzerTypeMS2               String
# specifyMSAssayTechnique                String
# specifyMSInstrumentModel               String
# specifyOtherCleavageAgent              String
# specifyOtherModificationParameters     String
# specifyPlatformLocation                String
# specifyPlatformVersion                 String
# specifyProteomicsAssayType             String
# specifySampleType                      String
# acquisitionMode                           NaN
# acquisitionSoftware                       NaN
# acquistionSoftwareVersion                 NaN
# cleavageAgents                            NaN
# databaseName                              NaN
# databaseSource                            NaN
# databaseWeblink                           NaN
# digestionMethod                           NaN
# fractionIdentifier                        NaN
# fragmentMassTolerance                     NaN
# modificationParameters                    NaN
# msAnalyteType                             NaN
# msAnalyzerTypeMS1                         NaN
# msAnalyzerTypeMS2                         NaN
# msAssayTechnique                          NaN
# msInstrumentModel                         NaN
# msTarget                                  NaN
# precursorMassTolerance                    NaN
# protoemicsAssayType                       NaN
# samplePrepProtocol                        NaN
# sampleType                                NaN
# spectrometerFrequency                     NaN
# dataFile                                  NaN
# specimenID                                NaN

# %%
dm.loc[dm["UsedIn"].str.contains("proteomics", na=False)].merge(p_df_final, how = 'outer', on = 'Attribute')
# Out:
#                                                                   Description_x  \
# Attribute
# platformLocation              The name of the laboratory, facility, vendor, ...
# technologyPlatformVersion     The specific version (application, manufacture...
# specifyDatabaseName                 Value is determined by the data contributor
# specifyDatabaseSource               Value is determined by the data contributor
# specifyDigestionMethod              Value is determined by the data contributor
# ...                                                                         ...
# OtherDatabaseName                                                           NaN
# OtherDatabaseSource                                                         NaN
# OtherDataFile                                                               NaN
# OtherModificationParameters                                                 NaN
# OtherCleavageAgents                                                         NaN
#
#                                                                  Valid Values_x  \
# Attribute
# platformLocation              OtherPlatformLocation, Unknown, Not collected,...
# technologyPlatformVersion     10x Visium Spatial Gene Expression, Affymetrix...
# specifyDatabaseName                                                         NaN
# specifyDatabaseSource                                                       NaN
# specifyDigestionMethod                                                      NaN
# ...                                                                         ...
# OtherDatabaseName                                                           NaN
# OtherDatabaseSource                                                         NaN
# OtherDataFile                                                               NaN
# OtherModificationParameters                                                 NaN
# OtherCleavageAgents                                                         NaN
#
#                              DependsOn_x  Properties_x Required_x  \
# Attribute
# platformLocation                     NaN           NaN       True
# technologyPlatformVersion            NaN           NaN       True
# specifyDatabaseName                  NaN           NaN      False
# specifyDatabaseSource                NaN           NaN      False
# specifyDigestionMethod               NaN           NaN      False
# ...                                  ...           ...        ...
# OtherDatabaseName                    NaN           NaN        NaN
# OtherDatabaseSource                  NaN           NaN        NaN
# OtherDataFile                        NaN           NaN        NaN
# OtherModificationParameters          NaN           NaN        NaN
# OtherCleavageAgents                  NaN           NaN        NaN
#
#                                     Parent_x  DependsOn Component  \
# Attribute
# platformLocation              ManifestColumn                  NaN
# technologyPlatformVersion     ManifestColumn                  NaN
# specifyDatabaseName           ManifestColumn                  NaN
# specifyDatabaseSource         ManifestColumn                  NaN
# specifyDigestionMethod        ManifestColumn                  NaN
# ...                                      ...                  ...
# OtherDatabaseName                        NaN                  NaN
# OtherDatabaseSource                      NaN                  NaN
# OtherDataFile                            NaN                  NaN
# OtherModificationParameters              NaN                  NaN
# OtherCleavageAgents                      NaN                  NaN
#
#                                         Source Validation Rules Module_x  ...  \
# Attribute                                                                 ...
# platformLocation              Sage Bionetworks              NaN    Assay  ...
# technologyPlatformVersion     Sage Bionetworks              NaN    Assay  ...
# specifyDatabaseName           Sage Bionetworks              NaN    Other  ...
# specifyDatabaseSource         Sage Bionetworks              NaN    Other  ...
# specifyDigestionMethod        Sage Bionetworks              NaN    Other  ...
# ...                                        ...              ...      ...  ...
# OtherDatabaseName                          NaN              NaN      NaN  ...
# OtherDatabaseSource                        NaN              NaN      NaN  ...
# OtherDataFile                              NaN              NaN      NaN  ...
# OtherModificationParameters                NaN              NaN      NaN  ...
# OtherCleavageAgents                        NaN              NaN      NaN  ...
#
#                              Required_y  Module_y columnType_y  \
# Attribute
# platformLocation                   True  Metadata       string
# technologyPlatformVersion          True  Metadata       string
# specifyDatabaseName                True     Other       string
# specifyDatabaseSource              True     Other       string
# specifyDigestionMethod             True     Other       string
# ...                                 ...       ...          ...
# OtherDatabaseName                 False     Other       string
# OtherDatabaseSource               False     Other       string
# OtherDataFile                     False     Other       string
# OtherModificationParameters       False     Other       string
# OtherCleavageAgents               False     Other       string
#
#                                                               Ontology_y  \
# Attribute
# platformLocation                                  Sage Bionetworks,DSLWG
# technologyPlatformVersion     http://purl.obolibrary.org/obo/NCIT_C45378
# specifyDatabaseName                                     Sage Bionetworks
# specifyDatabaseSource                                   Sage Bionetworks
# specifyDigestionMethod                                  Sage Bionetworks
# ...                                                                  ...
# OtherDatabaseName                                       Sage Bionetworks
# OtherDatabaseSource                                     Sage Bionetworks
# OtherDataFile                                           Sage Bionetworks
# OtherModificationParameters                             Sage Bionetworks
# OtherCleavageAgents                                     Sage Bionetworks
#
#                                                                           Notes  \
# Attribute
# platformLocation              A data contributor should be able to write in ...
# technologyPlatformVersion     A data contributor should be able to write in ...
# specifyDatabaseName           A data contributor should be able to write in ...
# specifyDatabaseSource         A data contributor should be able to write in ...
# specifyDigestionMethod        A data contributor should be able to write in ...
# ...                                                                         ...
# OtherDatabaseName             A data contributor should be able to write in ...
# OtherDatabaseSource           A data contributor should be able to write in ...
# OtherDataFile                                                               NaN
# OtherModificationParameters                                                 NaN
# OtherCleavageAgents                                                         NaN
#
#                                 Properties_y  \
# Attribute
# platformLocation              ManifestColumn
# technologyPlatformVersion     ManifestColumn
# specifyDatabaseName           ManifestColumn
# specifyDatabaseSource         ManifestColumn
# specifyDigestionMethod        ManifestColumn
# ...                                      ...
# OtherDatabaseName                 ValidValue
# OtherDatabaseSource               ValidValue
# OtherDataFile                     ValidValue
# OtherModificationParameters       ValidValue
# OtherCleavageAgents               ValidValue
#
#                                                      DependsOn_y  \
# Attribute
# platformLocation                                             NaN
# technologyPlatformVersion                                    NaN
# specifyDatabaseName                                          NaN
# specifyDatabaseSource                                        NaN
# specifyDigestionMethod                                       NaN
# ...                                                          ...
# OtherDatabaseName                            specifyDatabaseName
# OtherDatabaseSource                        specifyDatabaseSource
# OtherDataFile                               specifyOtherDataFile
# OtherModificationParameters   specifyOtherModificationParameters
# OtherCleavageAgents                    specifyOtherCleavageAgent
#
#                                             Parent_y OtherValue    UsedIn_y
# Attribute
# platformLocation                                 NaN        NaN  proteomics
# technologyPlatformVersion                        NaN        NaN  proteomics
# specifyDatabaseName                              NaN        NaN  proteomics
# specifyDatabaseSource                            NaN        NaN  proteomics
# specifyDigestionMethod                           NaN        NaN  proteomics
# ...                                              ...        ...         ...
# OtherDatabaseName                       databaseName      other  proteomics
# OtherDatabaseSource                   databaseSource      other  proteomics
# OtherDataFile                               dataFile      other  proteomics
# OtherModificationParameters   modificationParameters      other  proteomics
# OtherCleavageAgents                   cleavageAgents      other  proteomics
#
# [77 rows x 25 columns]

# %%
# combine duplicated rows
p_df_final = p_df_final.fillna("").astype(str).groupby(level=0).apply(
    lambda x: x.apply(lambda y: ",".join(y))
)

# %%
p_df_final.index.is_unique
# Out:
# True

# %%
# Update empty values with the new dataframe
dm.update(p_df_final, overwrite=False, errors = 'ignore')

# %%
dm.loc[dm['UsedIn'].str.contains('proteomics', na = False)].shape
# Out:
# (41, 13)

# %%
# join in the new template
dm_final = pd.concat([dm, p_df_final.loc[~p_df_final.index.isin(dm.index)]])
dm_final.shape
# Out:
# (733, 15)

# %%
# Replace any other values to leave open for contributors to add
dm_final.loc["platformLocation", "Valid Values"] = np.nan
dm_final.loc["dataFile", "Valid Values"] = np.nan
dm_final.loc["acquisitionMode", "Valid Values"] = np.nan
dm_final.loc["acquisitionSoftware", "Valid Values"] = np.nan

# %%
dm_final.loc[p_df_final.index]
# Out:
#                                                                    Description  \
# Attribute
# Label freeLabelQuantiation   When labelFreeQuantitation = `other`, add your...
# OtherCleavageAgents          When CleavageAgent = `other`, add your custom ...
# OtherDataFile                When DataFile = `other`, add your custom value...
# OtherDatabaseName            When DatabaseName = `other`, add your custom v...
# OtherDatabaseSource          When DatabaseSource = `other`, add your custom...
# ...                                                                        ...
# specifyProteomicsAssayType         Value is determined by the data contributor
# specifySampleType                  Value is determined by the data contributor
# specimenID                   Identifying string linked to a particular samp...
# spectrometerFrequency        The frequency at which a spectrometer causes h...
# technologyPlatformVersion    The specific version (application, manufacture...
#
#                                                                   Valid Values  \
# Attribute
# Label freeLabelQuantiation
# OtherCleavageAgents
# OtherDataFile
# OtherDatabaseName
# OtherDatabaseSource
# ...                                                                        ...
# specifyProteomicsAssayType
# specifySampleType
# specimenID
# spectrometerFrequency
# technologyPlatformVersion    10x Visium Spatial Gene Expression, Affymetrix...
#
#                                              DependsOn      Properties  \
# Attribute
# Label freeLabelQuantiation       labelFreeQuantitation      ValidValue
# OtherCleavageAgents          specifyOtherCleavageAgent      ValidValue
# OtherDataFile                     specifyOtherDataFile      ValidValue
# OtherDatabaseName                  specifyDatabaseName      ValidValue
# OtherDatabaseSource              specifyDatabaseSource      ValidValue
# ...                                                ...             ...
# specifyProteomicsAssayType                              ManifestColumn
# specifySampleType                                       ManifestColumn
# specimenID                                              ManifestColumn
# spectrometerFrequency                                   ManifestColumn
# technologyPlatformVersion                               ManifestColumn
#
#                             Required            Parent DependsOn Component  \
# Attribute
# Label freeLabelQuantiation     False  labelQuantiation                 NaN
# OtherCleavageAgents            False    cleavageAgents                 NaN
# OtherDataFile                  False          dataFile                 NaN
# OtherDatabaseName              False      databaseName                 NaN
# OtherDatabaseSource            False    databaseSource                 NaN
# ...                              ...               ...                 ...
# specifyProteomicsAssayType     False    ManifestColumn                 NaN
# specifySampleType              False    ManifestColumn                 NaN
# specimenID                      True    ManifestColumn                 NaN
# spectrometerFrequency           True    ManifestColumn                 NaN
# technologyPlatformVersion       True    ManifestColumn                 NaN
#
#                                        Source Validation Rules       Module  \
# Attribute
# Label freeLabelQuantiation                NaN              NaN        Other
# OtherCleavageAgents                       NaN              NaN        Other
# OtherDataFile                             NaN              NaN        Other
# OtherDatabaseName                         NaN              NaN        Other
# OtherDatabaseSource                       NaN              NaN        Other
# ...                                       ...              ...          ...
# specifyProteomicsAssayType   Sage Bionetworks              NaN        Other
# specifySampleType            Sage Bionetworks              NaN        Other
# specimenID                   Sage Bionetworks              NaN     Metadata
# spectrometerFrequency        Sage Bionetworks              NaN  Unspecified
# technologyPlatformVersion    Sage Bionetworks              NaN        Assay
#
#                                                                Ontology  \
# Attribute
# Label freeLabelQuantiation                             Sage Bionetworks
# OtherCleavageAgents                                    Sage Bionetworks
# OtherDataFile                                          Sage Bionetworks
# OtherDatabaseName                                      Sage Bionetworks
# OtherDatabaseSource                                    Sage Bionetworks
# ...                                                                 ...
# specifyProteomicsAssayType                             Sage Bionetworks
# specifySampleType                                      Sage Bionetworks
# specimenID                                             Sage Bionetworks
# spectrometerFrequency                            Sage Bionetworks,DSLWG
# technologyPlatformVersion    http://purl.obolibrary.org/obo/NCIT_C45378
#
#                                                                         UsedIn  \
# Attribute
# Label freeLabelQuantiation                                          proteomics
# OtherCleavageAgents                                                 proteomics
# OtherDataFile                                                       proteomics
# OtherDatabaseName                                                   proteomics
# OtherDatabaseSource                                                 proteomics
# ...                                                                        ...
# specifyProteomicsAssayType                                          proteomics
# specifySampleType            Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# specimenID                   Biospecimen human,Biospecimen nonHuman,Metabol...
# spectrometerFrequency                            Metabolomics Human,proteomics
# technologyPlatformVersion    Metabolomics Human,Microbiome,RNAseq,Whole Gen...
#
#                             columnType  \
# Attribute
# Label freeLabelQuantiation      string
# OtherCleavageAgents             string
# OtherDataFile                   string
# OtherDatabaseName               string
# OtherDatabaseSource             string
# ...                                ...
# specifyProteomicsAssayType      String
# specifySampleType               String
# specimenID                      string
# spectrometerFrequency           number
# technologyPlatformVersion       string
#
#                                                                          Notes  \
# Attribute
# Label freeLabelQuantiation
# OtherCleavageAgents
# OtherDataFile
# OtherDatabaseName            A data contributor should be able to write in ...
# OtherDatabaseSource          A data contributor should be able to write in ...
# ...                                                                        ...
# specifyProteomicsAssayType                                                 NaN
# specifySampleType                                                          NaN
# specimenID                                                                 NaN
# spectrometerFrequency                                                      NaN
# technologyPlatformVersion                                                  NaN
#
#                              OtherValue
# Attribute
# Label freeLabelQuantiation   Label Free
# OtherCleavageAgents               other
# OtherDataFile                     other
# OtherDatabaseName                 other
# OtherDatabaseSource               other
# ...                                 ...
# specifyProteomicsAssayType          NaN
# specifySampleType                   NaN
# specimenID                          NaN
# spectrometerFrequency               NaN
# technologyPlatformVersion           NaN
#
# [72 rows x 15 columns]

# %%
# qa check
with pd.option_context('display.max_rows', None):
    display(dm_final[dm_final.index.duplicated(keep=False)].sort_index())
# Out:
# Empty DataFrame
# Columns: [Description, Valid Values, DependsOn, Properties, Required, Parent, DependsOn Component, Source, Validation Rules, Module, Ontology, UsedIn, columnType, Notes, OtherValue]
# Index: []

# %%
# Check there are unique attributes
dm_final.index.is_unique
# Out:
# True

# %%
# no longer need column
dm_final = dm_final.drop(columns=["OtherValue"])

# %%
# Write out data model
dm_final.to_csv('../EL.data.model.csv')

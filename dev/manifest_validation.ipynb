# %% [markdown]
# # Manifest Validation

# %%
import random
import string
import pandas as pd
from pathlib import Path
from glob import glob
import os

# %% [markdown]
# # Validation of manifests

# %%
# number of rows to fill in
nrows = 10
random.seed = 27

# last minute chaos
chaos = False

# %% [markdown]
# Functions

# %%
def valid_values_to_list(df, attribute):
    valid_values = (
        df.query(f'Attribute == "{attribute}"')[
            "Valid Values"].str.split(",").values[0]
    )

    return valid_values

# %%
def get_random_value(list_of_vv):
    return random.choice(list_of_vv)

# %%
def get_rand_integer(min=0, max=100):
    return random.randint(min, max)

# %%
def get_rand_float(min=0, max=100):
    return round(random.uniform(0.0, 100.0), 2)

# %%
def get_random_string():
    t = lorem.sentence().split(" ")[0]
    return t

# %%
def introduce_random_NAs(df, N=5):
    """Another test to see if columns can handle empty values or if they will flag the empty value"""

    rows, cols = df.shape

    row_index = [get_rand_integer(max=rows - 1) for _ in range(N)]

    col_index = [get_rand_integer(max=cols - 1) for _ in range(N)]

    indexes = list(zip(row_index, col_index))

    # Print indexes to check where values got replaced
    print(indexes)
    # for i in indexes
    df.iloc[row_index, col_index] = np.NaN

    return df

# %%
# find attribute column, fill in with value
def fill_in_attribute(df, index, attribute, value):
    df.loc[index, attribute] = value
    return df

# %%
def gen_mixed_string_with_length(N=12):
    # initializing size of string

    # using random.choices()
    # generating random strings
    res = "".join(random.choices(string.ascii_uppercase + string.digits, k=N))

    # print result
    return res

# %%
def random_change():
    # list of functions to choose from
    choices = [
        introduce_random_NAs,
        gen_mixed_string_with_length,
        get_rand_integer,
        get_random_string,
        get_rand_float,
    ]

    choice = random.choice(choices)

    print(choice.__name__)

    return choice()

# %%
def partition(list_in, n):
    random.shuffle(list_in)
    return [list_in[i::n] for i in range(n)]

# %% [markdown]
# Create individual and biospecimen ids from random text

# %%
# for individaul IDs and specimenIDs
individaulIds = [gen_mixed_string_with_length(N=10) for _ in range(1, 100)]
specimenIds = [gen_mixed_string_with_length(N=5) for _ in range(1, 1000)]

# %%
specimenIds_partitioned = partition(specimenIds, 100)

# %%
ind_bio_map = []

for i, v in enumerate(individaulIds):
    for s in specimenIds_partitioned[i]:
        ind_bio_map.append({"individualID": v, "specimenID": s})

ind_bio_map = pd.DataFrame(ind_bio_map)

# %%
ind_bio_map.head(20)
# Out:
#    individualID specimenID
# 0    JPXMA6RZ99      I4B0N
# 1    JPXMA6RZ99      WZFHW
# 2    JPXMA6RZ99      NC5TS
# 3    JPXMA6RZ99      YMGPO
# 4    JPXMA6RZ99      09G79
# 5    JPXMA6RZ99      N01CM
# 6    JPXMA6RZ99      1N4GW
# 7    JPXMA6RZ99      XN5X5
# 8    JPXMA6RZ99      I55AK
# 9    JPXMA6RZ99      K3VVB
# 10   4I101VXJRM      QXZMV
# 11   4I101VXJRM      2OFI2
# 12   4I101VXJRM      50H8K
# 13   4I101VXJRM      8MNPM
# 14   4I101VXJRM      WHLEL
# 15   4I101VXJRM      ST1Y9
# 16   4I101VXJRM      TT08G
# 17   4I101VXJRM      4Q7JR
# 18   4I101VXJRM      RKOB4
# 19   4I101VXJRM      OEIUG

# %%
# Manifests
# Get all the RFC file paths
manifest_paths = glob(
    "../manifests/*.csv"
)
manifest_paths
# Out:
# []

# %% [markdown]
# Tested:
#
# - scRNAseq : Passed (Need to add validation for biospecimenId)

# %%
# load data model
data_model_path = ("../EL.data.model.csv"
)

dm = pd.read_csv(data_model_path)

dm.head()
# Out:
#                                      Attribute Description Valid Values  \
# 0   Affymetrix Genome-Wide Human SNP 6.0 Array         NaN          NaN
# 1           Affymetrix Human Gene 1.0 ST Array         NaN          NaN
# 2  Affymetrix Human Genome U133 Plus 2.0 Array         NaN          NaN
# 3                            Affymetrix U133AB         NaN          NaN
# 4                                          DNA         NaN          NaN
#
#   DependsOn  Properties Required      Parent DependsOn Component Source  \
# 0       NaN         NaN    False  ValidValue                 NaN    NaN
# 1       NaN         NaN    False  ValidValue                 NaN    NaN
# 2       NaN         NaN    False  ValidValue                 NaN    NaN
# 3       NaN         NaN    False  ValidValue                 NaN    NaN
# 4       NaN         NaN    False  ValidValue                 NaN    NaN
#
#   Validation Rules Module Type Ontology UsedIn
# 0              NaN  Assay  NaN      NaN    NaN
# 1              NaN  Assay  NaN      NaN    NaN
# 2              NaN  Assay  NaN      NaN    NaN
# 3              NaN  Assay  NaN      NaN    NaN
# 4              NaN  Assay  NaN      NaN    NaN

# %%
# load manifest
manifest_path = "../example-scRNAseq.csv"

df = pd.read_csv(manifest_path)

df = df.dropna(how="all", axis=0)

df = df.fillna('')

df.head()
# Out:
#   Filename specimenID sampleType specifySampleType  \
# 0
#
#   specifyMeasurementTechnique technologyPlatformVersion  \
# 0
#
#   specifyPlatformVersion platformLocation specifyPlatformLocation  \
# 0
#
#   referenceTranscriptID  ... libraryVersion specifyLibraryVersion isStranded  \
# 0                        ...
#
#   readStrandOrigin readLength readLengthUnits specifyReadLengthUnits runType  \
# 0
#
#   totalReads Component
# 0             ScRNAseq
#
# [1 rows x 39 columns]

# %%
manifest_name = Path(manifest_path).stem

parent_name = df['Component'].unique()[0]

df["Component"] = manifest_name

# %%
# Attributes from data model
attrs_to_fill = df.columns.tolist()

attrs_to_fill
# Out:
# ['Filename',
#  'specimenID',
#  'sampleType',
#  'specifySampleType',
#  'specifyMeasurementTechnique',
#  'technologyPlatformVersion',
#  'specifyPlatformVersion',
#  'platformLocation',
#  'specifyPlatformLocation',
#  'referenceTranscriptID',
#  'repositoryName',
#  'specifyRepositoryName',
#  'transcriptType',
#  'specifyTranscriptType',
#  'resultUnit',
#  'valueReported',
#  'rnaBatchID',
#  'rnaBatchSize',
#  'rnaBatchSizeUnit',
#  'specifyRNABatchSizeUnit',
#  'libraryBatchID',
#  'sequencingBatchID',
#  'sequencingBatchSize',
#  'sequencingBatchSizeUnit',
#  'specifySequencingBatchSizeUnit',
#  'libraryPrep',
#  'specifyLibraryPrep',
#  'libraryPreparationMethod',
#  'specifyLibraryPreparationMethod',
#  'libraryVersion',
#  'specifyLibraryVersion',
#  'isStranded',
#  'readStrandOrigin',
#  'readLength',
#  'readLengthUnits',
#  'specifyReadLengthUnits',
#  'runType',
#  'totalReads',
#  'Component']

# %%
dm_attrs = (
    dm[(dm["Attribute"].isin(attrs_to_fill))]
    .drop_duplicates(subset=["Attribute"])
    .copy()
)

dm_attrs
# Out:
#                            Attribute  \
# 16                        isStranded
# 17                    libraryBatchID
# 18                       libraryPrep
# 19          libraryPreparationMethod
# 20                    libraryVersion
# 21                  platformLocation
# 25                        readLength
# 26                   readLengthUnits
# 27                  readStrandOrigin
# 35             referenceTranscriptID
# 36                        rnaBatchID
# 37                      rnaBatchSize
# 38                  rnaBatchSizeUnit
# 39                           runType
# 43                 sequencingBatchID
# 44               sequencingBatchSize
# 45           sequencingBatchSizeUnit
# 46         technologyPlatformVersion
# 47                        totalReads
# 129                       specimenID
# 203               specifyLibraryPrep
# 204  specifyLibraryPreparationMethod
# 205            specifyLibraryVersion
# 211      specifyMeasurementTechnique
# 214          specifyPlatformLocation
# 215           specifyPlatformVersion
# 218          specifyRNABatchSizeUnit
# 219           specifyReadLengthUnits
# 220            specifyRepositoryName
# 223                specifySampleType
# 224   specifySequencingBatchSizeUnit
# 225            specifyTranscriptType
# 604                   repositoryName
# 605                       resultUnit
# 610                       sampleType
# 630                   transcriptType
# 644                    valueReported
# 647                         Filename
#
#                                            Description  \
# 16             Whether or not the library is stranded.
# 17   Library batch identifier, provided by the data...
# 18   The general strategy by which the library was ...
# 19                Method by which library was prepared
# 20   Library Version: for example, rnaSeq 10x libra...
# 21   The name of the laboratory, facility, vendor, ...
# 25                              The length of the read
# 26                           The units of measurement.
# 27   The strand from which the read originates in a...
# 35   The ID for the transcript/gene. Either the NCB...
# 36   RNA isolation batch identifier, provided by th...
# 37                               The number of samples
# 38   The unit of measurement for number of samples ...
# 39                                     The type of run
# 43   Sequencing batch identifier, provided by the d...
# 44                               The number of samples
# 45   The unit of measurement for number of samples ...
# 46   The specific version (application, manufacture...
# 47    Total number of sequencing reads from a library.
# 129  Identifying string linked to a particular samp...
# 203        Value is determined by the data contributor
# 204        Value is determined by the data contributor
# 205        Value is determined by the data contributor
# 211        Value is determined by the data contributor
# 214        Value is determined by the data contributor
# 215        Value is determined by the data contributor
# 218        Value is determined by the data contributor
# 219        Value is determined by the data contributor
# 220        Value is determined by the data contributor
# 223        Value is determined by the data contributor
# 224        Value is determined by the data contributor
# 225        Value is determined by the data contributor
# 604  The public repository name for the transcript ...
# 605                      The unit for the result value
# 610                       The type of sample collected
# 630                    The type of transcript reported
# 644         The count or gene count for the transcript
# 647  Name of the file. This helps to link annotatio...
#
#                                           Valid Values DependsOn  Properties  \
# 16                                          TRUE,FALSE       NaN         NaN
# 17                                                 NaN       NaN         NaN
# 18   amplicon,cellHashing,Chromium Single Cell 3',D...       NaN         NaN
# 19   10x,Accel-NGS 2S Plus,Accel-NGS Methyl-Seq,CEL...       NaN         NaN
# 20   OtherLibraryVersion,Unknown,Not collected,Not ...       NaN         NaN
# 21   OtherPlatformLocation,Unknown,Not collected,No...       NaN         NaN
# 25                                                 NaN       NaN         NaN
# 26   AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...       NaN         NaN
# 27                                     forward,reverse       NaN         NaN
# 35   Unknown,Not collected,Not applicable,Not Speci...       NaN         NaN
# 36   Unknown,Not collected,Not applicable,Not Speci...       NaN         NaN
# 37                                                 NaN       NaN         NaN
# 38   AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...       NaN         NaN
# 39                                 singleEnd,pairedEnd       NaN         NaN
# 43   Unknown,Not collected,Not applicable,Not Speci...       NaN         NaN
# 44                                                 NaN       NaN         NaN
# 45   AFU,AI,AU/ml,DK units/ml,bpg/dl,g/l,gm,HAU,IU,...       NaN         NaN
# 46   10x Visium Spatial Gene Expression,Affymetrix ...       NaN         NaN
# 47                                                 NaN       NaN         NaN
# 129                                                NaN       NaN         NaN
# 203                                                NaN       NaN         NaN
# 204                                                NaN       NaN         NaN
# 205                                                NaN       NaN         NaN
# 211                                                NaN       NaN         NaN
# 214                                                NaN       NaN         NaN
# 215                                                NaN       NaN         NaN
# 218                                                NaN       NaN         NaN
# 219                                                NaN       NaN         NaN
# 220                                                NaN       NaN         NaN
# 223                                                NaN       NaN         NaN
# 224                                                NaN       NaN         NaN
# 225                                                NaN       NaN         NaN
# 604  ArrayExpress,Broad Single Cell Portal,dbGAP,EN...       NaN         NaN
# 605                        FPKM,RPKM,TPM,Not Specified       NaN         NaN
# 610  Amniotic Fluid,Appendix,B cell,Basophils,Bone,...       NaN         NaN
# 630  lincRNA,mRNA,snRNA,OtherTranscriptType,Unknown...       NaN         NaN
# 644                                                NaN       NaN         NaN
# 647                                                NaN       NaN         NaN
#
#     Required         Parent DependsOn Component                    Source  \
# 16      True   DataProperty                 NaN          Sage Bionetworks
# 17      True   DataProperty                 NaN          Sage Bionetworks
# 18      True   DataProperty                 NaN          Sage Bionetworks
# 19      True   DataProperty                 NaN          Sage Bionetworks
# 20      True   DataProperty                 NaN          Sage Bionetworks
# 21      True   DataProperty                 NaN          Sage Bionetworks
# 25      True   DataProperty                 NaN          Sage Bionetworks
# 26      True   DataProperty                 NaN          Sage Bionetworks
# 27      True   DataProperty                 NaN          Sage Bionetworks
# 35      True   DataProperty                 NaN          Sage Bionetworks
# 36      True   DataProperty                 NaN          Sage Bionetworks
# 37     False   DataProperty                 NaN          Sage Bionetworks
# 38      True   DataProperty                 NaN          Sage Bionetworks
# 39      True   DataProperty                 NaN          Sage Bionetworks
# 43      True   DataProperty                 NaN          Sage Bionetworks
# 44      True   DataProperty                 NaN          Sage Bionetworks
# 45      True   DataProperty                 NaN          Sage Bionetworks
# 46      True   DataProperty                 NaN          Sage Bionetworks
# 47      True   DataProperty                 NaN          Sage Bionetworks
# 129     True   DataProperty                 NaN          Sage Bionetworks
# 203    False  Specification                 NaN          Sage Bionetworks
# 204    False  Specification                 NaN          Sage Bionetworks
# 205    False  Specification                 NaN          Sage Bionetworks
# 211    False  Specification                 NaN          Sage Bionetworks
# 214    False  Specification                 NaN          Sage Bionetworks
# 215    False  Specification                 NaN          Sage Bionetworks
# 218    False  Specification                 NaN          Sage Bionetworks
# 219    False  Specification                 NaN          Sage Bionetworks
# 220    False  Specification                 NaN          Sage Bionetworks
# 223    False  Specification                 NaN          Sage Bionetworks
# 224    False  Specification                 NaN          Sage Bionetworks
# 225    False  Specification                 NaN          Sage Bionetworks
# 604     True   DataProperty                 NaN          Sage Bionetworks
# 605     True   DataProperty                 NaN          Sage Bionetworks
# 610     True   DataProperty                 NaN  ImmPort,Sage Bionetworks
# 630     True   DataProperty                 NaN                   ImmPort
# 644     True   DataProperty                 NaN          Sage Bionetworks
# 647     True   DataProperty                 NaN                       NaN
#
#                                       Validation Rules       Module    Type  \
# 16                                                 NaN        Assay     str
# 17                                                 NaN        Assay     NaN
# 18                                                 NaN        Assay     NaN
# 19                                                 NaN        Assay     NaN
# 20                                                 NaN        Assay     NaN
# 21                                                 NaN        Assay     NaN
# 25             regex search ([0-9]+\.[0-9]*.)|([0-9]+)        Assay     NaN
# 26                                                 NaN        Assay     NaN
# 27                                                 NaN        Assay     NaN
# 35                                                 NaN        Assay     NaN
# 36                                                 NaN        Assay     NaN
# 37             regex search ([0-9]+\.[0-9]*.)|([0-9]+)        Assay     NaN
# 38                                                 NaN        Assay     NaN
# 39                                                 NaN        Assay     NaN
# 43                                                 NaN        Assay     NaN
# 44             regex search ([0-9]+\.[0-9]*.)|([0-9]+)        Assay     NaN
# 45                                                 NaN        Assay     NaN
# 46                                                 NaN        Assay     NaN
# 47             regex search ([0-9]+\.[0-9]*.)|([0-9]+)        Assay     NaN
# 129  matchAtLeastOne Biospecimenhuman.specimenID value     Metadata     NaN
# 203                                                NaN        Other  String
# 204                                                NaN        Other  String
# 205                                                NaN        Other  String
# 211                                                NaN        Other  String
# 214                                                NaN        Other  String
# 215                                                NaN        Other  String
# 218                                                NaN        Other  String
# 219                                                NaN        Other  String
# 220                                                NaN        Other  String
# 223                                                NaN        Other  String
# 224                                                NaN        Other  String
# 225                                                NaN        Other  String
# 604                                                NaN  Unspecified     NaN
# 605                                                NaN  Unspecified     NaN
# 610                                                NaN  Unspecified     NaN
# 630                                                NaN  Unspecified     NaN
# 644            regex search ([0-9]+\.[0-9]*.)|([0-9]+)  Unspecified     NaN
# 647                                                NaN  Valid Value     NaN
#
#     Ontology                                             UsedIn
# 16       NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 17       NaN  Microbiome,Whole Genome Sequencing,bsSeq,scRNAseq
# 18       NaN  Microbiome,Whole Genome Sequencing,bsSeq,scRNAseq
# 19       NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 20       NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 21       NaN  Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# 25       NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 26       NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 27       NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 35       NaN      RNAseq,Whole Genome Sequencing,bsSeq,scRNAseq
# 36       NaN                   Whole Genome Sequencing,scRNAseq
# 37       NaN                                           scRNAseq
# 38       NaN                                           scRNAseq
# 39       NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 43       NaN  Microbiome,Whole Genome Sequencing,bsSeq,scRNAseq
# 44       NaN                          Microbiome,bsSeq,scRNAseq
# 45       NaN                          Microbiome,bsSeq,scRNAseq
# 46       NaN  Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# 47       NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 129      NaN  Biospecimen human,Biospecimen nonHuman,Metabol...
# 203      NaN  Microbiome,Whole Genome Sequencing,bsSeq,scRNAseq
# 204      NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 205      NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 211      NaN  Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# 214      NaN  Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# 215      NaN  Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# 218      NaN                                           scRNAseq
# 219      NaN  Microbiome,RNAseq,Whole Genome Sequencing,bsSe...
# 220      NaN            RNAseq,Whole Genome Sequencing,scRNAseq
# 223      NaN  Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# 224      NaN                          Microbiome,bsSeq,scRNAseq
# 225      NaN            RNAseq,Whole Genome Sequencing,scRNAseq
# 604      NaN            RNAseq,Whole Genome Sequencing,scRNAseq
# 605      NaN            RNAseq,Whole Genome Sequencing,scRNAseq
# 610      NaN  Metabolomics Human,Microbiome,RNAseq,Whole Gen...
# 630      NaN            RNAseq,Whole Genome Sequencing,scRNAseq
# 644      NaN            RNAseq,Whole Genome Sequencing,scRNAseq
# 647      NaN                                                NaN

# %%
# find values in dm_attrrs with valid values filled in
vv_attrs = dm_attrs[~dm_attrs["Valid Values"].isna()]["Attribute"].tolist()

# %%
vv_attrs
# Out:
# ['isStranded',
#  'libraryPrep',
#  'libraryPreparationMethod',
#  'libraryVersion',
#  'platformLocation',
#  'readLengthUnits',
#  'readStrandOrigin',
#  'referenceTranscriptID',
#  'rnaBatchID',
#  'rnaBatchSizeUnit',
#  'runType',
#  'sequencingBatchID',
#  'sequencingBatchSizeUnit',
#  'technologyPlatformVersion',
#  'repositoryName',
#  'resultUnit',
#  'sampleType',
#  'transcriptType']

# %%
# fill in values for the mainfest with the data model
for attribute in vv_attrs:
    for i in range(nrows):
        index = i
        temp_vv = valid_values_to_list(dm_attrs, attribute)
        new_val = get_random_value(temp_vv)
        df = fill_in_attribute(df, index, attribute, new_val)

# %%
df
# Out:
#   Filename specimenID           sampleType specifySampleType  \
# 0                          Lung lymph node
# 1      NaN        NaN                 Bone               NaN
# 2      NaN        NaN      Urinary bladder               NaN
# 3      NaN        NaN       Dendritic cell               NaN
# 4      NaN        NaN      OtherSampleType               NaN
# 5      NaN        NaN                brain               NaN
# 6      NaN        NaN            Mouse Ear               NaN
# 7      NaN        NaN            Basophils               NaN
# 8      NaN        NaN  Inguinal lymph node               NaN
# 9      NaN        NaN                  PBL               NaN
#
#   specifyMeasurementTechnique                   technologyPlatformVersion  \
# 0                                             Vectra H1 3D Imaging System
# 1                         NaN                              Not applicable
# 2                         NaN                                     Unknown
# 3                         NaN                       Illumina NextSeq 1000
# 4                         NaN                            Nanostring GeoMx
# 5                         NaN  Illumina HumanOmniExpress-24 v1.0 BeadChip
# 6                         NaN                    Vevo 3100 Imaging System
# 7                         NaN                        Illumina HumanHap300
# 8                         NaN                                       scale
# 9                         NaN                       Illumina NovaSeq 6000
#
#   specifyPlatformVersion       platformLocation specifyPlatformLocation  \
# 0                                Not applicable
# 1                    NaN  OtherPlatformLocation                     NaN
# 2                    NaN          Not Specified                     NaN
# 3                    NaN  OtherPlatformLocation                     NaN
# 4                    NaN  OtherPlatformLocation                     NaN
# 5                    NaN         Not applicable                     NaN
# 6                    NaN         Not applicable                     NaN
# 7                    NaN  OtherPlatformLocation                     NaN
# 8                    NaN          Not collected                     NaN
# 9                    NaN          Not Specified                     NaN
#
#   referenceTranscriptID  ...       libraryVersion specifyLibraryVersion  \
# 0        Not applicable  ...        Not collected
# 1               Unknown  ...        Not collected                   NaN
# 2         Not collected  ...  OtherLibraryVersion                   NaN
# 3         Not Specified  ...        Not collected                   NaN
# 4        Not applicable  ...        Not collected                   NaN
# 5         Not Specified  ...  OtherLibraryVersion                   NaN
# 6               Unknown  ...        Not Specified                   NaN
# 7        Not applicable  ...              Unknown                   NaN
# 8        Not applicable  ...  OtherLibraryVersion                   NaN
# 9         Not collected  ...        Not collected                   NaN
#
#   isStranded readStrandOrigin readLength  readLengthUnits  \
# 0       TRUE          reverse                       AU/ml
# 1      FALSE          forward        NaN            pg/ml
# 2       TRUE          forward        NaN            Pound
# 3       TRUE          reverse        NaN    Not Specified
# 4       TRUE          forward        NaN              HAU
# 5      FALSE          reverse        NaN            ug/dl
# 6      FALSE          forward        NaN  optical density
# 7      FALSE          forward        NaN             iu/l
# 8       TRUE          forward        NaN               pM
# 9       TRUE          forward        NaN               ml
#
#   specifyReadLengthUnits    runType totalReads         Component
# 0                         singleEnd             example-scRNAseq
# 1                    NaN  pairedEnd        NaN               NaN
# 2                    NaN  pairedEnd        NaN               NaN
# 3                    NaN  pairedEnd        NaN               NaN
# 4                    NaN  pairedEnd        NaN               NaN
# 5                    NaN  singleEnd        NaN               NaN
# 6                    NaN  singleEnd        NaN               NaN
# 7                    NaN  singleEnd        NaN               NaN
# 8                    NaN  pairedEnd        NaN               NaN
# 9                    NaN  singleEnd        NaN               NaN
#
# [10 rows x 39 columns]

# %%
# update df with sample of individual and biospecimen sample ids
ind_sample = ind_bio_map.sample(nrows, replace=True)[
    ["individualID", "specimenID"]
].reset_index(drop=True)

df.update(ind_sample)

# %%
df
# Out:
#   Filename specimenID           sampleType specifySampleType  \
# 0               6VTXG      Lung lymph node
# 1      NaN      4Z2UM                 Bone               NaN
# 2      NaN      2ID8X      Urinary bladder               NaN
# 3      NaN      NESZ5       Dendritic cell               NaN
# 4      NaN      ZBJSB      OtherSampleType               NaN
# 5      NaN      UTZ9D                brain               NaN
# 6      NaN      27S1P            Mouse Ear               NaN
# 7      NaN      5P83Y            Basophils               NaN
# 8      NaN      LF97B  Inguinal lymph node               NaN
# 9      NaN      LC9BR                  PBL               NaN
#
#   specifyMeasurementTechnique                   technologyPlatformVersion  \
# 0                                             Vectra H1 3D Imaging System
# 1                         NaN                              Not applicable
# 2                         NaN                                     Unknown
# 3                         NaN                       Illumina NextSeq 1000
# 4                         NaN                            Nanostring GeoMx
# 5                         NaN  Illumina HumanOmniExpress-24 v1.0 BeadChip
# 6                         NaN                    Vevo 3100 Imaging System
# 7                         NaN                        Illumina HumanHap300
# 8                         NaN                                       scale
# 9                         NaN                       Illumina NovaSeq 6000
#
#   specifyPlatformVersion       platformLocation specifyPlatformLocation  \
# 0                                Not applicable
# 1                    NaN  OtherPlatformLocation                     NaN
# 2                    NaN          Not Specified                     NaN
# 3                    NaN  OtherPlatformLocation                     NaN
# 4                    NaN  OtherPlatformLocation                     NaN
# 5                    NaN         Not applicable                     NaN
# 6                    NaN         Not applicable                     NaN
# 7                    NaN  OtherPlatformLocation                     NaN
# 8                    NaN          Not collected                     NaN
# 9                    NaN          Not Specified                     NaN
#
#   referenceTranscriptID  ...       libraryVersion specifyLibraryVersion  \
# 0        Not applicable  ...        Not collected
# 1               Unknown  ...        Not collected                   NaN
# 2         Not collected  ...  OtherLibraryVersion                   NaN
# 3         Not Specified  ...        Not collected                   NaN
# 4        Not applicable  ...        Not collected                   NaN
# 5         Not Specified  ...  OtherLibraryVersion                   NaN
# 6               Unknown  ...        Not Specified                   NaN
# 7        Not applicable  ...              Unknown                   NaN
# 8        Not applicable  ...  OtherLibraryVersion                   NaN
# 9         Not collected  ...        Not collected                   NaN
#
#   isStranded readStrandOrigin readLength  readLengthUnits  \
# 0       TRUE          reverse                       AU/ml
# 1      FALSE          forward        NaN            pg/ml
# 2       TRUE          forward        NaN            Pound
# 3       TRUE          reverse        NaN    Not Specified
# 4       TRUE          forward        NaN              HAU
# 5      FALSE          reverse        NaN            ug/dl
# 6      FALSE          forward        NaN  optical density
# 7      FALSE          forward        NaN             iu/l
# 8       TRUE          forward        NaN               pM
# 9       TRUE          forward        NaN               ml
#
#   specifyReadLengthUnits    runType totalReads         Component
# 0                         singleEnd             example-scRNAseq
# 1                    NaN  pairedEnd        NaN               NaN
# 2                    NaN  pairedEnd        NaN               NaN
# 3                    NaN  pairedEnd        NaN               NaN
# 4                    NaN  pairedEnd        NaN               NaN
# 5                    NaN  singleEnd        NaN               NaN
# 6                    NaN  singleEnd        NaN               NaN
# 7                    NaN  singleEnd        NaN               NaN
# 8                    NaN  pairedEnd        NaN               NaN
# 9                    NaN  singleEnd        NaN               NaN
#
# [10 rows x 39 columns]

# %%
swap_validation_coder = {v: k for k, v in validation_coder.items()}

# column coding for values
dm_attrs["swapper"] = (
    dm_attrs["Validation Rules"].fillna(
        "number").replace(swap_validation_coder)
)

dm_attrs["swapper"] = dm_attrs["swapper"].apply(
    lambda x: re.sub("^\d*?\.?\d$", "number", x)
)

# need a better regex later
dm_attrs["swapper"] = dm_attrs["swapper"].apply(
    lambda x: re.sub(
        "number numbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumbernumber",
        "number",
        x,
    )
)

print(dm_attrs["swapper"].unique())

dm_attrs.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/nlee/Documents/Projects/ELITE/ELITE-data-models/dev/manifest_validation.ipynb Cell 33 line 1
# ----> <a href='vscode-notebook-cell:/Users/nlee/Documents/Projects/ELITE/ELITE-data-models/dev/manifest_validation.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> swap_validation_coder = {v: k for k, v in validation_coder.items()}
#       <a href='vscode-notebook-cell:/Users/nlee/Documents/Projects/ELITE/ELITE-data-models/dev/manifest_validation.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> # column coding for values
#       <a href='vscode-notebook-cell:/Users/nlee/Documents/Projects/ELITE/ELITE-data-models/dev/manifest_validation.ipynb#X44sZmlsZQ%3D%3D?line=3'>4</a> dm_attrs["swapper"] = (
#       <a href='vscode-notebook-cell:/Users/nlee/Documents/Projects/ELITE/ELITE-data-models/dev/manifest_validation.ipynb#X44sZmlsZQ%3D%3D?line=4'>5</a>     dm_attrs["Validation Rules"].fillna(
#       <a href='vscode-notebook-cell:/Users/nlee/Documents/Projects/ELITE/ELITE-data-models/dev/manifest_validation.ipynb#X44sZmlsZQ%3D%3D?line=5'>6</a>         "number").replace(swap_validation_coder)
#       <a href='vscode-notebook-cell:/Users/nlee/Documents/Projects/ELITE/ELITE-data-models/dev/manifest_validation.ipynb#X44sZmlsZQ%3D%3D?line=6'>7</a> )
#
# NameError: name 'validation_coder' is not defined

# %%
free_form_attrs = dm_attrs[
    (dm_attrs["Valid Values"] == "")
    & (~dm_attrs["Attribute"].isin(["individualID", "specimenID"]))
]

free_form_attrs

# %%
def generate_values(value):
    if value == 'string':
        # generate string
        return get_random_string()
    elif value == 'number':
        # generate random number
        return get_rand_integer()
    elif value == 'mixed'
        # split string into regex expressions i.e. numbers and valid values
        choices = ['string', 'number']
        # chose random to fill in cell

# %%
test = "([0-9]+\\.[0-9]*.)|([0-9]+)"
test2 = "^\\d*?\\.?\\d$|Other|Unknown|Not collected|Not applicable"

# def match_pattern(rule):

pattern_checker = {
    "strip_patterns": "regex|search|match",
    "number": "(?![a-zA-Z]+)(\[0-9\])",
    "string": "([a-zA-Z]+)(?!\[0-9\])",
    "mixed": "(?:[a-zA-Z]+\d+)",
}

result = False

while result == False:
    for k, v in pattern_checker.items():
        result = bool(re.search(pattern=v, string=test))
        print(pattern)
        print(result)


# pattern = '(?![a-zA-Z]+)(\[0-9\])'
# results = bool(re.search(pattern = pattern, string = test))
# results

# %%
for attribute in free_form_attrs["Attribute"].tolist():
    for i in range(nrows):
        index = i
        test = free_form_attrs.query(f'Attribute == "{attribute}"')
        new_val = test["swapper"].apply(generate_values).values[0]
        df = fill_in_attribute(df, index, attribute, new_val)

# %%
# write out test manifest to file for testing in DCA
df["Component"] = manifest_name

if chaos:
    df = introduce_random_NAs(df)

# %%
# Write out manifest
csv_path = os.path.join(
    "../testing/test_manifests",
    manifest_name + "-test.csv",
)

df.to_csv(csv_path)

# %% [markdown]
# # Run Validation Test

# %%
# manifest_path = "C:/Users/nlee/Documents/Projects/schematic/schematic/tests/data/mock_manifests/example_biospecimen_test.csv"
print(
    f"schematic model --config {schematic_config} validate --manifest_path {csv_path} --data_type {manifest_name}")
# !schematic model --config {schematic_config} validate --manifest_path {csv_path} --data_type {manifest_name}

# %% [markdown]
# # Submit Manifest

# %%
print(csv_path)
print(schematic_config)
print(manifest_name)
dataset_id = "syn51753850"

# %% [markdown]
# - d option is the project

# %%
dataset_id = 'syn51753844'

# !schematic model --config C:/Users/nlee/Documents/Projects/schematic/schematic/config.yml submit -mp C:/Users/nlee/Documents/Projects/ELITE-DCC/ELITE-data-models/test_manifests/WholeGenomeSequencing_test.csv -d syn51753850 -vc WholeGenomeSequencing -mrt both

# %%
search_df(dm2, "valueReported")

# %% [markdown]
# # Store Manifest In Dataset For Testing

# %%
import synapseclient
from synapseclient import File

manifest_folder_id = 'syn51728840'

# %run C:\Users\nlee\Documents\Projects\utils\syanpse_login.py

# %%
csv_entity = File(
    csv_path,
    description=f"Test manifest for {manifest_name}",
    parent=data_folder,
    annotations={"resourceType": "manifest", "manifestType": {manifest_name}},
)

csv_entity = syn.store(csv_entity)

# %%
s = syn.getColumns("syn51748558")

# %%
for i in s:
    print(i)

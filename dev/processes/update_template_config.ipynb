# %%
import json
import pandas as pd
import re
from datetime import datetime

# %%
# load data model
with open('../../EL.data.model.jsonld', 'r', encoding='UTF-8') as f: 
    dm_json = json.load(f)

# %%
# get template names
for i in dm_json['@graph']: 
    try: 
        if bool(re.search('template', i['@id'])): 
            # print(i)
            templates = [v for n in i["schema:domainIncludes"] for _,v in n.items()]
    except KeyError: 
        pass

# %%
# re-create template
# get 'sms:displayName' for "display_name" and '@id' for "schema_name"

manifest_schemas = []

for i in dm_json['@graph']: 
    try: 
        if i['@id'] in templates: 
            if bool(re.search('individual|biospecimen', i['@id'], flags=re.IGNORECASE)): 
                record_type = 'record'
            else: 
                record_type = 'file'
                
            temp_template = {
                'display_name': i['sms:displayName'], 
                "schema_name": i['@id'].strip('bts:'),
                "type": record_type
            }

            manifest_schemas.append(temp_template)
    except KeyError: 
        pass

manifest_schemas_df = (
    pd.DataFrame(manifest_schemas)
    .sort_values(["type", "display_name"], ascending=True)
    .reset_index(drop=True)
)
print(manifest_schemas_df.to_markdown(index=False))
print()
print("Shape: ", manifest_schemas_df.shape)
# Out:
# | display_name                           | schema_name                        | type   |
# |:---------------------------------------|:-----------------------------------|:-------|
# | assay_RNAseq_template                  | AssayRNAseqTemplate                | file   |
# | assay_bsSeq_template                   | AssayBsSeqTemplate                 | file   |
# | assay_metabolomics_template            | AssayMetabolomicsTemplate          | file   |
# | assay_metagenomics_template            | AssayMetagenomicsTemplate          | file   |
# | assay_microbiome_template              | AssayMicrobiomeTemplate            | file   |
# | assay_phenotype_human_template         | AssayPhenotypeHumanTemplate        | file   |
# | assay_proteomics_template              | AssayProteomicsTemplate            | file   |
# | assay_scRNAseq_template                | AssayScRNAseqTemplate              | file   |
# | assay_whole_genome_sequencing_template | AssayWholeGenomeSequencingTemplate | file   |
# | file_annotation_template               | FileAnnotationTemplate             | file   |
# | genotyping_human_template              | GenotypingHumanTemplate            | file   |
# | study_folder_template                  | StudyFolderTemplate                | file   |
# | biospecimen_human_template             | BiospecimenHumanTemplate           | record |
# | biospecimen_non_human_template         | BiospecimenNonHumanTemplate        | record |
# | individual_human_template              | IndividualHumanTemplate            | record |
# | individual_non_human_template          | IndividualNonHumanTemplate         | record |
#
# Shape:  (16, 3)

# %%
from IPython.display import Markdown

# %%
with open("../../dca-template-config.json", "r", encoding="UTF-8") as f:
    template_config = json.load(f)

# difference
m = manifest_schemas_df.merge(
    pd.DataFrame(template_config["manifest_schemas"]),
    on="display_name",
    how="outer",
    suffixes=["_new", "_previous"],
    indicator=True,
)


print(m[sorted(list(m.columns))].to_markdown(index = False))

template_config["manifest_schemas"] = manifest_schemas  # update manifests
template_config["schema_version"] = "v" + datetime.now().strftime(
    "%Y.%m.%d"
)  # increment schema version
# Out:
# | _merge     | display_name                           | schema_name_new                    | schema_name_previous   | type_new   | type_previous   |
# |:-----------|:---------------------------------------|:-----------------------------------|:-----------------------|:-----------|:----------------|
# | right_only | Biospecimen_human                      | nan                                | BiospecimenHuman       | nan        | record          |
# | right_only | Biospecimen_non_Human                  | nan                                | BiospecimenNonHuman    | nan        | record          |
# | right_only | Genotyping_Human                       | nan                                | GenotypingHuman        | nan        | file            |
# | right_only | Individual_Human                       | nan                                | IndividualHuman        | nan        | record          |
# | right_only | Individual_non_Human                   | nan                                | IndividualNonHuman     | nan        | record          |
# | right_only | Metabolomics                           | nan                                | Metabolomics           | nan        | file            |
# | right_only | Metagenomics                           | nan                                | Metagenomics           | nan        | file            |
# | right_only | Microbiome                             | nan                                | Microbiome             | nan        | file            |
# | right_only | Proteomics                             | nan                                | Proteomics             | nan        | file            |
# | right_only | RNAseq                                 | nan                                | RNAseq                 | nan        | file            |
# | right_only | Whole_Genome_Sequencing                | nan                                | WholeGenomeSequencing  | nan        | file            |
# | left_only  | assay_RNAseq_template                  | AssayRNAseqTemplate                | nan                    | file       | nan             |
# | left_only  | assay_bsSeq_template                   | AssayBsSeqTemplate                 | nan                    | file       | nan             |
# | left_only  | assay_metabolomics_template            | AssayMetabolomicsTemplate          | nan                    | file       | nan             |
# | left_only  | assay_metagenomics_template            | AssayMetagenomicsTemplate          | nan                    | file       | nan             |
# | left_only  | assay_microbiome_template              | AssayMicrobiomeTemplate            | nan                    | file       | nan             |
# | left_only  | assay_phenotype_human_template         | AssayPhenotypeHumanTemplate        | nan                    | file       | nan             |
# | left_only  | assay_proteomics_template              | AssayProteomicsTemplate            | nan                    | file       | nan             |
# | left_only  | assay_scRNAseq_template                | AssayScRNAseqTemplate              | nan                    | file       | nan             |
# | left_only  | assay_whole_genome_sequencing_template | AssayWholeGenomeSequencingTemplate | nan                    | file       | nan             |
# | left_only  | biospecimen_human_template             | BiospecimenHumanTemplate           | nan                    | record     | nan             |
# | left_only  | biospecimen_non_human_template         | BiospecimenNonHumanTemplate        | nan                    | record     | nan             |
# | right_only | bsSeq                                  | nan                                | BsSeq                  | nan        | file            |
# | left_only  | file_annotation_template               | FileAnnotationTemplate             | nan                    | file       | nan             |
# | left_only  | genotyping_human_template              | GenotypingHumanTemplate            | nan                    | file       | nan             |
# | left_only  | individual_human_template              | IndividualHumanTemplate            | nan                    | record     | nan             |
# | left_only  | individual_non_human_template          | IndividualNonHumanTemplate         | nan                    | record     | nan             |
# | right_only | scRNAseq                               | nan                                | ScRNAseq               | nan        | file            |
# | left_only  | study_folder_template                  | StudyFolderTemplate                | nan                    | file       | nan             |

# %%
print('New Schema: \n')
print(json.dumps(template_config, indent = 4))
# Out:
# New Schema:
#
# {
#     "manifest_schemas": [
#         {
#             "display_name": "biospecimen_human_template",
#             "schema_name": "BiospecimenHumanTemplate",
#             "type": "record"
#         },
#         {
#             "display_name": "biospecimen_non_human_template",
#             "schema_name": "BiospecimenNonHumanTemplate",
#             "type": "record"
#         },
#         {
#             "display_name": "assay_bsSeq_template",
#             "schema_name": "AssayBsSeqTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "genotyping_human_template",
#             "schema_name": "GenotypingHumanTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "individual_human_template",
#             "schema_name": "IndividualHumanTemplate",
#             "type": "record"
#         },
#         {
#             "display_name": "individual_non_human_template",
#             "schema_name": "IndividualNonHumanTemplate",
#             "type": "record"
#         },
#         {
#             "display_name": "assay_metabolomics_template",
#             "schema_name": "AssayMetabolomicsTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "assay_metagenomics_template",
#             "schema_name": "AssayMetagenomicsTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "assay_microbiome_template",
#             "schema_name": "AssayMicrobiomeTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "assay_phenotype_human_template",
#             "schema_name": "AssayPhenotypeHumanTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "assay_proteomics_template",
#             "schema_name": "AssayProteomicsTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "assay_RNAseq_template",
#             "schema_name": "AssayRNAseqTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "assay_whole_genome_sequencing_template",
#             "schema_name": "AssayWholeGenomeSequencingTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "assay_scRNAseq_template",
#             "schema_name": "AssayScRNAseqTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "study_folder_template",
#             "schema_name": "StudyFolderTemplate",
#             "type": "file"
#         },
#         {
#             "display_name": "file_annotation_template",
#             "schema_name": "FileAnnotationTemplate",
#             "type": "file"
#         }
#     ],
#     "service_version": "v23.1.1",
#     "schema_version": "v2024.05.30"
# }

# %%
with open("../../dca-template-config.json", "w", encoding="UTF-8") as f:
    json.dump(template_config, f, ensure_ascii=False, indent=4)
